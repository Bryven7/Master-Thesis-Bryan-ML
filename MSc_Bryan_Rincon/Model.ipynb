# %%
import os
current_path  = os.getcwd()
if current_path == "c:\\Users\\bryan\\OneDrive - Université Libre de Bruxelles\\Master 2 Ingénieur Civile\\Master Thesis\\Master-Thesis-Bryan-ML\\MSc_Bryan_Rincon":
    os.chdir("..")
    print(os.getcwd())
print(os.getcwd())
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fasteda import fast_eda
from openTSNE import TSNE
import random
import scipy.signal as signal
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
import math
from itertools import groupby
import ruptures as rpt
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support, accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit, train_test_split, RandomizedSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.base import BaseEstimator, TransformerMixin, clone
from sklearn.model_selection import StratifiedKFold
from joblib import Parallel, delayed
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.svm import OneClassSVM
import pickle
from tsfresh.feature_selection.relevance import calculate_relevance_table
from collections import Counter
# Out:
# c:\Users\bryan\OneDrive - Université Libre de Bruxelles\Master 2 Ingénieur Civile\Master Thesis\Master-Thesis-Bryan-ML
# c:\Users\bryan\OneDrive - Université Libre de Bruxelles\Master 2 Ingénieur Civile\Master Thesis\Master-Thesis-Bryan-ML

# %% [markdown]
# # Datasets (detailed in the “Data and Features Exploration” Notebook)

# %%
# File path to CSV file
VRBA_eruptions_path = "MSc_Bryan_Rincon/Datasets/Rincon_de_la_Vieja_discrete_2019-01-01_2025-01-01_AcousticVRBA.csv"
Rincon_de_la_Vieja_path = "MSc_Bryan_Rincon/Datasets/Rincon_de_la_Vieja_continuous_2019-01-01_2025-01-01.csv"
Rincon_path = "MSc_Bryan_Rincon/Datasets/Rincon 2014-2024.xlsx"
Lahares_path = "MSc_Bryan_Rincon/Datasets/Lahares_updated.csv"
RainChirps_path = "MSc_Bryan_Rincon/Datasets/RainChirps4km.csv"
Rain2019_2024_path = "MSc_Bryan_Rincon/Datasets/Rain2019_2024.csv"
Rincon_filtered_path = "MSc_Bryan_Rincon/Datasets/Rincon_2019_2024_filtered.csv"
# rsam_VORI_path = "Msc_Bryan_Rincon/Datasets/rsam_0.8_4Hz_VORI.csv"
# dsar_VORI_path = "MSc_Bryan_Rincon/Datasets/dsar_VORI.csv"
rsam_VORI_path = "Msc_Bryan_Rincon/Datasets/rsam_VORI_2019-2025.csv"
dsar_VORI_path = "MSc_Bryan_Rincon/Datasets/dsar_VORI_2019-2025.csv"


# # Load the CSV file into a DataFrame
VRBA_eruptions_df = pd.read_csv(VRBA_eruptions_path)
Rincon_de_la_Vieja_df = pd.read_csv(Rincon_de_la_Vieja_path)
Rincon_original_df = pd.read_excel(Rincon_path)
Rincon_df = pd.read_csv(Rincon_filtered_path)
Lahares_df = pd.read_csv(Lahares_path, sep=';')
#RainChirps_df = pd.read_csv(RainChirps_path)
Rain2019_2024_df = pd.read_csv(Rain2019_2024_path)
rsam_VORI_df = pd.read_csv(rsam_VORI_path)
dsar_VORI_df = pd.read_csv(dsar_VORI_path)


## Delete path variables
del current_path, VRBA_eruptions_path, Rincon_de_la_Vieja_path, Rincon_path, Lahares_path, RainChirps_path, Rain2019_2024_path, Rincon_filtered_path, rsam_VORI_path, dsar_VORI_path

# %% [markdown]
# # Data preparation (detailed in the “Data and Features Exploration” notebook)

# %% [markdown]
# ### Dataset Overview

# %%
## Overview of the datasets

# #Convert relevant columns to datetime
VRBA_eruptions_df[['t1', 't2']] = VRBA_eruptions_df[['t1', 't2']].apply(pd.to_datetime, format='mixed')
Rincon_de_la_Vieja_df['time'] = pd.to_datetime(Rincon_de_la_Vieja_df['time'], format='mixed')
Rincon_original_df['Fecha'] = pd.to_datetime(Rincon_original_df['Fecha'], format='mixed')
Rincon_df['time'] = pd.to_datetime(Rincon_df['time'], format='mixed')
# RainChirps_df['Unnamed: 0'] = pd.to_datetime(RainChirps_df['Unnamed: 0'], format='mixed')
Rain2019_2024_df['Time'] = pd.to_datetime(Rain2019_2024_df['Time'], format='mixed')
Lahares_df[['Eruption time', 'Lahar time']] = Lahares_df[['Eruption time', 'Lahar time']].apply(pd.to_datetime, format='mixed')
rsam_VORI_df['timestamp'] = pd.to_datetime(rsam_VORI_df['timestamp'], format='mixed')
dsar_VORI_df['timestamp'] = pd.to_datetime(dsar_VORI_df['timestamp'], format='mixed')

# # Set the right index
Rincon_de_la_Vieja_df = Rincon_de_la_Vieja_df.set_index('time')
Rincon_df = Rincon_df.set_index('time').sort_index()
Rain2019_2024_df = Rain2019_2024_df.set_index('Time')
rsam_VORI_df = rsam_VORI_df.set_index('timestamp')
dsar_VORI_df =  dsar_VORI_df.set_index('timestamp')


# # The basic info and descriptive statistics of the DataFrames are shown below:
print("VRBA Eruptions DataFrame:")
print(VRBA_eruptions_df.info())
print(VRBA_eruptions_df.describe())


print("\nRincon de la Vieja Continuous DataFrame:")
print(Rincon_de_la_Vieja_df.info())
print(Rincon_de_la_Vieja_df.describe())

print("\nRincon DataFrame:")
print(Rincon_df.info())
print(Rincon_df.describe())

print("\nRain 2019-2024 DataFrame:")
print(Rain2019_2024_df.info())
print(Rain2019_2024_df.describe())

print("\nrsam_VORI Dataframe")
print(rsam_VORI_df.info())
print(rsam_VORI_df.describe())

print("\ndsar_VORI Dataframe")
print(dsar_VORI_df.info())
print(dsar_VORI_df.describe())
# Out:
# VRBA Eruptions DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 967 entries, 0 to 966
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_id       967 non-null    int64
#  1   label          967 non-null    object
#  2   station        967 non-null    object
#  3   sensor_type    967 non-null    object
#  4   t1             967 non-null    datetime64[ns]
#  5   t2             967 non-null    datetime64[ns]
#  6   amplitude_max  967 non-null    float64
#  7   amplitude_rms  967 non-null    float64
#  8   amplitude_p2p  967 non-null    float64
#  9   energy         967 non-null    float64
#  10  duration       967 non-null    float64
#  11  magnitude      967 non-null    float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(3)
# memory usage: 90.8+ KB
# None
#             event_id                             t1  \
# count     967.000000                            967
# mean    88765.031024  2022-08-22 11:14:22.229142528
# min       583.000000     2019-01-20 07:27:05.050000
# 25%     17700.000000  2022-01-26 15:28:03.761499904
# 50%     78421.000000  2023-01-06 14:19:38.534000128
# 75%    147589.500000     2023-08-25 02:28:58.904000
# max    173492.000000     2024-12-31 03:05:51.038000
# std     60646.567363                            NaN
#
#                                   t2  amplitude_max  amplitude_rms  \
# count                            967     967.000000     967.000000
# mean   2022-08-22 11:15:50.756762880       0.308552       0.087465
# min       2019-01-20 07:29:11.950000       0.003000       0.000000
# 25%       2022-01-26 15:30:29.192000       0.050000       0.015000
# 50%    2023-01-06 14:20:13.998000128       0.103000       0.032000
# 75%    2023-08-25 02:30:54.944499968       0.247500       0.081500
# max       2024-12-31 03:07:12.098000      17.436000       3.242000
# std                              NaN       0.867807       0.195260
#
#        amplitude_p2p        energy     duration   magnitude
# count     967.000000  9.670000e+02   967.000000  967.000000
# mean        0.648961  6.259377e+05    88.527620    2.817050
# min         0.005000  1.482800e+01     1.247000    0.784625
# 25%         0.107500  2.547747e+03    25.259000    2.282118
# 50%         0.225000  1.218176e+04    49.121000    2.737426
# 75%         0.512000  8.081618e+04   117.497500    3.288024
# max        28.126000  1.280676e+08  1402.151000    5.431984
# std         1.646017  5.145145e+06   113.641528    0.736043
#
# Rincon de la Vieja Continuous DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2501485 entries, 2019-01-01 00:01:00 to 2025-01-01 00:00:00
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   channel_id         int64
#  1   dsar               float64
#  2   rsam               float64
#  3   trigger            float64
#  4   freq_bands_mean    float64
#  5   freq_top_k         float64
#  6   freq_index         float64
#  7   spectral_kurtosis  float64
#  8   tonality           float64
#  9   station            object
#  10  channel            object
# dtypes: float64(8), int64(1), object(2)
# memory usage: 229.0+ MB
# None
# c:\Users\bryan\anaconda3\envs\MASTER_THESIS\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        channel_id          dsar          rsam       trigger  freq_bands_mean  \
# count   2501485.0  2.501484e+06  2.501485e+06  2.501482e+06     2.501463e+06
# mean          4.0  8.952695e-01  1.083555e+02  2.524579e-01     3.915977e+00
# std           0.0  7.107066e-01  4.359005e+03  6.272270e-01     7.259706e-01
# min           4.0  6.506897e-03  7.330034e-10  0.000000e+00     1.298668e+00
# 25%           4.0  5.365507e-01  2.834283e+01  0.000000e+00     3.429077e+00
# 50%           4.0  7.610639e-01  4.177987e+01  0.000000e+00     4.043785e+00
# 75%           4.0  1.002964e+00  7.173440e+01  0.000000e+00     4.449928e+00
# max           4.0  2.484838e+02  2.822957e+06  1.200000e+01     7.871830e+00
#
#          freq_top_k    freq_index  spectral_kurtosis      tonality
# count  2.501472e+06  2.501483e+06       2.501483e+06  2.501479e+06
# mean   2.078415e+00           inf       1.878347e+01  2.039374e+01
# std    1.073341e+00           NaN       1.751674e+01  6.872862e+00
# min    8.290285e-01 -5.802415e+00       1.500000e+00  0.000000e+00
# 25%    1.448509e+00 -1.738085e+00       8.162839e+00  1.598292e+01
# 50%    1.840527e+00 -1.081928e+00       1.370936e+01  1.878076e+01
# 75%    2.427929e+00 -6.948968e-01       2.386080e+01  2.323496e+01
# max    1.016081e+01           inf       1.081654e+03  2.077064e+03
#
# Rincon DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2191 entries, 2019-01-01 to 2024-12-31
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   VT        2191 non-null   float64
#  1   LP        2191 non-null   float64
#  2   tornillo  2191 non-null   float64
# dtypes: float64(3)
# memory usage: 68.5 KB
# None
#                 VT           LP     tornillo
# count  2191.000000  2191.000000  2191.000000
# mean      0.535372     2.726609     1.051118
# std       2.219569     5.744453     3.014446
# min       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000
# 50%       0.000000     1.000000     0.000000
# 75%       0.000000     3.000000     1.000000
# max      49.000000   144.000000    52.000000
#
# Rain 2019-2024 DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2193 entries, 2019-01-01 to 2025-01-01
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Precipitations  2193 non-null   float64
# dtypes: float64(1)
# memory usage: 34.3 KB
# None
#        Precipitations
# count     2193.000000
# mean         6.438567
# std         12.394561
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          8.568400
# max        115.249400
#
# rsam_VORI Dataframe
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2926267 entries, 2019-01-01 00:01:00 to 2024-12-31 15:09:00
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   value   float64
# dtypes: float64(1)
# memory usage: 44.7 MB
# None
#               value
# count  2.926267e+06
# mean   9.548031e+02
# std    3.299214e+04
# min    0.000000e+00
# 25%    1.220206e+02
# 50%    2.286721e+02
# 75%    4.066484e+02
# max    7.980409e+06
#
# dsar_VORI Dataframe
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2926267 entries, 2019-01-01 00:01:00 to 2024-12-31 15:09:00
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   value   float64
# dtypes: float64(1)
# memory usage: 44.7 MB
# None
#               value
# count  2.926267e+06
# mean   1.713856e+02
# std    1.033006e+04
# min    1.048957e-01
# 25%    1.749330e+00
# 50%    2.547626e+00
# 75%    3.377956e+00
# max    2.114427e+06

# %%
# # Drop irrelevant columns
Rincon_de_la_Vieja_df = Rincon_de_la_Vieja_df.drop(columns=['station', 'channel'])
VRBA_eruptions_df = VRBA_eruptions_df.drop(columns=['event_id', 'label', 'sensor_type', 'station'])

# dsar_VORI_df = dsar_VORI_df.drop(columns=['Unnamed: 0'])
# rsam_VORI_df = rsam_VORI_df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# %% [markdown]
# ### Lahares Data

# %%
## Add Lahares to the VRBA DataFrame
print("\nLahares DataFrame:")
Lahares_df.info()

# Drop rows + Dates in the same format
Lahares_df = Lahares_df[Lahares_df['Eruption time'].dt.year >= 2019]
vrba_minutes = VRBA_eruptions_df["t1"].dt.floor('min')
lahar_minutes = Lahares_df["Eruption time"]

# Add new column to VRBA_eruptions_df to indicate if lahar occurred
VRBA_eruptions_df["Lahares"] = vrba_minutes.isin(lahar_minutes)

# Add new eruptions where Lahares occurred but not registered
lahares_dates_not_in_VRBA = lahar_minutes[~lahar_minutes.isin(vrba_minutes)]

mag_map = Lahares_df.set_index("Eruption time")["Eruption infrasound magnitude"]

new_rows = pd.DataFrame({
    "t1": lahares_dates_not_in_VRBA,
    "Lahares": True,
    "magnitude": lahares_dates_not_in_VRBA.map(mag_map).str.replace(',', '.').astype(float)
})

VRBA_eruptions_df = pd.concat(
    [VRBA_eruptions_df, new_rows],
    ignore_index=True
)

# Add the time difference before the lahar occurred

VRBA_eruptions_df = pd.merge_asof(
    VRBA_eruptions_df.sort_values('t1'),
    Lahares_df[['Eruption time', 'Time difference (min)']].sort_values('Eruption time'),
    left_on='t1',
    right_on='Eruption time',
    direction='backward',
    tolerance=pd.Timedelta('1Min')
).rename(
    columns={'Time difference (min)': 'Time before Lahar (min)'}
).drop(columns=['Eruption time'])

print(VRBA_eruptions_df[VRBA_eruptions_df["Lahares"] == True])
# Out:
# Lahares DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Event                          22 non-null     int64
#  1   Eruption time                  22 non-null     datetime64[ns]
#  2   Lahar time                     15 non-null     datetime64[ns]
#  3   Time difference (min)          15 non-null     float64
#  4   Eruption infrasound magnitude  15 non-null     object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 1012.0+ bytes
#                          t1                      t2  amplitude_max  \
# 0   2019-01-20 07:27:05.050 2019-01-20 07:29:11.950          5.916
# 37  2020-01-30 18:13:42.427 2020-01-30 18:14:33.666          5.284
# 94  2020-05-25 09:25:52.157 2020-05-25 09:26:35.065          2.599
# 208 2021-06-28 11:42:04.132 2021-06-28 11:42:51.981         17.436
# 240 2022-01-23 08:24:45.682 2022-01-23 08:26:16.278          1.967
# 245 2022-01-30 19:08:00.000                     NaT            NaN
# 326 2022-06-01 00:33:00.000                     NaT            NaN
# 494 2023-02-06 15:05:00.000                     NaT            NaN
# 536 2023-04-14 15:35:36.445 2023-04-14 15:36:48.035          5.206
# 544 2023-04-21 21:50:10.251 2023-04-21 21:50:54.415          9.581
# 576 2023-05-14 08:58:05.785 2023-05-14 08:59:16.201          3.137
# 595 2023-05-25 20:35:31.649 2023-05-25 20:36:24.461          5.699
# 606 2023-05-28 03:34:53.507 2023-05-28 03:36:07.444          7.481
# 608 2023-05-29 08:44:09.899 2023-05-29 08:45:46.700          3.890
# 838 2023-11-05 21:17:00.000                     NaT            NaN
#
#      amplitude_rms  amplitude_p2p        energy  duration  magnitude  Lahares  \
# 0            0.754          9.851  1.835937e+07   126.900   4.866785     True
# 37           1.499         11.688  2.931116e+07    51.239   5.002912     True
# 94           0.792          5.808  6.851999e+06    42.908   4.579998     True
# 208          3.242         28.126  1.280676e+08    47.849   5.431984     True
# 240          0.477          4.962  5.260570e+06    90.596   4.503092     True
# 245            NaN            NaN           NaN       NaN   4.400000     True
# 326            NaN            NaN           NaN       NaN   5.000000     True
# 494            NaN            NaN           NaN       NaN   4.700000     True
# 536          1.195         10.673  2.601364e+07    71.590   4.968185     True
# 544          2.267         18.170  5.782243e+07    44.164   5.200605     True
# 576          0.890          7.384  1.420949e+07    70.416   4.792228     True
# 595          1.428         12.654  2.741889e+07    52.812   4.983493     True
# 606          1.487         14.805  4.164346e+07    73.937   5.105096     True
# 608          0.690          7.118  1.172367e+07    96.801   4.736273     True
# 838            NaN            NaN           NaN       NaN   4.400000     True
#
#      Time before Lahar (min)
# 0                       16.0
# 37                      13.0
# 94                      26.0
# 208                      8.2
# 240                     30.0
# 245                     32.0
# 326                     11.0
# 494                     22.0
# 536                     32.0
# 544                     14.0
# 576                     16.0
# 595                     19.0
# 606                     18.0
# 608                     22.0
# 838                     27.0

# %% [markdown]
# ### Eruptions Data

# %%
# Order the VRBA_eruptions_df by 't1' to ensure chronological order
VRBA_eruptions_df = VRBA_eruptions_df.sort_values(by='t1')

# %% [markdown]
# ### Continuous Measurements Data

# %% [markdown]
# Let's see how the Rincon de la Vieja and Rincon data is distributed over time.

# %% [markdown]
# ####  Continuous Data

# %%
# rsam_VORI_df = rsam_VORI_df[(rsam_VORI_df['timestamp'] >= pd.to_datetime('2019-01-01'))&(rsam_VORI_df['timestamp'] < pd.to_datetime('2025-01-01'))]
# dsar_VORI_df = dsar_VORI_df[(dsar_VORI_df['timestamp'] >= pd.to_datetime('2019-01-01'))&(dsar_VORI_df['timestamp'] < pd.to_datetime('2025-01-01'))]

# rsam_VORI_df.to_csv('MSc_Bryan_Rincon/Datasets/rsam_VORI_2019-2025.csv', index=False)
# dsar_VORI_df.to_csv('MSc_Bryan_Rincon/Datasets/dsar_VORI_2019-2025.csv', index= False)

# %%
# Filter the potential outliers of the RSAM signal
Rincon_de_la_Vieja_df = Rincon_de_la_Vieja_df[(20 < Rincon_de_la_Vieja_df['rsam']) & (Rincon_de_la_Vieja_df['rsam'] < 1e5)]
rsam_VORI_df = rsam_VORI_df[(20 < rsam_VORI_df['value']) & (rsam_VORI_df['value'] < 1e5)]

# %% [markdown]
# #### Seismic and Geophysical Data

# %%
Rincon_original_df = Rincon_original_df.rename(columns={'Fecha':'time'})
Rincon_original_df = Rincon_original_df[(Rincon_original_df['time'] >= pd.to_datetime('2019-01-01')) & (Rincon_original_df['time'] < pd.to_datetime('2025-01-01')) ]
print("\nRincon DataFrame after filtering 2019-2024:")
Rincon_original_df.info()
# Out:
# Rincon DataFrame after filtering 2019-2024:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2191 entries, 1826 to 4016
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           2191 non-null   datetime64[ns]
#  1   VT             2191 non-null   float64
#  2   LP             2191 non-null   float64
#  3   Tcorto         2155 non-null   float64
#  4   Tremor         1812 non-null   float64
#  5   tfreq          992 non-null    float64
#  6   Erupcion       1588 non-null   float64
#  7   efreq          170 non-null    float64
#  8   dpresion       549 non-null    float64
#  9   Amplitud       777 non-null    float64
#  10  Damplitud      466 non-null    object
#  11  sene           187 non-null    float64
#  12  iene           181 non-null    float64
#  13  VASR           185 non-null    float64
#  14  tornillo       2191 non-null   float64
#  15  Deslizamiento  1 non-null      float64
#  16  Exhalacion     1193 non-null   float64
# dtypes: datetime64[ns](1), float64(15), object(1)
# memory usage: 308.1+ KB

# %%
# ## Keep only features having less than 5% missing data
# Rincon_df = Rincon_df[['time','VT', 'LP', 'tornillo']]
# Rincon_df.to_csv('MSc_Bryan_Rincon/Datasets/Rincon_2019_2024_filtered.csv', index=False)

# %% [markdown]
# # Features Extraction Functions (detailed in the “Data and Features Exploration” notebook)

# %% [markdown]
# ### Temporal Features

# %%
def add_temporal_features(df):
    # 0 = Dry Season (Dec–Apr), 1 = Rainy Season (May–Nov)
    dry_months = {12, 1, 2, 3, 4}
    df = df.copy()
    df['season'] = np.where(df['t1'].dt.month.isin(dry_months), 0, 1).astype(int)

    # month feature
    df['month'] = df['t1'].dt.month
    # Cyclical month feature
    df['month norm'] = np.sin((df['t1'].dt.month - 1) * (2 * np.pi / 12))

    # time-of-day feature
    df['Time of the Day'] = df['t1'].dt.hour + df['t1'].dt.minute / 60
    # Cyclical time-of-day feature
    tod = df['t1'].dt.hour + df['t1'].dt.minute / 60
    df['Time of the Day norm'] = np.sin(tod * (2 * np.pi / 24))
    return df

# %% [markdown]
# ### Continuous Measurements Features Extraction

# %% [markdown]
# #### Eruption chains

# %%
## Find sequences of following eruptions
def find_eruption_chains(df, window_size):
    chains = []
    # Check if dataframe is empty
    if df.empty:
        return chains
    # Ensure data is sorted by time 
    df_sorted = df.sort_values('t1')
    # Initialize the first chain with the first eruption
    # current_chain stores the indices of the eruptions
    first_id = df_sorted.index[0] 
    current_chain = [int(first_id)]
    # Keep track of the 'last seen' time to compare against
    last_time = df_sorted.loc[first_id, 't1']
    # Iterate through the rest of the eruptions
    for i in range(1, len(df_sorted)):
        curr_id = df_sorted.index[i]
        curr_time = df_sorted.loc[curr_id, 't1']
        # Current Time vs. LAST ADDED Time 
        if curr_time - last_time <= window_size:
            # In the window of the previous eruption, add to chain
            current_chain.append(int(curr_id))
            last_time = curr_time 
        else:
            # Time gap is too big
            # Store the finished chain
            chains.append(current_chain)
            # Start a new chain with the current eruption
            current_chain = [int(curr_id)]
            last_time = curr_time
    # Append the final chain after the loop finishes
    chains.append(current_chain)
    head_chains = [chain[0] for chain in chains]
    return chains, head_chains

# %%
def find_days_of_low_magnitude_eruptions(chain, df,  window_size,magnitude_threshold=2.0):
    erup_time = pd.to_datetime(df.loc[chain, 't1']) 
    erup_magnitude = df.loc[chain, 'magnitude']
    
    low_magnitude_sequences = []
    low_magnitude_sequences_times = []
    
    low_mag_seq = []
    low_mag_seq_times = []
    
    # We keep track of the last strong eruption time to calculate the "true" gap duration when we encounter a new strong eruption
    last_strong_erup_time = erup_time.iloc[0] # Init with the time of the first eruption in the chain, but it will be updated as we go through the chain
    
    for i in range(len(chain)):
        current_time = erup_time.iloc[i]
        current_mag = erup_magnitude.iloc[i]
        
        if current_mag < magnitude_threshold:
            low_mag_seq.append(chain[i])
            low_mag_seq_times.append(current_time)
        else:
            # Find a strong eruption, we check if we had a sequence of low magnitude eruptions before
            if low_mag_seq:
                # Calculate the "true" gap duration from the last strong eruption to the current time (which is the time of the new strong eruption)
                true_gap_duration = current_time - last_strong_erup_time
                # Keep the sequence if the true gap duration is greater than or equal to the window size, otherwise ignore it
                if true_gap_duration >= window_size:
                    print(f"Low mag seq: {low_mag_seq_times[0].strftime('%Y-%m-%d')} to {low_mag_seq_times[-1].strftime('%Y-%m-%d')} | Gap Duration: {true_gap_duration} | Dropped: {len(low_mag_seq)}")
                    low_magnitude_sequences.append(low_mag_seq)
                    
                    low_magnitude_sequences_times.append(low_mag_seq_times)

                low_mag_seq = []
                low_mag_seq_times = []
            
            last_strong_erup_time = current_time
    # After the loop, we check if there is an ongoing sequence of low magnitude eruptions that we need to evaluate
    if low_mag_seq:
        # Calculate the "true" gap duration from the last strong eruption to the last low magnitude eruption time
        true_gap_duration = low_mag_seq_times[-1] - last_strong_erup_time
        
        if true_gap_duration >= window_size:
            print(f"Final Low mag seq: {low_mag_seq_times[0].strftime('%Y-%m-%d')} to {low_mag_seq_times[-1].strftime('%Y-%m-%d')} | Gap Duration: {true_gap_duration} | Dropped: {len(low_mag_seq)}")
            low_magnitude_sequences.append(low_mag_seq)
            low_magnitude_sequences_times.append(low_mag_seq_times)

    return erup_time, erup_magnitude, low_magnitude_sequences, low_magnitude_sequences_times

# %%
def apply_purged_grouping(df, window_size, time_col='t1', cut_dates=['2022-05-22', '2023-05-15', '2023-06-25', '2023-09-01', '2023-10-15']):
    """
    Forces hard cuts in time-series data to break up massive sequences.
    Drops data within the purge window and re-calculates isolated sequence IDs.
    """
    # Work on a copy to keep original data safe
    df_clean = df.copy()

    # Deleted Eruptions
    deleted_eruptions = []

    # Identify rows to drop (The Purge Zone)
    rows_to_drop = pd.Series(False, index=df_clean.index)
    
    for date_str in cut_dates:
        start_purge = pd.to_datetime(date_str)
        end_purge = start_purge + window_size
        
        # Find eruptions that fall inside our dead zone
        in_purge_zone = (df_clean[time_col] >= start_purge) & (df_clean[time_col] <= end_purge)
        rows_to_drop = rows_to_drop | in_purge_zone
        deleted_eruptions.extend(df_clean[in_purge_zone].index.tolist())
        
    # Drop the rows
    df_clean = df_clean[~rows_to_drop].copy()
    
    # Automatically generate the new Safe_Group_IDs
    # Any gap > purge_window_days automatically starts a new group.
    time_diffs = df_clean[time_col].diff()
    
    # The first row is always the start of Group 0. Every gap > 5 days adds +1 to the ID.
    new_sequence_starts = time_diffs > window_size
    df_clean['Erup_Group_ID'] = new_sequence_starts.cumsum()
    
    return df_clean, deleted_eruptions

# %% [markdown]
# #### Seismic Data

# %% [markdown]
# ##### Eruption Windows

# %%
def get_eruptions_windows_data(continuous_df, reference_df, window_size, maximum_observation_time_before_eruption,time_type = 'min'):

    # Security check
    increasing_index = continuous_df.index.is_monotonic_increasing
    datetime_index = isinstance(continuous_df.index, pd.DatetimeIndex)
    if not datetime_index :
        raise ValueError("The continuous DataFrame index must be a DatetimeIndex.")
    if not increasing_index:
        #print("Sorting continuous DataFrame by index...")
        continuous_df = continuous_df.sort_index()
     
    # Dictionaries to store results
    eruptions_windows_indices = {}

    max_obs_bfr_eruption = maximum_observation_time_before_eruption
    
    for index, row in reference_df.items():
        
        eruption_time = row.floor(time_type)

        start_time = eruption_time - window_size
        end_time = eruption_time - max_obs_bfr_eruption

        # Create a mask for the time window
        mask = (continuous_df.index >= start_time) & (continuous_df.index <= end_time)
        window_data = continuous_df.loc[mask]
        # Store indices 
        eruptions_windows_indices[index] = window_data.index.tolist()

    # Return both dictionaries
    return eruptions_windows_indices

# %%
def build_or_load_eruptions_windows_indices(
    datasets,
    eruption_times,
    window_size,
    output_dir='MSc_Bryan_Rincon/Eruptions indices',
    mode='load',
    max_obs_minutes=7,
    max_obs_days=1,
):
    """
    Automated extraction, computation, and loading of eruption windows for multiple datasets.
    
    Parameters:
    -----------
    datasets : dict
        Configuration dictionary mapping dataset names to their config.
        Example:
        {
            'eruptions_windows_indices_VRBA': {
                'df': Rincon_de_la_Vieja_df,
                'file_name': 'eruptions_windows_indices_VRBA.npy',
                'time_type': None,  # optional
            },
            'sei_geo_eruptions_windows_indices': {
                'df': Rincon_df,
                'file_name': 'sei_geo_eruptions_windows_indices.npy',
                'time_type': 'D',  # optional, for daily granularity
            }
        }
    
    eruption_times : pd.Series
        Series containing eruption time points (e.g., VRBA_eruptions_df['t1'])
    
    window_size : pd.Timedelta
        The time window size (e.g., WINDOW_SIZE)
    
    output_dir : str, default 'MSc_Bryan_Rincon/Eruptions indices'
        Directory where numpy files are saved/loaded
    
    mode : str, default 'load'
        - 'load': Load pre-computed data from numpy files (fastest)
        - 'save': Compute and save to numpy files
        - 'compute': Compute without saving
    
    max_obs_minutes : int, default 7
        Minutes before eruption for standard observation window
    
    max_obs_days : int, default 1
        Days before eruption for daily-granularity datasets
    
    Returns:
    --------
    dict : Dictionary mapping dataset names to their eruptions_windows_indices
    
    Example Usage:
    --------------
    # First time: compute and save all datasets
    all_windows = build_or_load_eruptions_windows_indices(
        datasets=ERUPTION_WINDOWS_CONFIG,
        eruption_times=VRBA_eruptions_df['t1'],
        window_size=WINDOW_SIZE,
        mode='save'
    )
    
    # Subsequent runs: load from disk (fast)
    all_windows = build_or_load_eruptions_windows_indices(
        datasets=ERUPTION_WINDOWS_CONFIG,
        eruption_times=VRBA_eruptions_df['t1'],
        window_size=WINDOW_SIZE,
        mode='load'
    )
    
    # Extract individual results
    vrba_data = all_windows['eruptions_windows_indices_VRBA']
    rsam_data = all_windows['eruptions_windows_indices_rsam_VORI']
    dsar_data = all_windows['eruptions_windows_indices_dsar_VORI']
    sei_data = all_windows['sei_geo_eruptions_windows_indices']
    """
    
    results = {}
    max_obs_minutes_td = pd.Timedelta(minutes=max_obs_minutes)
    max_obs_days_td = pd.Timedelta(days=max_obs_days)

    for result_name, cfg in datasets.items():
        file_path = f"{output_dir}/{cfg['file_name']}"

        # Load mode: retrieve pre-computed data from disk
        if mode == 'load':
            results[result_name] = np.load(file_path, allow_pickle=True).item()
            continue

        # Compute or Save mode: determine which observation window to use
        time_type = cfg.get('time_type', None)
        max_obs = max_obs_days_td if time_type == 'D' else max_obs_minutes_td

        # Build kwargs for get_eruptions_windows_data
        kwargs = {
            'maximum_observation_time_before_eruption': max_obs,
        }
        if time_type == 'D':
            kwargs['time_type'] = 'D'

        # Call the extraction function
        windows = get_eruptions_windows_data(
            cfg['df'],
            eruption_times,
            window_size,
            **kwargs,
        )

        results[result_name] = windows

        # Save mode: persist to disk
        if mode == 'save':
            np.save(file_path, windows)
    return results

# %%
ERUPTION_WINDOWS_CONFIG = {
    'eruptions_windows_indices_VRBA': {
        'df': Rincon_de_la_Vieja_df,
        'file_name': 'eruptions_windows_indices_VRBA.npy',
    },
    'eruptions_windows_indices_rsam_VORI': {
        'df': rsam_VORI_df,
        'file_name': 'eruptions_windows_indices_rsam_VORI.npy',
    },
    'eruptions_windows_indices_dsar_VORI': {
        'df': dsar_VORI_df,
        'file_name': 'eruptions_windows_indices_dsar_VORI.npy',
    },
    'sei_geo_eruptions_windows_indices': {
        'df': Rincon_df,
        'file_name': 'sei_geo_eruptions_windows_indices.npy',
        'time_type': 'D',  # Use 1-day observation window
    },
}

# %% [markdown]
# ##### No Eruption Windows

# %%
# Exclude data points that are too close to eruptions
def get_surrounding_eruption_indices(continuous_df, eruption_df, neighbour_limit):

    surrounding_indices = {}
    
    for index, row in eruption_df.iterrows():
        eruption_time = row['t1'] 
     
        start_exclusion = eruption_time - neighbour_limit[0]
        end_exclusion = eruption_time + neighbour_limit[1]
        
        mask = (continuous_df.index >= start_exclusion) & (continuous_df.index <= end_exclusion)
        indices_to_exclude = continuous_df.index[mask].tolist()
        
        if indices_to_exclude:
            surrounding_indices[index] = indices_to_exclude
            
    return surrounding_indices

# %%
# List all data points left unused after excluding eruption windows
def get_unused_data_indices(df, eruptions_windows_indices):
    # Collect all indices currently used in eruption windows
    all_used_indices = set()
    for indices in eruptions_windows_indices.values():
        all_used_indices.update(indices)
    
    # Get all available indices from the DataFrame
    all_data_indices = set(df.index.tolist())
    
    # Find the difference (available - used) and sort them
    unused_indices = sorted(list(all_data_indices - all_used_indices))
    
    #print(f"Number of unused data points: {len(unused_indices)}")
    
    return unused_indices

# %%
# Group close non eruptions points together

def create_group_non_eruption_points(unused_indices, window_duration):

    if len(unused_indices) == 0:
        print("No unused data points to group.")
        return []

    sorted_indices = sorted(unused_indices)

    groups = []
    current_group = [sorted_indices[0]]


    for i in range(1, len(sorted_indices)):
        time_diff = sorted_indices[i] - sorted_indices[i-1]

        if time_diff > window_duration:
            groups.append(current_group)
            current_group = [sorted_indices[i]]
        else:
            current_group.append(sorted_indices[i])

    if current_group:
        groups.append(current_group)

    return groups

# %%
## Create Window of maximum WINDOW SIZE days of no-eruption data
def create_no_eruption_windows(groups, window_duration, offset, maximum_observation_time_before_eruption, max_chain_length=36, return_chains=False):

    no_eruptions_windows_indices = {}
    virtual_no_eruption_times = []
    
    # id for each window
    window_id = 0 

    # Security gap before virtual no-eruption time
    max_obs_bfr_eruption = maximum_observation_time_before_eruption

    # Store the chains of no-eruption windows for each group
    no_eruption_chains = []
    

    for group_id, group in enumerate(groups):
        # Skip empty groups
        if not group:
            continue 

        start_time = group[0]
        max_time = group[-1]

        current_start = start_time

        # window in the same group
        if current_start + window_duration > max_time:
            continue
        chain = []

        while current_start + window_duration <= max_time:
            # Virtual no-eruption 
            virtual_no_eruption_time = current_start + window_duration
        
            # Security end time
            security_end_time = virtual_no_eruption_time - max_obs_bfr_eruption
            
            # Get indices within the current window
            window_indices = [t for t in group if current_start <= t <= security_end_time]

            number_of_points = len(window_indices)

            # Skip empty windows
            if number_of_points == 0:
                current_start += offset
                continue

            # Store in dictionary with its window id
            no_eruptions_windows_indices[window_id] = window_indices

            # Store the virtual no-eruption time
            virtual_no_eruption_times.append(virtual_no_eruption_time)

            # Increment for next window
            chain.append(window_id)
            window_id += 1

            if len(chain) >= max_chain_length and  offset < window_duration:

                no_eruption_chains.append(chain)
                chain = []
                current_start += window_duration
            else :
                current_start += offset
        if chain:  # Check if there's an unfinished chain at the end of the group
            no_eruption_chains.append(chain)

    return no_eruptions_windows_indices, np.array(virtual_no_eruption_times), no_eruption_chains

# %%
def chain_stratified_undersampling(no_eruption_chains, no_erup_dict, target_nb):
    """
    Samples no-eruption windows while respecting isolated chains.
    The number of windows drawn from each chain is proportional to its length.
    """
    total_available_windows = sum(len(chain) for chain in no_eruption_chains)
    
    selected_keys = []
    
    if target_nb >= total_available_windows:
        print(f"Not enough total windows available. There are only {total_available_windows} available, keeping all.")
        return list(no_erup_dict.keys())

    
    # Iterate through each isolated chain
    for chain in no_eruption_chains:
        
        # Calculate the quota: How many windows should this chain provide?
        # (Chain size / Total available) * Target requirement
        proportion = len(chain) / total_available_windows
        quota = max(1, int(round(proportion * target_nb)))
        
        # If the chain is supposed to provide windows, extract them
        if quota > 0:
            # Safety check: Cannot extract more windows than the chain contains
            quota = min(quota, len(chain))
            
            # Systematic sampling WITHIN the chain (to maximize the gap between windows)
            indices = np.linspace(0, len(chain) - 1, quota, dtype=int)
            for idx in indices:
                selected_keys.append(chain[idx])

    # Final adjustment (due to rounding, we might end up with 398 or 402 instead of 400)
    # If there are slightly too many, randomly remove the excess
    if len(selected_keys) > target_nb:
        selected_keys = random.sample(selected_keys, target_nb)
    # If there are slightly too few, we could compensate (usually negligible)
        
    # Reconstruct the final dictionary
    # balanced_no_eruptions = {k: no_erup_dict[k] for k in selected_keys}
    
    print(f"Extraction complete: {len(selected_keys)} windows extracted from {len(no_eruption_chains)} chains.")
    return selected_keys  #balanced_no_eruptions

# %%
def build_or_load_no_eruption_windows_indices(
    datasets,
    eruptions_df,
    window_size,
    neighbour_limits,
    continuous_offset,
    max_obs_minutes=7,
    output_dir='MSc_Bryan_Rincon/Eruptions indices',
    mode='load',
    time_type= 'min',
):
    """
    Automated extraction, computation, and loading of non-eruption windows for multiple datasets.
    
    Parameters:
    -----------
    datasets : dict
        Configuration dictionary mapping dataset names to their config.
        Must include reference dataset (typically VRBA) for creating non-eruption groups.
        Example:
        {
            'no_eruption_windows_indices_VRBA': {
                'df': Rincon_de_la_Vieja_df,
                'file_name': 'no_eruption_windows_indices_VRBA.npy',
                'virtual_file_name': 'virtual_no_eruption_times.npy',
                'is_reference': True,  # Only one dataset should be True
            },
            'no_eruption_windows_indices_rsam_VORI': {
                'df': rsam_VORI_df,
                'file_name': 'no_eruption_windows_indices_rsam_VORI.npy',
                'virtual_file_name': 'virtual_no_eruption_times.npy',
            },
            'no_eruption_windows_indices_dsar_VORI': {
                'df': dsar_VORI_df,
                'file_name': 'no_eruption_windows_indices_dsar_VORI.npy',
                'virtual_file_name': 'virtual_no_eruption_times.npy',
            }
        }
    
    eruptions_df : pd.DataFrame
        DataFrame containing eruption information (typically VRBA_eruptions_df)
    
    window_size : pd.Timedelta
        The time window size (e.g., WINDOW_SIZE)
    
    neighbour_limits : list of pd.Timedelta
        Time limits to exclude around eruptions [before_limit, after_limit]
        Example: [pd.Timedelta(days=14), pd.Timedelta(days=2)]
    
    continuous_offset : pd.Timedelta
        Offset for creating virtual non-eruption times
        Example: pd.Timedelta(days=4)
    
    max_obs_minutes : int, default 7
        Minutes before non-eruption times for observation window
    
    output_dir : str, default 'MSc_Bryan_Rincon/Eruptions indices'
        Directory where numpy files are saved/loaded
    
    mode : str, default 'load'
        - 'load': Load pre-computed data from numpy files (fastest)
        - 'save': Compute and save to numpy files
        - 'compute': Compute without saving
    
    Returns:
    --------
    dict : Dictionary mapping dataset names to their no_eruption_windows_indices
    dict : Dictionary of virtual non-eruption times used for computation
    """
    
    results = {}
    max_obs_td = pd.Timedelta(minutes=max_obs_minutes)
    virtual_no_eruption_times = None
    no_eruption_chains = None
    reference_unused_indices = None
    
    # Find the reference dataset (is_reference=True)
    reference_name = None
    reference_cfg = None
    for name, cfg in datasets.items():
        if cfg.get('is_reference', False):
            reference_name = name
            reference_cfg = cfg
            break
    
    if reference_name is None:
        raise ValueError("One dataset must have 'is_reference': True")
    
    if mode == 'load':
        for result_name, cfg in datasets.items():
            file_path = f"{output_dir}/{cfg['file_name']}"
            # Charger depuis pickle au lieu de numpy
            pkl_path = file_path.replace('.npy', '.pkl')
            with open(pkl_path, 'rb') as f:
                results[result_name] = pickle.load(f)
        
        # Also load virtual times
        if reference_cfg.get('virtual_file_name', False):
            virtual_times_path = f"{output_dir}/{reference_cfg['virtual_file_name']}"
            virtual_no_eruption_times = np.load(virtual_times_path, allow_pickle=True)

        # Load no-eruption chains if needed
        if reference_cfg.get('no_eruption_chains_file_name', False):
            chains_path = f"{output_dir}/{reference_cfg['no_eruption_chains_file_name']}"
            with open(chains_path, 'rb') as f:
                no_eruption_chains = pickle.load(f)

        
        return results, virtual_no_eruption_times, no_eruption_chains
    
    # Compute mode: generate from scratch
    # Step 1: Get indices to exclude around eruptions (reference dataset only)
    nearby_eruption_indices = get_surrounding_eruption_indices(
        reference_cfg['df'],
        eruptions_df,
        neighbour_limits
    )
    
    # Step 2: Get unused data indices after exclusion
    reference_unused_indices = get_unused_data_indices(
        reference_cfg['df'],
        nearby_eruption_indices
    )
    
    # Step 3: Create groups of non-eruption points
    non_eruption_groups = create_group_non_eruption_points(
        reference_unused_indices,
        window_size
    )
    #print(f"Number of non-eruption data point groups: {len(non_eruption_groups)}")
    
    # Step 4: Create no-eruption windows for reference dataset
    no_eruption_windows_reference, virtual_no_eruption_times, no_eruption_chains = create_no_eruption_windows(
        non_eruption_groups,
        window_size,
        continuous_offset,
        maximum_observation_time_before_eruption=max_obs_td
    )
    #print(f"Number of no-eruption windows created: {len(no_eruption_windows_reference)}")
    
    results[reference_name] = no_eruption_windows_reference
    
    # Step 5: Get no-eruption windows for other datasets using virtual times
    for result_name, cfg in datasets.items():
        if cfg.get('is_reference', False):
            continue  # Already computed above
        
        windows = get_eruptions_windows_data(
            cfg['df'],
            pd.Series(virtual_no_eruption_times),
            window_size,
            maximum_observation_time_before_eruption=max_obs_td,
            time_type=time_type
        )
        results[result_name] = windows

    # Step 6: Save mode - persist all to disk
    if mode == 'save':
        for result_name, data in results.items():
            cfg = datasets[result_name]
            file_path = f"{output_dir}/{cfg['file_name']}"
            # Remplacer np.save par pickle
            with open(file_path.replace('.npy', '.pkl'), 'wb') as f:
                pickle.dump(data, f)
        
        # Also save virtual times
        if reference_cfg.get('virtual_file_name', False):
            virtual_times_path = f"{output_dir}/{reference_cfg['virtual_file_name']}"
            np.save(virtual_times_path, virtual_no_eruption_times)

        if reference_cfg.get('no_eruption_chains_file_name', False):
            chains_path = f"{output_dir}/{reference_cfg['no_eruption_chains_file_name']}"
            with open(chains_path, 'wb') as f:
                pickle.dump(no_eruption_chains, f)
    
    return results, virtual_no_eruption_times, no_eruption_chains

# %%
NO_ERUPTION_WINDOWS_CONFIG = {
    'no_eruption_windows_indices_VRBA': {
        'df': Rincon_de_la_Vieja_df,
        'file_name': 'no_eruption_windows_indices_VRBA.npy',
        'virtual_file_name': 'virtual_no_eruption_times.npy',
        'is_reference': True,  # This dataset creates the non-eruption groups
    },
    'no_eruption_windows_indices_rsam_VORI': {
        'df': rsam_VORI_df,
        'file_name': 'no_eruption_windows_indices_rsam_VORI.npy',
        'virtual_file_name': 'virtual_no_eruption_times.npy',

    },
    'no_eruption_windows_indices_dsar_VORI': {
        'df': dsar_VORI_df,
        'file_name': 'no_eruption_windows_indices_dsar_VORI.npy',
        'virtual_file_name': 'virtual_no_eruption_times.npy',
    }
}

# %% [markdown]
# ##### No overlapping Eruption and No Eruption Windows

# %%
# Extract head eruption windows data
def extract_head_eruption_windows_data(eruptions_windows_indices_VRBA, eruptions_windows_indices_rsam_VORI, eruptions_windows_indices_dsar_VORI, sei_geo_eruptions_windows_indices, head_chains, print_number=False):
    # Implementation for extracting head eruption windows data
    head_eruptions_windows_indices_VRBA = {erup_id: eruptions_windows_indices_VRBA[erup_id] for erup_id in head_chains}
    head_eruptions_windows_indices_rsam_VORI = {erup_id: eruptions_windows_indices_rsam_VORI[erup_id] for erup_id in head_chains}
    head_eruptions_windows_indices_dsar_VORI = {erup_id: eruptions_windows_indices_dsar_VORI[erup_id] for erup_id in head_chains}
    head_sei_geo_eruptions_windows_indices = {erup_id: sei_geo_eruptions_windows_indices[erup_id] for erup_id in head_chains}
    if print_number:
        print(f"Number of head eruption windows: {len(head_eruptions_windows_indices_VRBA)}")

    return head_eruptions_windows_indices_VRBA, head_eruptions_windows_indices_rsam_VORI, head_eruptions_windows_indices_dsar_VORI, head_sei_geo_eruptions_windows_indices

# %% [markdown]
# ##### Eruption and No Eruption Windows Features Extraction

# %%
## Median filter the RSAM data in each valid list of continuous data points per eruption window

MEDIAN_NUMBER = int(pd.Timedelta(days=1)/pd.Timedelta(minutes=1))
#MEDIAN_NUMBER = int(pd.Timedelta(hours=1)/pd.Timedelta(minutes=1)) 


def median_filter(valid_lists,continuous_df, metric):# Need a list of lists as input
    MEDIAN_NUMBER = int(pd.Timedelta(days=1)/pd.Timedelta(minutes=1))
    n = len(valid_lists)
    filtered = []
    for i in range(n):
        Rincon_metric = continuous_df[metric][continuous_df.index.isin(valid_lists[i])].copy()
        Rincon_metric = Rincon_metric.rolling(window=MEDIAN_NUMBER,min_periods=int(MEDIAN_NUMBER / 2), center=True).median()
        filtered.append(Rincon_metric)
    return filtered

# %%
# Separate window on subset of continuous data with a certain limit of missing data allowed
continuous_LIMIT_HOLE = pd.Timedelta(hours=1)  # Maximum allowed gap between data points
SEI_GEO_LIMIT_HOLE = pd.Timedelta(days=1)  # Maximum allowed gap between data points for SEI-GEO data       

def select_valid_lists(indices_list, limit_hole=continuous_LIMIT_HOLE):
    # Check if the list is empty
    if not indices_list:
        return []
    
    # Initiate lists
    valid_lists =[]
    current_group = [indices_list[0]]

    for i in range(1, len(indices_list)):
        current = indices_list[i]
        prev = current_group[-1]

        #  Check the gap
        if (current - prev) <= limit_hole: 
            # Gap is within limit: add to current group
            current_group.append(current)
        else :
            if limit_hole == continuous_LIMIT_HOLE:   
                # Gap is too big: group is finished.
                if len(current_group)>0.5*MEDIAN_NUMBER :
                    valid_lists.append(current_group)
            elif limit_hole == SEI_GEO_LIMIT_HOLE:
                valid_lists.append(current_group)
            # Start a new group with the current number
            current_group = [current]
            
    # Handle the last group remaining after the loop
    if limit_hole == continuous_LIMIT_HOLE:   
        if len(current_group)> 0.5*MEDIAN_NUMBER :
            valid_lists.append(current_group)
    elif limit_hole == SEI_GEO_LIMIT_HOLE:
        valid_lists.append(current_group)
    return valid_lists

# %%
def get_window_coverage(indices_dict, window_duration, measure_frequency, station, maximum_observation_time_before_eruption=7, limit_hole=continuous_LIMIT_HOLE):
    """
    Filters eruption windows to keep only those exceeding a minimum data coverage percentage.
    
    Parameters:
    - indices_dict: Dictionary of raw indices for each window {id: [indices]}.
    - window_duration: Duration of the window (e.g., 5 days).
    - measure_frequency: Frequency of measurements (e.g., 1 minute).
    - coverage_threshold: Minimum percentage of data required (default 50).
    - station: Station name for reference.
    - maximum_observation_time_before_eruption: Time before eruption to consider.
    
    Returns:
    - coverage_filtered_indices: Dictionary with coverage info for each window.
    """
    coverage_filtered_indices = {}

    # Iterate through the dictionary 
    for eruption_id, window_indices in indices_dict.items():
        
        # Get valid continuous segments 
        valid_segments = select_valid_lists(window_indices, limit_hole=limit_hole)
        
        # Calculate total present data points
        total_data_points = sum(len(group) for group in valid_segments)
       
        # Calculate coverage percentage
        coverage_percentage = (total_data_points / ((window_duration - maximum_observation_time_before_eruption) / measure_frequency)) * 100
        
        
        coverage_filtered_indices[eruption_id] = {  
                                                    'indices' : window_indices,
                                                    'coverage_percentage' : coverage_percentage,
                                                    'station' : station
                                                }
          
    return coverage_filtered_indices

# %%
def build_window_coverage_data(
    window_datasets,
    window_size,
    measure_frequency,
    max_obs_minutes=7,
):
    """
    Automated computation of window coverage data for multiple window types and datasets.
    
    Parameters:
    -----------
    window_datasets : dict
        Configuration dictionary mapping window type names to their datasets.
    
    window_size : pd.Timedelta
        The time window size (e.g., WINDOW_SIZE)
    
    measure_frequency : pd.Timedelta
        Measurement frequency for coverage calculation (e.g., pd.Timedelta(minutes=1))
    
    max_obs_minutes : int, default 7
        Minutes before eruptions for observation window
    
    Returns:
    --------
    dict : Nested dictionary organized as:
           {window_type: {dataset_name: coverage_data}}
    """
    
    results = {}
    max_obs_td = pd.Timedelta(minutes=max_obs_minutes)
    
    for window_type, datasets in window_datasets.items():
        results[window_type] = {}
        print(f"Getting {window_type} window data coverage...")
        
        for dataset_name, cfg in datasets.items():
            coverage_data = get_window_coverage(
                cfg['indices'],
                window_size,
                measure_frequency,
                station=cfg['station'],
                maximum_observation_time_before_eruption=max_obs_td,
            )
            results[window_type][dataset_name] = coverage_data
    
    return results

# %%
def count_high_coverage_windows(coverage_data, threshold=50):
    """
    Count the number of windows with coverage above a certain threshold.
    
    Parameters:
    -----------
    coverage_data : dict
        Dictionary with window IDs as keys and coverage info as values.
        Example: {0: {'indices': [...], 'coverage_percentage': 75.0, 'station': 'VRBA'}, ...}
    threshold : float
        Coverage percentage threshold to count windows.
        
    Returns:
    --------
    int
        Number of windows with coverage above the threshold.
    """
    count = 0
    for window_info in coverage_data.values():
        if window_info['coverage_percentage'] >= threshold:
            count += 1
    return count


def print_coverage_summary(coverage_datasets, thresholds=[50, 70, 99]):
    """
    Print coverage summary for multiple datasets at different thresholds.
    
    Parameters:
    -----------
    coverage_datasets : dict
        Dictionary with dataset names as keys and coverage data as values.
        Example: {'Eruption VRBA': eruption_coverage_data_VRBA, ...}
    thresholds : list
        List of coverage thresholds (in percent) to report.
    """
    for threshold in thresholds:
        print(f"=== Coverage >= {threshold}% ===")
        for name, data in coverage_datasets.items():
            high_coverage = count_high_coverage_windows(data, threshold=threshold)
            total = len(data)
            percentage = (high_coverage / total * 100) if total > 0 else 0
            print(f"{name}: {high_coverage} / {total} ({percentage:.1f}%)")
        print()

# %%
# Function to plot eruption windows data RSAM and DSAR
def get_filtered_window_data(eid, cov_vrba, cov_rsam_vori, cov_dsar_vori, show_stats=False, inverse_rsam=False):
    """
    Retrieves and filters RSAM and DSAR data for a specific eruption ID.
    """
    # Prepare raw index lists
    list_vrba = select_valid_lists(cov_vrba[eid]['indices'])
    list_rsam_vori = select_valid_lists(cov_rsam_vori[eid]['indices'])
    list_dsar_vori = select_valid_lists(cov_dsar_vori[eid]['indices'])

    if show_stats:
            print(f"Eruption Window ID: {eid} - VRBA valid segments: {len(list_vrba)}, VORI RSAM valid segments: {len(list_rsam_vori)}, VORI DSAR valid segments: {len(list_dsar_vori)}")

    # Apply median filter
    if not inverse_rsam :
        filt_rsam_vrba = median_filter(list_vrba, Rincon_de_la_Vieja_df, 'rsam')
        filt_rsam_vori = median_filter(list_rsam_vori, rsam_VORI_df, 'value')
    else:
        Inverse_rsam_VRBA_df = 1/Rincon_de_la_Vieja_df['rsam']
        Inverse_rsam_VORI_df = 1/rsam_VORI_df['value']
        filt_rsam_vrba = median_filter(list_vrba, Inverse_rsam_VRBA_df.to_frame(name='rsam'), 'rsam')
        filt_rsam_vori = median_filter(list_rsam_vori, Inverse_rsam_VORI_df.to_frame(name='value'), 'value')
    filt_dsar_vrba = median_filter(list_vrba, Rincon_de_la_Vieja_df, 'dsar')
    filt_dsar_vori = median_filter(list_dsar_vori, dsar_VORI_df, 'value')

    return filt_rsam_vrba, filt_dsar_vrba, filt_rsam_vori, filt_dsar_vori

def plot_peaks_on_segment(s, peak_info, annotate=True):
    """
    Plot peaks and troughs on a given signal segment.
    s : pandas Series
    peak_info : dict for one segment (peaks[eid][station][metric][segment_id])
    """

    # High peaks 
    h_idx = peak_info.get("h_index", [])
    if len(h_idx) > 0:
        plt.scatter(s.index[h_idx], s.values[h_idx], marker='x', color='red', label='Peaks')
        h_widths = peak_info.get("h_widths_plot", [])
        left_ips = np.clip(h_widths[2].astype(int), 0, len(s) - 1)
        right_ips = np.clip(h_widths[3].astype(int), 0, len(s) - 1)
        plt.hlines(h_widths[1],s.index[left_ips], s.index[right_ips], color='C3')

        if annotate:
            for i, idx in enumerate(h_idx):
                prom = peak_info["h_prominences"][i]
                t = s.index[idx]
                v = s.values[idx]

                plt.vlines(t, v - prom, v, color='orange', linestyle='--', alpha=0.7)
                plt.text(t, v + 0.05 * v, f'Prominence:{prom:.1f}', color='orange', ha='center')

    # Low troughs
    l_idx = peak_info.get("l_index", [])
    if len(l_idx) > 0:
        plt.scatter(s.index[l_idx], s.values[l_idx], marker='x', color='green')
        l_widths = peak_info.get("l_widths_plot", [])
        left_ips = np.clip(l_widths[2].astype(int), 0, len(s) - 1)
        right_ips = np.clip(l_widths[3].astype(int), 0, len(s) - 1)
        plt.hlines(-l_widths[1],s.index[left_ips], s.index[right_ips], color='purple', linestyle='-', alpha=0.7)
        if annotate:
            for i, idx in enumerate(l_idx):
                depth = peak_info["l_prominences"][i]
                t = s.index[idx]
                v = s.values[idx]

                plt.vlines(t, v, v + depth, color='purple', linestyle='--', alpha=0.7)
                plt.text(t, v - 0.05 * v, f'Drop: {depth:.1f}', color='purple', ha='center')


def plot_eruption_windows(erup_ids, cov_vrba, cov_rsam_vori, cov_dsar_vori, peaks = None, inverse_rsam=False):
    plt.style.use("default")
    plt.figure(figsize=(30, 5 * len(erup_ids)))

    # Color maps (using objects to avoid index errors)
    cmap_vrba = plt.cm.tab10
    cmap_rsam_vori = plt.cm.tab20b
    cmap_dsar_vori = plt.cm.Accent

    for i, eid in enumerate(erup_ids):
        # Get filtered data
        filt_rsam_vrba, filt_dsar_vrba, filt_rsam_vori, filt_dsar_vori = get_filtered_window_data(eid, cov_vrba, cov_rsam_vori, cov_dsar_vori, inverse_rsam=inverse_rsam)

        # Plot RSAM
        plt.subplot(len(erup_ids), 2, 2*i + 1)
        has_plot = False
        
        for k, s in enumerate(filt_rsam_vrba):
            if len(s) > 0:
                plt.plot(s.index, s.values, label=f'RSAM VRBA {k+1}', color=cmap_vrba(k % 10))
                if peaks is not None and eid in peaks:
                    plot_peaks_on_segment(s, peaks[eid]['VRBA']['RSAM'][k], annotate=True)
                has_plot = True
                
        for k, s in enumerate(filt_rsam_vori):
            if len(s) > 0:
                plt.plot(s.index, s.values, label=f'RSAM VORI {k+1}', color=cmap_rsam_vori(k % 20), linestyle='--')
                if peaks is not None and eid in peaks:
                    plot_peaks_on_segment(s, peaks[eid]['VORI']['RSAM'][k], annotate=True)
                has_plot = True

        plt.title(f'ID: {eid} (RSAM)')
        plt.ylabel('RSAM')
        if has_plot: plt.legend(fontsize='small')

        # Plot DSAR
        plt.subplot(len(erup_ids), 2, 2*i + 2)
        has_plot = False

        for k, s in enumerate(filt_dsar_vrba):
            if len(s) > 0:
                plt.plot(s.index, s.values, label=f'DSAR VRBA {k+1}', color=cmap_vrba(k % 10))
                if peaks is not None and eid in peaks:
                    plot_peaks_on_segment(s, peaks[eid]['VRBA']['DSAR'][k], annotate=True)
                has_plot = True

        for k, s in enumerate(filt_dsar_vori):
            if len(s) > 0:
                plt.plot(s.index, s.values, label=f'DSAR VORI {k+1}', color=cmap_dsar_vori(k % 8))
                if peaks is not None and eid in peaks:
                    plot_peaks_on_segment(s, peaks[eid]['VORI']['DSAR'][k], annotate=True)
                has_plot = True

        plt.title(f'ID: {eid} (DSAR)')
        plt.ylabel('DSAR')
        if has_plot: plt.legend(fontsize='small')

    plt.tight_layout()
    plt.show()

# %%
# Function to extract peak and trough information from metric data

def extract_metric_info(metric_clean, metric_inverted, h_selected, l_selected):
    high_peaks = {}
    high_peak_widths = {}
    h_prominences = {}
    high_peak_heights = {}

    low_trough = {}
    low_trough_widths = {}
    l_prominences = {}
    low_trough_heights = {}

    for (key, index) in h_selected:
        if key not in high_peaks:
            high_peaks[key] = []
            high_peak_widths[key] = []
            h_prominences[key] = []
            high_peak_heights[key] = []
        high_peaks[key].append(index)

        high_peak_widths[key] = signal.peak_widths(metric_clean[key], high_peaks[key], rel_height=1.0)
        # Find the prominence of the high peaks
        h_prominences[key] = signal.peak_prominences(metric_clean[key], high_peaks[key])[0]
        # Find the heights of the peaks
        high_peak_heights[key] = metric_clean[key][high_peaks[key]]

        
    for (key, index) in l_selected:
        if key not in low_trough:
            low_trough[key] = []
            low_trough_widths[key] = []
            l_prominences[key] = []
            low_trough_heights[key] = []
        low_trough[key].append(index)

        low_trough_widths[key] = signal.peak_widths(metric_inverted[key], low_trough[key], rel_height=1.0)
        # Find the depth of the drops
        l_prominences[key] = signal.peak_prominences(metric_inverted[key], low_trough[key])[0]
        # Find the heights of the troughs (negative values)
        low_trough_heights[key] = metric_clean[key][low_trough[key]]

    return high_peaks, high_peak_widths,h_prominences, high_peak_heights, low_trough,low_trough_widths,l_prominences, low_trough_heights

# %%
## Analyze RSAM data to find peaks and troughs

# Parameters for peak detection

DISTANCE_PEAKS = pd.Timedelta(days=0.5)/pd.Timedelta(minutes=1)  # Minimum distance between peaks in number of data points

HEIGHT_THRESHOLD = 80
def clean_dict(data_dict):
        cleaned = {}
        for k, v in data_dict.items():
            # If v is a tuple (raw scipy output), take the first item
            if isinstance(v, tuple):
                cleaned[k] = v[0]
            else:
                cleaned[k] = v
        return cleaned

def analyze_and_plot_metric(metrics_signals, dates):
    high_peaks_index = []
    low_trough_index = []
    high_peaks_values = []
    low_trough_values = []
    metric_clean = {}
    metric_inverted = {}
    dates_clean = {}

    
    for index, metric_signal in enumerate(metrics_signals):

        # Remove NaNs
        mask = metric_signal.notna().values
        metric_clean[index] = metric_signal.values[mask]
        dates_clean[index] = np.array(dates[index])[mask]

        # Create an inverted copy for minima detection
        metric_inverted[index] = -metric_clean[index]

        # Check if metric_clean is empty
        if len(metric_clean[index]) == 0:
            print("No valid metric data to analyze in this window.")
            continue
        else:
            # Find the peaks 
            peaks= signal.find_peaks(metric_clean[index], distance=DISTANCE_PEAKS)[0]
            # Strore information per peak
            for peak in peaks:
                high_peaks_index.append((index, peak))
                high_peaks_values.append(metric_clean[index][peak])

            # Find the troughs
            troughs = signal.find_peaks(metric_inverted[index], distance=DISTANCE_PEAKS)[0]
            # Store information per trough
            for trough in troughs:
                low_trough_index.append((index, trough))
                low_trough_values.append(metric_inverted[index][trough])

    # Stop if no peaks or troughs found
    if len(high_peaks_index) == 0 and len(low_trough_index) == 0:
        #print("No peaks or troughs found in the data.")
        return {}, {}, {}, {}, {}, {}, {}, {}

    # Select 10% highest peaks end lowest troughs
    if len(high_peaks_values) > 0:
        h_p = np.percentile(high_peaks_values, HEIGHT_THRESHOLD)
        h_mask = np.array(high_peaks_values) >= h_p
    else:
        h_mask = [] # Empty mask if no peaks

    if len(low_trough_values) > 0:
        l_p = np.percentile(low_trough_values, HEIGHT_THRESHOLD)
        l_mask = np.array(low_trough_values) >= l_p
    else:
        l_mask = [] # Empty mask if no troughs

    h_selected = [(segment,index) for (segment, index), m in zip(high_peaks_index, h_mask) if m]
    l_selected = [(segment,index) for (segment, index), m in zip(low_trough_index, l_mask) if m]

    high_peaks, high_peak_widths, h_prominences,  high_peak_heights, low_troughs, low_trough_widths, l_prominences, low_trough_heights = extract_metric_info(metric_clean, metric_inverted, h_selected, l_selected) 
        
    #high_peak_widths = clean_dict(high_peak_widths)
    h_prominences = clean_dict(h_prominences)
    #low_trough_widths = clean_dict(low_trough_widths)
    l_prominences = clean_dict(l_prominences)

    return high_peaks, high_peak_widths, h_prominences, high_peak_heights, low_troughs, low_trough_widths, l_prominences, low_trough_heights

# %%
def extract_metrics_info(window_id,indices_VRBA, indices_rsam_VORI, indices_dsar_VORI, plot=False):
    # Get filtered data for the window
    filt_rsam_vrba, filt_dsar_vrba, filt_rsam_vori, filt_dsar_vori = get_filtered_window_data(window_id, indices_VRBA, indices_rsam_VORI, indices_dsar_VORI, show_stats=False)

    # Initialize storage for peaks and troughs information
    station_metric = [['VRBA','RSAM'], ['VRBA','DSAR'], ['VORI','RSAM'], ['VORI','DSAR']]

    peaks = {}
    if window_id not in peaks:
        peaks[window_id] = {}
    for station, metric in station_metric:
        peaks[window_id].setdefault(station, {})
        peaks[window_id][station].setdefault(metric, {})


    # Store peaks and troughs information for each metric
    for i, filter in enumerate([filt_rsam_vrba, filt_dsar_vrba, filt_rsam_vori, filt_dsar_vori]):
        high_peaks, high_peak_widths, h_prominences, high_peak_heights, low_troughs, low_trough_widths, l_prominences, low_trough_heights = analyze_and_plot_metric(filter, dates=[s.index for s in filter])
        for segment_id in range(len(filter)):
            peaks[window_id][station_metric[i][0]][station_metric[i][1]].setdefault(segment_id, {})
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["h_index"] = high_peaks.get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["h_widths_plot"] = high_peak_widths.get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["h_widths"] = clean_dict(high_peak_widths).get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["h_prominences"] = h_prominences.get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["h_heights"] = high_peak_heights.get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["l_index"] = low_troughs.get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["l_widths_plot"] = low_trough_widths.get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["l_widths"] = clean_dict(low_trough_widths).get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["l_heights"] = low_trough_heights.get(segment_id, [])
            peaks[window_id][station_metric[i][0]][station_metric[i][1]][segment_id]["l_prominences"] = l_prominences.get(segment_id, [])

    # Plot eruption windows with peaks and troughs annotated
    if plot:
            plot_eruption_windows(
                erup_ids=[window_id],
                cov_vrba=indices_VRBA,
                cov_rsam_vori=indices_rsam_VORI,
                cov_dsar_vori=indices_dsar_VORI,
                peaks=peaks)
    return peaks

# %%
# Function to join all part data into a single array
def join_data(part_data):
    if len(part_data) > 0:
        join_data = np.concatenate(list(part_data.values()))
    else:
        join_data = np.array([])
    return join_data

# %% [markdown]
# Feature added following paper "Multitimescale Template Matching: Discovering Eruption Precursors across
# Diverse Volcanic Settings
# "

# %%
def calculate_simple_metrics(windows_indices_VRBA, window_indices_rsam_VORI, window_indices_dsar_VORI, q_low=0.8, q_high=1, min_q=0.1):
    # Get the filtered data
    windows_rsam_VRBA = Rincon_de_la_Vieja_df['rsam'].loc[windows_indices_VRBA]
    windows_dsar_VRBA = Rincon_de_la_Vieja_df['dsar'].loc[windows_indices_VRBA]
    windows_rsam_VORI = rsam_VORI_df['value'].loc[window_indices_rsam_VORI]
    windows_dsar_VORI = dsar_VORI_df['value'].loc[window_indices_dsar_VORI]

    windows = [windows_rsam_VRBA, windows_dsar_VRBA, windows_rsam_VORI, windows_dsar_VORI]
    quantile_above_80_mean = []
    means = []
    stds = []
    medians = []
    var = []
    low_quantile_mean = []
    high_quantile_mean = []
    low_percentile = []

    for data in windows:
        # Remove NaN values
        data = np.array(data)
        data = data[~np.isnan(data)]
        
        # Check if we have enough data to find a quantile
        if len(data) == 0:
            quantile_above_80_mean.append(0.0)
            means.append(0.0)
            stds.append(0.0)
            medians.append(0.0)
            var.append(0.0)
            low_quantile_mean.append(0.0)
            high_quantile_mean.append(0.0)
            low_percentile.append(0.0)
            continue
            
        # Apply Quantile Filter
        low, high = np.quantile(data, [q_low, q_high])
        filtered = data[(data >= low) & (data <= high)]
        
        # Calculate Mean Difference. We need at least 2 points to have 1 difference value
        if len(filtered) >= 2:
            diffs = np.abs(np.diff(filtered))
            quantile_above_80_mean.append(np.mean(diffs))
        else:
            quantile_above_80_mean.append(0.0)

        # Calculate other simple metrics
        means.append(np.mean(data))
        stds.append(np.std(data))
        medians.append(np.median(data))
        var.append(np.var(data))

        # Calculate mean of values below a certain quantile
        sorted_data = np.sort(data)
        n_low = max(1, int(len(data) * min_q))  # At least 1 value
        n_high = max(1, int(len(data) * (1 - min_q)))  # At least 1 value
        lowest_values = sorted_data[:n_low]
        high_values = sorted_data[n_high:]
        if len(lowest_values) > 0:
            low_quantile_mean.append(np.mean(lowest_values))
        else:
            low_quantile_mean.append(0.0)
        if len(high_values) > 0:
            high_quantile_mean.append(np.mean(high_values))
        else:
            high_quantile_mean.append(0.0)
        low_percentile.append(np.percentile(data, min_q * 100))

    return quantile_above_80_mean, means, stds, medians, var, low_quantile_mean, high_quantile_mean, low_percentile # A regarder

# %%
def get_simple_ruptures_info(segment, min_size=360, pen=0.0):
    # # Detection (Pelt finds the breakpoints)
    # signal = segment.values.reshape(-1, 1)
    # algo = rpt.Pelt(model="l2", min_size=min_size).fit(signal)
    # pen = 10
    # pen = np.var(segment) * pen
    # result_indices = algo.predict(pen=pen)

    # Detection (Pelt finds the breakpoints)
    signal = segment.values.reshape(-1, 1)
    algo = rpt.Pelt(model="linear", min_size=min_size).fit(signal)
    result_indices = algo.predict(pen=pen)

    results = []
    start_idx = 0
    slope_threshold = None  # Will be set adaptively based on signal range and duration
    for end_idx in result_indices:
        # Create segment
        segment_data = segment.iloc[start_idx:end_idx]
        
        if len(segment_data) < 2:
            start_idx = end_idx
            continue
        # Time Information  
        t_start = segment_data.index[0]
        t_end = segment_data.index[-1]

        # Basic Statistics
        vals = segment_data.values
        mean_val = np.nanmean(vals) if len(vals) > 0 else 0.0
        std = np.std(vals)
        var = np.var(vals)

        # Metrics Calculation 
        # Convert to hours for slope calculation
        t_hours = (segment_data.index - t_start).total_seconds().values.reshape(-1, 1) / 3600.0

        # Fit linear regression to get slope
        slope, intercept = np.polyfit(t_hours.flatten(), vals, 1)

        # Adaptive threshold: plateau if slope is small relative to signal range
        if slope_threshold is None:
            signal_range = np.max(signal) - np.min(signal)
            total_duration = len(signal)
            # Expected slope if signal changed fully over entire duration
            max_expected_slope = signal_range / total_duration
            # Plateau threshold: 10% of max expected slope
            slope_threshold = 40 * max_expected_slope
    
        # Derivatives
        derivatives = np.gradient(vals, t_hours.flatten())
        mean_derivative = np.nanmean(derivatives) if len(derivatives) > 0 else 0.0
        mean_abs_derivative = np.nanmean(np.abs(derivatives)) if len(derivatives) > 0 else 0.0

        # Acceleration
        acceleration = np.gradient(derivatives, t_hours.flatten())
        mean_acceleration = np.nanmean(np.abs(acceleration)) if len(acceleration) > 0 else 0.0

        if slope > slope_threshold:
            current_state = "RAISING"
        elif slope < -slope_threshold:
            current_state = "FALLING"
        else:
            current_state = "STABLE"
        
        results.append({
            'state': current_state,
            'start': t_start,
            'end': t_end,
            'slope': slope,
            #'quality': [quality],
            'mean_derivative': mean_derivative,
            'mean_abs_derivative': mean_abs_derivative,
            'mean_acceleration': mean_acceleration,
            'mean_value': mean_val,
            'std': std,
            'var': var
        })
        
        start_idx = end_idx
        
    
    return results

# %%
def get_segments_ruptures_info(segment, min_size=360, pen=0.0):
    # Detection (Pelt finds the breakpoints)
    signal = segment.values.reshape(-1, 1)
    algo = rpt.Pelt(model="linear", min_size=min_size).fit(signal)
    result_indices = algo.predict(pen=pen)

    results = []
    start_idx = 0

    slope_threshold = None

    for end_idx in result_indices:
        # Create segment
        segment_data = segment.iloc[start_idx:end_idx]
        
        if len(segment_data) < 2:
            start_idx = end_idx
            continue

        # Basic Statistics
        vals = segment_data.values
        mean_val = np.nanmean(vals) if len(vals) > 0 else 0.0
        std = np.std(vals)
        var = np.var(vals)

        
        # Time Information 
        t_start = segment_data.index[0]
        t_end = segment_data.index[-1]
        
        # Metrics Calculation 
        # Convert to hours for slope calculation
        t_hours = (segment_data.index - t_start).total_seconds().values.reshape(-1, 1) / 3600.0
        

        # Derivative
        lr = LinearRegression().fit(t_hours, vals)
        r2 = lr.score(t_hours, vals)
        
        # Fit linear regression to get slope
        slope, intercept = np.polyfit(t_hours.flatten(), vals, 1)

        # Adaptive threshold: plateau if slope is small relative to signal range
        if slope_threshold is None:
            signal_range = np.max(signal) - np.min(signal)
            total_duration = len(signal)
            # Expected slope if signal changed fully over entire duration
            max_expected_slope = signal_range / total_duration
            # Plateau threshold: 10% of max expected slope
            slope_threshold = 40 * max_expected_slope
        
        if slope > slope_threshold:
            current_state = "RAISING"
        elif slope < -slope_threshold:
            current_state = "FALLING"
        else:
            current_state = "STABLE"


        if r2 > 0.8: quality = "LINEAR_TREND"
        elif r2 > 0.4: quality = "MODERATE_TREND"
        else: quality = "WEAK_TREND"

        # Simple initial merge (if state is identical to previous)
        merged = False
        if results:
            prev_result = results[-1]
            if prev_result['state'] == current_state:
                results[-1]['end'] = t_end
                results[-1]['quality'].append(quality)
                results[-1]['last_slope'] = slope 
                # Update mean value for the next comparison (simple average approximation)
                results[-1]['mean_value'] = (results[-1]['mean_value'] + mean_val) / 2
                merged = True

        if not merged:
            results.append({
                'state': current_state,
                'start': t_start,
                'end': t_end,
                'last_slope': slope,
                'quality': [quality],
                'mean_value': mean_val
            })
        
        start_idx = end_idx

    final_results = []
    
    for result in results:
        part_seg = segment.loc[result['start']:result['end']]

        # Duration in hours
        result['duration_hours'] = (result['end'] - result['start']).total_seconds() / 3600.0
        
        # Recalculate Mean 
        if len(part_seg) > 0:
            result['mean_value'] = np.nanmean(part_seg.values)
        else:
            result['mean_value'] = 0
        
        # Recalculate Slope on the final segment 
        t_hours = (part_seg.index - result['start']).total_seconds().values.reshape(-1, 1) / 3600.0 
        if len(t_hours) > 1:
            lr = LinearRegression().fit(t_hours, part_seg.values)
            result['slope'] = lr.coef_[0]
            result['r2'] = lr.score(t_hours, part_seg.values)
        else:
            result['slope'] = 0
            result['r2'] = 0

        # Derivatives
        t_absolute = (part_seg.index - part_seg.index[0]).total_seconds().to_numpy()
        derivatives = np.gradient(part_seg.values, t_absolute)
        result["mean_derivative"] = np.nanmean(derivatives) if len(derivatives) > 0 else 0.0
        result["mean_abs_derivative"] = np.nanmean(np.abs(derivatives)) if len(derivatives) > 0 else 0.0
        
        # Acceleration
        acceleration = np.gradient(derivatives, t_absolute)
        result["acceleration"] = np.nanmean(np.abs(acceleration)) if len(acceleration) > 0 else 0.0
        
        # Clean up temporary keys
        if 'last_slope' in result: del result['last_slope']
        
        final_results.append(result)
    
    return final_results

# %%
# quiescence_threshold_rsam_VRBA = np.percentile(Rincon_de_la_Vieja_df['rsam'], 20)
# quiescence_threshold_rsam_VORI = np.percentile(rsam_VORI_df['value'], 20)
dsar_threshold_VRBA = np.percentile(np.log(Rincon_de_la_Vieja_df['dsar'] + 1e-6), 80)
dsar_threshold_VORI = np.percentile(np.log(dsar_VORI_df['value'] + 1e-6), 80)
dsar_threshold = {'VRBA': dsar_threshold_VRBA, 'VORI': dsar_threshold_VORI}

# %%
def extract_literature_features(results_rsam, results_inv_rsam, results_log_dsar, metric, dsar_threshold):
    if any(len(x) == 0 for x in [results_rsam, results_inv_rsam, results_log_dsar]):
        return {}

    # Get the last segment info for inv RSAM and DSAR
    last_inv = results_inv_rsam[-1]
    last_dsar = results_log_dsar[-1]
    last_rsam = results_rsam[-1]
    
    features = {}
    dsar_threshold_VRBA = dsar_threshold['VRBA']
    dsar_threshold_VORI = dsar_threshold['VORI']
    
    # Cascading material failure (Ardid paper)
    is_dsar_high = (last_dsar['mean_value'] > dsar_threshold_VORI) if metric == "VORI" else (last_dsar['mean_value'] > dsar_threshold_VRBA)
    # Ardid paper - Inv RSAM quality
    q_map = {"LINEAR_TREND": 3, "MODERATE_TREND": 2, "WEAK_TREND": 1, "STABLE": 0}
    best_q = 0
    scores = [q_map.get(q, 0) for q in last_inv['quality']]
    best_q = max(scores) if scores else 0
        
    #features['inv_rsam_quality_acceleration'] = best_q if last_inv['state'] == "FALLING" else 0

    features['is_cascading_material_failure'] = 1 if (last_inv['state'] == "FALLING" and last_dsar['state'] == "RAISING" and is_dsar_high and best_q == 3) else 0

    # Possible Seal failure 
    #is_rsam_low  =(last_rsam['mean_value'] < quiescence_threshold_rsam_VORI) if metric == "VORI" else (last_rsam['mean_value'] < quiescence_threshold_rsam_VRBA)
    is_rsam_quiet = (last_rsam['state'] in ["FALLING", "STABLE"])# and is_rsam_low
    features['is_possible_seal_failure'] = 1 if (is_rsam_quiet and last_dsar['state'] == "RAISING" and is_dsar_high) else 0

    
    
    # Pressurization
    try :
        features['is_pressurizing'] = 1 if (last_dsar['state'] == "RAISING" or (last_dsar['state'] == "STABLE" and results_log_dsar[-2]['state'] == "RAISING" ) and is_dsar_high) else 0
    except :
        features['is_pressurizing'] = 1 if (last_dsar['state'] == "RAISING" and is_dsar_high) else 0
    
    # Slope Interaction (Signals divergence)
    denom = last_inv['slope'] if abs(last_inv['slope']) > 1e-9 else 1e-9  #Slope are at that order of magnitude
    features['slope_ratio'] = last_dsar['slope'] / denom

    # Count number of states changes
    features['num_state_changes_inv_rsam'] = len(results_inv_rsam)
    features['num_state_changes_log_dsar'] = len(results_log_dsar)

    # Quiescence detection
    features['is_hydrothermal_seal'] = 0
    features['falling_rsam_acceleration'] = 0
    features['falling_rsam_slope'] = 0
    features['falling_rsam_mean_derivative'] = 0
    features['falling_rsam_mean_abs_derivative'] = 0
    features['quiescence_rsam_duration'] = 0
    features['quiescence_rsam_drop_ratio'] = 0
    for i, result in enumerate(results_rsam):
        is_stable = (result['state'] == "STABLE")
        was_falling_before = (i > 0 and results_rsam[i-1]['state'] == "FALLING")
        # is_quiet_level = (result['mean_value'] < quiescence_threshold_rsam_VORI) if metric == "VORI" else (result['mean_value'] < quiescence_threshold_rsam_VRBA)
        # Calculate drop_ratio with multiple safety checks
        drop_ratio = 0
        if i > 2:
            # Safety check: Validate i-2 index and its values
            if results_rsam[i-2] is not None and 'mean_value' in results_rsam[i-2]:
                prev_prev_value = results_rsam[i-2]['mean_value']
                if not pd.isna(prev_prev_value) and prev_prev_value is not None:
                    denominator = (prev_prev_value + 1e-6)
                    if not pd.isna(denominator) and denominator != 0:
                        drop_ratio = (prev_prev_value - result['mean_value']) / denominator
                        # Safety check: Ensure drop_ratio is valid
                        if pd.isna(drop_ratio) or np.isinf(drop_ratio):
                            drop_ratio = 0
        elif i > 0:
            # Safety check: Validate i-1 index and its values
            if results_rsam[i-1] is not None and 'mean_value' in results_rsam[i-1]:
                prev_value = results_rsam[i-1]['mean_value']
                if not pd.isna(prev_value) and prev_value is not None:
                    denominator = (prev_value + 1e-6)
                    if not pd.isna(denominator) and denominator != 0:
                        drop_ratio = (prev_value - result['mean_value']) / denominator
                        # Safety check: Ensure drop_ratio is valid
                        if pd.isna(drop_ratio) or np.isinf(drop_ratio):
                            drop_ratio = 0
        
        if pd.isna(drop_ratio) or np.isinf(drop_ratio):
            print(f"Warning: Invalid drop_ratio calculated at index {i} for window. Setting drop_ratio to 0.")
            drop_ratio = 0
        is_drop_significant = drop_ratio > 0.5
        is_quiet_duration_longer = (result['duration_hours'] >= features['quiescence_rsam_duration']) if features['quiescence_rsam_duration'] > 0 else True
        if is_stable and is_drop_significant and was_falling_before and is_quiet_duration_longer:
            features['is_hydrothermal_seal'] = 1
            features['falling_rsam_acceleration'] = results_rsam[i-1]['acceleration']
            features['falling_rsam_slope'] = results_rsam[i-1]['slope']
            features['falling_rsam_mean_derivative'] = results_rsam[i-1]['mean_derivative']
            features['falling_rsam_mean_abs_derivative'] = results_rsam[i-1]['mean_abs_derivative']
            features['quiescence_rsam_duration'] = result['duration_hours']
            features['quiescence_rsam_drop_ratio'] = drop_ratio
            
        if pd.isna(features['quiescence_rsam_drop_ratio']):
            raise ValueError("A NAN case has bypassed the safety checks, investigate the data and calculations for this case.")
        
    return features

# %%
def get_metrics_behavior(id, windows_indices_VRBA, window_indices_rsam_VORI, window_indices_dsar_VORI, dsar_threshold: dict, plot=False):

    ALL_FEATURES = {
        "VRBA": {},
        "VORI": {},
    }

    all_features = {
        "is_cascading_material_failure" : 0,
        "is_possible_seal_failure" : 0,
        "inv_rsam_quality_acceleration" : 0,
        "is_pressurizing" : 0,
        "slope_ratio" : 0,
        "num_state_changes_inv_rsam" : 0,
        "num_state_changes_log_dsar" : 0,
        "is_hydrothermal_seal" : 0,
        "falling_rsam_acceleration" : 0,
        "falling_rsam_slope" : 0,
        "falling_rsam_mean_derivative" : 0,
        "falling_rsam_mean_abs_derivative" : 0,
        "quiescence_rsam_duration" : 0,
        "quiescence_rsam_drop_ratio" : 0
    }

    
    # Station and metric definitions
    station_metric = [['RSAM', 'VRBA'], ['DSAR', 'VRBA'], ['RSAM', 'VORI'], ['DSAR', 'VORI']]
    colors = ['blue', 'orange', 'green', 'red']
    
    ## Get filtered data
    filt_metrics = get_filtered_window_data(id, windows_indices_VRBA, window_indices_rsam_VORI, window_indices_dsar_VORI, show_stats=False)

    for i, metric_data in enumerate(filt_metrics):
        current_metric = station_metric[i][0] # e.g., RSAM
        current_station = station_metric[i][1] # e.g., VRBA
        dict_key = f"{current_station}"
        
        ## Initialize arrays for station pair
        # We reset these when starting a new station (i=0 for VRBA, i=2 for VORI)
        if i % 2 == 0:
            slope_segments_rsam_final = np.array([])
            slope_segments_rsam_inv_final = np.array([])
            slope_segments_dsar_final = np.array([])


        if plot:
            print(f"Processing metric: {current_metric} at station {current_station} for window ID {id}")
            plt.figure(figsize=(15, 5))

        for segment_idx, segment in enumerate(metric_data):

            ## Remove NaN values
            mask = segment.notna().values
            if np.sum(mask) != len(segment):
                print(f"There were NaN values in the segment for id {id} with station {dict_key}.")
            
            segment = segment[mask]
            
            if len(segment) == 0:
                continue
            
            ## Process RSAM (Inverse)
            if current_metric == 'RSAM':
                inv = 1 / (segment + 1e-6)
                
                # Detect change points
                slope_segments_rsam_inv = get_segments_ruptures_info(inv)
                slope_segments_rsam = get_segments_ruptures_info(segment)
                #slope_segments_rsam_inv = get_simple_ruptures_info(inv)
                #slope_segments_rsam = get_simple_ruptures_info(segment)
                
                # Accumulate results
                slope_segments_rsam_final = np.concatenate((slope_segments_rsam_final, slope_segments_rsam))
                slope_segments_rsam_inv_final = np.concatenate((slope_segments_rsam_inv_final, slope_segments_rsam_inv))
                
                if plot:
                    for regime in slope_segments_rsam_inv:
                        #print(f" {regime['state']} starting at {regime['start']} and ending at {regime['end']} with slope {regime['slope']:.8f} with m_derivative {regime['mean_derivative']:.8f} with m_abs_derivative {regime['mean_abs_derivative']:.8f} with acceleration {regime['acceleration']:.8f} with mean value {regime['mean_value']:.8f}")
                        print(f" {regime['state']} starting at {regime['start']} and ending at {regime['end']} with slope {regime['slope']:.8f} with quality {regime['quality']} with mean value {regime['mean_value']:.8f}")
                    print(f"Analyzing segment n°{segment_idx+1} with {len(segment)} data points")
                    plt.plot(segment.index, inv.values, label=f'Segment {current_metric} {segment_idx+1}', color=colors[i])
                    for cp in slope_segments_rsam_inv:
                        plt.axvline(x=cp['start'], color=colors[i], linestyle='--', label='Change Point' if cp == slope_segments_rsam_inv[0] else "")

            ## Process DSAR (Log)
            elif current_metric == 'DSAR':
                segment_log = np.log(segment + 1e-6)
                
                # Detect change points
                slope_segments_dsar = get_segments_ruptures_info(segment_log)
                #slope_segments_dsar = get_simple_ruptures_info(segment_log)
                
                # Accumulate results
                slope_segments_dsar_final = np.concatenate((slope_segments_dsar_final, slope_segments_dsar))

                if plot:
                    for regime in slope_segments_dsar:
                        print(f" {regime['state']} starting at {regime['start']} and ending at {regime['end']} with slope {regime['slope']:.8f} with quality {regime['quality']} with mean value {regime['mean_value']:.8f}")
                    print(f"Analyzing segment n°{segment_idx+1} with {len(segment)} data points")
                    plt.plot(segment.index, segment_log.values, label=f'Segment {current_metric} {current_station} {segment_idx+1}', color=colors[i])
                    for cp in slope_segments_dsar:
                        plt.axvline(x=cp['start'], color=colors[i], linestyle='--', label='Change Point' if cp == slope_segments_dsar[0] else "")

        ## Feature Extraction
        # We only extract features after processing DSAR (since it requires both RSAM and DSAR data)
        if current_metric == 'DSAR':
            # Extract combined features for the station
            features = extract_literature_features(slope_segments_rsam_final, slope_segments_rsam_inv_final, slope_segments_dsar_final, current_station, dsar_threshold)
            if features is not None:
                all_features.update(features)
            # Save to main dictionary using the composite key
            # Note: We assign these features to the specific DSAR key, or potentially both if needed
            ALL_FEATURES[dict_key] = {f"{k}": v for k, v in all_features.items()}

        ## Finalize Plot
        if plot:
            plt.title(f'Metric: {current_metric} {current_station} with Detected Change Points')
            plt.xlabel('Time')
            plt.ylabel('Value')
            plt.legend()
            plt.show()

    return ALL_FEATURES

# %% [markdown]
# ##### All features Extraction

# %%
def extract_metrics_features_global(id, info, basic_metrics, coverage_data_VRBA, coverage_rsam_data_VORI, coverage_dsar_data_VORI, behavioral_features=None):


    station_metric = [['VRBA','RSAM'], ['VRBA','DSAR'], ['VORI','RSAM'], ['VORI','DSAR']]

    Data = {}

    for i, (station, metric) in enumerate(station_metric):

        #print(station, metric)
        
        # Get the dictionary of segments for this station/metric
        segments = info[id][station][metric] 

        # Extract dictionaries for each feature across all segments
        h_widths   = {seg_id: data["h_widths"] for seg_id, data in segments.items()}
        h_proms    = {seg_id: data["h_prominences"] for seg_id, data in segments.items()}
        h_heights  = {seg_id: data["h_heights"] for seg_id, data in segments.items()}
        
        l_widths   = {seg_id: data["l_widths"] for seg_id, data in segments.items()}
        l_proms    = {seg_id: data["l_prominences"] for seg_id, data in segments.items()}
        l_heights  = {seg_id: data["l_heights"] for seg_id, data in segments.items()}
      
        all_h_widths = join_data(h_widths)
        all_l_widths = join_data(l_widths)
        all_h_prominences = join_data(h_proms)
        all_l_prominences = join_data(l_proms)
        all_high_peak_heights = join_data(h_heights)
        all_low_trough_heights = join_data(l_heights)

        # Peaks data
        if len(all_h_prominences) > 0:
            Data[f'Number of peaks {metric}'+' '+f'{station}'] = len(all_h_prominences)
            Data[f'Avg Prominence {metric}'+' '+f'{station}'] = np.mean(all_h_prominences)
            Data[f'Max Prominence {metric}'+' '+f'{station}'] = np.max(all_h_prominences)
            Data[f'Std Prominence {metric}'+' '+f'{station}'] = np.std(all_h_prominences)
            Data[f'Avg h Width {metric}'+' '+f'{station}'] = np.mean(all_h_widths)  # all_h_widths contains the widths
            Data[f'Max h Width {metric}'+' '+f'{station}'] = np.max(all_h_widths)
            Data[f'Std h Width {metric}'+' '+f'{station}'] = np.std(all_h_widths)
            Data[f'Avg peak {metric}'+' '+f'{station}'] = np.mean(all_high_peak_heights)
            Data[f'Max peak {metric}'+' '+f'{station}'] = np.max(all_high_peak_heights)
            Data[f'Std peak {metric}'+' '+f'{station}'] = np.std(all_high_peak_heights)
        else:
            Data[f'Number of peaks {metric}'+' '+f'{station}'] = 0
            Data[f'Avg Prominence {metric}'+' '+f'{station}'] = 0
            Data[f'Max Prominence {metric}'+' '+f'{station}'] = 0
            Data[f'Std Prominence {metric}'+' '+f'{station}'] = 0
            Data[f'Avg h Width {metric}'+' '+f'{station}'] = 0
            Data[f'Max h Width {metric}'+' '+f'{station}'] = 0
            Data[f'Std h Width {metric}'+' '+f'{station}'] = 0
            Data[f'Avg peak {metric}'+' '+f'{station}'] = 0
            Data[f'Max peak {metric}'+' '+f'{station}'] = 0
            Data[f'Std peak {metric}'+' '+f'{station}'] = 0

        # Troughs data
        if len(all_l_prominences) > 0:
            Data[f'Number of drops {metric}'+' '+f'{station}'] = len(all_l_prominences)
            Data[f'Avg Drop Depth {metric}'+' '+f'{station}'] = np.mean(all_l_prominences)
            Data[f'Max Drop Depth {metric}'+' '+f'{station}'] = np.max(all_l_prominences)
            Data[f'Std Drop Depth {metric}'+' '+f'{station}'] = np.std(all_l_prominences)
            Data[f'Avg l Width {metric}'+' '+f'{station}'] = np.mean(all_l_widths)  # all_l_widths contains the widths
            Data[f'Max l Width {metric}'+' '+f'{station}'] = np.max(all_l_widths)
            Data[f'Std l Width {metric}'+' '+f'{station}'] = np.std(all_l_widths)
            Data[f'Avg drop {metric}'+' '+f'{station}'] = np.mean(all_low_trough_heights)
            Data[f'Max drop {metric}'+' '+f'{station}'] = np.min(all_low_trough_heights)
            Data[f'Std drop {metric}'+' '+f'{station}'] = np.std(all_low_trough_heights)
        else:
            Data[f'Number of drops {metric}'+' '+f'{station}'] = 0
            Data[f'Avg Drop Depth {metric}'+' '+f'{station}'] = 0
            Data[f'Max Drop Depth {metric}'+' '+f'{station}'] = 0
            Data[f'Std Drop Depth {metric}'+' '+f'{station}'] = 0
            Data[f'Avg l Width {metric}'+' '+f'{station}'] = 0
            Data[f'Max l Width {metric}'+' '+f'{station}'] = 0
            Data[f'Std l Width {metric}'+' '+f'{station}'] = 0
            Data[f'Avg drop {metric}'+' '+f'{station}'] = 0
            Data[f'Max drop {metric}'+' '+f'{station}'] = 0
            Data[f'Std drop {metric}'+' '+f'{station}'] = 0
        # Basic metrics
        Data[f'Quantile Changes {metric}'+' '+f'{station}'] = basic_metrics[0][i]
        Data[f'Avg Value {metric}'+' '+f'{station}'] = basic_metrics[1][i]
        Data[f'Std Value {metric}'+' '+f'{station}'] = basic_metrics[2][i]
        Data[f'Median Value {metric}'+' '+f'{station}'] = basic_metrics[3][i]
        Data[f'Var Value {metric}'+' '+f'{station}'] = basic_metrics[4][i]
        Data[f'Mean Min Values {metric}'+' '+f'{station}'] = basic_metrics[5][i]

    # Coverage Window
    Data[f'Coverage Percentage VRBA'] = coverage_data_VRBA
    Data[f'Coverage Percentage VORI RSAM'] = coverage_rsam_data_VORI
    Data[f'Coverage Percentage VORI DSAR'] = coverage_dsar_data_VORI

    # Behavioral features
    for key, dic in behavioral_features.items():
        for feat_key, feat_value in dic.items():
            Data[f'{feat_key} {key}'] = feat_value
        
    features = pd.DataFrame([Data])
    
    return features

# %%
def get_behave_features_per_eruption(windows_indices_VRBA, window_indices_rsam_VORI, window_indices_dsar_VORI, head=False, plot= False):
    all_features = []
    for i, key in enumerate(windows_indices_VRBA.keys()):
        if (i%100)==0:
            print(f"Processing eruption {i} / {len(windows_indices_VRBA)}") 
        info = extract_metrics_info(key, windows_indices_VRBA, window_indices_rsam_VORI, window_indices_dsar_VORI, plot=plot)
        basic_metrics = calculate_simple_metrics(windows_indices_VRBA[key]['indices'], window_indices_rsam_VORI[key]['indices'], window_indices_dsar_VORI[key]['indices'])
        #behavior_features = get_metrics_behavior(key, windows_indices_VRBA, window_indices_rsam_VORI, window_indices_dsar_VORI)
        features = extract_metrics_features_global(key, info, basic_metrics, windows_indices_VRBA[key]['coverage_percentage'], window_indices_rsam_VORI[key]['coverage_percentage'], window_indices_dsar_VORI[key]['coverage_percentage'])#, behavior_features)
        #features = extract_reduce(windows_indices_VRBA[key]['coverage_percentage'], window_indices_rsam_VORI[key]['coverage_percentage'], window_indices_dsar_VORI[key]['coverage_percentage'], behavior_features)
        all_features.append(features)
    all_features_df = pd.concat(all_features, ignore_index=True)
    return all_features_df

# %% [markdown]
# ##### All features Analysis

# %%
def prepare_eruption_features(df, eruption_coverage_data_VRBA, show = False):
    df['Type'] = 1
    df.index = eruption_coverage_data_VRBA.keys()
    if show:
        print(df.head())

# %%
def prepare_no_eruption_features(df, no_eruption_coverage_data_VRBA, virtual_no_eruption_times, show=False):
    df['Type'] = 0  # 0 for no-eruption windows
    df['Lahares'] = 0  # No Lahares in no-eruption windows
    df['magnitude'] = 0  # No magnitude in no-eruption windows
    df['t1'] = pd.NaT  # Initialize t1 column with NaT
    for i, key in  enumerate(no_eruption_coverage_data_VRBA.keys()):
        df.at[i, 't1'] = virtual_no_eruption_times[key] # Assign a representative date for the no-eruption window
    df = add_temporal_features(df)
    # df.drop(columns=['t1'], inplace=True) 
    df.index = no_eruption_coverage_data_VRBA.keys()
    if show:
        print(df.head())
    return df

# %%
# !Merge the RSAM features of eruptions with the VRBA eruptions DataFrame CHANGE IF HEAD
def merge_all_features(catalog_df, eruptions_features_df, no_eruption_features_df):
   feature_columns= ['season', 'month norm', 'Time of the Day norm', 'month', 'Time of the Day']
   catalog_df = add_temporal_features(catalog_df)
   VRBA_features_df = catalog_df[feature_columns + ['t1', 'Lahares','magnitude']].merge(eruptions_features_df, left_index=True, right_index=True)
   VRBA_features_df['Lahares'] = VRBA_features_df['Lahares'].astype(int) 
   VRBA_features_df = pd.concat(
    [VRBA_features_df, no_eruption_features_df],
    ignore_index=True
   )
   return VRBA_features_df

# %% [markdown]
# ### Discrete (Daily) Measurements Features Extraction

# %% [markdown]
# #### Geophysical and Seismic Data Features Extraction

# %% [markdown]
# ##### Eruption and Non Eruption Windows Features Extraction

# %%
# Function to extract geoseismic features from a given window of data
def extract_geoseismic_features(window, event_types):
    
    data = {}

    for event in event_types:
        # Get the series for the specific event type
        value = window[event]
        valid_values = value.dropna()
        
        # Total accumulation of events
        data[f"Sum_{event}"] = value.sum(skipna=True) if not valid_values.empty else 0
        
        # Current state of the volcano (ignoring missing data)
        # Drop NaNs and take the last one. If all are NaN, default to 0.
        data[f"Last_{event}"] = valid_values.iloc[-1] if not valid_values.empty else 0
        
        # Peak intensity 
        v_max = valid_values.max() if not valid_values.empty else 0
        v_min = valid_values.min() if not valid_values.empty else 0
        
        data[f"Max_{event}"] = v_max
        data[f"Delta_Max_Min_{event}"] = v_max - v_min

        if pd.isna(v_max) or pd.isna(v_min):
            raise ValueError(f"NaN values found in max/min calculation for event '{event}'")
        
        if event != 'tornillos' and event != 'Precipitations':  # Assuming these events don't have the same swarm behavior
            if len(valid_values) >= 3:
                if len(valid_values) == 3:
                    avg_days_1_2 = valid_values.iloc[0:2].mean()
                    day_3 = valid_values.iloc[2]
                    is_raising = 0
                    # Swarm detection logic: if the average of the first two days is 0 and the third day has events, it's a swarm. Otherwise, if the third day has more than twice the average of the first two days, it's a swarm.
                    if avg_days_1_2 == 0 and day_3 > 0:
                        is_raising = 1
                    else:
                        is_raising = 1 if day_3 > (2 * avg_days_1_2) else 0
                    
                    data[f"is_raising_{event}"] = is_raising
                
                elif len(valid_values)==4:
                    avg_days_1_3 = valid_values.iloc[0:3].mean()
                    day_4 = valid_values.iloc[3]
                    is_raising = 0
                    if avg_days_1_3 == 0 and day_4 > 0:
                        is_raising = 1
                    else:
                        is_raising = 1 if day_4 > (2 * avg_days_1_3) else 0
                    
                    data[f"is_raising_{event}"] = is_raising

                elif len(valid_values) == 5:
                    avg_days_1_4 = valid_values.iloc[0:3].mean()
                    last_days = valid_values.iloc[4:].mean()  # We take the average of the last two days to smooth out potential outliers
                    is_raising = 0
                    if avg_days_1_4 == 0 and last_days > 0:
                        is_raising = 1
                    else:
                        is_raising = 1 if last_days > (1.5 * avg_days_1_4) else 0
                    
                    data[f"is_raising_{event}"] = is_raising
            else:
                data[f"is_raising_{event}"] = 0  # Default to no raising if we don't have above 3 days of data


    return data

# %%
def extract_geoseismic_features_per_event(windows_indices):
    all_features = []
    for i, key in enumerate(windows_indices.keys()):
        if (i%100)==0:
            print(f"Processing event {i} / {len(windows_indices)}") 
        data = windows_indices[key]
        window_data = Rincon_df.loc[data]
        sei_geo_columns = list(Rincon_df.columns)
        features = extract_geoseismic_features(window_data, sei_geo_columns)
        window_data_rain = Rain2019_2024_df.loc[data]
        rain_columns = list(Rain2019_2024_df.columns)
        rain_features = extract_geoseismic_features(window_data_rain, rain_columns)
        features.update(rain_features)
        all_features.append(features)
    all_features_df = pd.DataFrame(all_features)
    return all_features_df

# %% [markdown]
# # TRAIN/TEST SPLITS

# %% [markdown]
# ## Leave one year out

# %% [markdown]
# We are going to use a leave-one-year-out cross-validation approach to evaluate the performance of our models. This means that we will train our model on data from all years except one, and then test it on the left-out year. We will repeat this process for each year in our dataset.

# %%
def create_test_leave_one_year_out_splits():
    splits = {}
    years = [2019, 2020, 2021, 2022, 2023, 2024]
    for test_year in years:
        train_years = [y for y in years if y != test_year]
        splits[test_year] = train_years
        print(f"Test Year: {test_year} | Train Years: {train_years}")
    return splits

# %%
train_test_years_splits = create_test_leave_one_year_out_splits()
# Out:
# Test Year: 2019 | Train Years: [2020, 2021, 2022, 2023, 2024]
# Test Year: 2020 | Train Years: [2019, 2021, 2022, 2023, 2024]
# Test Year: 2021 | Train Years: [2019, 2020, 2022, 2023, 2024]
# Test Year: 2022 | Train Years: [2019, 2020, 2021, 2023, 2024]
# Test Year: 2023 | Train Years: [2019, 2020, 2021, 2022, 2024]
# Test Year: 2024 | Train Years: [2019, 2020, 2021, 2022, 2023]

# %%
# Function to select data for specific years
def select_dataset_years(df, years):
    return df[df.index.year.isin(years)]

# %%
# Create training AND test datasets for each test year
Rincon_de_la_Vieja_training_df = {}
rsam_VORI_training_df = {}
dsar_VORI_training_df = {}
Rincon_training_df = {}
VRBA_eruptions_training_df = {}

# Test sets
Rincon_de_la_Vieja_test_df = {}
rsam_VORI_test_df = {}
dsar_VORI_test_df = {}
Rincon_test_df = {}
VRBA_eruptions_test_df = {}

for test_year, train_years in train_test_years_splits.items():
    Rincon_de_la_Vieja_training_df[test_year] = select_dataset_years(Rincon_de_la_Vieja_df, train_years)
    rsam_VORI_training_df[test_year] = select_dataset_years(rsam_VORI_df, train_years)
    dsar_VORI_training_df[test_year] = select_dataset_years(dsar_VORI_df, train_years)
    Rincon_training_df[test_year] = select_dataset_years(Rincon_df, train_years)
    VRBA_eruptions_training_df[test_year] = VRBA_eruptions_df[VRBA_eruptions_df['t1'].dt.year.isin(train_years)]

    # Create test datasets for each test year

    Rincon_de_la_Vieja_test_df[test_year] = select_dataset_years(Rincon_de_la_Vieja_df, [test_year])
    rsam_VORI_test_df[test_year] = select_dataset_years(rsam_VORI_df, [test_year])
    dsar_VORI_test_df[test_year] = select_dataset_years(dsar_VORI_df, [test_year])
    Rincon_test_df[test_year] = select_dataset_years(Rincon_df, [test_year])
    VRBA_eruptions_test_df[test_year] = VRBA_eruptions_df[VRBA_eruptions_df['t1'].dt.year == test_year]

training_datasets = {
    'Rincon_de_la_Vieja': Rincon_de_la_Vieja_training_df,
    'RSAM_VORI': rsam_VORI_training_df,
    'DSAR_VORI': dsar_VORI_training_df,
    'Rincon': Rincon_training_df,
    'VRBA_eruptions': VRBA_eruptions_training_df
}

test_datasets = {
    'Rincon_de_la_Vieja': Rincon_de_la_Vieja_test_df,
    'RSAM_VORI': rsam_VORI_test_df,
    'DSAR_VORI': dsar_VORI_test_df,
    'Rincon': Rincon_test_df,
    'VRBA_eruptions': VRBA_eruptions_test_df
}

# %% [markdown]
# ### Windows Extraction

# %% [markdown]
# Now that we have the train/test splits, we are going to extract the corresponding windows of data for each split and apply the same feature extraction process as described before. We will then train our models on the training data and evaluate them on the testing data for each split.

# %% [markdown]
# #### Configs

# %%
# Create the configurations for head eruption and head no eruption windows based on the training datasets
def create_eruption_and_no_eruption_windows_configs(test_year, training_datasets, test_set=False, suffixe=""):
    
    if test_set:
        prefixe = "test_"
    else:        
        prefixe = ""
    
    HEAD_ERUPTION_WINDOWS_CONFIG = {
        'eruptions_windows_indices_VRBA': {
            'df': training_datasets['Rincon_de_la_Vieja'][test_year],
            'file_name': f'{prefixe}head_eruptions_windows_indices_VRBA_{test_year}{suffixe}.npy',
        },
        'eruptions_windows_indices_rsam_VORI': {
            'df': training_datasets['RSAM_VORI'][test_year],
            'file_name': f'{prefixe}head_eruptions_windows_indices_rsam_VORI_{test_year}{suffixe}.npy',
        },
        'eruptions_windows_indices_dsar_VORI': {
            'df': training_datasets['DSAR_VORI'][test_year],
            'file_name': f'{prefixe}head_eruptions_windows_indices_dsar_VORI_{test_year}{suffixe}.npy',
        },
        'sei_geo_eruption_windows_indices': {
            'df': training_datasets['Rincon'][test_year],
            'file_name': f'{prefixe}sei_geo_head_eruptions_windows_indices_{test_year}{suffixe}.npy',
            'time_type': 'D',  # Use 1-day observation window
        },
    }

    HEAD_NO_ERUPTION_WINDOWS_CONFIG = {
        'no_eruption_windows_indices_VRBA': {
            'df': training_datasets['Rincon_de_la_Vieja'][test_year],
            'file_name': f'{prefixe}head_no_eruption_windows_indices_VRBA_{test_year}{suffixe}.npy',
            'virtual_file_name': f'{prefixe}virtual_head_no_eruption_windows_{test_year}{suffixe}.npy',
            'is_reference': True,  # This dataset creates the non-eruption groups
        },
        'no_eruption_windows_indices_rsam_VORI': {
            'df': training_datasets['RSAM_VORI'][test_year],
            'file_name': f'{prefixe}head_no_eruption_windows_indices_rsam_VORI_{test_year}{suffixe}.npy',
        },
        'no_eruption_windows_indices_dsar_VORI': {
            'df': training_datasets['DSAR_VORI'][test_year],
            'file_name': f'{prefixe}head_no_eruption_windows_indices_dsar_VORI_{test_year}{suffixe}.npy',
        },
        'sei_geo_no_eruption_windows_indices': {
            'df': training_datasets['Rincon'][test_year],
            'file_name': f'{prefixe}sei_geo_head_no_eruption_windows_indices_{test_year}{suffixe}.npy',
            'time_type': 'D',  # Use 1-day observation window
        }
    }

    return HEAD_ERUPTION_WINDOWS_CONFIG, HEAD_NO_ERUPTION_WINDOWS_CONFIG

# %%
# Create the configurations for eruption and no eruption windows based on the training datasets
def create_eruption_and_no_eruption_5days_windows_configs(test_year, training_datasets, test_set = False, suffixe = ""):
    
    if test_set:
        prefixe = "test_"
    else:        
        prefixe = ""

    
    ERUPTION_WINDOWS_CONFIG = {
        'eruptions_windows_indices_VRBA': {
            'df': training_datasets['Rincon_de_la_Vieja'][test_year],
            'file_name': f'{prefixe}eruptions_5days_windows_indices_VRBA_{test_year}{suffixe}.npy',
        },
        'eruptions_windows_indices_rsam_VORI': {
            'df': training_datasets['RSAM_VORI'][test_year],
            'file_name': f'{prefixe}eruptions_5days_windows_indices_rsam_VORI_{test_year}{suffixe}.npy',
        },
        'eruptions_windows_indices_dsar_VORI': {
            'df': training_datasets['DSAR_VORI'][test_year],
            'file_name': f'{prefixe}eruptions_5days_windows_indices_dsar_VORI_{test_year}{suffixe}.npy',
        },
        'sei_geo_eruption_windows_indices': {
            'df': training_datasets['Rincon'][test_year],
            'file_name': f'{prefixe}sei_geo_eruptions_5days_windows_indices_{test_year}{suffixe}.npy',
            'time_type': 'D',  # Use 1-day observation window
        },
    }

    NO_ERUPTION_WINDOWS_CONFIG = {
        'no_eruption_windows_indices_VRBA': {
            'df': training_datasets['Rincon_de_la_Vieja'][test_year],
            'file_name': f'{prefixe}no_eruption_5days_windows_indices_VRBA_{test_year}{suffixe}.npy',
            'virtual_file_name': f'{prefixe}virtual_no_eruption_5days_windows_indices_VRBA_{test_year}{suffixe}.npy',
            'no_eruption_chains_file_name': f'{prefixe}no_eruption_chains_{test_year}{suffixe}.npy',
            'is_reference': True,  # This dataset creates the non-eruption groups
        },
        'no_eruption_windows_indices_rsam_VORI': {
            'df': training_datasets['RSAM_VORI'][test_year],
            'file_name': f'{prefixe}no_eruption_5days_windows_indices_rsam_VORI_{test_year}{suffixe}.npy',
        },
        'no_eruption_windows_indices_dsar_VORI': {
            'df': training_datasets['DSAR_VORI'][test_year],
            'file_name': f'{prefixe}no_eruption_5days_windows_indices_dsar_VORI_{test_year}{suffixe}.npy',
        },
        'sei_geo_no_eruption_windows_indices': {
            'df': training_datasets['Rincon'][test_year],
            'file_name': f'{prefixe}no_eruption_5days_windows_indices_sei_geo_{test_year}{suffixe}.npy',
            'time_type': 'D',  # Use 1-day observation window
        }
    }

    return ERUPTION_WINDOWS_CONFIG,  NO_ERUPTION_WINDOWS_CONFIG

# %%
def create_eruption_and_no_eruption_windows_coverage_configs(test_year, training_windows_indices, test_set = False):
    
    HEAD_WINDOW_COVERAGE_CONFIG = {
    'head_eruption': {
        'eruptions_windows_indices_VRBA': {
            'indices': training_windows_indices['head_eruption']['eruptions_windows_indices_VRBA'],
            'station': 'VRBA',
        },
        'eruptions_windows_indices_rsam_VORI': {
            'indices': training_windows_indices['head_eruption']['eruptions_windows_indices_rsam_VORI'],
            'station': 'VORI',
        },
        'eruptions_windows_indices_dsar_VORI': {
            'indices': training_windows_indices['head_eruption']['eruptions_windows_indices_dsar_VORI'],
            'station': 'VORI',
        },
    },
    'head_no_eruption': {
        'no_eruption_windows_indices_VRBA': {
            'indices': training_windows_indices['head_no_eruption']['no_eruption_windows_indices_VRBA'],
            'station': 'VRBA',
        },
        'no_eruption_windows_indices_rsam_VORI': {
            'indices': training_windows_indices['head_no_eruption']['no_eruption_windows_indices_rsam_VORI'],
            'station': 'VORI',
        },
        'no_eruption_windows_indices_dsar_VORI': {
            'indices': training_windows_indices['head_no_eruption']['no_eruption_windows_indices_dsar_VORI'],
            'station': 'VORI',
        },
    },
    }
    
    MEASURE_FREQUENCY = pd.Timedelta(minutes=1)
    return HEAD_WINDOW_COVERAGE_CONFIG, MEASURE_FREQUENCY #, WINDOW_COVERAGE_CONFIG

# %%
def create_eruption_and_no_eruption_5days_windows_coverage_configs(test_year, training_windows_indices):
    WINDOW_COVERAGE_CONFIG = {
    'eruption': {
        'eruptions_windows_indices_VRBA': {
            'indices': training_windows_indices['eruption']['eruptions_windows_indices_VRBA'],
            'station': 'VRBA',
        },
        'eruptions_windows_indices_rsam_VORI': {
            'indices': training_windows_indices['eruption']['eruptions_windows_indices_rsam_VORI'],
            'station': 'VORI',
        },
        'eruptions_windows_indices_dsar_VORI': {
            'indices': training_windows_indices['eruption']['eruptions_windows_indices_dsar_VORI'],
            'station': 'VORI',
        },
    },
    'no_eruption': {
        'no_eruption_windows_indices_VRBA': {
            'indices': training_windows_indices['no_eruption']['no_eruption_windows_indices_VRBA'],
            'station': 'VRBA',
        },
        'no_eruption_windows_indices_rsam_VORI': {
            'indices': training_windows_indices['no_eruption']['no_eruption_windows_indices_rsam_VORI'],
            'station': 'VORI',
        },
        'no_eruption_windows_indices_dsar_VORI': {
            'indices': training_windows_indices['no_eruption']['no_eruption_windows_indices_dsar_VORI'],
            'station': 'VORI',
        },
    },
    }
    
    MEASURE_FREQUENCY = pd.Timedelta(minutes=1)
    return WINDOW_COVERAGE_CONFIG, MEASURE_FREQUENCY #, WINDOW_COVERAGE_CONFIG

# %%
# Extract head eruption window and head no eruption windows for each test year with 3 days observation window and specific configurations
def extract_windows_pipeline(test_year, training_datasets, test_set=False, max_obs_minutes=7, suffixe=""):
    # Eruption and no eruption windows configurations
    ERUPTION_CONFIG, HEAD_NO_ER_CONFIG = create_eruption_and_no_eruption_windows_configs(test_year, training_datasets, test_set, suffixe)
    
    # Constants
    WINDOW_SIZE = pd.Timedelta(days=3)
    NEIGHBOUR_LIMITS = [pd.Timedelta(days=5), pd.Timedelta(days=4)]
    HEAD_OFFSET = pd.Timedelta(days=6)
    HEAD_OFFSET_TEST = pd.Timedelta(days=6)

    # Catolog of eruptions without the test year
    if not test_set:
        eruptions_filtered = VRBA_eruptions_df[VRBA_eruptions_df['t1'].dt.year != test_year].copy()
    else:
        eruptions_filtered = VRBA_eruptions_df[VRBA_eruptions_df['t1'].dt.year == test_year].copy()
        
    print("Initial number of eruptions: ", len(eruptions_filtered))

    # Extract eruption windows
    all_eruption_windows = build_or_load_eruptions_windows_indices(
        datasets=ERUPTION_CONFIG,
        eruption_times=eruptions_filtered['t1'],
        window_size=WINDOW_SIZE,
        mode='load',
        max_obs_minutes= max_obs_minutes,
        output_dir=f"MSc_Bryan_Rincon/Eruptions indices{suffixe}/"
    )  
  
    print(f"Number eruption windows : {len(all_eruption_windows['sei_geo_eruption_windows_indices'])}")
    # Extract head eruption windows
    _, head_chains = find_eruption_chains(eruptions_filtered, WINDOW_SIZE)
    
    h_vrba, h_rsam, h_dsar, h_sei = extract_head_eruption_windows_data(
        all_eruption_windows['eruptions_windows_indices_VRBA'], 
        all_eruption_windows['eruptions_windows_indices_rsam_VORI'], 
        all_eruption_windows['eruptions_windows_indices_dsar_VORI'], 
        all_eruption_windows['sei_geo_eruption_windows_indices'], 
        head_chains, 
        print_number=True
    )

    all_head_eruption_windows = {
        'eruptions_windows_indices_VRBA': h_vrba,
        'eruptions_windows_indices_rsam_VORI': h_rsam,
        'eruptions_windows_indices_dsar_VORI': h_dsar,
        'sei_geo_eruption_windows_indices': h_sei
    }

    # Extract head no eruption windows
    all_head_no_eruption_windows, head_virtual_times, _= build_or_load_no_eruption_windows_indices(
        datasets=HEAD_NO_ER_CONFIG,
        eruptions_df=eruptions_filtered,
        window_size=WINDOW_SIZE,
        neighbour_limits=NEIGHBOUR_LIMITS,
        continuous_offset=HEAD_OFFSET,
        mode='load',
        max_obs_minutes=max_obs_minutes,
        output_dir=f"MSc_Bryan_Rincon/Eruptions indices{suffixe}/"
    )
    print(f"Number Head no eruption window : {len(head_virtual_times)}")

    return {
        'head_eruption': all_head_eruption_windows,
        'head_no_eruption': all_head_no_eruption_windows,
        'head_chains': head_chains,
        'head_virtual_times': head_virtual_times,
    }

# # Save the different windows indices for each test year
# training_windows_coverage = {}
# training_windows_indices = {}
# for test_year in train_test_years_splits.keys():
#     print(f"\nExtracting windows for test year: {test_year}")
    
#     # Store results in a local variable to process and then discard
#     current_year_data = extract_windows_pipeline(test_year, training_datasets)
    

#     training_windows_indices[test_year] = {
#         'head_eruption': {'sei_geo_eruption_windows_indices':current_year_data['head_eruption']['sei_geo_eruption_windows_indices']},
#         'head_no_eruption': {'sei_geo_no_eruption_windows_indices':current_year_data['head_no_eruption']['sei_geo_no_eruption_windows_indices']},
#         'head_chains': current_year_data['head_chains'],
#         'head_virtual_times': current_year_data['head_virtual_times'],
#     }

#     # Window coverage configurations
#     # We pass the dictionary directly
#     WINDOW_COVERAGE_CONFIG, MEASURE_FREQUENCY = create_eruption_and_no_eruption_windows_coverage_configs(test_year, current_year_data)
    
#     # Calculate coverage for the extracted windows
#     coverage_results = build_window_coverage_data(
#         window_datasets=WINDOW_COVERAGE_CONFIG,
#         window_size=pd.Timedelta(days=3),
#         measure_frequency=MEASURE_FREQUENCY,
#         max_obs_minutes=7
#     )
    
#     # Store only what is necessary to save memory
#     training_windows_coverage[test_year] = {
#         'head_eruption': coverage_results['head_eruption'],
#         'head_no_eruption': coverage_results['head_no_eruption']
#     }
    
#     # Explicit memory cleanup for large temporary objects
#     del current_year_data
#     del coverage_results

# %%
# Extract eruption window and no eruption windows for each test year with 5 days observation window and specific configurations
def extract_5days_windows_pipeline(test_year, training_datasets, test_set = False, max_obs_minutes=7, suffixe = ""):
    # Eruption and no eruption windows configurations
    ERUPTION_CONFIG, NO_ER_CONFIG = create_eruption_and_no_eruption_5days_windows_configs(test_year, training_datasets, test_set, suffixe)

    # Constants
    WINDOW_SIZE = pd.Timedelta(days=5)
    NEIGHBOUR_LIMITS = [pd.Timedelta(days=5), pd.Timedelta(days=4)]
    OFFSET = pd.Timedelta(days=0.3)
    OFFSET_TEST = pd.Timedelta(days=1)

    # Catolog of eruptions without the test year
    if not test_set:
        eruptions_filtered = VRBA_eruptions_df[VRBA_eruptions_df['t1'].dt.year != test_year].copy()
    else:
        eruptions_filtered = VRBA_eruptions_df[VRBA_eruptions_df['t1'].dt.year == test_year].copy()

    print("Initial number of eruptions: ", len(eruptions_filtered))

    if not test_set:
        # Eruptions to delete to not have long sequence of eruptions impossible to split
        eruptions_filtered_clean , eruptions_to_delete = apply_purged_grouping(
            df=eruptions_filtered,
            window_size=WINDOW_SIZE)
        print(f"Number of eruptions after filtering: {len(eruptions_filtered_clean)} | Number of eruptions deleted: {len(eruptions_to_delete)}")

        # Extract eruption windows
        all_eruption_windows = build_or_load_eruptions_windows_indices(
            datasets=ERUPTION_CONFIG,
            eruption_times=eruptions_filtered_clean['t1'],
            window_size=WINDOW_SIZE,
            mode='load',
            max_obs_minutes=max_obs_minutes,
            output_dir=f"MSc_Bryan_Rincon/Eruptions indices{suffixe}/"

        )

        nb_eruptions_windows = len(all_eruption_windows['eruptions_windows_indices_VRBA'])
        print(f"Number eruption windows : {nb_eruptions_windows}")
        chains, _ = find_eruption_chains(eruptions_filtered, WINDOW_SIZE)

        all_no_eruption_windows, virtual_times, no_eruption_chains = build_or_load_no_eruption_windows_indices(
            datasets=NO_ER_CONFIG,
            eruptions_df=eruptions_filtered,
            window_size=WINDOW_SIZE,
            neighbour_limits=NEIGHBOUR_LIMITS,
            continuous_offset=OFFSET,
            mode='load',
            max_obs_minutes=max_obs_minutes,
            output_dir=f"MSc_Bryan_Rincon/Eruptions indices{suffixe}/"
            )
        print(f"Number no eruption chains : {len(no_eruption_chains)}")
        print(f"Number no eruption windows before selection: {len(all_no_eruption_windows['no_eruption_windows_indices_VRBA'])}")
        selected_no_eruption_windows_id = chain_stratified_undersampling(no_eruption_chains, all_no_eruption_windows['no_eruption_windows_indices_VRBA'], nb_eruptions_windows )

        if selected_no_eruption_windows_id :
            for key in all_no_eruption_windows.keys():
                all_no_eruption_windows[key] = {k: v for k, v in all_no_eruption_windows[key].items() if k in selected_no_eruption_windows_id}

            # virtual_times = virtual_times[np.array(selected_no_eruption_windows_id, dtype=int)]

        print(f"Number no eruption window : {len(all_no_eruption_windows['no_eruption_windows_indices_VRBA'])}")
    
    else:
        # Extract eruption windows
        all_eruption_windows = build_or_load_eruptions_windows_indices(
            datasets=ERUPTION_CONFIG,
            eruption_times=eruptions_filtered['t1'],
            window_size=WINDOW_SIZE,
            mode='load',
            max_obs_minutes=max_obs_minutes,
            output_dir=f"MSc_Bryan_Rincon/Eruptions indices{suffixe}/"
        )  


        nb_eruptions_windows = len(all_eruption_windows['eruptions_windows_indices_VRBA'])
        print(f"Number eruption windows : {nb_eruptions_windows}")
        chains, _ = find_eruption_chains(eruptions_filtered, WINDOW_SIZE)


        # Extract no eruption windows matching all eruption windows
        all_no_eruption_windows, virtual_times, no_eruption_chains = build_or_load_no_eruption_windows_indices(
            datasets=NO_ER_CONFIG,
            eruptions_df=eruptions_filtered,
            window_size=WINDOW_SIZE,
            neighbour_limits=NEIGHBOUR_LIMITS,
            continuous_offset=OFFSET_TEST,
            mode='load',
            max_obs_minutes=max_obs_minutes,
            output_dir=f"MSc_Bryan_Rincon/Eruptions indices{suffixe}/"
            )
        print(f"Number no eruption chains : {len(no_eruption_chains)}")
        print(f"Number no eruption window : {len(all_no_eruption_windows['no_eruption_windows_indices_VRBA'])}")


    return  {
        'eruption': all_eruption_windows,
        'no_eruption': all_no_eruption_windows,
        'eruption_chains': chains,
        'no_eruption_chains': no_eruption_chains,
        'virtual_times': virtual_times
    }

# # Save the different windows indices for each test year with 5 days observation window and specific configurations
# for test_year in train_test_years_splits.keys():
#     print(f"\nExtracting windows for test year: {test_year}")

# %% [markdown]
# ### Features Extraction

# %% [markdown]
# We extract all the features for each splits, in the same way as the previous Notebook.

# %%
# Feature extraction pipeline with all the the feature extraction functions merged into one function to extract features for all the different windows and save them into CSV files
def extract_windows_features_pipeline(training_windows,training_windows_coverage, training_datasets, plot=False, test_set = False, dsar_threshold=None, suffixe = ""):
    all_training_features = {}
    for test_year in training_windows_coverage.keys():
        if not test_set:
            dsar_threshold_VRBA = np.percentile(np.log(training_datasets['Rincon_de_la_Vieja'][test_year]['dsar'] + 1e-6), 80)
            dsar_threshold_VORI = np.percentile(np.log(training_datasets['DSAR_VORI'][test_year]['value'] + 1e-6), 80)
            dsar_threshold = {'VRBA': dsar_threshold_VRBA, 'VORI': dsar_threshold_VORI}
        all_training_features[test_year] = {}
        print(f"\nExtracting features for test year: {test_year}")
        for window_type in training_windows_coverage[test_year].keys():
            print(f"Processing window type: {window_type}")
            types_indices_cov = list(training_windows_coverage[test_year][window_type].keys())
            types_indices_sei_geo = list(training_windows[test_year][window_type].keys())
            # if len(types_indices) != 2:
            #     raise ValueError(f"Warning: Expected 4 types of windows for {window_type} in test year {test_year}, but found {len(types_indices)}. Skipping feature extraction for this window type.")
                
            windows_indices_VRBA = training_windows_coverage[test_year][window_type][types_indices_cov[0]]
            windows_indices_rsam_VORI = training_windows_coverage[test_year][window_type][types_indices_cov[1]]
            windows_indices_dsar_VORI = training_windows_coverage[test_year][window_type][types_indices_cov[2]]
            windows_indices_sei_geo = training_windows[test_year][window_type][types_indices_sei_geo[0]]
            all_features = []
            for i, key in enumerate(windows_indices_VRBA.keys()):
                if (i%100)==0:
                    print(f"Processing window {i} of {len(windows_indices_VRBA)}")
                # Extract features for windows
                behavior_features = get_metrics_behavior(key, windows_indices_VRBA, windows_indices_rsam_VORI, windows_indices_dsar_VORI, dsar_threshold)
                info = extract_metrics_info(key, windows_indices_VRBA, windows_indices_rsam_VORI, windows_indices_dsar_VORI, plot=plot)
                basic_metrics = calculate_simple_metrics(windows_indices_VRBA[key]['indices'], windows_indices_rsam_VORI[key]['indices'], windows_indices_dsar_VORI[key]['indices'])
                features = extract_metrics_features_global(key, info, basic_metrics, windows_indices_VRBA[key]['coverage_percentage'], windows_indices_rsam_VORI[key]['coverage_percentage'], windows_indices_dsar_VORI[key]['coverage_percentage'], behavior_features)
                # Extract sei geo features
                data = windows_indices_sei_geo[key]

                window_data = Rincon_df.loc[data]
                sei_geo_columns = list(Rincon_df.columns)
                geo_dict = extract_geoseismic_features(window_data, sei_geo_columns)
                geo_df = pd.DataFrame([geo_dict]) 

                window_data_rain = Rain2019_2024_df.loc[data]
                rain_columns = list(Rain2019_2024_df.columns)
                rain_dict = extract_geoseismic_features(window_data_rain, rain_columns)
                rain_df = pd.DataFrame([rain_dict]) 
                features = pd.concat([features.reset_index(drop=True), geo_df, rain_df], axis=1)
                all_features.append(features)
            all_features_df = pd.concat(all_features, ignore_index=True)
            # print(all_features_df.head())
            # print(all_features_df.describe())
            # raise ValueError("Stopping execution after feature extraction for the first window type to check results.")
            if test_set:
                all_features_df.to_csv(f'MSc_Bryan_Rincon/Eruption features{suffixe}/test_{window_type}_features_{test_year}.csv', index=False)
            else:
                all_features_df.to_csv(f'MSc_Bryan_Rincon/Eruption features{suffixe}/{window_type}_features_{test_year}.csv', index=False)
            # all_training_features[test_year][window_type] = all_features_df
    return dsar_threshold
    
    
# Extracted features for the different windows
# training_features = extract_windows_features_pipeline(training_windows_indices, training_windows_coverage, training_datasets, plot=False)

# %%
# Function to assign group IDs to the DataFrame based on the provided chains of indices
def assign_group_id(df, chains):
    df['group_id'] = -1  # Initialize with -1 for no group
    for i, chain in enumerate(chains):
        df.loc[df.index.isin(chain), 'group_id'] = i
    return df

# %%
# Function to create the features table for a given test year, merging eruption and no eruption features, and saving the result to a CSV file
def create_features_table(key,train_test_years_splits, training_datasets, training_windows_coverage, training_windows_indices,five_days_window = False, test_set = False, suffixe = ""):
    print(f"\nCreating features table for test year: {key}")
    if five_days_window:
        eruption_types = ['eruption','no_eruption', 'virtual_times']
        create_group_id = True # Set to True to create a group id column based on the chains, 
    else:
        eruption_types = ['head_eruption','head_no_eruption','head_virtual_times']
        create_group_id = False 

    #eruption_types = ['head_eruption','head_no_eruption','head_virtual_times']
    save_features_name = False
    features_name = None
    #for key in train_test_years_splits.keys():
    name_erup = f'{eruption_types[0]}_features_{key}.csv'
    name_no_erup = f'{eruption_types[1]}_features_{key}.csv'
    if test_set:
        df_erup = pd.read_csv(f'MSc_Bryan_Rincon/Eruption features{suffixe}/test_{name_erup}')
        df_no_erup = pd.read_csv(f'MSc_Bryan_Rincon/Eruption features{suffixe}/test_{name_no_erup}')
    else:
        df_erup = pd.read_csv(f'MSc_Bryan_Rincon/Eruption features{suffixe}/{name_erup}')
        df_no_erup = pd.read_csv(f'MSc_Bryan_Rincon/Eruption features{suffixe}/{name_no_erup}')
    if not save_features_name:
        features_name = df_erup.columns.tolist()
        print(f"Features columns saved")
        save_features_name = True
    prepare_eruption_features(df_erup, training_windows_coverage[key][eruption_types[0]]['eruptions_windows_indices_VRBA'], False)
    df_no_erup = prepare_no_eruption_features(df_no_erup, training_windows_coverage[key][eruption_types[1]]['no_eruption_windows_indices_VRBA'], training_windows_indices[key][eruption_types[2]],False)
    # Create group id column based on the chains
    if create_group_id:
        df_erup = assign_group_id(df_erup, training_windows_indices[key]['eruption_chains'])
        df_no_erup = assign_group_id(df_no_erup, training_windows_indices[key]['no_eruption_chains'])
        df_no_erup['group_id'] = df_no_erup['group_id'] + df_erup['group_id'].max() + 1  # Ensure unique group ids across both DataFrames

    if test_set:    
        Rincon_features_df = merge_all_features(test_datasets['VRBA_eruptions'][key], df_erup, df_no_erup)
    else:
        Rincon_features_df = merge_all_features(training_datasets['VRBA_eruptions'][key], df_erup, df_no_erup)
        
    # Create stratification column based on eruption and season
    erup_label = np.where(Rincon_features_df['Type'] == 1, 'erup', 'no_erup')
    season_label = np.where(Rincon_features_df['season'] == 1, 'rainy', 'dry')        
    Rincon_features_df['Stratification'] = erup_label + '_' + season_label
    if test_set:
        Rincon_features_df.to_csv(f'MSc_Bryan_Rincon/Rincon features{suffixe}/Rincon_{eruption_types[0]}_features_{key}_test.csv', index=False)
    else:
        Rincon_features_df.to_csv(f'MSc_Bryan_Rincon/Rincon features{suffixe}/Rincon_{eruption_types[0]}_features_{key}.csv', index=False)
    return features_name

#features_name = create_features_table(train_test_years_splits, training_datasets, training_windows_coverage, training_windows_indices)

# %%
# Function to run the entire pipeline for a given test year, including window extraction, coverage calculation, feature extraction, and saving the results
def fused_pipeline(test_year, training_datasets, five_days_window=True, test_set = False, max_obs_minutes=7, suffixe = ""):
    training_windows_coverage = {}
    training_windows_indices = {}
    # Store results in a local variable to process and then discard
    if five_days_window:
        current_year_data = extract_5days_windows_pipeline(test_year, training_datasets, test_set, max_obs_minutes=max_obs_minutes, suffixe=suffixe)
        training_windows_indices[test_year] = {
            'eruption': {'sei_geo_eruption_windows_indices':current_year_data['eruption']['sei_geo_eruption_windows_indices']},
            'no_eruption': {'sei_geo_no_eruption_windows_indices':current_year_data['no_eruption']['sei_geo_no_eruption_windows_indices']},
            'eruption_chains': current_year_data['eruption_chains'],
            'no_eruption_chains': current_year_data['no_eruption_chains'],
            'virtual_times': current_year_data['virtual_times']
        }
        WINDOW_COVERAGE_CONFIG, MEASURE_FREQUENCY = create_eruption_and_no_eruption_5days_windows_coverage_configs(test_year, current_year_data)
        # Calculate coverage for the extracted windows
        coverage_results = build_window_coverage_data(
            window_datasets=WINDOW_COVERAGE_CONFIG,
            window_size=pd.Timedelta(days=5),
            measure_frequency=MEASURE_FREQUENCY,
            max_obs_minutes=max_obs_minutes
        )

        # Store only what is necessary to save memory
        training_windows_coverage[test_year] = {
            'eruption': coverage_results['eruption'],
            'no_eruption': coverage_results['no_eruption']
        }
    
    else:
        current_year_data = extract_windows_pipeline(test_year, training_datasets, test_set, max_obs_minutes=max_obs_minutes, suffixe=suffixe)
    
        training_windows_indices[test_year] = {
        'head_eruption': {'sei_geo_eruption_windows_indices':current_year_data['head_eruption']['sei_geo_eruption_windows_indices']},
        'head_no_eruption': {'sei_geo_no_eruption_windows_indices':current_year_data['head_no_eruption']['sei_geo_no_eruption_windows_indices']},
        'head_chains': current_year_data['head_chains'],
        'head_virtual_times': current_year_data['head_virtual_times'],
        }

        WINDOW_COVERAGE_CONFIG, MEASURE_FREQUENCY = create_eruption_and_no_eruption_windows_coverage_configs(test_year, current_year_data)
        # Calculate coverage for the extracted windows
        coverage_results = build_window_coverage_data(
            window_datasets=WINDOW_COVERAGE_CONFIG,
            window_size=pd.Timedelta(days=3),
            measure_frequency=MEASURE_FREQUENCY,
            max_obs_minutes=max_obs_minutes
        )
        
        training_windows_coverage[test_year] = {
            'head_eruption': coverage_results['head_eruption'],
            'head_no_eruption': coverage_results['head_no_eruption']
        }
    

    # Explicit memory cleanup for large temporary objects
    del current_year_data
    del coverage_results


    ## Extract features for the extracted windows
    print(f"\nExtracting features for training  set without test year: {test_year}")
    if test_set == False:
        dsar_dict = extract_windows_features_pipeline(training_windows_indices, training_windows_coverage, training_datasets, plot=False, suffixe=suffixe)
        dsar_thresholds[test_year] = dsar_dict
    else:
        extract_windows_features_pipeline(training_windows_indices, training_windows_coverage, training_datasets, plot=False, test_set=test_set, dsar_threshold=dsar_thresholds[test_year], suffixe=suffixe)

    # Store the features to a CSV file and get the features name for the next steps
    return create_features_table(test_year, train_test_years_splits, training_datasets, training_windows_coverage, training_windows_indices, five_days_window=five_days_window, test_set=test_set, suffixe=suffixe)

dsar_thresholds = {}

# Head eruption and head no eruption windows with 3 days observation window

suffixe = ""  # Suffix for the output files
max_obs_minutes =   7# Maximum observation minutes for the features extraction

for test_year in train_test_years_splits.keys():
    print(f"\nExtracting features for training  set without test year: {test_year}")
    features_name = fused_pipeline(test_year, training_datasets,five_days_window=False,max_obs_minutes=max_obs_minutes, suffixe=suffixe)
    print(f"Extracted features columns for test year {test_year}: ", features_name)
    fused_pipeline(test_year, test_datasets,five_days_window=False, test_set = True,max_obs_minutes=max_obs_minutes, suffixe=suffixe)

# Head eruption and head no eruption windows with 5 days observation window

for test_year in train_test_years_splits.keys():
    print(f"\nExtracting features for training  set without test year: {test_year}")
    features_name = fused_pipeline(test_year, training_datasets,five_days_window=True,max_obs_minutes=max_obs_minutes, suffixe=suffixe)
    print(f"Extracted features columns for test year {test_year}: ", features_name)
    fused_pipeline(test_year, test_datasets,five_days_window=True, test_set = True,max_obs_minutes=max_obs_minutes, suffixe=suffixe)


# Store the features into a file
#pd.to_pickle(features_name, 'MSc_Bryan_Rincon/Rincon features/features_name_1hour.pkl')


print("Pipeline executed successfully for all test years.")
# print("Extracted features columns: ", features_name)
# Out:
# Extracting features for training  set without test year: 2019
# Initial number of eruptions:  936
# Number eruption windows : 936
# Number of head eruption windows: 116
# Number Head no eruption window : 81
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2019
#
# Extracting features for test year: 2019
# Processing window type: head_eruption
# Processing window 0 of 116
# Processing window 100 of 116
# Processing window type: head_no_eruption
# Processing window 0 of 81
#
# Creating features table for test year: 2019
# Features columns saved
# Extracted features columns for test year 2019:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  35
# Number eruption windows : 35
# Number of head eruption windows: 13
# Number Head no eruption window : 39
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2019
#
# Extracting features for test year: 2019
# Processing window type: head_eruption
# Processing window 0 of 13
# Processing window type: head_no_eruption
# Processing window 0 of 39
#
# Creating features table for test year: 2019
# Features columns saved
#
# Extracting features for training  set without test year: 2020
# Initial number of eruptions:  803
# Number eruption windows : 803
# Number of head eruption windows: 106
# Number Head no eruption window : 107
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2020
#
# Extracting features for test year: 2020
# Processing window type: head_eruption
# Processing window 0 of 106
# Processing window 100 of 106
# Processing window type: head_no_eruption
# Processing window 0 of 107
# Processing window 100 of 107
#
# Creating features table for test year: 2020
# Features columns saved
# Extracted features columns for test year 2020:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  168
# Number eruption windows : 168
# Number of head eruption windows: 23
# Number Head no eruption window : 13
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2020
#
# Extracting features for test year: 2020
# Processing window type: head_eruption
# Processing window 0 of 23
# Processing window type: head_no_eruption
# Processing window 0 of 13
#
# Creating features table for test year: 2020
# Features columns saved
#
# Extracting features for training  set without test year: 2021
# Initial number of eruptions:  946
# Number eruption windows : 946
# Number of head eruption windows: 113
# Number Head no eruption window : 79
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2021
#
# Extracting features for test year: 2021
# Processing window type: head_eruption
# Processing window 0 of 113
# Processing window 100 of 113
# Processing window type: head_no_eruption
# Processing window 0 of 79
#
# Creating features table for test year: 2021
# Features columns saved
# Extracted features columns for test year 2021:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  25
# Number eruption windows : 25
# Number of head eruption windows: 16
# Number Head no eruption window : 40
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2021
#
# Extracting features for test year: 2021
# Processing window type: head_eruption
# Processing window 0 of 16
# Processing window type: head_no_eruption
# Processing window 0 of 40
#
# Creating features table for test year: 2021
# Features columns saved
#
# Extracting features for training  set without test year: 2022
# Initial number of eruptions:  721
# Number eruption windows : 721
# Number of head eruption windows: 101
# Number Head no eruption window : 108
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2022
#
# Extracting features for test year: 2022
# Processing window type: head_eruption
# Processing window 0 of 101
# Processing window 100 of 101
# Processing window type: head_no_eruption
# Processing window 0 of 108
# Processing window 100 of 108
#
# Creating features table for test year: 2022
# Features columns saved
# Extracted features columns for test year 2022:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  250
# Number eruption windows : 250
# Number of head eruption windows: 29
# Number Head no eruption window : 11
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2022
#
# Extracting features for test year: 2022
# Processing window type: head_eruption
# Processing window 0 of 29
# Processing window type: head_no_eruption
# Processing window 0 of 11
#
# Creating features table for test year: 2022
# Features columns saved
#
# Extracting features for training  set without test year: 2023
# Initial number of eruptions:  577
# Number eruption windows : 577
# Number of head eruption windows: 112
# Number Head no eruption window : 113
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2023
#
# Extracting features for test year: 2023
# Processing window type: head_eruption
# Processing window 0 of 112
# Processing window 100 of 112
# Processing window type: head_no_eruption
# Processing window 0 of 113
# Processing window 100 of 113
#
# Creating features table for test year: 2023
# Features columns saved
# Extracted features columns for test year 2023:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  394
# Number eruption windows : 394
# Number of head eruption windows: 19
# Number Head no eruption window : 6
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2023
#
# Extracting features for test year: 2023
# Processing window type: head_eruption
# Processing window 0 of 19
# Processing window type: head_no_eruption
# Processing window 0 of 6
#
# Creating features table for test year: 2023
# Features columns saved
#
# Extracting features for training  set without test year: 2024
# Initial number of eruptions:  872
# Number eruption windows : 872
# Number of head eruption windows: 99
# Number Head no eruption window : 108
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2024
#
# Extracting features for test year: 2024
# Processing window type: head_eruption
# Processing window 0 of 99
# Processing window type: head_no_eruption
# Processing window 0 of 108
# Processing window 100 of 108
#
# Creating features table for test year: 2024
# Features columns saved
# Extracted features columns for test year 2024:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  99
# Number eruption windows : 99
# Number of head eruption windows: 31
# Number Head no eruption window : 11
# Getting head_eruption window data coverage...
# Getting head_no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2024
#
# Extracting features for test year: 2024
# Processing window type: head_eruption
# Processing window 0 of 31
# Processing window type: head_no_eruption
# Processing window 0 of 11
#
# Creating features table for test year: 2024
# Features columns saved
#
# Extracting features for training  set without test year: 2019
# Initial number of eruptions:  936
# Number of eruptions after filtering: 910 | Number of eruptions deleted: 26
# Number eruption windows : 910
# Number no eruption chains : 33
# Number no eruption windows before selection: 922
# Extraction complete: 910 windows extracted from 33 chains.
# Number no eruption window : 910
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2019
#
# Extracting features for test year: 2019
# Processing window type: eruption
# Processing window 0 of 910
# Processing window 100 of 910
# Processing window 200 of 910
# Processing window 300 of 910
# Processing window 400 of 910
# Processing window 500 of 910
# Processing window 600 of 910
# Processing window 700 of 910
# Processing window 800 of 910
# Processing window 900 of 910
# Processing window type: no_eruption
# Processing window 0 of 910
# Processing window 100 of 910
# Processing window 200 of 910
# Processing window 300 of 910
# Processing window 400 of 910
# Processing window 500 of 910
# Processing window 600 of 910
# Processing window 700 of 910
# Processing window 800 of 910
# Processing window 900 of 910
#
# Creating features table for test year: 2019
# Features columns saved
# Extracted features columns for test year 2019:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  35
# Number eruption windows : 35
# Number no eruption chains : 8
# Number no eruption window : 196
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2019
#
# Extracting features for test year: 2019
# Processing window type: eruption
# Processing window 0 of 35
# Processing window type: no_eruption
# Processing window 0 of 196
# Processing window 100 of 196
#
# Creating features table for test year: 2019
# Features columns saved
#
# Extracting features for training  set without test year: 2020
# Initial number of eruptions:  803
# Number of eruptions after filtering: 777 | Number of eruptions deleted: 26
# Number eruption windows : 777
# Number no eruption chains : 44
# Number no eruption windows before selection: 1279
# Extraction complete: 777 windows extracted from 44 chains.
# Number no eruption window : 777
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2020
#
# Extracting features for test year: 2020
# Processing window type: eruption
# Processing window 0 of 777
# Processing window 100 of 777
# Processing window 200 of 777
# Processing window 300 of 777
# Processing window 400 of 777
# Processing window 500 of 777
# Processing window 600 of 777
# Processing window 700 of 777
# Processing window type: no_eruption
# Processing window 0 of 777
# Processing window 100 of 777
# Processing window 200 of 777
# Processing window 300 of 777
# Processing window 400 of 777
# Processing window 500 of 777
# Processing window 600 of 777
# Processing window 700 of 777
#
# Creating features table for test year: 2020
# Features columns saved
# Extracted features columns for test year 2020:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  168
# Number eruption windows : 168
# Number no eruption chains : 5
# Number no eruption window : 52
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2020
#
# Extracting features for test year: 2020
# Processing window type: eruption
# Processing window 0 of 168
# Processing window 100 of 168
# Processing window type: no_eruption
# Processing window 0 of 52
#
# Creating features table for test year: 2020
# Features columns saved
#
# Extracting features for training  set without test year: 2021
# Initial number of eruptions:  946
# Number of eruptions after filtering: 920 | Number of eruptions deleted: 26
# Number eruption windows : 920
# Number no eruption chains : 33
# Number no eruption windows before selection: 916
# Not enough total windows available. There are only 916 available, keeping all.
# Number no eruption window : 916
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2021
#
# Extracting features for test year: 2021
# Processing window type: eruption
# Processing window 0 of 920
# Processing window 100 of 920
# Processing window 200 of 920
# Processing window 300 of 920
# Processing window 400 of 920
# Processing window 500 of 920
# Processing window 600 of 920
# Processing window 700 of 920
# Processing window 800 of 920
# Processing window 900 of 920
# Processing window type: no_eruption
# Processing window 0 of 916
# Processing window 100 of 916
# Processing window 200 of 916
# Processing window 300 of 916
# Processing window 400 of 916
# Processing window 500 of 916
# Processing window 600 of 916
# Processing window 700 of 916
# Processing window 800 of 916
# Processing window 900 of 916
#
# Creating features table for test year: 2021
# Features columns saved
# Extracted features columns for test year 2021:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  25
# Number eruption windows : 25
# Number no eruption chains : 9
# ...
# Extracted features columns for test year 2022:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  250
# Number eruption windows : 250
# Number no eruption chains : 3
# Number no eruption window : 44
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2022
#
# Extracting features for test year: 2022
# Processing window type: eruption
# Processing window 0 of 250
# Processing window 100 of 250
# Processing window 200 of 250
# Processing window type: no_eruption
# Processing window 0 of 44
#
# Creating features table for test year: 2022
# Features columns saved
#
# Extracting features for training  set without test year: 2023
# Initial number of eruptions:  577
# Number of eruptions after filtering: 573 | Number of eruptions deleted: 4
# Number eruption windows : 573
# Number no eruption chains : 48
# Number no eruption windows before selection: 1396
# Extraction complete: 573 windows extracted from 48 chains.
# Number no eruption window : 573
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2023
#
# Extracting features for test year: 2023
# Processing window type: eruption
# Processing window 0 of 573
# Processing window 100 of 573
# Processing window 200 of 573
# Processing window 300 of 573
# Processing window 400 of 573
# Processing window 500 of 573
# Processing window type: no_eruption
# Processing window 0 of 573
# Processing window 100 of 573
# Processing window 200 of 573
# Processing window 300 of 573
# Processing window 400 of 573
# Processing window 500 of 573
#
# Creating features table for test year: 2023
# Features columns saved
# Extracted features columns for test year 2023:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  394
# Number eruption windows : 394
# Number no eruption chains : 1
# Number no eruption window : 8
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2023
#
# Extracting features for test year: 2023
# Processing window type: eruption
# Processing window 0 of 394
# Processing window 100 of 394
# Processing window 200 of 394
# Processing window 300 of 394
# Processing window type: no_eruption
# Processing window 0 of 8
#
# Creating features table for test year: 2023
# Features columns saved
#
# Extracting features for training  set without test year: 2024
# Initial number of eruptions:  872
# Number of eruptions after filtering: 846 | Number of eruptions deleted: 26
# Number eruption windows : 846
# Number no eruption chains : 43
# Number no eruption windows before selection: 1299
# Extraction complete: 832 windows extracted from 43 chains.
# Number no eruption window : 832
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2024
#
# Extracting features for test year: 2024
# Processing window type: eruption
# Processing window 0 of 846
# Processing window 100 of 846
# Processing window 200 of 846
# Processing window 300 of 846
# Processing window 400 of 846
# Processing window 500 of 846
# Processing window 600 of 846
# Processing window 700 of 846
# Processing window 800 of 846
# Processing window type: no_eruption
# Processing window 0 of 832
# Processing window 100 of 832
# Processing window 200 of 832
# Processing window 300 of 832
# Processing window 400 of 832
# Processing window 500 of 832
# Processing window 600 of 832
# Processing window 700 of 832
# Processing window 800 of 832
#
# Creating features table for test year: 2024
# Features columns saved
# Extracted features columns for test year 2024:  ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Coverage Percentage VRBA', 'Coverage Percentage VORI RSAM', 'Coverage Percentage VORI DSAR', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'inv_rsam_quality_acceleration VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'inv_rsam_quality_acceleration VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipi ...
# Initial number of eruptions:  99
# Number eruption windows : 99
# Number no eruption chains : 5
# Number no eruption window : 44
# Getting eruption window data coverage...
# Getting no_eruption window data coverage...
#
# Extracting features for training  set without test year: 2024
#
# Extracting features for test year: 2024
# Processing window type: eruption
# Processing window 0 of 99
# Processing window type: no_eruption
# Processing window 0 of 44
#
# Creating features table for test year: 2024
# Features columns saved
# Pipeline executed successfully for all test years.

# %% [markdown]
# ## Train / Validation Splits

# %% [markdown]
# Now that we have all the window, we are going to split it to do a train/validation split. To do so, we will do a stratified shuffle keeping 80% for training and 20% for validation. As we want the model to be as effective during dry and rainy season and also when theres less eruption and vice versa , we do a stratified split on one the 4 possibilities : eruption in rainy season, eruption in dry season, no eruption in rainy season and no eruption in dry season.

# %% [markdown]
# #### Features gestion

# %%
##  Column Definition for Modeling and Analysis 

# Read the features name from the file
features_name = pd.read_pickle('MSc_Bryan_Rincon/Rincon features/features_name.pkl')

# Target labels and core temporal features
head_target_columns = ['Type', 'magnitude','Lahares']
target_columns     = ['Type', 'magnitude', 'Lahares','group_id']
temporal_features      = ['season']

# Features that might introduce bias (to be tested in future iterations)
SENSITIVE_FEATURES = ['month', 'Time of the Day', 'month norm', 'Time of the Day norm']

# Data quality features (usually excluded from training)
coverage_features  = [
    'Coverage Percentage VRBA', 
    'Coverage Percentage VORI RSAM', 
    'Coverage Percentage VORI DSAR'
]

# Extracting feature groups based on the station they are derived from and the rest
VORI_features   = [f for f in features_name if 'VORI' in f and 'Coverage' not in f]
VRBA_features   = [f for f in features_name if 'VRBA' in f and 'Coverage' not in f]
common_features = [f for f in features_name if 'VORI' not in f and 'VRBA' not in f] 

# Logging feature distribution
print(f"VORI features: {len(VORI_features)} | "
      f"VRBA features: {len(VRBA_features)} | "
      f"Common features: {len(common_features)}")

##  Exclusion Lists (Drop) for Modeling

# Standard drop list (Metadata + Coverage)
base_drop = ['Stratification', 't1'] + coverage_features

# Keep sensitive features
drop_columns  = base_drop

# Remove sensitive features to evaluate performance impact/bias
drop_columns2 = base_drop + SENSITIVE_FEATURES
# Out:
# VORI features: 66 | VRBA features: 66 | Common features: 19

# %%
# Function to identify binary columns in a DataFrame
def get_binary_columns(df):
    binary_cols = []
    for col in df.columns:
        unique_values = set(df[col].dropna().unique())
        if len(unique_values) <= 2:
            binary_cols.append(col)
            
    return binary_cols

# %% [markdown]
# #### Stratified Shuffle Split
# Because the windows are independent of each other, we can do a stratified shuffle split to have a good representation of the different classes in both the training and validation sets.

# %%
## (Head eruption features) Prepare training and validation datasets for each test year and feature set


X_Train_VORI = {}
X_Train_VRBA = {}

Y_Train_VORI = {}
Y_Train_VRBA = {}

X_Test_VORI = {}
X_Test_VRBA = {}

Y_Test_VORI = {}
Y_Test_VRBA = {}

coverage_Train = {}
coverage_Test = {}

time_Test = {}



x_train_VORI = {}
x_train_VRBA = {}

y_train_VORI = {}
y_train_VRBA = {}

x_val_VORI = {}
x_val_VRBA = {}

y_val_VORI = {}
y_val_VRBA = {}

coverage_train = {}
coverage_val = {}

time_val = {}

# Stratified split of the data for each test year, ensuring the same distribution of eruption types and seasons in both training and validation sets
for key in train_test_years_splits.keys():
    Rincon_features_df = pd.read_csv(f'MSc_Bryan_Rincon/Rincon features/Rincon_head_eruption_features_{key}.csv')
    Rincon_features_test_df = pd.read_csv(f'MSc_Bryan_Rincon/Rincon features/Rincon_head_eruption_features_{key}_test.csv')

    train, val = train_test_split(
        Rincon_features_df,
        test_size = 0.2,
        random_state=42,
        stratify=Rincon_features_df['Stratification']
    )

    X_full = Rincon_features_df.copy()
    X_Test = Rincon_features_test_df.copy()

    train = train.copy()
    val = val.copy()

    coverage_train[key] = train[coverage_features]
    coverage_val[key] = val[coverage_features]

    coverage_Train[key] = Rincon_features_df[coverage_features]
    coverage_Test[key] = Rincon_features_test_df[coverage_features]

    time_val[key] = val['t1']
    time_Test[key] = Rincon_features_test_df['t1']
    
    no_variance_cols = [col for col in train.columns if train[col].nunique() <= 1]
    no_Variance_cols = [col for col in X_full.columns if X_full[col].nunique() <= 1]


    train = train.drop(columns=drop_columns)
    val = val.drop(columns=drop_columns)

    if no_variance_cols:
        print(f"Columns with no variance in training set for test year {key}: {no_variance_cols}")
        train = train.drop(columns=no_variance_cols)
        val = val.drop(columns=no_variance_cols)

    if no_Variance_cols:
        print(f"Columns with no variance in full dataset for test year {key}: {no_Variance_cols}")
        X_full = X_full.drop(columns=no_Variance_cols)
        X_Test = X_Test.drop(columns=no_Variance_cols)

    # # Identify binary columns to exclude from scaling
    # binary_columns_train = get_binary_columns(train)
    # others_columns_train = list(set(train.columns) - set(binary_columns_train))

    # # Scale only the non-binary features to preserve the integrity of binary variables
    # scaler = StandardScaler()

    # train[others_columns_train] = scaler.fit_transform(train[others_columns_train])
    # val[others_columns_train] = scaler.transform(val[others_columns_train])

    # Prepare separate datasets for VORI and VRBA features, ensuring to include common and temporal features in both
    train_vori_features = VORI_features + common_features + temporal_features
    train_vrba_features = VRBA_features + common_features + temporal_features

    filt_vori = [col for col in train_vori_features if col in train.columns]
    filt_vrba = [col for col in train_vrba_features if col in train.columns]

    filt_full_vori = [col for col in train_vori_features if col in X_full.columns]
    filt_full_vrba = [col for col in train_vrba_features if col in X_full.columns]

    # Prepare separate datasets for VORI and VRBA features
    X_Train_VORI[key] = X_full[filt_full_vori]
    Y_Train_VORI[key] = X_full[head_target_columns]

    X_Test_VORI[key] = X_Test[filt_full_vori]
    Y_Test_VORI[key] = X_Test[head_target_columns] 

    X_Train_VRBA[key] = X_full[filt_full_vrba]
    Y_Train_VRBA[key] = X_full[head_target_columns]

    X_Test_VRBA[key] = X_Test[filt_full_vrba]
    Y_Test_VRBA[key] = X_Test[head_target_columns]

    x_train_VORI[key] = train[filt_vori]
    y_train_VORI[key] = train[head_target_columns]

    x_val_VORI[key] = val[filt_vori]
    y_val_VORI[key] = val[head_target_columns]

    x_train_VRBA[key] = train[filt_vrba]
    y_train_VRBA[key] = train[head_target_columns]

    x_val_VRBA[key] = val[filt_vrba]
    y_val_VRBA[key] = val[head_target_columns]
# Out:
# Columns with no variance in training set for test year 2019: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2019: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in training set for test year 2020: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2020: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in training set for test year 2021: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2021: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in training set for test year 2022: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2022: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in training set for test year 2023: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2023: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in training set for test year 2024: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2024: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']

# %% [markdown]
# #### Group stratified Shuffle Split
# As we have many windows that are part of the same eruption chain, we can join them in a group to be sure when doing the cross validation that we dont have windows from the same eruption chain in both the training and validation sets.

# %%
## (Eruption features) Prepare training and validation datasets for each test year and feature set

X_Train_5_VORI = {}
X_Train_5_VRBA = {}

Y_Train_5_VORI = {}
Y_Train_5_VRBA = {}

X_Test_5_VORI = {}
X_Test_5_VRBA = {}

Y_Test_5_VORI = {}
Y_Test_5_VRBA = {}

coverage_5days_Train = {}
coverage_5days_Test = {}

time_5days_Test = {}


x_train_5_VORI = {}
x_train_5_VRBA = {}

y_train_5_VORI = {}
y_train_5_VRBA = {}

x_val_5_VORI = {}
x_val_5_VRBA = {}

y_val_5_VORI = {}
y_val_5_VRBA = {}

coverage_5days_train = {}
coverage_5days_val = {}

time_5days_val = {}
# Stratified Group split: preserves both group integrity and eruption/non-eruption distribution
sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)

for key in train_test_years_splits.keys():
    print(f"\nProcessing test year: {key} with Stratified Group K-Fold")
    Rincon_features_df = pd.read_csv(f'MSc_Bryan_Rincon/Rincon features/Rincon_eruption_features_{key}.csv')
    Rincon_features_test_df = pd.read_csv(f'MSc_Bryan_Rincon/Rincon features/Rincon_eruption_features_{key}_test.csv')
    
    # Use the first fold for train/val split 
    X_full = Rincon_features_df.copy()
    X_Test = Rincon_features_test_df.copy()
    y_strat = Rincon_features_df['Stratification']
    groups = Rincon_features_df['group_id']
    
    train_idx, val_idx = next(sgkf.split(X_full, y_strat, groups))

    train = Rincon_features_df.iloc[train_idx].copy()
    val = Rincon_features_df.iloc[val_idx].copy()

    print(f'training size: {len(train)} | validation size: {len(val)} ')
    
    coverage_5days_train[key] = train[coverage_features]
    coverage_5days_val[key] = val[coverage_features]

    coverage_5days_Train[key] = Rincon_features_df[coverage_features]
    coverage_5days_Test[key] = Rincon_features_test_df[coverage_features]

    time_5days_val[key] = val['t1']
    time_5days_Test[key] = Rincon_features_test_df['t1']
    
    train = train.drop(columns=drop_columns2)
    val = val.drop(columns=drop_columns2)

    # Print columns with no variance in the training set
    no_variance_cols = [col for col in train.columns if train[col].nunique() <= 1]
    no_Variance_cols = [col for col in X_full.columns if X_full[col].nunique() <= 1]

    if no_variance_cols:
        print(f"Columns with no variance in training set for test year {key}: {no_variance_cols}")
        train = train.drop(columns=no_variance_cols)
        val = val.drop(columns=no_variance_cols)

    if no_Variance_cols:
        print(f"Columns with no variance in full dataset for test year {key}: {no_Variance_cols}")
        X_full = X_full.drop(columns=no_Variance_cols)
        X_Test = X_Test.drop(columns=no_Variance_cols)

    ## Identify binary columns to exclude from scaling
    # binary_columns_train = get_binary_columns(train)
    # others_columns_train = list(set(train.columns) - set(binary_columns_train)-set(target_columns))

    # # Scale only the non-binary features
    # scaler = StandardScaler()
    # train[others_columns_train] = scaler.fit_transform(train[others_columns_train])
    # val[others_columns_train] = scaler.transform(val[others_columns_train])

    
    
    # Prepare separate datasets for VORI and VRBA features, ensuring to include common and temporal features in both
    train_vori_features = VORI_features + common_features + temporal_features
    train_vrba_features = VRBA_features + common_features + temporal_features

    filt_vori = [col for col in train_vori_features if col in train.columns]
    filt_vrba = [col for col in train_vrba_features if col in train.columns]

    filt_full_vori = [col for col in train_vori_features if col in X_full.columns]
    filt_full_vrba = [col for col in train_vrba_features if col in X_full.columns]

    # Prepare separate datasets for VORI and VRBA features
    X_Train_5_VORI[key] = X_full[filt_full_vori]
    Y_Train_5_VORI[key] = X_full[target_columns]

    X_Test_5_VORI[key] = X_Test[filt_full_vori]
    Y_Test_5_VORI[key] = X_Test[target_columns] 

    X_Train_5_VRBA[key] = X_full[filt_full_vrba]
    Y_Train_5_VRBA[key] = X_full[target_columns]

    X_Test_5_VRBA[key] = X_Test[filt_full_vrba]
    Y_Test_5_VRBA[key] = X_Test[target_columns]


    x_train_5_VORI[key] = train[filt_vori]
    y_train_5_VORI[key] = train[target_columns]

    x_val_5_VORI[key] = val[filt_vori]
    y_val_5_VORI[key] = val[target_columns]

    x_train_5_VRBA[key] = train[filt_vrba]
    y_train_5_VRBA[key] = train[target_columns]

    x_val_5_VRBA[key] = val[filt_vrba]
    y_val_5_VRBA[key] = val[target_columns]
# Out:
# Processing test year: 2019 with Stratified Group K-Fold
# training size: 1596 | validation size: 224
# Columns with no variance in training set for test year 2019: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2019: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
#
# Processing test year: 2020 with Stratified Group K-Fold
# training size: 1407 | validation size: 147
# Columns with no variance in training set for test year 2020: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2020: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
#
# Processing test year: 2021 with Stratified Group K-Fold
# training size: 1494 | validation size: 342
# Columns with no variance in training set for test year 2021: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2021: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
#
# Processing test year: 2022 with Stratified Group K-Fold
# training size: 1227 | validation size: 160
# Columns with no variance in training set for test year 2022: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2022: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
#
# Processing test year: 2023 with Stratified Group K-Fold
# training size: 1038 | validation size: 108
# Columns with no variance in training set for test year 2023: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2023: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
#
# Processing test year: 2024 with Stratified Group K-Fold
# training size: 1489 | validation size: 189
# Columns with no variance in training set for test year 2024: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']
# Columns with no variance in full dataset for test year 2024: ['inv_rsam_quality_acceleration VRBA', 'inv_rsam_quality_acceleration VORI']

# %% [markdown]
# ## Model

# %% [markdown]
# A Random Forest Classifier was selected as the core predictive model. This algorithm was chosen
# due to its demonstrated efficacy in prior seismological studies and its intrinsic mechanism for
# ranking feature importance, which is crucial for interpreting the physical mechanisms driving the
# model’s decisions.

# %% [markdown]
# #### Random Forest Classifier optimization

# %%
# Function to optimize and train Random Forest models for both VORI and VRBA stations (3-day and 5-day windows) using RandomizedSearchCV
def train_and_optimize_rf_models(train_test_years_splits, 
x_train_VORI, y_train_VORI, x_train_5_VORI, y_train_5_VORI,
x_train_VRBA, y_train_VRBA, x_train_5_VRBA, y_train_5_VRBA,
n_iter_search=200, random_state=42 ):
    """
    Optimizes and trains Random Forest models for VORI and VRBA stations 
    (3 and 5-day windows) via RandomizedSearchCV, and returns the best models.
    """

    # Hyperparameter grid for Random Forest

    param_grid = {
        'n_estimators': [10, 50, 100, 200, 300, 500],            
        'max_depth': [3, 5, 7, 10],                      
        'min_samples_split': [2, 5, 10, 20],                  
        'min_samples_leaf': [1, 2, 4, 8],                    
        'max_features': ['sqrt', 'log2', 0.5, 0.8],
        'bootstrap': [True, False],
        'class_weight': ['balanced', 'balanced_subsample']
    }

    # Initialize the scorer (f2_scorer) and cross-validator
    f2_scorer = make_scorer(fbeta_score, beta=2)
    sgkf_search = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=random_state)

    # Dictionaries to store the results
    best_models_VORI = {}
    best_5days_models_VORI = {}
    best_models_VRBA = {}
    best_5days_models_VRBA = {}

    for key in train_test_years_splits.keys():
        print(f"\nOptimizing Random Forest for test year: {key}")
        
        # STATION : VORI (3 days)
        rf_3_VORI = RandomForestClassifier(random_state=random_state)
        random_search_VORI = RandomizedSearchCV(
            estimator=rf_3_VORI,
            param_distributions=param_grid,
            n_iter=n_iter_search,
            scoring=f2_scorer,
            cv=5,
            verbose=1,
            n_jobs=-1,
            random_state=random_state
        )
        random_search_VORI.fit(x_train_VORI[key], y_train_VORI[key]['Type'])
        best_models_VORI[key] = random_search_VORI.best_estimator_
        print(f"Best parameters for VORI 3 days (test year {key}): {random_search_VORI.best_params_}")

        # STATION : VORI (5 days)
        rf_5_VORI = RandomForestClassifier(random_state=random_state)
        random_search_VORI_5 = RandomizedSearchCV(
            estimator=rf_5_VORI,
            param_distributions=param_grid,
            n_iter=n_iter_search,
            scoring=f2_scorer,
            cv=sgkf_search, 
            verbose=1,
            n_jobs=-1,
            random_state=random_state
        )
        groups_train_VORI = y_train_5_VORI[key]['group_id']
        random_search_VORI_5.fit(x_train_5_VORI[key], y_train_5_VORI[key]['Type'], groups=groups_train_VORI)
        best_5days_models_VORI[key] = random_search_VORI_5.best_estimator_
        print(f"Best parameters for VORI 5 days (test year {key}): {random_search_VORI_5.best_params_}")

        # STATION : VRBA (3 days)
        rf_3_VRBA = RandomForestClassifier(random_state=random_state)
        random_search_VRBA = RandomizedSearchCV(
            estimator=rf_3_VRBA,
            param_distributions=param_grid,
            n_iter=n_iter_search,
            scoring=f2_scorer,
            cv=5,
            verbose=1,
            n_jobs=-1,
            random_state=random_state
        )
        random_search_VRBA.fit(x_train_VRBA[key], y_train_VRBA[key]['Type'])
        best_models_VRBA[key] = random_search_VRBA.best_estimator_
        print(f"Best parameters for VRBA 3 days (test year {key}): {random_search_VRBA.best_params_}")

        # STATION : VRBA (5 days)
        rf_5_VRBA = RandomForestClassifier(random_state=random_state)
        random_search_VRBA_5 = RandomizedSearchCV(
            estimator=rf_5_VRBA,
            param_distributions=param_grid,
            n_iter=n_iter_search,
            scoring=f2_scorer,
            cv=sgkf_search, 
            verbose=1,
            n_jobs=-1,
            random_state=random_state
        )
        groups_train_VRBA = y_train_5_VRBA[key]['group_id']
        random_search_VRBA_5.fit(x_train_5_VRBA[key], y_train_5_VRBA[key]['Type'], groups=groups_train_VRBA)
        best_5days_models_VRBA[key] = random_search_VRBA_5.best_estimator_
        print(f"Best parameters for VRBA 5 days (test year {key}): {random_search_VRBA_5.best_params_}")

    # Return the 4 dictionaries containing the final models
    return best_models_VORI, best_5days_models_VORI, best_models_VRBA, best_5days_models_VRBA

# %%
best_models_VORI_train, best_5days_models_VORI_train, best_models_VRBA_train, best_5days_models_VRBA_train = train_and_optimize_rf_models(
    train_test_years_splits=train_test_years_splits,
    x_train_VORI=x_train_VORI, y_train_VORI=y_train_VORI, 
    x_train_5_VORI=x_train_5_VORI, y_train_5_VORI=y_train_5_VORI,
    x_train_VRBA=x_train_VRBA, y_train_VRBA=y_train_VRBA, 
    x_train_5_VRBA=x_train_5_VRBA, y_train_5_VRBA=y_train_5_VRBA,
    n_iter_search=200 
)
# Out:
# Optimizing Random Forest for test year: 2019
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2019): {'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2019): {'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2019): {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2019): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.5, 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': True}
#
# Optimizing Random Forest for test year: 2020
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2020): {'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2020): {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2020): {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2020): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 5, 'class_weight': 'balanced_subsample', 'bootstrap': False}
#
# Optimizing Random Forest for test year: 2021
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2021): {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2021): {'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2021): {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2021): {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
#
# Optimizing Random Forest for test year: 2022
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2022): {'n_estimators': 10, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 0.5, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2022): {'n_estimators': 50, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2022): {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'log2', 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2022): {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': False}
#
# Optimizing Random Forest for test year: 2023
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2023): {'n_estimators': 10, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2023): {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2023): {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 3, 'class_weight': 'balanced_subsample', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2023): {'n_estimators': 10, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 0.8, 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': True}
#
# Optimizing Random Forest for test year: 2024
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2024): {'n_estimators': 100, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2024): {'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2024): {'n_estimators': 50, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2024): {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': True}

# %%
# Show detailed evaluation reports for the best models of each station and test year, including confusion matrices, 
# classification reports, feature importance, and error analysis based on eruption magnitude.

def print_truth_table_analysis(key, y_pred_summary, station, y_true, five_days=False, return_time = False, coverage = coverage_val, time = time_val, coverage_5days = coverage_5days_val, time_5days = time_5days_val):
    print(f"\n Summary for {station} ")
    idx_both_tp = (y_pred_summary['VORI'] == 1) & (y_pred_summary['VRBA'] == 1)& (y_true == 1)
    idx_both_tn = (y_pred_summary['VORI'] == 0) & (y_pred_summary['VRBA'] == 0) & (y_true == 0)
    idx_both_fp = (y_pred_summary['VORI'] == 1) & (y_pred_summary['VRBA'] == 1) & (y_true == 0)
    idx_both_fn = (y_pred_summary['VORI'] == 0) & (y_pred_summary['VRBA'] == 0) & (y_true == 1)


    if five_days:
        coverage = coverage_5days[key]
        time = time_5days[key]
    else:
        coverage = coverage[key]
        time = time[key]
    ## Calculate mean coverage for each group
    # Both Detected (TP)
    vori_rsam_for_both_tp = coverage.loc[idx_both_tp, 'Coverage Percentage VORI RSAM']
    vori_dsar_for_both_tp = coverage.loc[idx_both_tp, 'Coverage Percentage VORI DSAR']
    vrba_for_both_tp = coverage.loc[idx_both_tp, 'Coverage Percentage VRBA']
    # Both Detected (TN)
    vori_rsam_for_both_tn = coverage.loc[idx_both_tn, 'Coverage Percentage VORI RSAM']
    vori_dsar_for_both_tn = coverage.loc[idx_both_tn, 'Coverage Percentage VORI DSAR']
    vrba_for_both_tn = coverage.loc[idx_both_tn, 'Coverage Percentage VRBA']
    # Both Missed (FN)  
    vori_rsam_for_both_fn = coverage.loc[idx_both_fn, 'Coverage Percentage VORI RSAM']
    vori_dsar_for_both_fn = coverage.loc[idx_both_fn, 'Coverage Percentage VORI DSAR']
    vrba_for_both_fn = coverage.loc[idx_both_fn, 'Coverage Percentage VRBA']
    # Both False Positives (FP)
    vori_rsam_for_both_fp = coverage.loc[idx_both_fp, 'Coverage Percentage VORI RSAM']
    vori_dsar_for_both_fp = coverage.loc[idx_both_fp, 'Coverage Percentage VORI DSAR']
    vrba_for_both_fp = coverage.loc[idx_both_fp, 'Coverage Percentage VRBA']

        
    print(f"Both Detected (TP): {idx_both_tp.sum()} | Mean VORI RSAM Coverage: {vori_rsam_for_both_tp.mean():.2f}±{vori_rsam_for_both_tp.std():.2f}% | Mean VORI DSAR Coverage: {vori_dsar_for_both_tp.mean():.2f}±{vori_dsar_for_both_tp.std():.2f}% | Mean VRBA Coverage: {vrba_for_both_tp.mean():.2f}±{vrba_for_both_tp.std():.2f}%")
    print(f"Both Missed (FN): {idx_both_fn.sum()} | Mean VORI RSAM Coverage: {vori_rsam_for_both_fn.mean():.2f}±{vori_rsam_for_both_fn.std():.2f}% | Mean VORI DSAR Coverage: {vori_dsar_for_both_fn.mean():.2f}±{vori_dsar_for_both_fn.std():.2f}% | Mean VRBA Coverage: {vrba_for_both_fn.mean():.2f}±{vrba_for_both_fn.std():.2f}%")
    print(f"Both False Positives (FP): {idx_both_fp.sum()} | Mean VORI RSAM Coverage: {vori_rsam_for_both_fp.mean():.2f}±{vori_rsam_for_both_fp.std():.2f}% | Mean VORI DSAR Coverage: {vori_dsar_for_both_fp.mean():.2f}±{vori_dsar_for_both_fp.std():.2f}% | Mean VRBA Coverage: {vrba_for_both_fp.mean():.2f}±{vrba_for_both_fp.std():.2f}%")
    print(f"Both True Negatives (TN): {idx_both_tn.sum()} | Mean VORI RSAM Coverage: {vori_rsam_for_both_tn.mean():.2f}±{vori_rsam_for_both_tn.std():.2f}% | Mean VORI DSAR Coverage: {vori_dsar_for_both_tn.mean():.2f}±{vori_dsar_for_both_tn.std():.2f}% | Mean VRBA Coverage: {vrba_for_both_tn.mean():.2f}±{vrba_for_both_tn.std():.2f}%")

        
    idx_vori_only_tp = (y_pred_summary['VORI'] == 1) & (y_pred_summary['VRBA'] == 0) & (y_true == 1)
    idx_vrba_only_tp = (y_pred_summary['VORI'] == 0) & (y_pred_summary['VRBA'] == 1) & (y_true == 1)
    idx_vrba_only_tn = (y_pred_summary['VORI'] == 1) & (y_pred_summary['VRBA'] == 0) & (y_true == 0)
    idx_vori_only_tn = (y_pred_summary['VORI'] == 0) & (y_pred_summary['VRBA'] == 1) & (y_true == 0)

    ## Calculate mean coverage for each group
    # VORI only detected true events (TP)
    vori_rsam_for_vori_only_tp = coverage.loc[idx_vori_only_tp, 'Coverage Percentage VORI RSAM']
    vori_dsar_for_vori_only_tp = coverage.loc[idx_vori_only_tp, 'Coverage Percentage VORI DSAR']
    vrba_for_vori_only_tp = coverage.loc[idx_vori_only_tp, 'Coverage Percentage VRBA']
    # VRBA only detected true events (TP)
    vori_rsam_for_vrba_only_tp = coverage.loc[idx_vrba_only_tp, 'Coverage Percentage VORI RSAM']
    vori_dsar_for_vrba_only_tp = coverage.loc[idx_vrba_only_tp, 'Coverage Percentage VORI DSAR']
    vrba_for_vrba_only_tp = coverage.loc[idx_vrba_only_tp, 'Coverage Percentage VRBA']
    # VORI only detected true negatives (TN)
    vori_rsam_for_vori_only_tn = coverage.loc[idx_vori_only_tn, 'Coverage Percentage VORI RSAM']
    vori_dsar_for_vori_only_tn = coverage.loc[idx_vori_only_tn, 'Coverage Percentage VORI DSAR']
    vrba_for_vori_only_tn = coverage.loc[idx_vori_only_tn, 'Coverage Percentage VRBA']
    # VRBA only detected true negatives (TN)
    vori_rsam_for_vrba_only_tn = coverage.loc[idx_vrba_only_tn, 'Coverage Percentage VORI RSAM']
    vori_dsar_for_vrba_only_tn = coverage.loc[idx_vrba_only_tn, 'Coverage Percentage VORI DSAR']
    vrba_for_vrba_only_tn = coverage.loc[idx_vrba_only_tn, 'Coverage Percentage VRBA']
    

    print(f"VORI Detected Without VRBA (TP): {idx_vori_only_tp.sum()} | Mean VORI RSAM Coverage: {vori_rsam_for_vori_only_tp.mean():.2f}+-{vori_rsam_for_vori_only_tp.std():.2f}% | Mean VORI DSAR Coverage: {vori_dsar_for_vori_only_tp.mean():.2f}+-{vori_dsar_for_vori_only_tp.std():.2f}% | Mean VRBA Coverage: {vrba_for_vori_only_tp.mean():.2f}+-{vrba_for_vori_only_tp.std():.2f}%")
    print(f"VRBA Detected Without VORI (TP): {idx_vrba_only_tp.sum()} | Mean VORI RSAM Coverage: {vori_rsam_for_vrba_only_tp.mean():.2f}+-{vori_rsam_for_vrba_only_tp.std():.2f}% | Mean VORI DSAR Coverage: {vori_dsar_for_vrba_only_tp.mean():.2f}+-{vori_dsar_for_vrba_only_tp.std():.2f}% | Mean VRBA Coverage: {vrba_for_vrba_only_tp.mean():.2f}+-{vrba_for_vrba_only_tp.std():.2f}%")
    print(f"VORI Detected Without VRBA (TN): {idx_vori_only_tn.sum()} | Mean VORI RSAM Coverage: {vori_rsam_for_vori_only_tn.mean():.2f}+-{vori_rsam_for_vori_only_tn.std():.2f}% | Mean VORI DSAR Coverage: {vori_dsar_for_vori_only_tn.mean():.2f}+-{vori_dsar_for_vori_only_tn.std():.2f}% | Mean VRBA Coverage: {vrba_for_vori_only_tn.mean():.2f}+-{vrba_for_vori_only_tn.std():.2f}%")
    print(f"VRBA Detected Without VORI (TN): {idx_vrba_only_tn.sum()} | Mean VORI RSAM Coverage: {vori_rsam_for_vrba_only_tn.mean():.2f}+-{vori_rsam_for_vrba_only_tn.std():.2f}% | Mean VORI DSAR Coverage: {vori_dsar_for_vrba_only_tn.mean():.2f}+-{vori_dsar_for_vrba_only_tn.std():.2f}% | Mean VRBA Coverage: {vrba_for_vrba_only_tn.mean():.2f}+-{vrba_for_vrba_only_tn.std():.2f}%")
        
    if return_time:
        time_both_tp = time.values[idx_both_tp]
        time_both_tn = time.values[idx_both_tn]
        time_both_fn = time.values[idx_both_fn]
        time_both_fp = time.values[idx_both_fp]
        time_vori_only_tp = time.values[idx_vori_only_tp]
        time_vrba_only_tp = time.values[idx_vrba_only_tp]
        time_vori_only_tn = time.values[idx_vori_only_tn]
        time_vrba_only_tn = time.values[idx_vrba_only_tn]
        
        time_return = {
            'both_tp': time_both_tp,
            'both_tn': time_both_tn,
            'both_fn': time_both_fn,
            'both_fp': time_both_fp,
            'vori_only_tp': time_vori_only_tp,
            'vrba_only_tp': time_vrba_only_tp,
            'vori_only_tn': time_vori_only_tn,
            'vrba_only_tn': time_vrba_only_tn
        }

        coverage_return = {
            'both_tp': vori_rsam_for_both_tp,
            'both_tn': vori_rsam_for_both_tn,
            'both_fn': vori_rsam_for_both_fn,
            'both_fp': vori_rsam_for_both_fp,
            'vori_only_tp': vori_rsam_for_vori_only_tp,
            'vrba_only_tp': vori_rsam_for_vrba_only_tp,
            'vori_only_tn': vori_rsam_for_vori_only_tn,
            'vrba_only_tn': vori_rsam_for_vrba_only_tn
        }

        return time_return, coverage_return
    


def print_report_best_model_per_year_out_of_dataset(
        best_models_VORI, best_features_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI, 
        best_models_VRBA, best_features_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA, 
        train_test_years_splits, best_features=None, five_days=False, return_time = False,
        time_5days = time_5days_val, time = time_val, coverage = coverage_val, coverage_5days = coverage_5days_val
    ):

    features_classement = {}

    if return_time:
        time_analysis_results = {}
        coverage_analysis_results = {}

    
    for key in train_test_years_splits.keys():
        print(f"\n{'='*60}")
        not_tested_years = [y for y in train_test_years_splits.keys() if y != key]
        print(f" EVALUATION TRAIN Dataset {not_tested_years} without test year {key} ")

        # Group station configurations: (Name, Models, Features, X_train, X_val, y_train, y_val)
        configs = [
            ("VORI", best_models_VORI, best_features_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI),
            ("VRBA", best_models_VRBA, best_features_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA)
        ]

        y_pred_summary = {}
        features_classement[key] = {}

        for station, models, features_dict, x_train, x_val, y_train, y_val in configs:
            print(f"\n    STATION: {station}    ")
            
            y_true = y_val[key]['Type']
            
            # Model Preparation & Predictions 
            if best_features is not None:
                sel_features = features_dict[key] 
                
                # Clone and fit on the subset to prevent data leakage
                model = clone(models[key])
                model.fit(x_train[key][sel_features], y_train[key]['Type'])
                
                y_pred = model.predict(x_val[key][sel_features])
                current_columns = sel_features
            else:
                # Use the pre-trained model directly
                model = models[key]
                y_pred = model.predict(x_val[key])
                current_columns = x_val[key].columns

            y_pred_summary[station] = y_pred

            # Basic Metrics
            print("\n Confusion Matrix ")
            print(confusion_matrix(y_true, y_pred))
            
            print("\n Classification Report ")
            print(classification_report(y_true, y_pred, zero_division=0))
            
            # Feature Importance
            print(f"\n Top Features ({station}) ")
            # Map importances to the active feature set
            importances = pd.Series(model.feature_importances_, index=current_columns)
            features_classement[key][station] = importances.sort_values(ascending=False)
            print(features_classement[key][station].head(20))

            # Error & Magnitude Analysis 
            print_error_and_magnitude_analysis(key, y_val, y_true, y_pred, five_days=five_days, time_5days=time_5days, time=time)
            
            print("-" * 40)
    
        ### Summary of both stations
        if return_time:
            time_analysis_results[key], coverage_analysis_results[key] = print_truth_table_analysis(key, y_pred_summary, station, y_true, five_days=five_days, return_time=return_time, coverage=coverage, time=time, coverage_5days=coverage_5days, time_5days=time_5days)
        else:
            print_truth_table_analysis(key, y_pred_summary, station, y_true, five_days=five_days, coverage=coverage, time=time, coverage_5days=coverage_5days, time_5days=time_5days)
    
    if return_time:
        return coverage_analysis_results, time_analysis_results, features_classement

def print_error_and_magnitude_analysis(key, y_val, y_true, y_pred, five_days=False, time_5days = time_5days_val, time = time_val):
    # Error & Magnitude Analysis
    print(f"\n Error & Magnitude Analysis ")
            
    # Identify True Positives (TP) and False Negatives (FN)
    is_event = (y_true == 1)
    idx_tp = is_event & (y_pred == 1)
    idx_fn = is_event & (y_pred == 0)


    # Extract magnitudes for missed vs detected events
    mag_tp = y_val[key].loc[idx_tp, 'magnitude']
    mag_fn = y_val[key].loc[idx_fn, 'magnitude']

    print(f"Mean Magnitude (Detected - TP): {mag_tp.mean():.2f} ± {mag_tp.std():.2f}")
    print(f"Mean Magnitude (Missed - FN):   {mag_fn.mean():.2f} ± {mag_fn.std():.2f}")

    if mag_fn.mean() < mag_tp.mean():
        print("High magnitude events were more detected")
    else:
        print("Low magnitude events were more detected")

    
    # Isolate Lahar events
    is_lahars = (y_val[key]['Lahares'] == 1)
    idx_tp_lahars = idx_tp & is_lahars
    idx_fn_lahars = idx_fn & is_lahars

    # Extract magnitudes and time for missed vs detected Lahar events
    mag_tp_lahars = y_val[key].loc[idx_tp_lahars, 'magnitude']
    mag_fn_lahars = y_val[key].loc[idx_fn_lahars, 'magnitude']
    if five_days:
        time = time_5days[key]
    else:
        time = time[key]
    print(f' length of time array: {len(time)}')
    time_tp_lahars = time.values[idx_tp_lahars]
    time_fn_lahars = time.values[idx_fn_lahars]
    
    print(f"Detected Lahars (TP): {idx_tp_lahars.sum()} | Missed Lahars (FN): {idx_fn_lahars.sum()}")
    if idx_tp_lahars.sum() > 0:
        print(f"\n Detected Lahar Events (TP) - Magnitude and Time")
        for i,idx in enumerate(mag_tp_lahars.index):
            print(f"Detected Lahar Event - Magnitude: {y_val[key].loc[idx, 'magnitude']:.2f}, Time: {time_tp_lahars[i]}")
    if idx_fn_lahars.sum() > 0:
        print(f"\n Missed Lahar Events (FN) - Magnitude and Time")
        for i,idx in enumerate(mag_fn_lahars.index):
            print(f"Missed Lahar Event - Magnitude: {y_val[key].loc[idx, 'magnitude']:.2f}, Time: {time_fn_lahars[i]}")

# %%
# Result head windows for best model per year
print_report_best_model_per_year_out_of_dataset(
    best_models_VORI_train, None, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA_train, None, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits,
    best_features=None,  # Set to None to use the full feature set for evaluation
    time=time_val, coverage=coverage_val, time_5days=time_5days_val, coverage_5days=coverage_5days_val
)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 8  8]
#  [ 3 21]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        16
#            1       0.72      0.88      0.79        24
#
#     accuracy                           0.72        40
#    macro avg       0.73      0.69      0.69        40
# weighted avg       0.73      0.72      0.71        40
#
#
#  Top Features (VORI)
# Sum_LP                          0.052273
# Quantile Changes RSAM VORI      0.046619
# slope_ratio VORI                0.037030
# Max drop DSAR VORI              0.031075
# Mean Min Values RSAM VORI       0.029244
# Quantile Changes DSAR VORI      0.028574
# Max l Width DSAR VORI           0.025626
# Mean Min Values DSAR VORI       0.025040
# Sum_Precipitations              0.023493
# Max_LP                          0.022152
# Delta_Max_Min_Precipitations    0.022137
# Max drop RSAM VORI              0.020598
# Median Value DSAR VORI          0.020380
# Avg h Width DSAR VORI           0.019671
# Var Value RSAM VORI             0.019303
# Max peak DSAR VORI              0.018458
# Avg Value RSAM VORI             0.018347
# Max Drop Depth DSAR VORI        0.018303
# Avg l Width DSAR VORI           0.018094
# Avg Drop Depth DSAR VORI        0.017503
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.76 ± 0.90
# Mean Magnitude (Missed - FN):   3.82 ± 0.23
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 7  9]
#  [ 4 20]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.64      0.44      0.52        16
#            1       0.69      0.83      0.75        24
#
#     accuracy                           0.68        40
#    macro avg       0.66      0.64      0.64        40
# weighted avg       0.67      0.68      0.66        40
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.039112
# Mean Min Values RSAM VRBA     0.030633
# Sum_LP                        0.030145
# Avg Value DSAR VRBA           0.028656
# Max_LP                        0.027542
# Max peak DSAR VRBA            0.027427
# Std Value RSAM VRBA           0.026601
# Max l Width RSAM VRBA         0.026529
# Var Value RSAM VRBA           0.024169
# Sum_Precipitations            0.024162
# Std Value DSAR VRBA           0.022845
# Max Prominence RSAM VRBA      0.022553
# Delta_Max_Min_LP              0.021692
# Avg Value RSAM VRBA           0.021353
# Avg peak RSAM VRBA            0.021256
# Median Value DSAR VRBA        0.021251
# Median Value RSAM VRBA        0.020921
# Max l Width DSAR VRBA         0.020829
# Var Value DSAR VRBA           0.020526
# Max Drop Depth RSAM VRBA      0.020508
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.96 ± 0.97
# Mean Magnitude (Missed - FN):   2.54 ± 0.49
# High magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 17 | Mean VORI RSAM Coverage: 91.17±11.61% | Mean VORI DSAR Coverage: 98.69±3.63% | Mean VRBA Coverage: 73.09±23.14%
# Both Missed (FN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 99.88±0.07% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 78.24±21.01%
# Both True Negatives (TN): 4 | Mean VORI RSAM Coverage: 73.52±32.74% | Mean VORI DSAR Coverage: 73.95±33.18% | Mean VRBA Coverage: 69.51±24.42%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 49.98+-57.71% | Mean VORI DSAR Coverage: 49.98+-57.71% | Mean VRBA Coverage: 59.04+-18.34%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 88.72+-19.16% | Mean VORI DSAR Coverage: 88.83+-19.26% | Mean VRBA Coverage: 66.73+-5.70%
# VORI Detected Without VRBA (TN): 4 | Mean VORI RSAM Coverage: 89.53+-12.84% | Mean VORI DSAR Coverage: 93.37+-13.16% | Mean VRBA Coverage: 68.02+-22.27%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 66.59+-57.67% | Mean VORI DSAR Coverage: 73.20+-46.34% | Mean VRBA Coverage: 88.51+-19.95%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[13  8]
#  [ 7 15]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.65      0.62      0.63        21
#            1       0.65      0.68      0.67        22
#
#     accuracy                           0.65        43
#    macro avg       0.65      0.65      0.65        43
# weighted avg       0.65      0.65      0.65        43
#
#
#  Top Features (VORI)
# Max_tornillo                  0.031815
# Median Value DSAR VORI        0.031737
# Delta_Max_Min_tornillo        0.029437
# Avg Prominence RSAM VORI      0.027995
# Max l Width RSAM VORI         0.027280
# Sum_tornillo                  0.027178
# Var Value RSAM VORI           0.025685
# Avg drop DSAR VORI            0.025204
# Avg h Width RSAM VORI         0.024880
# Max Prominence RSAM VORI      0.024653
# Quantile Changes DSAR VORI    0.024281
# Avg l Width RSAM VORI         0.023972
# Sum_LP                        0.022295
# Sum_Precipitations            0.021722
# Mean Min Values DSAR VORI     0.021654
# Max h Width RSAM VORI         0.021031
# Quantile Changes RSAM VORI    0.020660
# Std Value RSAM VORI           0.020630
# slope_ratio VORI              0.019638
# Avg Value DSAR VORI           0.019590
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.31 ± 0.53
# Mean Magnitude (Missed - FN):   3.59 ± 0.84
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[14  7]
#  [ 6 16]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.67      0.68        21
#            1       0.70      0.73      0.71        22
#
#     accuracy                           0.70        43
#    macro avg       0.70      0.70      0.70        43
# weighted avg       0.70      0.70      0.70        43
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.068343
# Var Value DSAR VRBA           0.054277
# Std Value DSAR VRBA           0.043400
# slope_ratio VRBA              0.031966
# Quantile Changes DSAR VRBA    0.026367
# Avg Prominence RSAM VRBA      0.024923
# Avg peak DSAR VRBA            0.022623
# Sum_LP                        0.022536
# Max Drop Depth DSAR VRBA      0.022282
# Max Prominence RSAM VRBA      0.022078
# Std Value RSAM VRBA           0.021916
# Var Value RSAM VRBA           0.021712
# Max_tornillo                  0.021039
# Sum_tornillo                  0.020681
# Delta_Max_Min_tornillo        0.020498
# Avg Drop Depth DSAR VRBA      0.020162
# Median Value DSAR VRBA        0.020078
# Mean Min Values DSAR VRBA     0.019993
# Max Prominence DSAR VRBA      0.019792
# Sum_Precipitations            0.018797
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.67
# Mean Magnitude (Missed - FN):   3.18 ± 1.23
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 13 | Mean VORI RSAM Coverage: 86.93±27.65% | Mean VORI DSAR Coverage: 87.42±27.84% | Mean VRBA Coverage: 69.36±21.56%
# Both Missed (FN): 4 | Mean VORI RSAM Coverage: 96.75±5.91% | Mean VORI DSAR Coverage: 96.94±6.03% | Mean VRBA Coverage: 69.21±8.56%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 97.46±5.57% | Mean VORI DSAR Coverage: 97.47±5.57% | Mean VRBA Coverage: 50.10±16.71%
# Both True Negatives (TN): 11 | Mean VORI RSAM Coverage: 97.75±7.28% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 94.46±12.40%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 98.93+-1.44% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 72.19+-4.31%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 94.40+-9.62% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 31.96+-29.12%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 82.59+-24.56% | Mean VORI DSAR Coverage: 82.59+-24.56% | Mean VRBA Coverage: 62.17+-8.84%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 99.09+-1.50% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 82.97+-15.54%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 7  9]
#  [ 5 18]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.58      0.44      0.50        16
#            1       0.67      0.78      0.72        23
#
#     accuracy                           0.64        39
#    macro avg       0.62      0.61      0.61        39
# weighted avg       0.63      0.64      0.63        39
#
#
#  Top Features (VORI)
# Quantile Changes RSAM VORI         0.062054
# Avg drop DSAR VORI                 0.038014
# Mean Min Values DSAR VORI          0.037439
# Max peak DSAR VORI                 0.036766
# Max drop DSAR VORI                 0.036122
# slope_ratio VORI                   0.033770
# Median Value DSAR VORI             0.028239
# Avg Prominence RSAM VORI           0.027292
# Max drop RSAM VORI                 0.025709
# Sum_tornillo                       0.024995
# Avg Value RSAM VORI                0.024735
# Max Prominence RSAM VORI           0.023083
# Avg l Width RSAM VORI              0.022271
# Avg drop RSAM VORI                 0.021772
# Last_tornillo                      0.020485
# num_state_changes_inv_rsam VORI    0.020118
# Avg peak DSAR VORI                 0.019271
# Std Value RSAM VORI                0.019196
# Median Value RSAM VORI             0.016726
# Sum_VT                             0.016595
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.70 ± 0.82
# Mean Magnitude (Missed - FN):   2.76 ± 0.62
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[10  6]
#  [ 5 18]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.62      0.65        16
#            1       0.75      0.78      0.77        23
#
#     accuracy                           0.72        39
#    macro avg       0.71      0.70      0.71        39
# weighted avg       0.72      0.72      0.72        39
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.053522
# Median Value DSAR VRBA        0.037588
# Avg Value DSAR VRBA           0.033844
# Avg peak DSAR VRBA            0.030044
# Mean Min Values RSAM VRBA     0.029108
# Std Value RSAM VRBA           0.026339
# Max peak DSAR VRBA            0.026034
# Quantile Changes DSAR VRBA    0.023845
# Var Value DSAR VRBA           0.023693
# Median Value RSAM VRBA        0.023029
# Std Value DSAR VRBA           0.022664
# Avg drop RSAM VRBA            0.022314
# Max drop RSAM VRBA            0.022000
# Avg Prominence RSAM VRBA      0.020985
# Max drop DSAR VRBA            0.020803
# Avg l Width RSAM VRBA         0.020321
# Mean Min Values DSAR VRBA     0.020134
# Sum_tornillo                  0.019659
# Max l Width RSAM VRBA         0.019644
# Max Prominence DSAR VRBA      0.019372
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.61 ± 0.79
# Mean Magnitude (Missed - FN):   3.08 ± 0.59
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 15 | Mean VORI RSAM Coverage: 86.26±35.04% | Mean VORI DSAR Coverage: 86.36±35.08% | Mean VRBA Coverage: 62.69±28.28%
# Both Missed (FN): 2 | Mean VORI RSAM Coverage: 90.11±13.92% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 79.05±29.56%
# Both False Positives (FP): 6 | Mean VORI RSAM Coverage: 93.89±14.06% | Mean VORI DSAR Coverage: 94.16±14.18% | Mean VRBA Coverage: 62.61±25.52%
# Both True Negatives (TN): 7 | Mean VORI RSAM Coverage: 99.95±0.00% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 88.68±16.35%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 99.92+-0.05% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.57+-32.71%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 53.57+-6.66%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 99.74+-0.35% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 89.79+-17.60%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 8 14]
#  [ 9 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.47      0.36      0.41        22
#            1       0.44      0.55      0.49        20
#
#     accuracy                           0.45        42
#    macro avg       0.46      0.46      0.45        42
# weighted avg       0.46      0.45      0.45        42
#
#
#  Top Features (VORI)
# Quantile Changes RSAM VORI         0.102434
# Max peak DSAR VORI                 0.092480
# Var Value RSAM VORI                0.067093
# Std Value RSAM VORI                0.066051
# Last_tornillo                      0.055292
# Sum_VT                             0.047297
# Max Prominence RSAM VORI           0.040019
# is_raising_tornillo                0.033871
# Avg l Width RSAM VORI              0.026774
# Sum_LP                             0.026490
# Avg Drop Depth RSAM VORI           0.026420
# Avg peak DSAR VORI                 0.024026
# num_state_changes_log_dsar VORI    0.023194
# Avg Prominence DSAR VORI           0.022659
# Max l Width RSAM VORI              0.022339
# Max drop RSAM VORI                 0.021629
# Avg Drop Depth DSAR VORI           0.019656
# num_state_changes_inv_rsam VORI    0.017463
# Sum_tornillo                       0.017364
# Median Value RSAM VORI             0.017357
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.95 ± 0.78
# Mean Magnitude (Missed - FN):   3.24 ± 1.29
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[10 12]
#  [ 8 12]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.56      0.45      0.50        22
#            1       0.50      0.60      0.55        20
#
#     accuracy                           0.52        42
#    macro avg       0.53      0.53      0.52        42
# weighted avg       0.53      0.52      0.52        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.058862
# Avg peak DSAR VRBA            0.050143
# Max peak DSAR VRBA            0.041018
# Var Value DSAR VRBA           0.038647
# Var Value RSAM VRBA           0.033508
# Quantile Changes DSAR VRBA    0.032810
# Std Value DSAR VRBA           0.030522
# Std Value RSAM VRBA           0.027774
# Max h Width DSAR VRBA         0.026776
# Max l Width RSAM VRBA         0.026559
# Median Value DSAR VRBA        0.025806
# Avg Value DSAR VRBA           0.023761
# Avg Value RSAM VRBA           0.023506
# Max drop DSAR VRBA            0.022553
# Avg Prominence RSAM VRBA      0.022317
# Avg h Width DSAR VRBA         0.020912
# Sum_Precipitations            0.019935
# Max_LP                        0.019576
# Mean Min Values DSAR VRBA     0.019264
# Avg Prominence DSAR VRBA      0.018493
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.11 ± 0.80
# Mean Magnitude (Missed - FN):   3.04 ± 1.36
# High magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 8 | Mean VORI RSAM Coverage: 80.76±34.33% | Mean VORI DSAR Coverage: 80.90±34.41% | Mean VRBA Coverage: 59.07±32.30%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 94.49±8.60% | Mean VORI DSAR Coverage: 99.95±0.01% | Mean VRBA Coverage: 72.48±43.10%
# Both False Positives (FP): 9 | Mean VORI RSAM Coverage: 84.85±33.81% | Mean VORI DSAR Coverage: 87.18±27.80% | Mean VRBA Coverage: 74.31±29.10%
# Both True Negatives (TN): 5 | Mean VORI RSAM Coverage: 99.64±0.71% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 86.23±15.66%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 93.38+-11.30% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 76.34+-20.46%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 95.91+-7.80% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.00+-30.92%
# VORI Detected Without VRBA (TN): 3 | Mean VORI RSAM Coverage: 98.83+-1.81% | Mean VORI DSAR Coverage: 98.88+-1.86% | Mean VRBA Coverage: 51.02+-50.04%
# VRBA Detected Without VORI (TN): 5 | Mean VORI RSAM Coverage: 99.25+-1.10% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 69.74+-17.14%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[12 10]
#  [11 12]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.52      0.55      0.53        22
#            1       0.55      0.52      0.53        23
#
#     accuracy                           0.53        45
#    macro avg       0.53      0.53      0.53        45
# weighted avg       0.53      0.53      0.53        45
#
#
#  Top Features (VORI)
# Max l Width RSAM VORI         0.108774
# Mean Min Values DSAR VORI     0.067445
# Avg h Width DSAR VORI         0.062630
# Quantile Changes RSAM VORI    0.056237
# Avg drop RSAM VORI            0.051914
# Max drop DSAR VORI            0.048356
# slope_ratio VORI              0.046407
# Std Value RSAM VORI           0.045024
# Max Drop Depth DSAR VORI      0.040363
# Avg drop DSAR VORI            0.038406
# Avg Prominence DSAR VORI      0.034925
# Avg Drop Depth DSAR VORI      0.032164
# Max l Width DSAR VORI         0.027952
# is_pressurizing VORI          0.023720
# Max h Width DSAR VORI         0.020843
# Avg Drop Depth RSAM VORI      0.020840
# Median Value RSAM VORI        0.020595
# Avg Value RSAM VORI           0.020253
# Max_Precipitations            0.018180
# Delta_Max_Min_tornillo        0.016263
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.92 ± 1.04
# Mean Magnitude (Missed - FN):   2.64 ± 0.85
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[15  7]
#  [14  9]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.52      0.68      0.59        22
#            1       0.56      0.39      0.46        23
#
#     accuracy                           0.53        45
#    macro avg       0.54      0.54      0.52        45
# weighted avg       0.54      0.53      0.52        45
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.243982
# Mean Min Values RSAM VRBA       0.147453
# Var Value DSAR VRBA             0.099884
# Std Value DSAR VRBA             0.091059
# Avg Drop Depth DSAR VRBA        0.060815
# Avg Value RSAM VRBA             0.041726
# Max Drop Depth DSAR VRBA        0.028646
# Max peak RSAM VRBA              0.026633
# Mean Min Values DSAR VRBA       0.023554
# Avg peak RSAM VRBA              0.022740
# Median Value DSAR VRBA          0.015023
# Std Value RSAM VRBA             0.014715
# Max peak DSAR VRBA              0.014013
# Delta_Max_Min_Precipitations    0.013750
# Avg peak DSAR VRBA              0.013370
# Sum_Precipitations              0.012726
# Avg Value DSAR VRBA             0.011323
# Var Value RSAM VRBA             0.009776
# Avg l Width RSAM VRBA           0.009136
# Max l Width RSAM VRBA           0.007985
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.93 ± 1.03
# Mean Magnitude (Missed - FN):   2.69 ± 0.91
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 5 | Mean VORI RSAM Coverage: 99.90±0.05% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 67.62±31.66%
# Both Missed (FN): 7 | Mean VORI RSAM Coverage: 97.13±7.44% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 83.00±20.02%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.95±0.00% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 48.66±25.23%
# Both True Negatives (TN): 8 | Mean VORI RSAM Coverage: 99.61±0.91% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 87.46±26.57%
# VORI Detected Without VRBA (TP): 7 | Mean VORI RSAM Coverage: 82.03+-37.39% | Mean VORI DSAR Coverage: 82.04+-37.39% | Mean VRBA Coverage: 62.89+-31.09%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 96.02+-7.87% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 42.57+-14.71%
# VORI Detected Without VRBA (TN): 4 | Mean VORI RSAM Coverage: 99.89+-0.06% | Mean VORI DSAR Coverage: 99.96+-0.01% | Mean VRBA Coverage: 68.58+-21.07%
# VRBA Detected Without VORI (TN): 7 | Mean VORI RSAM Coverage: 70.65+-41.08% | Mean VORI DSAR Coverage: 75.42+-33.47% | Mean VRBA Coverage: 84.88+-37.49%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[10 12]
#  [10 10]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.45      0.48        22
#            1       0.45      0.50      0.48        20
#
#     accuracy                           0.48        42
#    macro avg       0.48      0.48      0.48        42
# weighted avg       0.48      0.48      0.48        42
#
#
#  Top Features (VORI)
# Var Value RSAM VORI             0.054534
# Delta_Max_Min_Precipitations    0.049222
# Quantile Changes RSAM VORI      0.047714
# Max_Precipitations              0.044924
# Std Value RSAM VORI             0.038182
# Max drop RSAM VORI              0.037739
# Max l Width RSAM VORI           0.033365
# Sum_Precipitations              0.033280
# Mean Min Values RSAM VORI       0.029823
# Max h Width DSAR VORI           0.028865
# Last_Precipitations             0.028676
# Avg h Width RSAM VORI           0.025863
# Max Prominence RSAM VORI        0.024191
# Avg Drop Depth RSAM VORI        0.023719
# Avg Prominence RSAM VORI        0.021145
# Std Value DSAR VORI             0.020233
# Max h Width RSAM VORI           0.020001
# Max Drop Depth RSAM VORI        0.019591
# Avg l Width RSAM VORI           0.019562
# Max Drop Depth DSAR VORI        0.018772
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.36 ± 0.46
# Mean Magnitude (Missed - FN):   2.80 ± 0.59
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[16  6]
#  [10 10]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67        22
#            1       0.62      0.50      0.56        20
#
#     accuracy                           0.62        42
#    macro avg       0.62      0.61      0.61        42
# weighted avg       0.62      0.62      0.61        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.056966
# Max_Precipitations              0.044481
# Max peak DSAR VRBA              0.042892
# Avg l Width DSAR VRBA           0.041724
# Delta_Max_Min_Precipitations    0.039772
# Std Value RSAM VRBA             0.031906
# Avg Prominence RSAM VRBA        0.031382
# Median Value DSAR VRBA          0.030984
# Avg peak DSAR VRBA              0.030877
# Std Value DSAR VRBA             0.029720
# Mean Min Values RSAM VRBA       0.028563
# Last_Precipitations             0.028504
# slope_ratio VRBA                0.027551
# Avg Value DSAR VRBA             0.023949
# Median Value RSAM VRBA          0.023187
# Sum_Precipitations              0.022251
# Avg Value RSAM VRBA             0.021299
# Avg Drop Depth DSAR VRBA        0.019207
# Var Value RSAM VRBA             0.018987
# Max drop DSAR VRBA              0.018661
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.35 ± 0.48
# Mean Magnitude (Missed - FN):   2.81 ± 0.57
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 8 | Mean VORI RSAM Coverage: 99.84±0.17% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 71.06±20.93%
# Both Missed (FN): 8 | Mean VORI RSAM Coverage: 88.64±24.97% | Mean VORI DSAR Coverage: 91.68±23.41% | Mean VRBA Coverage: 67.88±37.71%
# Both False Positives (FP): 6 | Mean VORI RSAM Coverage: 94.10±13.85% | Mean VORI DSAR Coverage: 94.39±13.62% | Mean VRBA Coverage: 79.87±26.33%
# Both True Negatives (TN): 10 | Mean VORI RSAM Coverage: 99.64±0.62% | Mean VORI DSAR Coverage: 99.96±0.01% | Mean VRBA Coverage: 66.20±20.33%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 90.10+-13.80% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 81.92+-25.51%
# VRBA Detected Without VORI (TP): 2 | Mean VORI RSAM Coverage: 60.61+-55.64% | Mean VORI DSAR Coverage: 72.51+-38.81% | Mean VRBA Coverage: 77.39+-24.79%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 6 | Mean VORI RSAM Coverage: 99.86+-0.21% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 82.01+-16.45%

# %%
# Result windows for best model per year
print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI_train, None, x_train_5_VORI, x_val_5_VORI, y_train_5_VORI, y_val_5_VORI,
    best_5days_models_VRBA_train, None, x_train_5_VRBA, x_val_5_VRBA, y_train_5_VRBA, y_val_5_VRBA,
    train_test_years_splits,
    best_features=None , # Set to None to use the full feature set for evaluation
    five_days=True,
    time=time_val, coverage=coverage_val, time_5days=time_5days_val, coverage_5days=coverage_5days_val

)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[65 74]
#  [42 43]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      0.47      0.53       139
#            1       0.37      0.51      0.43        85
#
#     accuracy                           0.48       224
#    macro avg       0.49      0.49      0.48       224
# weighted avg       0.52      0.48      0.49       224
#
#
#  Top Features (VORI)
# Sum_LP                          0.124930
# Max_LP                          0.075099
# Delta_Max_Min_LP                0.064100
# Delta_Max_Min_tornillo          0.041511
# Max_tornillo                    0.039233
# Mean Min Values DSAR VORI       0.033437
# Last_LP                         0.032485
# Sum_tornillo                    0.028481
# Quantile Changes RSAM VORI      0.027434
# Avg drop DSAR VORI              0.023451
# Max drop DSAR VORI              0.022079
# Mean Min Values RSAM VORI       0.021273
# Sum_Precipitations              0.021137
# Max_Precipitations              0.019150
# Median Value DSAR VORI          0.018523
# season                          0.017497
# Delta_Max_Min_Precipitations    0.017062
# Median Value RSAM VORI          0.016961
# Max peak RSAM VORI              0.016949
# Max drop RSAM VORI              0.015926
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.36 ± 0.79
# Mean Magnitude (Missed - FN):   3.54 ± 0.68
# Low magnitude events were more detected
#  length of time array: 224
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[62 77]
#  [41 44]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.60      0.45      0.51       139
#            1       0.36      0.52      0.43        85
#
#     accuracy                           0.47       224
#    macro avg       0.48      0.48      0.47       224
# weighted avg       0.51      0.47      0.48       224
#
#
#  Top Features (VRBA)
# Sum_LP                          0.375312
# Quantile Changes RSAM VRBA      0.098192
# Max_LP                          0.054075
# Delta_Max_Min_tornillo          0.047189
# Sum_VT                          0.037754
# Max_tornillo                    0.035825
# Var Value DSAR VRBA             0.030741
# Last_LP                         0.029012
# Std Value RSAM VRBA             0.020648
# Mean Min Values RSAM VRBA       0.020252
# Avg Value DSAR VRBA             0.018874
# Quantile Changes DSAR VRBA      0.016905
# Std Value DSAR VRBA             0.012926
# Sum_Precipitations              0.012849
# Var Value RSAM VRBA             0.011721
# Avg Value RSAM VRBA             0.011526
# Median Value DSAR VRBA          0.010590
# Delta_Max_Min_Precipitations    0.009708
# Mean Min Values DSAR VRBA       0.009536
# Max peak RSAM VRBA              0.009316
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.30 ± 0.79
# Mean Magnitude (Missed - FN):   3.60 ± 0.65
# Low magnitude events were more detected
#  length of time array: 224
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 35 | Mean VORI RSAM Coverage: 95.89±6.92% | Mean VORI DSAR Coverage: 98.65±4.54% | Mean VRBA Coverage: 80.79±22.32%
# Both Missed (FN): 33 | Mean VORI RSAM Coverage: 91.50±12.60% | Mean VORI DSAR Coverage: 94.74±12.98% | Mean VRBA Coverage: 86.46±20.62%
# Both False Positives (FP): 69 | Mean VORI RSAM Coverage: 99.89±0.45% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 48.22±29.94%
# Both True Negatives (TN): 57 | Mean VORI RSAM Coverage: 99.72±0.28% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 86.70±18.65%
# VORI Detected Without VRBA (TP): 8 | Mean VORI RSAM Coverage: 91.22+-12.07% | Mean VORI DSAR Coverage: 97.44+-7.07% | Mean VRBA Coverage: 84.69+-20.94%
# VRBA Detected Without VORI (TP): 9 | Mean VORI RSAM Coverage: 87.79+-32.99% | Mean VORI DSAR Coverage: 88.84+-33.31% | Mean VRBA Coverage: 83.77+-20.41%
# VORI Detected Without VRBA (TN): 8 | Mean VORI RSAM Coverage: 99.80+-0.32% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 55.83+-27.16%
# VRBA Detected Without VORI (TN): 5 | Mean VORI RSAM Coverage: 95.83+-0.75% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 100.00+-0.00%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[80 23]
#  [10 34]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83       103
#            1       0.60      0.77      0.67        44
#
#     accuracy                           0.78       147
#    macro avg       0.74      0.77      0.75       147
# weighted avg       0.80      0.78      0.78       147
#
#
#  Top Features (VORI)
# Sum_LP                        0.069590
# Mean Min Values DSAR VORI     0.042592
# Max_LP                        0.040517
# Median Value DSAR VORI        0.040076
# Max drop DSAR VORI            0.038768
# Avg drop DSAR VORI            0.035988
# Max_tornillo                  0.034454
# Delta_Max_Min_tornillo        0.032162
# Avg peak DSAR VORI            0.031558
# Max peak DSAR VORI            0.030677
# Delta_Max_Min_LP              0.030259
# Quantile Changes RSAM VORI    0.027572
# Var Value RSAM VORI           0.025382
# Max peak RSAM VORI            0.023812
# Sum_tornillo                  0.023062
# Std Value RSAM VORI           0.020940
# Avg peak RSAM VORI            0.020900
# Mean Min Values RSAM VORI     0.020235
# Avg Value RSAM VORI           0.019652
# Last_LP                       0.019576
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.88 ± 0.82
# Mean Magnitude (Missed - FN):   3.57 ± 1.08
# Low magnitude events were more detected
#  length of time array: 147
# Detected Lahars (TP): 1 | Missed Lahars (FN): 3
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[92 11]
#  [17 27]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87       103
#            1       0.71      0.61      0.66        44
#
#     accuracy                           0.81       147
#    macro avg       0.78      0.75      0.76       147
# weighted avg       0.80      0.81      0.81       147
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.120814
# Var Value DSAR VRBA           0.098081
# Max_LP                        0.091138
# Avg Value DSAR VRBA           0.068098
# Sum_LP                        0.065437
# Avg peak DSAR VRBA            0.043076
# Avg Drop Depth DSAR VRBA      0.041623
# Std Value DSAR VRBA           0.040680
# Quantile Changes DSAR VRBA    0.032234
# Max drop DSAR VRBA            0.030438
# Var Value RSAM VRBA           0.026175
# Delta_Max_Min_LP              0.025841
# Mean Min Values RSAM VRBA     0.023559
# Last_LP                       0.023071
# Avg drop RSAM VRBA            0.022671
# Mean Min Values DSAR VRBA     0.020076
# Median Value DSAR VRBA        0.018877
# Std Value RSAM VRBA           0.014216
# Max peak DSAR VRBA            0.012466
# Avg drop DSAR VRBA            0.012060
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.72 ± 0.73
# Mean Magnitude (Missed - FN):   3.54 ± 0.99
# Low magnitude events were more detected
#  length of time array: 147
# Detected Lahars (TP): 1 | Missed Lahars (FN): 3
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 26 | Mean VORI RSAM Coverage: 95.08±5.78% | Mean VORI DSAR Coverage: 95.09±5.79% | Mean VRBA Coverage: 62.72±8.65%
# Both Missed (FN): 9 | Mean VORI RSAM Coverage: 84.45±23.64% | Mean VORI DSAR Coverage: 85.03±23.24% | Mean VRBA Coverage: 53.72±30.99%
# Both False Positives (FP): 11 | Mean VORI RSAM Coverage: 94.29±2.80% | Mean VORI DSAR Coverage: 94.32±2.81% | Mean VRBA Coverage: 54.96±1.49%
# Both True Negatives (TN): 80 | Mean VORI RSAM Coverage: 99.35±1.72% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 90.19±15.41%
# VORI Detected Without VRBA (TP): 8 | Mean VORI RSAM Coverage: 99.91+-0.06% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 64.24+-5.61%
# VRBA Detected Without VORI (TP): 1 | Mean VORI RSAM Coverage: 80.77+-nan% | Mean VORI DSAR Coverage: 80.77+-nan% | Mean VRBA Coverage: 69.05+-nan%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 12 | Mean VORI RSAM Coverage: 87.73+-16.24% | Mean VORI DSAR Coverage: 99.00+-3.29% | Mean VRBA Coverage: 91.60+-15.89%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[116  56]
#  [ 26 144]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.74       172
#            1       0.72      0.85      0.78       170
#
#     accuracy                           0.76       342
#    macro avg       0.77      0.76      0.76       342
# weighted avg       0.77      0.76      0.76       342
#
#
#  Top Features (VORI)
# Mean Min Values DSAR VORI     0.070739
# Max drop DSAR VORI            0.057904
# Avg drop DSAR VORI            0.054353
# Median Value DSAR VORI        0.044119
# Avg peak DSAR VORI            0.038814
# Max peak DSAR VORI            0.036130
# Std Value DSAR VORI           0.030747
# Var Value DSAR VORI           0.030724
# Delta_Max_Min_tornillo        0.028256
# Max_tornillo                  0.027999
# Sum_LP                        0.024301
# Quantile Changes DSAR VORI    0.023550
# Max_LP                        0.022910
# Avg Prominence RSAM VORI      0.022247
# Quantile Changes RSAM VORI    0.022060
# Sum_VT                        0.021357
# Max peak RSAM VORI            0.019485
# Max_Precipitations            0.019413
# Max Prominence RSAM VORI      0.018281
# Var Value RSAM VORI           0.017425
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.61 ± 0.56
# Mean Magnitude (Missed - FN):   3.12 ± 0.53
# Low magnitude events were more detected
#  length of time array: 342
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 90  82]
#  [ 17 153]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.52      0.65       172
#            1       0.65      0.90      0.76       170
#
#     accuracy                           0.71       342
#    macro avg       0.75      0.71      0.70       342
# weighted avg       0.75      0.71      0.70       342
#
#
#  Top Features (VRBA)
# Avg peak DSAR VRBA            0.147926
# Max peak DSAR VRBA            0.090794
# Median Value DSAR VRBA        0.090592
# Avg Value DSAR VRBA           0.079966
# Mean Min Values RSAM VRBA     0.069073
# Std peak RSAM VRBA            0.038120
# Quantile Changes RSAM VRBA    0.029808
# Quantile Changes DSAR VRBA    0.029175
# Max_LP                        0.021714
# Delta_Max_Min_LP              0.020918
# Std Value DSAR VRBA           0.019604
# Sum_VT                        0.018887
# Sum_tornillo                  0.017112
# Var Value DSAR VRBA           0.016922
# Sum_LP                        0.016813
# Max drop RSAM VRBA            0.015484
# Avg Drop Depth DSAR VRBA      0.015377
# Avg Value RSAM VRBA           0.014568
# Std Prominence RSAM VRBA      0.013777
# Delta_Max_Min_tornillo        0.013060
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.67 ± 0.58
# Mean Magnitude (Missed - FN):   2.87 ± 0.57
# Low magnitude events were more detected
#  length of time array: 342
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 133 | Mean VORI RSAM Coverage: 96.71±7.01% | Mean VORI DSAR Coverage: 99.16±4.75% | Mean VRBA Coverage: 65.80±20.98%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 99.85±0.04% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 98.80±0.24%
# Both False Positives (FP): 55 | Mean VORI RSAM Coverage: 99.22±3.03% | Mean VORI DSAR Coverage: 99.30±2.94% | Mean VRBA Coverage: 57.16±41.27%
# Both True Negatives (TN): 89 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 88.52±15.71%
# VORI Detected Without VRBA (TP): 11 | Mean VORI RSAM Coverage: 95.45+-5.22% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 86.43+-20.96%
# VRBA Detected Without VORI (TP): 20 | Mean VORI RSAM Coverage: 99.86+-0.03% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 90.38+-24.97%
# VORI Detected Without VRBA (TN): 27 | Mean VORI RSAM Coverage: 99.92+-0.03% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 74.81+-24.35%
# VRBA Detected Without VORI (TN): 1 | Mean VORI RSAM Coverage: 99.94+-nan% | Mean VORI DSAR Coverage: 99.94+-nan% | Mean VRBA Coverage: 99.90+-nan%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[86 13]
#  [36 25]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.87      0.78        99
#            1       0.66      0.41      0.51        61
#
#     accuracy                           0.69       160
#    macro avg       0.68      0.64      0.64       160
# weighted avg       0.69      0.69      0.67       160
#
#
#  Top Features (VORI)
# Sum_LP                        0.062219
# Mean Min Values DSAR VORI     0.057154
# Max drop DSAR VORI            0.049000
# Median Value DSAR VORI        0.048070
# Max_LP                        0.040965
# Avg peak DSAR VORI            0.040567
# Quantile Changes RSAM VORI    0.038606
# Delta_Max_Min_LP              0.038325
# Max peak DSAR VORI            0.036152
# Avg drop DSAR VORI            0.034132
# Last_LP                       0.030140
# Var Value RSAM VORI           0.029642
# Std Value DSAR VORI           0.029333
# Avg Value RSAM VORI           0.024573
# Var Value DSAR VORI           0.021736
# Median Value RSAM VORI        0.021636
# Max_Precipitations            0.021270
# Max peak RSAM VORI            0.021204
# Std Value RSAM VORI           0.021025
# Avg Value DSAR VORI           0.020490
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.45 ± 0.57
# Mean Magnitude (Missed - FN):   2.91 ± 0.76
# Low magnitude events were more detected
#  length of time array: 160
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[83 16]
#  [32 29]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.72      0.84      0.78        99
#            1       0.64      0.48      0.55        61
#
#     accuracy                           0.70       160
#    macro avg       0.68      0.66      0.66       160
# weighted avg       0.69      0.70      0.69       160
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.251751
# Sum_LP                        0.129189
# Quantile Changes DSAR VRBA    0.069722
# Quantile Changes RSAM VRBA    0.061990
# Var Value DSAR VRBA           0.050146
# Std Value DSAR VRBA           0.037124
# Mean Min Values DSAR VRBA     0.033818
# Delta_Max_Min_LP              0.031365
# Median Value RSAM VRBA        0.028926
# Sum_VT                        0.025624
# Avg drop RSAM VRBA            0.025408
# Mean Min Values RSAM VRBA     0.023805
# Sum_Precipitations            0.019417
# Avg Drop Depth DSAR VRBA      0.016045
# Max_LP                        0.015764
# Max drop RSAM VRBA            0.013108
# Avg Value DSAR VRBA           0.010763
# Sum_tornillo                  0.009318
# Max Drop Depth RSAM VRBA      0.009154
# Avg drop DSAR VRBA            0.008117
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.70 ± 0.61
# Mean Magnitude (Missed - FN):   2.74 ± 0.81
# Low magnitude events were more detected
#  length of time array: 160
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 12 | Mean VORI RSAM Coverage: 85.34±16.27% | Mean VORI DSAR Coverage: 87.12±17.47% | Mean VRBA Coverage: 80.51±20.70%
# Both Missed (FN): 19 | Mean VORI RSAM Coverage: 96.41±9.13% | Mean VORI DSAR Coverage: 97.32±8.18% | Mean VRBA Coverage: 84.54±17.51%
# Both False Positives (FP): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both True Negatives (TN): 70 | Mean VORI RSAM Coverage: 92.36±19.25% | Mean VORI DSAR Coverage: 94.11±16.02% | Mean VRBA Coverage: 95.57±9.53%
# VORI Detected Without VRBA (TP): 13 | Mean VORI RSAM Coverage: 95.05+-5.73% | Mean VORI DSAR Coverage: 98.19+-4.76% | Mean VRBA Coverage: 88.68+-19.41%
# VRBA Detected Without VORI (TP): 17 | Mean VORI RSAM Coverage: 93.99+-24.22% | Mean VORI DSAR Coverage: 94.07+-24.24% | Mean VRBA Coverage: 95.93+-10.81%
# VORI Detected Without VRBA (TN): 16 | Mean VORI RSAM Coverage: 62.82+-28.82% | Mean VORI DSAR Coverage: 62.90+-28.93% | Mean VRBA Coverage: 66.57+-23.55%
# VRBA Detected Without VORI (TN): 13 | Mean VORI RSAM Coverage: 39.06+-48.83% | Mean VORI DSAR Coverage: 40.89+-49.35% | Mean VRBA Coverage: 99.99+-0.03%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[42 14]
#  [19 33]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72        56
#            1       0.70      0.63      0.67        52
#
#     accuracy                           0.69       108
#    macro avg       0.70      0.69      0.69       108
# weighted avg       0.70      0.69      0.69       108
#
#
#  Top Features (VORI)
# Max_Precipitations              0.067116
# Delta_Max_Min_Precipitations    0.043875
# Sum_Precipitations              0.042938
# Max_tornillo                    0.037701
# Delta_Max_Min_tornillo          0.037291
# Quantile Changes RSAM VORI      0.035040
# Sum_tornillo                    0.034870
# Sum_LP                          0.034147
# Mean Min Values RSAM VORI       0.026453
# Mean Min Values DSAR VORI       0.021639
# Max_LP                          0.020909
# Delta_Max_Min_LP                0.020461
# Max drop DSAR VORI              0.019448
# Quantile Changes DSAR VORI      0.018640
# Avg Value DSAR VORI             0.018074
# Median Value RSAM VORI          0.017554
# Avg drop DSAR VORI              0.016805
# Avg drop RSAM VORI              0.016286
# Max peak RSAM VORI              0.015893
# Std drop RSAM VORI              0.015869
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.78 ± 0.96
# Mean Magnitude (Missed - FN):   3.16 ± 1.00
# Low magnitude events were more detected
#  length of time array: 108
# Detected Lahars (TP): 1 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000000000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132000000
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682000000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[42 14]
#  [24 28]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69        56
#            1       0.67      0.54      0.60        52
#
#     accuracy                           0.65       108
#    macro avg       0.65      0.64      0.64       108
# weighted avg       0.65      0.65      0.64       108
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.167572
# Quantile Changes RSAM VRBA    0.111700
# Quantile Changes DSAR VRBA    0.087640
# Mean Min Values DSAR VRBA     0.059924
# season                        0.056745
# Mean Min Values RSAM VRBA     0.056688
# Max_Precipitations            0.050225
# Avg peak DSAR VRBA            0.042629
# Delta_Max_Min_LP              0.031706
# Avg Value DSAR VRBA           0.031509
# Max drop RSAM VRBA            0.024810
# Avg drop DSAR VRBA            0.021997
# Sum_Precipitations            0.020151
# Sum_LP                        0.017621
# Avg peak RSAM VRBA            0.013187
# Avg drop RSAM VRBA            0.012095
# Delta_Max_Min_VT              0.010627
# Max peak RSAM VRBA            0.010037
# Sum_tornillo                  0.009633
# Avg Value RSAM VRBA           0.008681
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.77 ± 0.94
# Mean Magnitude (Missed - FN):   3.09 ± 1.03
# Low magnitude events were more detected
#  length of time array: 108
# Detected Lahars (TP): 1 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000000000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132000000
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682000000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 24 | Mean VORI RSAM Coverage: 37.52±45.54% | Mean VORI DSAR Coverage: 41.61±49.14% | Mean VRBA Coverage: 48.91±16.54%
# Both Missed (FN): 15 | Mean VORI RSAM Coverage: 90.19±19.38% | Mean VORI DSAR Coverage: 90.51±18.97% | Mean VRBA Coverage: 60.42±30.13%
# Both False Positives (FP): 7 | Mean VORI RSAM Coverage: 94.45±8.99% | Mean VORI DSAR Coverage: 94.65±9.12% | Mean VRBA Coverage: 60.51±2.79%
# Both True Negatives (TN): 35 | Mean VORI RSAM Coverage: 93.14±12.06% | Mean VORI DSAR Coverage: 96.13±10.90% | Mean VRBA Coverage: 62.27±14.37%
# VORI Detected Without VRBA (TP): 9 | Mean VORI RSAM Coverage: 84.41+-27.87% | Mean VORI DSAR Coverage: 85.37+-27.59% | Mean VRBA Coverage: 53.64+-22.47%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 84.55+-30.79% | Mean VORI DSAR Coverage: 94.94+-10.00% | Mean VRBA Coverage: 45.81+-21.85%
# VORI Detected Without VRBA (TN): 7 | Mean VORI RSAM Coverage: 96.53+-5.88% | Mean VORI DSAR Coverage: 97.74+-5.82% | Mean VRBA Coverage: 63.19+-6.56%
# VRBA Detected Without VORI (TN): 7 | Mean VORI RSAM Coverage: 78.78+-24.92% | Mean VORI DSAR Coverage: 82.80+-21.39% | Mean VRBA Coverage: 52.18+-7.87%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[81 25]
#  [40 43]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.76      0.71       106
#            1       0.63      0.52      0.57        83
#
#     accuracy                           0.66       189
#    macro avg       0.65      0.64      0.64       189
# weighted avg       0.65      0.66      0.65       189
#
#
#  Top Features (VORI)
# Sum_LP                          0.079865
# Max_LP                          0.045932
# Quantile Changes RSAM VORI      0.041380
# Mean Min Values DSAR VORI       0.038908
# Delta_Max_Min_LP                0.037169
# Delta_Max_Min_tornillo          0.034971
# Max_tornillo                    0.033379
# Max drop DSAR VORI              0.030958
# Max_Precipitations              0.030902
# Var Value RSAM VORI             0.029349
# Avg drop DSAR VORI              0.027221
# Median Value DSAR VORI          0.026593
# Std Value RSAM VORI             0.025714
# Delta_Max_Min_Precipitations    0.023745
# Mean Min Values RSAM VORI       0.021747
# Sum_tornillo                    0.021232
# Sum_Precipitations              0.020648
# Max peak RSAM VORI              0.020257
# Max peak DSAR VORI              0.019480
# Max drop RSAM VORI              0.019425
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.34 ± 0.82
# Mean Magnitude (Missed - FN):   3.50 ± 0.74
# Low magnitude events were more detected
#  length of time array: 189
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[95 11]
#  [26 57]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       106
#            1       0.84      0.69      0.75        83
#
#     accuracy                           0.80       189
#    macro avg       0.81      0.79      0.80       189
# weighted avg       0.81      0.80      0.80       189
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.181619
# Quantile Changes RSAM VRBA    0.151961
# Sum_LP                        0.138960
# Quantile Changes DSAR VRBA    0.053536
# Max_tornillo                  0.040036
# season                        0.033722
# Avg Value DSAR VRBA           0.030590
# Mean Min Values DSAR VRBA     0.030233
# Mean Min Values RSAM VRBA     0.029564
# Avg Value RSAM VRBA           0.028422
# Max drop RSAM VRBA            0.021373
# Sum_VT                        0.019893
# Delta_Max_Min_tornillo        0.019700
# Max peak RSAM VRBA            0.018918
# Median Value RSAM VRBA        0.018914
# Max_LP                        0.014407
# Var Value DSAR VRBA           0.011729
# Avg drop RSAM VRBA            0.011162
# Sum_Precipitations            0.009995
# Avg peak RSAM VRBA            0.008644
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.48 ± 0.78
# Mean Magnitude (Missed - FN):   3.27 ± 0.79
# High magnitude events were more detected
#  length of time array: 189
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 39 | Mean VORI RSAM Coverage: 95.74±7.61% | Mean VORI DSAR Coverage: 99.22±3.44% | Mean VRBA Coverage: 86.98±16.92%
# Both Missed (FN): 22 | Mean VORI RSAM Coverage: 87.49±13.79% | Mean VORI DSAR Coverage: 92.14±15.34% | Mean VRBA Coverage: 79.24±23.14%
# Both False Positives (FP): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both True Negatives (TN): 70 | Mean VORI RSAM Coverage: 95.68±13.06% | Mean VORI DSAR Coverage: 99.49±2.84% | Mean VRBA Coverage: 95.46±8.46%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 97.62+-2.95% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 93.69+-0.22%
# VRBA Detected Without VORI (TP): 18 | Mean VORI RSAM Coverage: 97.13+-6.06% | Mean VORI DSAR Coverage: 97.42+-6.16% | Mean VRBA Coverage: 83.48+-19.30%
# VORI Detected Without VRBA (TN): 11 | Mean VORI RSAM Coverage: 96.74+-6.47% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 80.15+-25.06%
# VRBA Detected Without VORI (TN): 25 | Mean VORI RSAM Coverage: 99.73+-0.22% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 98.50+-1.78%

# %% [markdown]
# Now that we have the bests models for each station, we are going to do feature selection to see if it is possible to get a better performance with less features.

# %% [markdown]
# #### Wrapper Feature Selection

# %% [markdown]
# ##### Wrapper Forward Selection

# %%
# Wrapper forward selection
class VolcanicFeatureForwardSelector(BaseEstimator, TransformerMixin):
    def __init__(self, beta=2, n_splits=3):
        self.selected_features_ = []
        self.beta = beta
        self.n_splits = n_splits

    def fit(self, X, y, best_models=None):
        skf = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
        columns = list(X.columns)
        n = len(columns)

        memory_score = 0
        memory_std = float("inf")

        if best_models is None:
            raise ValueError("best_models must be provided for feature selection.")

        for round_i in range(n):
            # Remaining candidate features
            candidates = list(set(columns) - set(self.selected_features_))

            def analyze_feature(c):
                features_to_include = self.selected_features_ + [c]
                fold_scores = []

                # Convert to array for faster CV evaluation
                X_subset = X[features_to_include].values
                y_array = y.values.ravel() if isinstance(y, (pd.DataFrame, pd.Series)) else y

                for train_index, test_index in skf.split(X_subset, y_array):
                    X_tr, X_ts = X_subset[train_index], X_subset[test_index]
                    Y_tr, Y_ts = y_array[train_index], y_array[test_index]

                    model = clone(best_models)
                    model.fit(X_tr, Y_tr)
                    Y_hat_ts = model.predict(X_ts)

                    score = fbeta_score(Y_ts, Y_hat_ts, beta=self.beta, zero_division=0)
                    fold_scores.append(score)

                return np.mean(fold_scores), fold_scores, c

            # Evaluate each candidate in parallel
            results = Parallel(n_jobs=-1)(delayed(analyze_feature)(c) for c in candidates)

            # Keep the feature with the best average F2 score
            best_candidate_info = max(results, key=lambda x: x[0])
            cv_score, fold_scores, best_candidate = best_candidate_info
            candidate_std = np.std(fold_scores)

            # Stop when performance starts to degrade
            if memory_score == 0:
                memory_score = cv_score
                memory_std = candidate_std
            else:
                if cv_score < memory_score or (cv_score == memory_score and candidate_std > memory_std):
                    print("The score decreased.")
                    break
                else:
                    memory_score = cv_score
                    memory_std = candidate_std

            self.selected_features_.append(best_candidate)
            print(f"Round {round_i + 1} | Added: {best_candidate} | CV F2-Score = {round(cv_score, 4)} | Std Dev = {round(candidate_std, 4)}")

        return self

    def transform(self, X, y=None):
        # Return the selected feature subset
        return X[self.selected_features_]

# %%
# (Head windows) evaluate forward feature selection for both VORI and VRBA datasets
best_features_fw_VORI = {}
best_features_fw_VRBA = {}
selector_fw_VORI = {}
selector_fw_VRBA = {}

for key in train_test_years_splits.keys():
    print(f"\n{'-'*60}")
    print(f"Feature selection for test year: {key}")

    # VORI dataset: fit the forward selector and retain the selected features
    selector_fw_VORI[key] = VolcanicFeatureForwardSelector()
    selector_fw_VORI[key].fit(x_train_VORI[key], y_train_VORI[key]["Type"], best_models=best_models_VORI_train[key])
    best_features_fw_VORI[key] = selector_fw_VORI[key].selected_features_
    print(f"Selected features for VORI (test year {key}): {best_features_fw_VORI[key]}")

    # VRBA dataset: fit the forward selector and retain the selected features
    selector_fw_VRBA[key] = VolcanicFeatureForwardSelector()
    selector_fw_VRBA[key].fit(x_train_VRBA[key], y_train_VRBA[key]["Type"], best_models=best_models_VRBA_train[key])
    best_features_fw_VRBA[key] = selector_fw_VRBA[key].selected_features_
    print(f"Selected features for VRBA (test year {key}): {best_features_fw_VRBA[key]}")

# Evaluate the final models using the selected features for both stations
print_report_best_model_per_year_out_of_dataset(
    best_models_VORI_train, best_features_fw_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA_train, best_features_fw_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits,
    best_features="SelectFromModel"  # Set to None to use the full feature set for evaluation
)
# Out:
# ------------------------------------------------------------
# Feature selection for test year: 2019
# Round 1 | Added: is_cascading_material_failure VORI | CV F2-Score = 0.87 | Std Dev = 0.0091
# The score decreased.
# Selected features for VORI (test year 2019): ['is_cascading_material_failure VORI']
# Round 1 | Added: Std h Width RSAM VRBA | CV F2-Score = 0.8812 | Std Dev = 0.0008
# Round 2 | Added: Std Prominence RSAM VRBA | CV F2-Score = 0.8812 | Std Dev = 0.0008
# Round 3 | Added: is_cascading_material_failure VRBA | CV F2-Score = 0.8812 | Std Dev = 0.0008
# The score decreased.
# Selected features for VRBA (test year 2019): ['Std h Width RSAM VRBA', 'Std Prominence RSAM VRBA', 'is_cascading_material_failure VRBA']
#
# ------------------------------------------------------------
# Feature selection for test year: 2020
# Round 1 | Added: Std l Width DSAR VORI | CV F2-Score = 0.7687 | Std Dev = 0.0169
# Round 2 | Added: is_possible_seal_failure VORI | CV F2-Score = 0.7909 | Std Dev = 0.0354
# Round 3 | Added: Std Drop Depth RSAM VORI | CV F2-Score = 0.7931 | Std Dev = 0.0139
# The score decreased.
# Selected features for VORI (test year 2020): ['Std l Width DSAR VORI', 'is_possible_seal_failure VORI', 'Std Drop Depth RSAM VORI']
# Round 1 | Added: Std h Width DSAR VRBA | CV F2-Score = 0.8215 | Std Dev = 0.0241
# Round 2 | Added: Std peak DSAR VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 3 | Added: Number of drops RSAM VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 4 | Added: is_possible_seal_failure VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 5 | Added: is_raising_LP | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 6 | Added: is_cascading_material_failure VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 7 | Added: Std peak RSAM VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 8 | Added: Std drop RSAM VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 9 | Added: Std Prominence DSAR VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 10 | Added: Number of peaks DSAR VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 11 | Added: Std l Width RSAM VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# Round 12 | Added: Std Drop Depth RSAM VRBA | CV F2-Score = 0.8232 | Std Dev = 0.0258
# The score decreased.
# Selected features for VRBA (test year 2020): ['Std h Width DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops RSAM VRBA', 'is_possible_seal_failure VRBA', 'is_raising_LP', 'is_cascading_material_failure VRBA', 'Std peak RSAM VRBA', 'Std drop RSAM VRBA', 'Std Prominence DSAR VRBA', 'Number of peaks DSAR VRBA', 'Std l Width RSAM VRBA', 'Std Drop Depth RSAM VRBA']
#
# ------------------------------------------------------------
# Feature selection for test year: 2021
# Round 1 | Added: is_cascading_material_failure VORI | CV F2-Score = 0.8772 | Std Dev = 0.0
# The score decreased.
# Selected features for VORI (test year 2021): ['is_cascading_material_failure VORI']
# Round 1 | Added: is_cascading_material_failure VRBA | CV F2-Score = 0.8772 | Std Dev = 0.0
# The score decreased.
# Selected features for VRBA (test year 2021): ['is_cascading_material_failure VRBA']
#
# ------------------------------------------------------------
# Feature selection for test year: 2022
# Round 1 | Added: Quantile Changes RSAM VORI | CV F2-Score = 0.6333 | Std Dev = 0.086
# Round 2 | Added: Max Drop Depth RSAM VORI | CV F2-Score = 0.6382 | Std Dev = 0.091
# Round 3 | Added: Max peak RSAM VORI | CV F2-Score = 0.6865 | Std Dev = 0.0682
# The score decreased.
# Selected features for VORI (test year 2022): ['Quantile Changes RSAM VORI', 'Max Drop Depth RSAM VORI', 'Max peak RSAM VORI']
# Round 1 | Added: Std Drop Depth DSAR VRBA | CV F2-Score = 0.7999 | Std Dev = 0.0091
# Round 2 | Added: quiescence_rsam_duration VRBA | CV F2-Score = 0.7999 | Std Dev = 0.0091
# Round 3 | Added: Std peak DSAR VRBA | CV F2-Score = 0.8051 | Std Dev = 0.0099
# Round 4 | Added: Number of drops RSAM VRBA | CV F2-Score = 0.8103 | Std Dev = 0.0151
# Round 5 | Added: Std h Width DSAR VRBA | CV F2-Score = 0.8103 | Std Dev = 0.0151
# Round 6 | Added: falling_rsam_acceleration VRBA | CV F2-Score = 0.8103 | Std Dev = 0.0151
# Round 7 | Added: is_possible_seal_failure VRBA | CV F2-Score = 0.8103 | Std Dev = 0.0151
# Round 8 | Added: Std drop DSAR VRBA | CV F2-Score = 0.8103 | Std Dev = 0.0151
# Round 9 | Added: Std h Width RSAM VRBA | CV F2-Score = 0.8103 | Std Dev = 0.0151
# The score decreased.
# Selected features for VRBA (test year 2022): ['Std Drop Depth DSAR VRBA', 'quiescence_rsam_duration VRBA', 'Std peak DSAR VRBA', 'Number of drops RSAM VRBA', 'Std h Width DSAR VRBA', 'falling_rsam_acceleration VRBA', 'is_possible_seal_failure VRBA', 'Std drop DSAR VRBA', 'Std h Width RSAM VRBA']
#
# ------------------------------------------------------------
# Feature selection for test year: 2023
# Round 1 | Added: is_cascading_material_failure VORI | CV F2-Score = 0.8348 | Std Dev = 0.008
# The score decreased.
# Selected features for VORI (test year 2023): ['is_cascading_material_failure VORI']
# Round 1 | Added: Std Drop Depth DSAR VRBA | CV F2-Score = 0.8014 | Std Dev = 0.015
# Round 2 | Added: Std drop DSAR VRBA | CV F2-Score = 0.8142 | Std Dev = 0.0068
# Round 3 | Added: is_cascading_material_failure VRBA | CV F2-Score = 0.8142 | Std Dev = 0.0068
# Round 4 | Added: is_hydrothermal_seal VRBA | CV F2-Score = 0.8142 | Std Dev = 0.0068
# The score decreased.
# Selected features for VRBA (test year 2023): ['Std Drop Depth DSAR VRBA', 'Std drop DSAR VRBA', 'is_cascading_material_failure VRBA', 'is_hydrothermal_seal VRBA']
#
# ------------------------------------------------------------
# Feature selection for test year: 2024
# Round 1 | Added: Std Prominence RSAM VORI | CV F2-Score = 0.7995 | Std Dev = 0.0221
# Round 2 | Added: is_cascading_material_failure VORI | CV F2-Score = 0.7995 | Std Dev = 0.0221
# Round 3 | Added: is_possible_seal_failure VORI | CV F2-Score = 0.7995 | Std Dev = 0.0221
# The score decreased.
# Selected features for VORI (test year 2024): ['Std Prominence RSAM VORI', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI']
# Round 1 | Added: Std Prominence DSAR VRBA | CV F2-Score = 0.8104 | Std Dev = 0.0216
# Round 2 | Added: Std h Width RSAM VRBA | CV F2-Score = 0.8139 | Std Dev = 0.0223
# The score decreased.
# Selected features for VRBA (test year 2024): ['Std Prominence DSAR VRBA', 'Std h Width RSAM VRBA']
#
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 0 16]
#  [ 0 24]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        16
#            1       0.60      1.00      0.75        24
#
#     accuracy                           0.60        40
#    macro avg       0.30      0.50      0.38        40
# weighted avg       0.36      0.60      0.45        40
#
#
#  Top Features (VORI)
# is_cascading_material_failure VORI    1.0
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.89 ± 0.91
# Mean Magnitude (Missed - FN):   nan ± nan
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 0 16]
#  [ 1 23]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        16
#            1       0.59      0.96      0.73        24
#
#     accuracy                           0.57        40
#    macro avg       0.29      0.48      0.37        40
# weighted avg       0.35      0.57      0.44        40
#
#
#  Top Features (VRBA)
# Std h Width RSAM VRBA                 0.423541
# Std Prominence RSAM VRBA              0.401308
# is_cascading_material_failure VRBA    0.175150
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.85 ± 0.92
# Mean Magnitude (Missed - FN):   3.69 ± nan
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 23 | Mean VORI RSAM Coverage: 84.30±28.92% | Mean VORI DSAR Coverage: 88.87±29.01% | Mean VRBA Coverage: 68.66±20.67%
# Both Missed (FN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both False Positives (FP): 16 | Mean VORI RSAM Coverage: 84.46±29.54% | Mean VORI DSAR Coverage: 86.79±26.30% | Mean VRBA Coverage: 75.43±21.21%
# Both True Negatives (TN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# VORI Detected Without VRBA (TP): 1 | Mean VORI RSAM Coverage: 77.12+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 99.63+-nan%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 3 18]
#  [ 0 22]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.14      0.25        21
#            1       0.55      1.00      0.71        22
#
#     accuracy                           0.58        43
#    macro avg       0.78      0.57      0.48        43
# weighted avg       0.77      0.58      0.49        43
#
#
#  Top Features (VORI)
# Std l Width DSAR VORI            0.724734
# Std Drop Depth RSAM VORI         0.200100
# is_possible_seal_failure VORI    0.075167
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.72 ± 0.87
# Mean Magnitude (Missed - FN):   nan ± nan
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 4 17]
#  [ 2 20]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.19      0.30        21
#            1       0.54      0.91      0.68        22
#
#     accuracy                           0.56        43
#    macro avg       0.60      0.55      0.49        43
# weighted avg       0.60      0.56      0.49        43
#
#
#  Top Features (VRBA)
# Std Prominence DSAR VRBA              0.213423
# Std h Width DSAR VRBA                 0.190366
# Number of peaks DSAR VRBA             0.175734
# Std peak DSAR VRBA                    0.149814
# Number of drops RSAM VRBA             0.096577
# is_raising_LP                         0.055798
# is_possible_seal_failure VRBA         0.038580
# Std peak RSAM VRBA                    0.028883
# Std drop RSAM VRBA                    0.022402
# Std l Width RSAM VRBA                 0.014829
# Std Drop Depth RSAM VRBA              0.013594
# is_cascading_material_failure VRBA    0.000000
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.79 ± 0.88
# Mean Magnitude (Missed - FN):   2.04 ± 0.61
# High magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 20 | Mean VORI RSAM Coverage: 90.02±22.74% | Mean VORI DSAR Coverage: 91.21±22.89% | Mean VRBA Coverage: 62.63±23.31%
# Both Missed (FN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both False Positives (FP): 14 | Mean VORI RSAM Coverage: 94.86±11.03% | Mean VORI DSAR Coverage: 96.59±9.62% | Mean VRBA Coverage: 72.79±24.50%
# Both True Negatives (TN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 98.93+-1.44% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 83.05+-11.05%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 3 | Mean VORI RSAM Coverage: 99.93+-0.04% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 81.42+-16.33%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 99.30+-1.30% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 99.87+-0.16%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 0 16]
#  [ 0 23]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        16
#            1       0.59      1.00      0.74        23
#
#     accuracy                           0.59        39
#    macro avg       0.29      0.50      0.37        39
# weighted avg       0.35      0.59      0.44        39
#
#
#  Top Features (VORI)
# is_cascading_material_failure VORI    1.0
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.71 ± 0.77
# Mean Magnitude (Missed - FN):   nan ± nan
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[16  0]
#  [23  0]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.41      1.00      0.58        16
#            1       0.00      0.00      0.00        23
#
#     accuracy                           0.41        39
#    macro avg       0.21      0.50      0.29        39
# weighted avg       0.17      0.41      0.24        39
#
#
#  Top Features (VRBA)
# is_cascading_material_failure VRBA    0.0
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): nan ± nan
# Mean Magnitude (Missed - FN):   2.71 ± 0.77
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both Missed (FN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both False Positives (FP): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both True Negatives (TN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# VORI Detected Without VRBA (TP): 23 | Mean VORI RSAM Coverage: 90.16+-28.75% | Mean VORI DSAR Coverage: 91.09+-28.75% | Mean VRBA Coverage: 63.43+-26.22%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 16 | Mean VORI RSAM Coverage: 97.64+-8.65% | Mean VORI DSAR Coverage: 97.78+-8.68% | Mean VRBA Coverage: 79.11+-23.23%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 9 13]
#  [ 5 15]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.64      0.41      0.50        22
#            1       0.54      0.75      0.62        20
#
#     accuracy                           0.57        42
#    macro avg       0.59      0.58      0.56        42
# weighted avg       0.59      0.57      0.56        42
#
#
#  Top Features (VORI)
# Quantile Changes RSAM VORI    0.417635
# Max peak RSAM VORI            0.291356
# Max Drop Depth RSAM VORI      0.291010
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.92 ± 1.06
# Mean Magnitude (Missed - FN):   3.56 ± 0.81
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 3 19]
#  [ 3 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.14      0.21        22
#            1       0.47      0.85      0.61        20
#
#     accuracy                           0.48        42
#    macro avg       0.49      0.49      0.41        42
# weighted avg       0.49      0.48      0.40        42
#
#
#  Top Features (VRBA)
# Std Drop Depth DSAR VRBA          0.352773
# Std drop DSAR VRBA                0.287260
# Std peak DSAR VRBA                0.199997
# Std h Width DSAR VRBA             0.159970
# quiescence_rsam_duration VRBA     0.000000
# Number of drops RSAM VRBA         0.000000
# falling_rsam_acceleration VRBA    0.000000
# is_possible_seal_failure VRBA     0.000000
# Std h Width RSAM VRBA             0.000000
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.14 ± 1.08
# Mean Magnitude (Missed - FN):   2.76 ± 0.61
# High magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 12 | Mean VORI RSAM Coverage: 84.63±28.46% | Mean VORI DSAR Coverage: 88.30±29.24% | Mean VRBA Coverage: 52.37±32.31%
# Both Missed (FN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both False Positives (FP): 11 | Mean VORI RSAM Coverage: 87.51±30.82% | Mean VORI DSAR Coverage: 89.50±25.39% | Mean VRBA Coverage: 69.29±33.14%
# Both True Negatives (TN): 1 | Mean VORI RSAM Coverage: 99.95±nan% | Mean VORI DSAR Coverage: 99.95±nan% | Mean VRBA Coverage: 99.95±nan%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 93.35+-11.32% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 99.95+-0.00%
# VRBA Detected Without VORI (TP): 5 | Mean VORI RSAM Coverage: 97.35+-5.57% | Mean VORI DSAR Coverage: 97.44+-5.62% | Mean VRBA Coverage: 79.94+-17.39%
# VORI Detected Without VRBA (TN): 8 | Mean VORI RSAM Coverage: 99.35+-1.11% | Mean VORI DSAR Coverage: 99.55+-1.14% | Mean VRBA Coverage: 67.62+-20.21%
# VRBA Detected Without VORI (TN): 2 | Mean VORI RSAM Coverage: 98.62+-1.79% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 99.27+-0.97%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 0 22]
#  [ 0 23]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.51      1.00      0.68        23
#
#     accuracy                           0.51        45
#    macro avg       0.26      0.50      0.34        45
# weighted avg       0.26      0.51      0.35        45
#
#
#  Top Features (VORI)
# is_cascading_material_failure VORI    1.0
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.79 ± 0.95
# Mean Magnitude (Missed - FN):   nan ± nan
# Low magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 1 21]
#  [ 2 21]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      0.05      0.08        22
#            1       0.50      0.91      0.65        23
#
#     accuracy                           0.49        45
#    macro avg       0.42      0.48      0.36        45
# weighted avg       0.42      0.49      0.37        45
#
#
#  Top Features (VRBA)
# Std Drop Depth DSAR VRBA              0.512139
# Std drop DSAR VRBA                    0.395067
# is_cascading_material_failure VRBA    0.081052
# is_hydrothermal_seal VRBA             0.011741
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.79 ± 0.97
# Mean Magnitude (Missed - FN):   2.80 ± 0.85
# Low magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 21 | Mean VORI RSAM Coverage: 93.22±22.28% | Mean VORI DSAR Coverage: 93.98±22.23% | Mean VRBA Coverage: 63.32±27.12%
# Both Missed (FN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both False Positives (FP): 21 | Mean VORI RSAM Coverage: 90.05±26.54% | Mean VORI DSAR Coverage: 91.78±21.83% | Mean VRBA Coverage: 77.13±31.37%
# Both True Negatives (TN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 90.09+-13.89% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 99.95+-0.00%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 1 | Mean VORI RSAM Coverage: 99.79+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 94.32+-nan%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 3 19]
#  [ 2 18]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.60      0.14      0.22        22
#            1       0.49      0.90      0.63        20
#
#     accuracy                           0.50        42
#    macro avg       0.54      0.52      0.43        42
# weighted avg       0.55      0.50      0.42        42
#
#
#  Top Features (VORI)
# Std Prominence RSAM VORI              1.0
# is_cascading_material_failure VORI    0.0
# is_possible_seal_failure VORI         0.0
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.57
# Mean Magnitude (Missed - FN):   2.85 ± 0.56
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 1 21]
#  [ 3 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.25      0.05      0.08        22
#            1       0.45      0.85      0.59        20
#
#     accuracy                           0.43        42
#    macro avg       0.35      0.45      0.33        42
# weighted avg       0.34      0.43      0.32        42
#
#
#  Top Features (VRBA)
# Std Prominence DSAR VRBA    0.593688
# Std h Width RSAM VRBA       0.406312
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.48 ± 0.54
# Mean Magnitude (Missed - FN):   3.13 ± 0.34
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 16 | Mean VORI RSAM Coverage: 94.26±18.01% | Mean VORI DSAR Coverage: 95.81±16.55% | Mean VRBA Coverage: 65.25±27.71%
# Both Missed (FN): 1 | Mean VORI RSAM Coverage: 99.95±nan% | Mean VORI DSAR Coverage: 99.95±nan% | Mean VRBA Coverage: 98.28±nan%
# Both False Positives (FP): 18 | Mean VORI RSAM Coverage: 97.85±8.00% | Mean VORI DSAR Coverage: 98.10±7.86% | Mean VRBA Coverage: 74.67±20.80%
# Both True Negatives (TN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 50.77+-41.72% | Mean VORI DSAR Coverage: 72.51+-38.81% | Mean VRBA Coverage: 97.44+-3.56%
# VRBA Detected Without VORI (TP): 1 | Mean VORI RSAM Coverage: 99.65+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 92.93+-nan%
# VORI Detected Without VRBA (TN): 3 | Mean VORI RSAM Coverage: 99.65+-0.41% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.43+-31.25%
# VRBA Detected Without VORI (TN): 1 | Mean VORI RSAM Coverage: 99.95+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 89.94+-nan%

# %%
best_features_fw_5days_VORI = {}
best_features_fw_5days_VRBA = {}
selector_fw_5days_VORI = {}
selector_fw_5days_VRBA = {}

for key in train_test_years_splits.keys():
    print(f"\n{'-'*60}")
    print(f"Feature selection for test year: {key}")

    selector_fw_5days_VORI[key] = VolcanicFeatureForwardSelector()
    selector_fw_5days_VORI[key].fit(
        x_train_5_VORI[key],
        y_train_5_VORI[key]['Type'],
        best_models=best_5days_models_VORI_train[key]
    )
    best_features_fw_5days_VORI[key] = selector_fw_5days_VORI[key].selected_features_
    print(f"Selected features for VORI (test year {key}): {best_features_fw_5days_VORI[key]}")

    selector_fw_5days_VRBA[key] = VolcanicFeatureForwardSelector()
    selector_fw_5days_VRBA[key].fit(
        x_train_5_VRBA[key],
        y_train_5_VRBA[key]['Type'],
        best_models=best_5days_models_VRBA_train[key]
    )
    best_features_fw_5days_VRBA[key] = selector_fw_5days_VRBA[key].selected_features_
    print(f"Selected features for VRBA (test year {key}): {best_features_fw_5days_VRBA[key]}")

print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI_train, best_features_fw_5days_VORI, x_train_5_VORI, x_val_5_VORI, y_train_5_VORI, y_val_5_VORI,
    best_5days_models_VRBA_train, best_features_fw_5days_VRBA, x_train_5_VRBA, x_val_5_VRBA, y_train_5_VRBA, y_val_5_VRBA,
    train_test_years_splits,
    best_features='selected'
)

# %% [markdown]
# The model has become “lazy,” realizing that with just a few features, it only needed to consistently predict an eruption to achieve a good F2 score. It might therefore be better to consider “backward” feature selection rather than “forward” feature selection. With “backward” feature selection, we start with the entire set of features and remove them one by one. We remove the feature that has the least impact on the model’s performance. We stop when we observe a significant drop in the model’s performance or when only a certain number of features remain.

# %% [markdown]
# #### Wrapper Backward Selection

# %%
# Wrapper backward elimination with tolerance-based stopping criterion
class VolcanicBackwardFeatureSelector(BaseEstimator, TransformerMixin):
    def __init__(self, beta=2, n_splits=3, tolerance=0.99):
        self.selected_features_ = []
        self.best_features_ever_ = [] # To store the absolute peak
        self.beta = beta
        self.n_splits = n_splits
        self.tolerance = tolerance

    def _get_score(self, X, y, model, skf):
        """Helper to compute CV score for a given subset."""
        fold_scores = []
        y_array = y.values.ravel() if isinstance(y, (pd.DataFrame, pd.Series)) else y
        
        for train_idx, test_idx in skf.split(X, y_array):
            X_tr, X_ts = X.values[train_idx], X.values[test_idx]
            y_tr, y_ts = y_array[train_idx], y_array[test_idx]
            
            m = clone(model)
            m.fit(X_tr, y_tr)
            y_pred = m.predict(X_ts)
            fold_scores.append(fbeta_score(y_ts, y_pred, beta=self.beta, zero_division=0))
        
        return np.mean(fold_scores), np.std(fold_scores)

    def fit(self, X, y, best_models=None):
        skf = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
        self.selected_features_ = list(X.columns)
        print(f"Initial number of features: {len(self.selected_features_)}")
        
        # Initial evaluation
        memory_score, memory_std = self._get_score(X[self.selected_features_], y, best_models, skf)
        
        self.best_score_ever_ = memory_score
        self.best_features_ever_ = list(self.selected_features_)
        
        print(f"Initial Score (Full Set): {round(memory_score, 4)}")

        for round_i in range(len(X.columns) - 1):
            candidates = self.selected_features_
            
            def analyze_removal(c):
                subset = [f for f in self.selected_features_ if f != c]
                score_mean, score_std = self._get_score(X[subset], y, best_models, skf)
                return score_mean, score_std, c

            results = Parallel(n_jobs=-1)(delayed(analyze_removal)(c) for c in candidates)
            best_cv, best_std, to_remove = max(results, key=lambda x: x[0])

            # Stopping Criterion with tolerance
            if best_cv < (memory_score * self.tolerance):
                print(f"-> Stopping: Score drop exceeds tolerance ({best_cv:.4f} < {memory_score * self.tolerance:.4f}) ---")
                break

            # Update current state
            memory_score = best_cv
            self.selected_features_.remove(to_remove)
            
            # Keep track of the absolute best
            if best_cv > self.best_score_ever_:
                self.best_score_ever_ = best_cv
                self.best_features_ever_ = list(self.selected_features_)

                print(f"Round {round_i+1} | Removed: {to_remove} | New F2: {round(memory_score, 4)}")
            
            elif best_cv < self.best_score_ever_*0.8:
                print("Warning: Significant score drop detected.")
                break
            elif len(self.selected_features_) <= 20 :
                print("Warning: Number of features is getting low, consider stopping.")
                break
            
        print(f"Final number of features: {len(self.best_features_ever_)} | Best F2 Score: {round(self.best_score_ever_, 4)}")
        return self

    def transform(self, X):
        return X[self.best_features_ever_]

# %%
# (Head Window) Test the backward elimination selector for both VORI and VRBA datasets
best_features_bckw_VORI = {}
best_features_bckw_VRBA = {}
selector_bckw_VORI = {}
selector_bckw_VRBA = {}

for key in train_test_years_splits.keys():
    print(f"\n{'-'*60}")
    print(f"Feature selection for test year: {key}")
    # VORI dataset: fit the backward selector and retain the selected features
    selector_bckw_VORI[key] = VolcanicBackwardFeatureSelector(tolerance=0.95)
    selector_bckw_VORI[key].fit(x_train_VORI[key], y_train_VORI[key]['Type'], best_models=best_models_VORI[key])
    best_features_bckw_VORI[key] = selector_bckw_VORI[key].best_features_ever_
    print(f"Selected features for VORI (test year {key}): {best_features_bckw_VORI[key]}")
    # VRBA dataset: fit the backward selector and retain the selected features
    selector_bckw_VRBA[key] = VolcanicBackwardFeatureSelector(tolerance=0.95)
    selector_bckw_VRBA[key].fit(x_train_VRBA[key], y_train_VRBA[key]['Type'], best_models=best_models_VRBA[key])
    best_features_bckw_VRBA[key] = selector_bckw_VRBA[key].best_features_ever_
    print(f"Selected features for VRBA (test year {key}): {best_features_bckw_VRBA[key]}")


# Evaluate the final models using the selected backward features for both stations
print_report_best_model_per_year_out_of_dataset(
    best_models_VORI_train, best_features_bckw_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA_train, best_features_bckw_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits,
    best_features='selected'  
)
# Out:
# ------------------------------------------------------------
# Feature selection for test year: 2019
# Initial number of features: 85
# Initial Score (Full Set): 0.659
# Round 1 | Removed: Avg Drop Depth RSAM VORI | New F2: 0.7245
# Round 2 | Removed: Avg Prominence DSAR VORI | New F2: 0.759
# Round 3 | Removed: Var Value RSAM VORI | New F2: 0.7705
# Round 40 | Removed: Number of drops RSAM VORI | New F2: 0.7721
# -> Stopping: Score drop exceeds tolerance (0.7321 < 0.7335) ---
# Final number of features: 45 | Best F2 Score: 0.7721
# Selected features for VORI (test year 2019): ['Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Avg drop RSAM VORI', 'Median Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Std h Width DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Std Value DSAR VORI', 'Mean Min Values DSAR VORI', 'is_possible_seal_failure VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Max_VT', 'Delta_Max_Min_VT', 'Sum_LP', 'Last_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Delta_Max_Min_Precipitations']
# Initial number of features: 85
# Initial Score (Full Set): 0.6938
# Round 1 | Removed: Delta_Max_Min_VT | New F2: 0.7097
# Round 3 | Removed: Var Value RSAM VRBA | New F2: 0.7442
# Round 10 | Removed: Std Prominence RSAM VRBA | New F2: 0.7645
# Round 15 | Removed: Std Prominence DSAR VRBA | New F2: 0.7648
# Round 23 | Removed: Avg Drop Depth DSAR VRBA | New F2: 0.7784
# Round 24 | Removed: Last_LP | New F2: 0.7891
# Round 32 | Removed: Sum_Precipitations | New F2: 0.7968
# Round 37 | Removed: Max l Width RSAM VRBA | New F2: 0.8069
# Round 42 | Removed: is_hydrothermal_seal VRBA | New F2: 0.8161
# Round 46 | Removed: Std drop RSAM VRBA | New F2: 0.825
# Round 49 | Removed: Var Value DSAR VRBA | New F2: 0.8335
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 36 | Best F2 Score: 0.8335
# Selected features for VRBA (test year 2019): ['Number of peaks RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Avg Value RSAM VRBA', 'Median Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Std h Width DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Max l Width DSAR VRBA', 'Std drop DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'is_pressurizing VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Last_VT', 'Max_VT', 'Max_LP', 'Delta_Max_Min_LP', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'season']
#
# ------------------------------------------------------------
# Feature selection for test year: 2020
# Initial number of features: 85
# Initial Score (Full Set): 0.6074
# Round 1 | Removed: Var Value RSAM VORI | New F2: 0.6546
# Round 2 | Removed: Avg drop DSAR VORI | New F2: 0.6734
# -> Stopping: Score drop exceeds tolerance (0.5933 < 0.5970) ---
# Final number of features: 83 | Best F2 Score: 0.6734
# Selected features for VORI (test year 2020): ['Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.616
# Round 1 | Removed: Quantile Changes DSAR VRBA | New F2: 0.6551
# Round 2 | Removed: is_cascading_material_failure VRBA | New F2: 0.6604
# Round 3 | Removed: Avg h Width RSAM VRBA | New F2: 0.6802
# Round 6 | Removed: Var Value DSAR VRBA | New F2: 0.6903
# Round 7 | Removed: is_possible_seal_failure VRBA | New F2: 0.6971
# -> Stopping: Score drop exceeds tolerance (0.6278 < 0.6291) ---
# Final number of features: 78 | Best F2 Score: 0.6971
# Selected features for VRBA (test year 2020): ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
#
# ------------------------------------------------------------
# Feature selection for test year: 2021
# Initial number of features: 85
# Initial Score (Full Set): 0.6774
# Round 1 | Removed: Mean Min Values DSAR VORI | New F2: 0.7504
# Round 5 | Removed: Last_Precipitations | New F2: 0.7693
# -> Stopping: Score drop exceeds tolerance (0.7063 < 0.7308) ---
# Final number of features: 80 | Best F2 Score: 0.7693
# Selected features for VORI (test year 2021): ['Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Max_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.7842
# Round 1 | Removed: Std Value RSAM VRBA | New F2: 0.8114
# Round 2 | Removed: Var Value RSAM VRBA | New F2: 0.8135
# Round 3 | Removed: Last_LP | New F2: 0.8224
# Round 5 | Removed: is_raising_LP | New F2: 0.8297
# Round 7 | Removed: Avg Value DSAR VRBA | New F2: 0.8385
# Round 9 | Removed: Std l Width DSAR VRBA | New F2: 0.8388
# Round 10 | Removed: Avg Drop Depth RSAM VRBA | New F2: 0.8457
# Round 19 | Removed: Std drop RSAM VRBA | New F2: 0.8533
# Round 28 | Removed: Max_VT | New F2: 0.8548
# Round 33 | Removed: num_state_changes_log_dsar VRBA | New F2: 0.8549
# Round 36 | Removed: Avg Prominence RSAM VRBA | New F2: 0.8578
# Round 39 | Removed: Max drop DSAR VRBA | New F2: 0.8599
# Round 40 | Removed: Std drop DSAR VRBA | New F2: 0.8616
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 45 | Best F2 Score: 0.8616
# Selected features for VRBA (test year 2021): ['Max Prominence RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Median Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_cascading_material_failure VRBA', 'num_state_changes_inv_rsam VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Last_VT', 'is_raising_VT', 'Sum_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo']
#
# ------------------------------------------------------------
# Feature selection for test year: 2022
# Initial number of features: 85
# Initial Score (Full Set): 0.6188
# Round 1 | Removed: season | New F2: 0.6216
# Round 2 | Removed: Mean Min Values DSAR VORI | New F2: 0.6522
# Round 6 | Removed: Median Value DSAR VORI | New F2: 0.6801
# Round 35 | Removed: Max h Width DSAR VORI | New F2: 0.6903
# -> Stopping: Score drop exceeds tolerance (0.6491 < 0.6558) ---
# Final number of features: 50 | Best F2 Score: 0.6903
# Selected features for VORI (test year 2022): ['Avg Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Avg Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Avg peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Std l Width DSAR VORI', 'Quantile Changes DSAR VORI', 'Std Value DSAR VORI', 'Var Value DSAR VORI', 'is_cascading_material_failure VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Delta_Max_Min_LP', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Delta_Max_Min_Precipitations']
# Initial number of features: 85
# Initial Score (Full Set): 0.5924
# Round 1 | Removed: Std Value DSAR VRBA | New F2: 0.6233
# Round 2 | Removed: Var Value DSAR VRBA | New F2: 0.674
# Round 3 | Removed: Mean Min Values DSAR VRBA | New F2: 0.6807
# -> Stopping: Score drop exceeds tolerance (0.6350 < 0.6466) ---
# Final number of features: 82 | Best F2 Score: 0.6807
# Selected features for VRBA (test year 2022): ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Median Value DSAR VRBA', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
#
# ------------------------------------------------------------
# Feature selection for test year: 2023
# Initial number of features: 85
# Initial Score (Full Set): 0.6247
# Round 1 | Removed: Median Value RSAM VORI | New F2: 0.6543
# Round 4 | Removed: Std h Width RSAM VORI | New F2: 0.6757
# Round 6 | Removed: Std Value DSAR VORI | New F2: 0.7146
# -> Stopping: Score drop exceeds tolerance (0.6606 < 0.6789) ---
# Final number of features: 79 | Best F2 Score: 0.7146
# Selected features for VORI (test year 2023): ['Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Std drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Avg Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.7151
# -> Stopping: Score drop exceeds tolerance (0.6573 < 0.6650) ---
# Final number of features: 85 | Best F2 Score: 0.7151
# Selected features for VRBA (test year 2023): ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Std Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
#
# ------------------------------------------------------------
# Feature selection for test year: 2024
# Initial number of features: 85
# Initial Score (Full Set): 0.5212
# Round 1 | Removed: Sum_LP | New F2: 0.5492
# Round 2 | Removed: Std peak DSAR VORI | New F2: 0.562
# Round 3 | Removed: Avg Value RSAM VORI | New F2: 0.5762
# Round 4 | Removed: Delta_Max_Min_Precipitations | New F2: 0.5851
# Round 5 | Removed: Avg drop RSAM VORI | New F2: 0.6106
# Round 8 | Removed: Max drop RSAM VORI | New F2: 0.6324
# Round 9 | Removed: Var Value RSAM VORI | New F2: 0.6551
# Round 13 | Removed: Mean Min Values DSAR VORI | New F2: 0.6643
# Round 14 | Removed: Max_tornillo | New F2: 0.6731
# Round 18 | Removed: Sum_VT | New F2: 0.6747
# Round 22 | Removed: Max peak DSAR VORI | New F2: 0.6809
# Round 25 | Removed: falling_rsam_acceleration VORI | New F2: 0.6842
# Round 31 | Removed: Max Drop Depth RSAM VORI | New F2: 0.6936
# Round 45 | Removed: Delta_Max_Min_VT | New F2: 0.6963
# Round 46 | Removed: Avg Drop Depth DSAR VORI | New F2: 0.6965
# Round 56 | Removed: Median Value RSAM VORI | New F2: 0.6971
# Round 63 | Removed: is_raising_VT | New F2: 0.6972
# Round 65 | Removed: Number of drops DSAR VORI | New F2: 0.6972
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 20 | Best F2 Score: 0.6972
# Selected features for VORI (test year 2024): ['Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Number of drops RSAM VORI', 'Max l Width RSAM VORI', 'Quantile Changes RSAM VORI', 'Std Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Avg drop DSAR VORI', 'Avg Value DSAR VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Last_LP', 'Max_LP', 'is_raising_LP', 'Last_Precipitations', 'Max_Precipitations']
# Initial number of features: 85
# Initial Score (Full Set): 0.4992
# Round 1 | Removed: Median Value DSAR VRBA | New F2: 0.5722
# Round 2 | Removed: Avg Value RSAM VRBA | New F2: 0.616
# Round 4 | Removed: Std Value DSAR VRBA | New F2: 0.6285
# Round 5 | Removed: Var Value DSAR VRBA | New F2: 0.6374
# Round 6 | Removed: Avg peak DSAR VRBA | New F2: 0.6733
# Round 10 | Removed: Max_VT | New F2: 0.6783
# Round 12 | Removed: Number of peaks RSAM VRBA | New F2: 0.6816
# Round 14 | Removed: Std h Width RSAM VRBA | New F2: 0.6942
# Round 20 | Removed: season | New F2: 0.6948
# Round 21 | Removed: Avg l Width RSAM VRBA | New F2: 0.6949
# Round 34 | Removed: Std drop DSAR VRBA | New F2: 0.6949
# Round 37 | Removed: Max_Precipitations | New F2: 0.7042
# Round 38 | Removed: Max h Width RSAM VRBA | New F2: 0.706
# Round 40 | Removed: Max_tornillo | New F2: 0.7066
# Round 48 | Removed: Std Drop Depth RSAM VRBA | New F2: 0.7119
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 37 | Best F2 Score: 0.7119
# Selected features for VRBA (test year 2024): ['Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Std l Width RSAM VRBA', 'Max drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Max h Width DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'slope_ratio VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Delta_Max_Min_VT', 'Sum_LP', 'Delta_Max_Min_LP', 'Sum_tornillo', 'Last_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Delta_Max_Min_Precipitations']
#
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 8  8]
#  [ 3 21]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        16
#            1       0.72      0.88      0.79        24
#
#     accuracy                           0.72        40
#    macro avg       0.73      0.69      0.69        40
# weighted avg       0.73      0.72      0.71        40
#
#
#  Top Features (VORI)
# Sum_LP                          0.079666
# Max drop DSAR VORI              0.056953
# Mean Min Values RSAM VORI       0.049448
# Mean Min Values DSAR VORI       0.048504
# Max peak DSAR VORI              0.046736
# Avg h Width DSAR VORI           0.045938
# Avg drop RSAM VORI              0.042010
# Max l Width DSAR VORI           0.040994
# Quantile Changes DSAR VORI      0.040669
# Delta_Max_Min_Precipitations    0.040494
# Max Drop Depth DSAR VORI        0.036871
# Sum_Precipitations              0.036023
# Median Value RSAM VORI          0.033063
# Avg l Width DSAR VORI           0.030724
# Avg Prominence RSAM VORI        0.029474
# Std Value DSAR VORI             0.026714
# Max Prominence RSAM VORI        0.026663
# Max l Width RSAM VORI           0.025373
# Last_LP                         0.022311
# Max peak RSAM VORI              0.020722
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.81 ± 0.92
# Mean Magnitude (Missed - FN):   3.42 ± 0.84
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[12  4]
#  [ 7 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.63      0.75      0.69        16
#            1       0.81      0.71      0.76        24
#
#     accuracy                           0.72        40
#    macro avg       0.72      0.73      0.72        40
# weighted avg       0.74      0.72      0.73        40
#
#
#  Top Features (VRBA)
# Max Drop Depth RSAM VRBA     0.088625
# Mean Min Values RSAM VRBA    0.075915
# Std Value DSAR VRBA          0.075275
# Max peak DSAR VRBA           0.071745
# Avg Value DSAR VRBA          0.061247
# Median Value DSAR VRBA       0.059809
# Max h Width RSAM VRBA        0.056547
# Max_LP                       0.056439
# Median Value RSAM VRBA       0.054901
# Mean Min Values DSAR VRBA    0.054089
# Avg Value RSAM VRBA          0.054054
# Max l Width DSAR VRBA        0.053628
# Avg l Width RSAM VRBA        0.051208
# Delta_Max_Min_LP             0.044289
# season                       0.027474
# Delta_Max_Min_tornillo       0.023309
# Sum_VT                       0.021447
# Max_VT                       0.020198
# is_pressurizing VRBA         0.010366
# Last_VT                      0.006433
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.93 ± 0.88
# Mean Magnitude (Missed - FN):   2.78 ± 1.07
# High magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 16 | Mean VORI RSAM Coverage: 80.37±33.28% | Mean VORI DSAR Coverage: 86.90±34.00% | Mean VRBA Coverage: 73.63±22.77%
# Both Missed (FN): 2 | Mean VORI RSAM Coverage: 99.78±0.02% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 69.46±4.49%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.91±0.04% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 71.09±23.86%
# Both True Negatives (TN): 7 | Mean VORI RSAM Coverage: 82.64±26.30% | Mean VORI DSAR Coverage: 85.09±27.27% | Mean VRBA Coverage: 68.40±18.27%
# VORI Detected Without VRBA (TP): 5 | Mean VORI RSAM Coverage: 86.10+-14.63% | Mean VORI DSAR Coverage: 90.76+-14.57% | Mean VRBA Coverage: 54.19+-12.46%
# VRBA Detected Without VORI (TP): 1 | Mean VORI RSAM Coverage: 99.95+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 90.86+-nan%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 73.64+-nan% | Mean VORI DSAR Coverage: 73.64+-nan% | Mean VRBA Coverage: 49.20+-nan%
# VRBA Detected Without VORI (TN): 5 | Mean VORI RSAM Coverage: 79.89+-44.66% | Mean VORI DSAR Coverage: 83.90+-35.90% | Mean VRBA Coverage: 93.11+-15.45%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[13  8]
#  [ 8 14]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        21
#            1       0.64      0.64      0.64        22
#
#     accuracy                           0.63        43
#    macro avg       0.63      0.63      0.63        43
# weighted avg       0.63      0.63      0.63        43
#
#
#  Top Features (VORI)
# Max_tornillo                  0.032853
# Median Value DSAR VORI        0.032278
# Avg Prominence RSAM VORI      0.031397
# Sum_tornillo                  0.030204
# Max drop DSAR VORI            0.029817
# Max l Width RSAM VORI         0.029734
# Quantile Changes DSAR VORI    0.029582
# Max Prominence RSAM VORI      0.027998
# Std Value RSAM VORI           0.026817
# Delta_Max_Min_tornillo        0.026296
# Avg Value DSAR VORI           0.025033
# Sum_Precipitations            0.024654
# Sum_LP                        0.023524
# Mean Min Values DSAR VORI     0.022380
# Max h Width RSAM VORI         0.021835
# Avg h Width RSAM VORI         0.021419
# Max peak DSAR VORI            0.019999
# Quantile Changes RSAM VORI    0.019391
# slope_ratio VORI              0.019033
# Mean Min Values RSAM VORI     0.018955
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.36 ± 0.51
# Mean Magnitude (Missed - FN):   3.34 ± 1.05
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[14  7]
#  [ 4 18]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72        21
#            1       0.72      0.82      0.77        22
#
#     accuracy                           0.74        43
#    macro avg       0.75      0.74      0.74        43
# weighted avg       0.75      0.74      0.74        43
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.062589
# Std Value DSAR VRBA           0.062276
# slope_ratio VRBA              0.034716
# Max Prominence RSAM VRBA      0.027334
# Avg Prominence RSAM VRBA      0.026175
# Max_tornillo                  0.026131
# Sum_Precipitations            0.025873
# Max peak DSAR VRBA            0.025212
# Std Value RSAM VRBA           0.025208
# Max Drop Depth DSAR VRBA      0.024817
# Sum_tornillo                  0.024685
# Mean Min Values RSAM VRBA     0.024305
# Median Value DSAR VRBA        0.024063
# Avg Drop Depth DSAR VRBA      0.023455
# Sum_LP                        0.022881
# Avg Value DSAR VRBA           0.021040
# Mean Min Values DSAR VRBA     0.020911
# Median Value RSAM VRBA        0.020834
# Avg peak DSAR VRBA            0.020747
# Max Drop Depth RSAM VRBA      0.019997
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.59 ± 0.72
# Mean Magnitude (Missed - FN):   3.29 ± 1.37
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 14 | Mean VORI RSAM Coverage: 87.86±26.79% | Mean VORI DSAR Coverage: 88.32±26.96% | Mean VRBA Coverage: 69.34±20.72%
# Both Missed (FN): 4 | Mean VORI RSAM Coverage: 96.24±5.63% | Mean VORI DSAR Coverage: 96.94±6.03% | Mean VRBA Coverage: 71.73±8.46%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 97.46±5.57% | Mean VORI DSAR Coverage: 97.47±5.57% | Mean VRBA Coverage: 50.10±16.71%
# Both True Negatives (TN): 11 | Mean VORI RSAM Coverage: 94.59±12.14% | Mean VORI DSAR Coverage: 96.80±10.47% | Mean VRBA Coverage: 91.60±14.48%
# VORI Detected Without VRBA (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 95.79+-8.34% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 40.26+-29.00%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 77.94+-31.13%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 99.09+-1.50% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 82.97+-15.54%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 7  9]
#  [ 6 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.54      0.44      0.48        16
#            1       0.65      0.74      0.69        23
#
#     accuracy                           0.62        39
#    macro avg       0.60      0.59      0.59        39
# weighted avg       0.61      0.62      0.61        39
#
#
#  Top Features (VORI)
# Quantile Changes RSAM VORI    0.071193
# Avg drop DSAR VORI            0.054790
# Max drop DSAR VORI            0.047692
# Max peak DSAR VORI            0.042946
# Median Value DSAR VORI        0.034910
# Max drop RSAM VORI            0.028633
# Avg Value RSAM VORI           0.027737
# Avg Prominence RSAM VORI      0.027717
# Max Prominence RSAM VORI      0.027303
# Last_tornillo                 0.026419
# Mean Min Values RSAM VORI     0.025616
# slope_ratio VORI              0.025518
# Sum_Precipitations            0.023285
# Avg drop RSAM VORI            0.021680
# Avg h Width RSAM VORI         0.021363
# Max l Width RSAM VORI         0.021338
# Avg l Width RSAM VORI         0.020956
# Delta_Max_Min_tornillo        0.020591
# Max Drop Depth RSAM VORI      0.019320
# Max_tornillo                  0.017475
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.66 ± 0.83
# Mean Magnitude (Missed - FN):   2.84 ± 0.59
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9  7]
#  [ 7 16]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56        16
#            1       0.70      0.70      0.70        23
#
#     accuracy                           0.64        39
#    macro avg       0.63      0.63      0.63        39
# weighted avg       0.64      0.64      0.64        39
#
#
#  Top Features (VRBA)
# Avg peak DSAR VRBA            0.068806
# Quantile Changes DSAR VRBA    0.065791
# Mean Min Values DSAR VRBA     0.057023
# Mean Min Values RSAM VRBA     0.048619
# Max Prominence RSAM VRBA      0.048358
# Avg Drop Depth DSAR VRBA      0.044234
# Median Value RSAM VRBA        0.041382
# Avg drop RSAM VRBA            0.039434
# Max drop RSAM VRBA            0.036072
# Avg l Width DSAR VRBA         0.034406
# Max l Width RSAM VRBA         0.033815
# Max peak RSAM VRBA            0.033563
# Delta_Max_Min_tornillo        0.033544
# Max Prominence DSAR VRBA      0.033431
# Max Drop Depth DSAR VRBA      0.032660
# Max Drop Depth RSAM VRBA      0.032443
# Avg h Width DSAR VRBA         0.031661
# Avg peak RSAM VRBA            0.031253
# Max h Width DSAR VRBA         0.030707
# Max h Width RSAM VRBA         0.030616
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.64 ± 0.81
# Mean Magnitude (Missed - FN):   2.87 ± 0.69
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 13 | Mean VORI RSAM Coverage: 84.16±37.36% | Mean VORI DSAR Coverage: 84.27±37.42% | Mean VRBA Coverage: 58.04±27.44%
# Both Missed (FN): 3 | Mean VORI RSAM Coverage: 93.39±11.36% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 67.66±28.53%
# Both False Positives (FP): 7 | Mean VORI RSAM Coverage: 94.75±13.04% | Mean VORI DSAR Coverage: 94.99±13.13% | Mean VRBA Coverage: 67.94±27.24%
# Both True Negatives (TN): 7 | Mean VORI RSAM Coverage: 99.86±0.24% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 88.68±16.35%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 99.93+-0.05% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 71.79+-28.68%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 71.37+-23.31%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 2 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 84.71+-21.56%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 8 14]
#  [10 10]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.44      0.36      0.40        22
#            1       0.42      0.50      0.45        20
#
#     accuracy                           0.43        42
#    macro avg       0.43      0.43      0.43        42
# weighted avg       0.43      0.43      0.43        42
#
#
#  Top Features (VORI)
# Std Value RSAM VORI           0.116229
# Avg peak DSAR VORI            0.114285
# Quantile Changes RSAM VORI    0.081002
# Last_tornillo                 0.068798
# Var Value RSAM VORI           0.053356
# Avg Prominence DSAR VORI      0.050906
# Delta_Max_Min_VT              0.046521
# Max peak RSAM VORI            0.046282
# Avg Value RSAM VORI           0.032793
# Avg Prominence RSAM VORI      0.032558
# Sum_LP                        0.032411
# Avg Drop Depth DSAR VORI      0.032007
# Max Drop Depth RSAM VORI      0.031117
# is_raising_tornillo           0.024001
# Delta_Max_Min_LP              0.022869
# Max drop RSAM VORI            0.021295
# Sum_Precipitations            0.019331
# Avg Drop Depth RSAM VORI      0.018961
# Std drop RSAM VORI            0.018468
# Std Drop Depth RSAM VORI      0.016438
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.85 ± 0.74
# Mean Magnitude (Missed - FN):   3.31 ± 1.24
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[11 11]
#  [ 7 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      0.50      0.55        22
#            1       0.54      0.65      0.59        20
#
#     accuracy                           0.57        42
#    macro avg       0.58      0.57      0.57        42
# weighted avg       0.58      0.57      0.57        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.074675
# Max peak DSAR VRBA            0.047857
# Avg peak DSAR VRBA            0.043213
# Median Value DSAR VRBA        0.038366
# Avg Value DSAR VRBA           0.038245
# Var Value RSAM VRBA           0.034945
# Avg h Width DSAR VRBA         0.034008
# Avg Value RSAM VRBA           0.030733
# Max h Width DSAR VRBA         0.030384
# Avg Prominence RSAM VRBA      0.030196
# Quantile Changes DSAR VRBA    0.026774
# Max drop DSAR VRBA            0.026644
# Std Value RSAM VRBA           0.025366
# Avg peak RSAM VRBA            0.024637
# Avg Drop Depth DSAR VRBA      0.023415
# Avg Drop Depth RSAM VRBA      0.021548
# Avg l Width RSAM VRBA         0.021278
# Max_LP                        0.020706
# Sum_LP                        0.020582
# Max Prominence RSAM VRBA      0.020414
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.94 ± 0.97
# Mean Magnitude (Missed - FN):   3.34 ± 1.14
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 8 | Mean VORI RSAM Coverage: 80.76±34.33% | Mean VORI DSAR Coverage: 80.90±34.41% | Mean VRBA Coverage: 59.07±32.30%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 94.49±8.60% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 85.52±18.58%
# Both False Positives (FP): 8 | Mean VORI RSAM Coverage: 82.98±35.64% | Mean VORI DSAR Coverage: 85.58±29.27% | Mean VRBA Coverage: 80.42±24.16%
# Both True Negatives (TN): 5 | Mean VORI RSAM Coverage: 99.62±0.69% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 84.49±18.26%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 90.10+-13.80% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 81.92+-25.51%
# VRBA Detected Without VORI (TP): 5 | Mean VORI RSAM Coverage: 96.72+-6.99% | Mean VORI DSAR Coverage: 99.95+-0.01% | Mean VRBA Coverage: 52.80+-39.85%
# VORI Detected Without VRBA (TN): 3 | Mean VORI RSAM Coverage: 98.83+-1.81% | Mean VORI DSAR Coverage: 98.88+-1.86% | Mean VRBA Coverage: 51.02+-50.04%
# VRBA Detected Without VORI (TN): 6 | Mean VORI RSAM Coverage: 99.38+-1.03% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 63.80+-23.87%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[12 10]
#  [10 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55        22
#            1       0.57      0.57      0.57        23
#
#     accuracy                           0.56        45
#    macro avg       0.56      0.56      0.56        45
# weighted avg       0.56      0.56      0.56        45
#
#
#  Top Features (VORI)
# Max l Width RSAM VORI         0.098542
# Quantile Changes RSAM VORI    0.065672
# Avg h Width DSAR VORI         0.064107
# slope_ratio VORI              0.054896
# Mean Min Values DSAR VORI     0.054130
# Max drop DSAR VORI            0.053344
# Max l Width DSAR VORI         0.048084
# Avg drop RSAM VORI            0.045229
# Max Drop Depth DSAR VORI      0.035006
# Var Value RSAM VORI           0.030628
# Std Value RSAM VORI           0.028512
# Avg drop DSAR VORI            0.028403
# Max Prominence DSAR VORI      0.027437
# Avg l Width DSAR VORI         0.024757
# Avg Drop Depth DSAR VORI      0.023313
# Avg peak DSAR VORI            0.022118
# Avg Drop Depth RSAM VORI      0.021336
# is_raising_tornillo           0.020382
# Avg Value RSAM VORI           0.019466
# Avg l Width RSAM VORI         0.019102
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.86 ± 1.02
# Mean Magnitude (Missed - FN):   2.70 ± 0.88
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[15  7]
#  [14  9]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.52      0.68      0.59        22
#            1       0.56      0.39      0.46        23
#
#     accuracy                           0.53        45
#    macro avg       0.54      0.54      0.52        45
# weighted avg       0.54      0.53      0.52        45
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.243982
# Mean Min Values RSAM VRBA       0.147453
# Var Value DSAR VRBA             0.099884
# Std Value DSAR VRBA             0.091059
# Avg Drop Depth DSAR VRBA        0.060815
# Avg Value RSAM VRBA             0.041726
# Max Drop Depth DSAR VRBA        0.028646
# Max peak RSAM VRBA              0.026633
# Mean Min Values DSAR VRBA       0.023554
# Avg peak RSAM VRBA              0.022740
# Median Value DSAR VRBA          0.015023
# Std Value RSAM VRBA             0.014715
# Max peak DSAR VRBA              0.014013
# Delta_Max_Min_Precipitations    0.013750
# Avg peak DSAR VRBA              0.013370
# Sum_Precipitations              0.012726
# Avg Value DSAR VRBA             0.011323
# Var Value RSAM VRBA             0.009776
# Avg l Width RSAM VRBA           0.009136
# Max l Width RSAM VRBA           0.007985
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.93 ± 1.03
# Mean Magnitude (Missed - FN):   2.69 ± 0.91
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 5 | Mean VORI RSAM Coverage: 99.90±0.05% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 67.62±31.66%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 96.67±8.03% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 85.58±20.62%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.95±0.00% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 48.66±25.23%
# Both True Negatives (TN): 8 | Mean VORI RSAM Coverage: 99.60±0.91% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 96.78±8.89%
# VORI Detected Without VRBA (TP): 8 | Mean VORI RSAM Coverage: 84.27+-35.19% | Mean VORI DSAR Coverage: 84.28+-35.19% | Mean VRBA Coverage: 63.47+-28.83%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 96.02+-7.87% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 42.57+-14.71%
# VORI Detected Without VRBA (TN): 4 | Mean VORI RSAM Coverage: 99.89+-0.06% | Mean VORI DSAR Coverage: 99.96+-0.01% | Mean VRBA Coverage: 68.58+-21.07%
# VRBA Detected Without VORI (TN): 7 | Mean VORI RSAM Coverage: 70.66+-41.09% | Mean VORI DSAR Coverage: 75.42+-33.47% | Mean VRBA Coverage: 74.22+-42.71%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[11 11]
#  [ 8 12]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.58      0.50      0.54        22
#            1       0.52      0.60      0.56        20
#
#     accuracy                           0.55        42
#    macro avg       0.55      0.55      0.55        42
# weighted avg       0.55      0.55      0.55        42
#
#
#  Top Features (VORI)
# Max_Precipitations                 0.128785
# Std Value RSAM VORI                0.118244
# Quantile Changes RSAM VORI         0.092121
# Max Prominence RSAM VORI           0.082876
# Last_Precipitations                0.079380
# Max l Width RSAM VORI              0.076466
# Mean Min Values RSAM VORI          0.071398
# Avg Value DSAR VORI                0.070913
# Avg h Width RSAM VORI              0.056643
# Max h Width RSAM VORI              0.054064
# Avg drop DSAR VORI                 0.053161
# Avg l Width DSAR VORI              0.040498
# Max_LP                             0.036708
# Last_LP                            0.019706
# Std Drop Depth DSAR VORI           0.008293
# is_raising_LP                      0.004959
# quiescence_rsam_duration VORI      0.003006
# quiescence_rsam_drop_ratio VORI    0.002267
# Std Prominence RSAM VORI           0.000512
# Number of drops RSAM VORI          0.000000
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.40 ± 0.57
# Mean Magnitude (Missed - FN):   2.86 ± 0.46
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[16  6]
#  [ 7 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.71        22
#            1       0.68      0.65      0.67        20
#
#     accuracy                           0.69        42
#    macro avg       0.69      0.69      0.69        42
# weighted avg       0.69      0.69      0.69        42
#
#
#  Top Features (VRBA)
# Sum_Precipitations              0.103171
# Quantile Changes RSAM VRBA      0.103145
# Avg Value DSAR VRBA             0.080634
# Mean Min Values RSAM VRBA       0.075221
# Avg Prominence RSAM VRBA        0.048800
# Delta_Max_Min_Precipitations    0.047155
# slope_ratio VRBA                0.045625
# Max Prominence RSAM VRBA        0.037600
# Var Value RSAM VRBA             0.037568
# Max Drop Depth DSAR VRBA        0.036027
# Mean Min Values DSAR VRBA       0.033395
# Avg peak RSAM VRBA              0.031919
# Max peak RSAM VRBA              0.031715
# Max h Width DSAR VRBA           0.030743
# Max drop RSAM VRBA              0.028668
# Avg h Width RSAM VRBA           0.024695
# Last_Precipitations             0.023948
# Sum_LP                          0.022469
# Quantile Changes DSAR VRBA      0.022225
# Median Value RSAM VRBA          0.022035
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.41 ± 0.60
# Mean Magnitude (Missed - FN):   2.89 ± 0.34
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 11 | Mean VORI RSAM Coverage: 91.66±21.51% | Mean VORI DSAR Coverage: 93.93±19.97% | Mean VRBA Coverage: 66.57±29.63%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 83.55±31.51% | Mean VORI DSAR Coverage: 90.81±22.40% | Mean VRBA Coverage: 73.28±28.10%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 99.91±0.07% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 88.24±18.52%
# Both True Negatives (TN): 10 | Mean VORI RSAM Coverage: 99.64±0.62% | Mean VORI DSAR Coverage: 99.96±0.01% | Mean VRBA Coverage: 66.20±20.33%
# VORI Detected Without VRBA (TP): 1 | Mean VORI RSAM Coverage: 99.86+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 99.95+-nan%
# VRBA Detected Without VORI (TP): 2 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 79.07+-27.17%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 65.85+-nan% | Mean VORI DSAR Coverage: 66.59+-nan% | Mean VRBA Coverage: 99.93+-nan%
# VRBA Detected Without VORI (TN): 6 | Mean VORI RSAM Coverage: 99.74+-0.34% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 71.70+-21.55%

# %%
# (Eruption Window) Test the backward elimination selector for both VORI and VRBA datasets
best_features_bckw_5days_VORI = {}
best_features_bckw_5days_VRBA = {}
selector_bckw_5days_VORI = {}
selector_bckw_5days_VRBA = {}

for key in train_test_years_splits.keys():
    print(f"\n{'-'*60}")
    print(f"Feature selection for test year: {key}")
    # VORI dataset: fit the backward selector and retain the selected features
    selector_bckw_5days_VORI[key] = VolcanicBackwardFeatureSelector(tolerance=0.95)
    selector_bckw_5days_VORI[key].fit(x_train_5_VORI[key], y_train_5_VORI[key]['Type'], best_models=best_5days_models_VORI[key])
    best_features_bckw_5days_VORI[key] = selector_bckw_5days_VORI[key].best_features_ever_
    print(f"Selected features for VORI (test year {key}): {best_features_bckw_5days_VORI[key]}")
    # VRBA dataset: fit the backward selector and retain the selected features
    selector_bckw_5days_VRBA[key] = VolcanicBackwardFeatureSelector(tolerance=0.95)
    selector_bckw_5days_VRBA[key].fit(x_train_5_VRBA[key], y_train_5_VRBA[key]['Type'], best_models=best_5days_models_VRBA[key])
    best_features_bckw_5days_VRBA[key] = selector_bckw_5days_VRBA[key].best_features_ever_
    print(f"Selected features for VRBA (test year {key}): {best_features_bckw_5days_VRBA[key]}")

# Evaluate the final 5-day models using the selected backward features for both stations
print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI_train, best_features_bckw_5days_VORI, x_train_5_VORI, x_val_5_VORI, y_train_5_VORI, y_val_5_VORI,
    best_5days_models_VRBA_train, best_features_bckw_5days_VRBA, x_train_5_VRBA, x_val_5_VRBA, y_train_5_VRBA, y_val_5_VRBA,
    train_test_years_splits,
    best_features='selected',
    five_days=True  
)
# Out:
# ------------------------------------------------------------
# Feature selection for test year: 2019
# Initial number of features: 85
# Initial Score (Full Set): 0.9517
# Round 1 | Removed: Delta_Max_Min_tornillo | New F2: 0.9556
# Round 2 | Removed: Std Drop Depth DSAR VORI | New F2: 0.9576
# Round 3 | Removed: Sum_tornillo | New F2: 0.9604
# Round 4 | Removed: Delta_Max_Min_LP | New F2: 0.9623
# Round 7 | Removed: Sum_LP | New F2: 0.9628
# Round 8 | Removed: Std Drop Depth RSAM VORI | New F2: 0.9658
# Round 10 | Removed: Std peak RSAM VORI | New F2: 0.968
# Round 13 | Removed: Std Prominence RSAM VORI | New F2: 0.9682
# Round 17 | Removed: Number of peaks RSAM VORI | New F2: 0.97
# Round 20 | Removed: is_raising_LP | New F2: 0.9709
# Round 21 | Removed: num_state_changes_log_dsar VORI | New F2: 0.9729
# Round 26 | Removed: Std drop DSAR VORI | New F2: 0.9729
# Round 28 | Removed: is_pressurizing VORI | New F2: 0.9749
# Round 32 | Removed: Avg Drop Depth DSAR VORI | New F2: 0.9759
# Round 43 | Removed: Std Prominence DSAR VORI | New F2: 0.9761
# Round 44 | Removed: Std l Width RSAM VORI | New F2: 0.9769
# Round 45 | Removed: Avg h Width DSAR VORI | New F2: 0.9791
# Round 51 | Removed: slope_ratio VORI | New F2: 0.9791
# Round 52 | Removed: Std h Width RSAM VORI | New F2: 0.9798
# Round 53 | Removed: Number of drops RSAM VORI | New F2: 0.9808
# Round 55 | Removed: Avg Prominence RSAM VORI | New F2: 0.9818
# Round 56 | Removed: Max Drop Depth RSAM VORI | New F2: 0.982
# Round 61 | Removed: Std peak DSAR VORI | New F2: 0.9834
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 24 | Best F2 Score: 0.9834
# Selected features for VORI (test year 2019): ['Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Max h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Number of drops DSAR VORI', 'Max drop DSAR VORI', 'Median Value DSAR VORI', 'Mean Min Values DSAR VORI', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Max_LP', 'Sum_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.9577
# Round 1 | Removed: Max_tornillo | New F2: 0.9633
# Round 2 | Removed: Last_tornillo | New F2: 0.9655
# Round 4 | Removed: Sum_LP | New F2: 0.9656
# Round 5 | Removed: Delta_Max_Min_tornillo | New F2: 0.9693
# Round 6 | Removed: Mean Min Values DSAR VRBA | New F2: 0.9705
# Round 7 | Removed: Last_LP | New F2: 0.9717
# Round 8 | Removed: Std Prominence RSAM VRBA | New F2: 0.9719
# Round 10 | Removed: Std peak RSAM VRBA | New F2: 0.9732
# Round 11 | Removed: Avg Drop Depth RSAM VRBA | New F2: 0.9732
# Round 14 | Removed: Std Prominence DSAR VRBA | New F2: 0.9734
# Round 15 | Removed: Std drop DSAR VRBA | New F2: 0.9741
# Round 21 | Removed: Std l Width RSAM VRBA | New F2: 0.9754
# Round 22 | Removed: Avg Drop Depth DSAR VRBA | New F2: 0.9756
# Round 26 | Removed: Std drop RSAM VRBA | New F2: 0.9761
# Round 31 | Removed: Max peak DSAR VRBA | New F2: 0.9793
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 54 | Best F2 Score: 0.9793
# Selected features for VRBA (test year 2019): ['Number of peaks RSAM VRBA', 'Max Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Median Value DSAR VRBA', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'is_pressurizing VRBA', 'slope_ratio VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Max_Precipitations', 'season']
#
# ------------------------------------------------------------
# Feature selection for test year: 2020
# Initial number of features: 85
# Initial Score (Full Set): 0.913
# Round 1 | Removed: Var Value DSAR VORI | New F2: 0.9187
# Round 2 | Removed: Std drop DSAR VORI | New F2: 0.9198
# Round 3 | Removed: Avg l Width RSAM VORI | New F2: 0.9218
# Round 7 | Removed: Number of drops RSAM VORI | New F2: 0.9232
# Round 8 | Removed: Max Drop Depth RSAM VORI | New F2: 0.9251
# Round 15 | Removed: Std Prominence RSAM VORI | New F2: 0.9271
# Round 17 | Removed: Std peak RSAM VORI | New F2: 0.9271
# Round 18 | Removed: Avg Value DSAR VORI | New F2: 0.9282
# Round 20 | Removed: Last_tornillo | New F2: 0.9287
# Round 22 | Removed: Avg drop DSAR VORI | New F2: 0.9296
# Round 26 | Removed: Avg h Width RSAM VORI | New F2: 0.9296
# Round 28 | Removed: Quantile Changes DSAR VORI | New F2: 0.9299
# Round 31 | Removed: quiescence_rsam_drop_ratio VORI | New F2: 0.931
# Round 32 | Removed: Max l Width RSAM VORI | New F2: 0.9352
# Round 37 | Removed: Avg Prominence DSAR VORI | New F2: 0.9355
# Round 39 | Removed: Avg h Width DSAR VORI | New F2: 0.9371
# Round 40 | Removed: Max h Width DSAR VORI | New F2: 0.9383
# Round 43 | Removed: Avg Prominence RSAM VORI | New F2: 0.9383
# Round 45 | Removed: Avg drop RSAM VORI | New F2: 0.9394
# Round 46 | Removed: Std Prominence DSAR VORI | New F2: 0.9416
# Round 51 | Removed: Last_VT | New F2: 0.9425
# Round 52 | Removed: quiescence_rsam_duration VORI | New F2: 0.9434
# Round 57 | Removed: Avg Value RSAM VORI | New F2: 0.9434
# Round 60 | Removed: Max h Width RSAM VORI | New F2: 0.9442
# Round 61 | Removed: falling_rsam_mean_derivative VORI | New F2: 0.9456
# Round 62 | Removed: falling_rsam_mean_abs_derivative VORI | New F2: 0.9458
# Round 63 | Removed: Mean Min Values RSAM VORI | New F2: 0.9498
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 22 | Best F2 Score: 0.9498
# Selected features for VORI (test year 2020): ['Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Std Value RSAM VORI', 'Var Value RSAM VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Max l Width DSAR VORI', 'Max drop DSAR VORI', 'Median Value DSAR VORI', 'Mean Min Values DSAR VORI', 'num_state_changes_log_dsar VORI', 'Delta_Max_Min_VT', 'Sum_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'Sum_Precipitations', 'Max_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.9164
# Round 1 | Removed: Quantile Changes RSAM VRBA | New F2: 0.9328
# Round 2 | Removed: is_hydrothermal_seal VRBA | New F2: 0.9337
# Round 4 | Removed: falling_rsam_acceleration VRBA | New F2: 0.9345
# Round 9 | Removed: Max peak DSAR VRBA | New F2: 0.9363
# Round 21 | Removed: Max_tornillo | New F2: 0.9385
# Round 47 | Removed: is_raising_VT | New F2: 0.9398
# Round 49 | Removed: Max_LP | New F2: 0.9403
# Round 51 | Removed: Max Drop Depth RSAM VRBA | New F2: 0.941
# Round 55 | Removed: falling_rsam_mean_derivative VRBA | New F2: 0.9431
# Round 60 | Removed: Avg l Width RSAM VRBA | New F2: 0.9437
# Round 63 | Removed: num_state_changes_inv_rsam VRBA | New F2: 0.9442
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 22 | Best F2 Score: 0.9442
# Selected features for VRBA (test year 2020): ['Std Prominence RSAM VRBA', 'Std h Width RSAM VRBA', 'Max peak RSAM VRBA', 'Max l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Avg Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Avg Prominence DSAR VRBA', 'Max h Width DSAR VRBA', 'Std h Width DSAR VRBA', 'Number of drops DSAR VRBA', 'Max l Width DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Median Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_pressurizing VRBA', 'Sum_VT', 'Sum_LP', 'Delta_Max_Min_LP', 'Last_tornillo', 'Delta_Max_Min_Precipitations']
#
# ------------------------------------------------------------
# Feature selection for test year: 2021
# Initial number of features: 85
# Initial Score (Full Set): 0.8878
# Round 1 | Removed: Std Prominence DSAR VORI | New F2: 0.8997
# Round 2 | Removed: Max drop DSAR VORI | New F2: 0.9055
# Round 7 | Removed: Last_Precipitations | New F2: 0.9129
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 78 | Best F2 Score: 0.9129
# Selected features for VORI (test year 2021): ['Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Max Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Max h Width RSAM VORI', 'Std h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max Drop Depth RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max l Width RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Max h Width DSAR VORI', 'Std h Width DSAR VORI', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Std peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'is_cascading_material_failure VORI', 'is_possible_seal_failure VORI', 'is_pressurizing VORI', 'slope_ratio VORI', 'num_state_changes_inv_rsam VORI', 'num_state_changes_log_dsar VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'quiescence_rsam_drop_ratio VORI', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Max_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.8557
# Round 2 | Removed: Avg peak DSAR VRBA | New F2: 0.8561
# Round 3 | Removed: Number of drops DSAR VRBA | New F2: 0.8649
# Round 8 | Removed: is_pressurizing VRBA | New F2: 0.8652
# Round 11 | Removed: Std l Width DSAR VRBA | New F2: 0.8684
# Round 17 | Removed: Std Prominence RSAM VRBA | New F2: 0.8691
# Round 18 | Removed: Max Drop Depth DSAR VRBA | New F2: 0.8693
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 67 | Best F2 Score: 0.8693
# Selected features for VRBA (test year 2021): ['Number of peaks RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Std peak RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg h Width DSAR VRBA', 'Max h Width DSAR VRBA', 'Max peak DSAR VRBA', 'Avg Drop Depth DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Last_VT', 'Max_VT', 'Delta_Max_Min_VT', 'Sum_LP', 'Last_LP', 'Max_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'Sum_Precipitations', 'Last_Precipitations', 'Delta_Max_Min_Precipitations']
#
# ------------------------------------------------------------
# Feature selection for test year: 2022
# Initial number of features: 85
# Initial Score (Full Set): 0.905
# Round 1 | Removed: Max Drop Depth DSAR VORI | New F2: 0.9159
# Round 2 | Removed: Max peak DSAR VORI | New F2: 0.9173
# Round 8 | Removed: Std drop RSAM VORI | New F2: 0.9186
# Round 17 | Removed: Avg l Width DSAR VORI | New F2: 0.9253
# Round 41 | Removed: is_hydrothermal_seal VORI | New F2: 0.9264
# Round 42 | Removed: Avg Prominence RSAM VORI | New F2: 0.9274
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 43 | Best F2 Score: 0.9274
# Selected features for VORI (test year 2022): ['Max Prominence RSAM VORI', 'Max h Width RSAM VORI', 'Avg peak RSAM VORI', 'Std peak RSAM VORI', 'Number of drops RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Max Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg h Width DSAR VORI', 'Avg peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'is_cascading_material_failure VORI', 'num_state_changes_inv_rsam VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'Sum_VT', 'Last_VT', 'is_raising_VT', 'Sum_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'is_raising_tornillo', 'Sum_Precipitations', 'Max_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.9319
# Round 1 | Removed: Max Drop Depth DSAR VRBA | New F2: 0.9402
# Round 2 | Removed: Number of drops DSAR VRBA | New F2: 0.9437
# Round 9 | Removed: Avg drop RSAM VRBA | New F2: 0.9437
# Round 10 | Removed: Delta_Max_Min_Precipitations | New F2: 0.9447
# Round 26 | Removed: Max_tornillo | New F2: 0.9448
# Round 27 | Removed: Max Prominence RSAM VRBA | New F2: 0.9454
# Round 28 | Removed: Std Drop Depth DSAR VRBA | New F2: 0.9454
# Round 30 | Removed: Last_VT | New F2: 0.9473
# Round 33 | Removed: is_pressurizing VRBA | New F2: 0.9501
# Round 43 | Removed: season | New F2: 0.951
# Round 47 | Removed: num_state_changes_log_dsar VRBA | New F2: 0.9533
# Round 49 | Removed: Max l Width RSAM VRBA | New F2: 0.9536
# Round 50 | Removed: is_cascading_material_failure VRBA | New F2: 0.9542
# Round 58 | Removed: Number of drops RSAM VRBA | New F2: 0.9543
# Round 60 | Removed: falling_rsam_acceleration VRBA | New F2: 0.9549
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 25 | Best F2 Score: 0.9549
# Selected features for VRBA (test year 2022): ['Avg Prominence RSAM VRBA', 'Max peak RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Var Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Max Prominence DSAR VRBA', 'Std h Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'quiescence_rsam_duration VRBA', 'Max_LP', 'Delta_Max_Min_LP', 'Last_tornillo', 'Delta_Max_Min_tornillo', 'Sum_Precipitations', 'Last_Precipitations']
#
# ------------------------------------------------------------
# Feature selection for test year: 2023
# Initial number of features: 85
# Initial Score (Full Set): 0.8928
# Round 1 | Removed: Max_Precipitations | New F2: 0.9002
# Round 2 | Removed: Delta_Max_Min_tornillo | New F2: 0.9038
# Round 4 | Removed: falling_rsam_mean_abs_derivative VORI | New F2: 0.9072
# Round 9 | Removed: Median Value DSAR VORI | New F2: 0.9083
# Round 10 | Removed: Std Drop Depth RSAM VORI | New F2: 0.9092
# Round 13 | Removed: Avg h Width RSAM VORI | New F2: 0.9093
# Round 14 | Removed: Max h Width RSAM VORI | New F2: 0.9116
# Round 19 | Removed: Avg Value RSAM VORI | New F2: 0.9132
# Round 21 | Removed: Last_tornillo | New F2: 0.9141
# Round 22 | Removed: Avg h Width DSAR VORI | New F2: 0.9147
# Round 23 | Removed: is_possible_seal_failure VORI | New F2: 0.9182
# Round 26 | Removed: Std Prominence RSAM VORI | New F2: 0.922
# Round 30 | Removed: Max Drop Depth DSAR VORI | New F2: 0.9221
# Round 31 | Removed: Std peak DSAR VORI | New F2: 0.9248
# Round 34 | Removed: Std h Width DSAR VORI | New F2: 0.9256
# Round 35 | Removed: Mean Min Values DSAR VORI | New F2: 0.9264
# Round 43 | Removed: Std Prominence DSAR VORI | New F2: 0.9284
# Round 45 | Removed: Number of peaks DSAR VORI | New F2: 0.93
# Round 51 | Removed: Max l Width RSAM VORI | New F2: 0.93
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 34 | Best F2 Score: 0.93
# Selected features for VORI (test year 2023): ['Avg Prominence RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Std l Width RSAM VORI', 'Avg drop RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Std Value RSAM VORI', 'Median Value RSAM VORI', 'Var Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Max Prominence DSAR VORI', 'Max peak DSAR VORI', 'Number of drops DSAR VORI', 'Avg l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Max drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Var Value DSAR VORI', 'is_pressurizing VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Max_LP', 'Delta_Max_Min_LP', 'Sum_tornillo', 'Last_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.8938
# Round 1 | Removed: num_state_changes_inv_rsam VRBA | New F2: 0.9001
# Round 5 | Removed: Avg Drop Depth RSAM VRBA | New F2: 0.9005
# Round 7 | Removed: Max Prominence DSAR VRBA | New F2: 0.9016
# Round 8 | Removed: Quantile Changes RSAM VRBA | New F2: 0.902
# Round 9 | Removed: Max peak RSAM VRBA | New F2: 0.9033
# Round 11 | Removed: Avg peak DSAR VRBA | New F2: 0.9043
# Round 12 | Removed: Max peak DSAR VRBA | New F2: 0.9077
# Round 13 | Removed: Avg Value DSAR VRBA | New F2: 0.9082
# Round 14 | Removed: Avg l Width DSAR VRBA | New F2: 0.9116
# Round 15 | Removed: Number of drops RSAM VRBA | New F2: 0.913
# Round 16 | Removed: Last_VT | New F2: 0.9132
# Round 18 | Removed: Max_Precipitations | New F2: 0.9148
# Round 20 | Removed: Last_tornillo | New F2: 0.9178
# Round 27 | Removed: Sum_Precipitations | New F2: 0.9183
# Round 28 | Removed: falling_rsam_mean_abs_derivative VRBA | New F2: 0.919
# Round 30 | Removed: Std h Width RSAM VRBA | New F2: 0.9192
# Round 32 | Removed: Avg h Width RSAM VRBA | New F2: 0.9254
# Round 44 | Removed: Last_LP | New F2: 0.9263
# Round 46 | Removed: Std peak RSAM VRBA | New F2: 0.9272
# Round 47 | Removed: Max Prominence RSAM VRBA | New F2: 0.9281
# Round 54 | Removed: Var Value RSAM VRBA | New F2: 0.9288
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 31 | Best F2 Score: 0.9288
# Selected features for VRBA (test year 2023): ['Number of peaks RSAM VRBA', 'Std Prominence RSAM VRBA', 'Std Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Std Value RSAM VRBA', 'Median Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Number of drops DSAR VRBA', 'Std Drop Depth DSAR VRBA', 'Std l Width DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Median Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_possible_seal_failure VRBA', 'is_pressurizing VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_mean_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Sum_LP', 'Delta_Max_Min_LP', 'Max_tornillo', 'Delta_Max_Min_tornillo', 'Last_Precipitations', 'season']
#
# ------------------------------------------------------------
# Feature selection for test year: 2024
# Initial number of features: 85
# Initial Score (Full Set): 0.9004
# Round 1 | Removed: Avg Value DSAR VORI | New F2: 0.9229
# Round 5 | Removed: Max_LP | New F2: 0.9234
# Round 9 | Removed: Std l Width RSAM VORI | New F2: 0.9259
# Round 13 | Removed: Max drop DSAR VORI | New F2: 0.9348
# Round 25 | Removed: Last_VT | New F2: 0.9364
# Round 37 | Removed: Max Drop Depth RSAM VORI | New F2: 0.9371
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 48 | Best F2 Score: 0.9371
# Selected features for VORI (test year 2024): ['Number of peaks RSAM VORI', 'Avg Prominence RSAM VORI', 'Std Prominence RSAM VORI', 'Avg h Width RSAM VORI', 'Avg peak RSAM VORI', 'Max peak RSAM VORI', 'Std peak RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Avg l Width RSAM VORI', 'Max drop RSAM VORI', 'Std drop RSAM VORI', 'Quantile Changes RSAM VORI', 'Avg Value RSAM VORI', 'Median Value RSAM VORI', 'Mean Min Values RSAM VORI', 'Number of peaks DSAR VORI', 'Avg Prominence DSAR VORI', 'Std Prominence DSAR VORI', 'Avg peak DSAR VORI', 'Std peak DSAR VORI', 'Max Drop Depth DSAR VORI', 'Std Drop Depth DSAR VORI', 'Avg l Width DSAR VORI', 'Max l Width DSAR VORI', 'Std l Width DSAR VORI', 'Avg drop DSAR VORI', 'Quantile Changes DSAR VORI', 'Std Value DSAR VORI', 'Median Value DSAR VORI', 'Var Value DSAR VORI', 'Mean Min Values DSAR VORI', 'is_cascading_material_failure VORI', 'is_pressurizing VORI', 'num_state_changes_inv_rsam VORI', 'is_hydrothermal_seal VORI', 'falling_rsam_acceleration VORI', 'falling_rsam_slope VORI', 'falling_rsam_mean_derivative VORI', 'falling_rsam_mean_abs_derivative VORI', 'quiescence_rsam_duration VORI', 'Sum_VT', 'Max_VT', 'Delta_Max_Min_VT', 'is_raising_VT', 'Delta_Max_Min_LP', 'Delta_Max_Min_tornillo', 'Max_Precipitations', 'season']
# Initial number of features: 85
# Initial Score (Full Set): 0.92
# Round 1 | Removed: Std Prominence RSAM VRBA | New F2: 0.9279
# Round 2 | Removed: Std h Width DSAR VRBA | New F2: 0.9328
# Round 4 | Removed: Last_VT | New F2: 0.9353
# Round 20 | Removed: Std Drop Depth DSAR VRBA | New F2: 0.9402
# Warning: Number of features is getting low, consider stopping.
# Final number of features: 65 | Best F2 Score: 0.9402
# Selected features for VRBA (test year 2024): ['Number of peaks RSAM VRBA', 'Max Prominence RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max h Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg peak RSAM VRBA', 'Max peak RSAM VRBA', 'Number of drops RSAM VRBA', 'Max Drop Depth RSAM VRBA', 'Avg l Width RSAM VRBA', 'Max l Width RSAM VRBA', 'Std l Width RSAM VRBA', 'Avg drop RSAM VRBA', 'Max drop RSAM VRBA', 'Std drop RSAM VRBA', 'Quantile Changes RSAM VRBA', 'Avg Value RSAM VRBA', 'Std Value RSAM VRBA', 'Mean Min Values RSAM VRBA', 'Number of peaks DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Max Prominence DSAR VRBA', 'Std Prominence DSAR VRBA', 'Avg peak DSAR VRBA', 'Max peak DSAR VRBA', 'Std peak DSAR VRBA', 'Number of drops DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max l Width DSAR VRBA', 'Std l Width DSAR VRBA', 'Avg drop DSAR VRBA', 'Max drop DSAR VRBA', 'Std drop DSAR VRBA', 'Quantile Changes DSAR VRBA', 'Avg Value DSAR VRBA', 'Std Value DSAR VRBA', 'Median Value DSAR VRBA', 'Var Value DSAR VRBA', 'Mean Min Values DSAR VRBA', 'is_cascading_material_failure VRBA', 'is_possible_seal_failure VRBA', 'slope_ratio VRBA', 'num_state_changes_inv_rsam VRBA', 'num_state_changes_log_dsar VRBA', 'is_hydrothermal_seal VRBA', 'falling_rsam_acceleration VRBA', 'falling_rsam_slope VRBA', 'falling_rsam_mean_derivative VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'quiescence_rsam_duration VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Sum_VT', 'Max_VT', 'Delta_Max_Min_VT', 'Sum_LP', 'Last_LP', 'Delta_Max_Min_LP', 'is_raising_LP', 'Sum_tornillo', 'Last_tornillo', 'Delta_Max_Min_tornillo', 'is_raising_tornillo', 'Last_Precipitations', 'Delta_Max_Min_Precipitations', 'season']
#
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[95 44]
#  [26 59]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73       139
#            1       0.57      0.69      0.63        85
#
#     accuracy                           0.69       224
#    macro avg       0.68      0.69      0.68       224
# weighted avg       0.70      0.69      0.69       224
#
#
#  Top Features (VORI)
# Max_LP                       0.198127
# Sum_Precipitations           0.063196
# Mean Min Values DSAR VORI    0.061372
# Max drop DSAR VORI           0.058535
# Mean Min Values RSAM VORI    0.057178
# Median Value DSAR VORI       0.052046
# Max drop RSAM VORI           0.046045
# Median Value RSAM VORI       0.044467
# Max peak RSAM VORI           0.043994
# Max peak DSAR VORI           0.041577
# Avg drop RSAM VORI           0.041089
# Avg peak DSAR VORI           0.039548
# season                       0.037737
# Var Value RSAM VORI          0.037408
# Avg peak RSAM VORI           0.037129
# Std Value RSAM VORI          0.032806
# Max_VT                       0.028333
# Std drop RSAM VORI           0.025269
# Delta_Max_Min_VT             0.024386
# Max h Width DSAR VORI        0.018489
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.52 ± 0.76
# Mean Magnitude (Missed - FN):   3.27 ± 0.68
# High magnitude events were more detected
#  length of time array: 224
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[65 74]
#  [23 62]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.47      0.57       139
#            1       0.46      0.73      0.56        85
#
#     accuracy                           0.57       224
#    macro avg       0.60      0.60      0.57       224
# weighted avg       0.63      0.57      0.57       224
#
#
#  Top Features (VRBA)
# Delta_Max_Min_LP              0.263182
# Median Value DSAR VRBA        0.117200
# Quantile Changes RSAM VRBA    0.108541
# Quantile Changes DSAR VRBA    0.052304
# Avg Value DSAR VRBA           0.044764
# Sum_tornillo                  0.043184
# season                        0.035605
# Var Value RSAM VRBA           0.026645
# Avg peak DSAR VRBA            0.025675
# Sum_VT                        0.023499
# Median Value RSAM VRBA        0.023097
# Max Drop Depth DSAR VRBA      0.022807
# Max Prominence RSAM VRBA      0.022368
# Max drop DSAR VRBA            0.018859
# Sum_Precipitations            0.015814
# Mean Min Values RSAM VRBA     0.013762
# Avg drop RSAM VRBA            0.013349
# Max_VT                        0.013178
# Max drop RSAM VRBA            0.010711
# Avg Value RSAM VRBA           0.010544
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.42 ± 0.79
# Mean Magnitude (Missed - FN):   3.52 ± 0.59
# Low magnitude events were more detected
#  length of time array: 224
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 49 | Mean VORI RSAM Coverage: 94.48±15.23% | Mean VORI DSAR Coverage: 96.57±14.85% | Mean VRBA Coverage: 84.11±20.88%
# Both Missed (FN): 13 | Mean VORI RSAM Coverage: 83.55±15.60% | Mean VORI DSAR Coverage: 88.28±18.52% | Mean VRBA Coverage: 80.78±26.57%
# Both False Positives (FP): 15 | Mean VORI RSAM Coverage: 99.68±0.97% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 55.86±37.12%
# Both True Negatives (TN): 36 | Mean VORI RSAM Coverage: 99.76±0.26% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 87.42±21.82%
# VORI Detected Without VRBA (TP): 10 | Mean VORI RSAM Coverage: 93.07+-8.05% | Mean VORI DSAR Coverage: 97.94+-6.33% | Mean VRBA Coverage: 93.42+-11.12%
# VRBA Detected Without VORI (TP): 13 | Mean VORI RSAM Coverage: 96.05+-9.27% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 77.41+-21.23%
# VORI Detected Without VRBA (TN): 59 | Mean VORI RSAM Coverage: 99.82+-0.25% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 65.82+-19.62%
# VRBA Detected Without VORI (TN): 29 | Mean VORI RSAM Coverage: 99.23+-1.61% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 46.45+-42.70%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[72 31]
#  [ 6 38]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.70      0.80       103
#            1       0.55      0.86      0.67        44
#
#     accuracy                           0.75       147
#    macro avg       0.74      0.78      0.73       147
# weighted avg       0.81      0.75      0.76       147
#
#
#  Top Features (VORI)
# Sum_LP                          0.113428
# Mean Min Values DSAR VORI       0.082113
# Max drop DSAR VORI              0.077208
# Avg peak RSAM VORI              0.062331
# Avg peak DSAR VORI              0.055473
# Max_tornillo                    0.055169
# Max_LP                          0.055047
# Max peak DSAR VORI              0.054797
# Median Value DSAR VORI          0.051654
# Std Value RSAM VORI             0.050163
# Var Value RSAM VORI             0.049571
# Max drop RSAM VORI              0.047632
# Delta_Max_Min_LP                0.045915
# Delta_Max_Min_tornillo          0.044875
# Delta_Max_Min_Precipitations    0.033868
# Max_Precipitations              0.033827
# Sum_Precipitations              0.026932
# Delta_Max_Min_VT                0.024659
# Max l Width DSAR VORI           0.014885
# season                          0.012168
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.96 ± 0.85
# Mean Magnitude (Missed - FN):   3.53 ± 1.28
# Low magnitude events were more detected
#  length of time array: 147
# Detected Lahars (TP): 2 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[90 13]
#  [23 21]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       103
#            1       0.62      0.48      0.54        44
#
#     accuracy                           0.76       147
#    macro avg       0.71      0.68      0.69       147
# weighted avg       0.74      0.76      0.75       147
#
#
#  Top Features (VRBA)
# Quantile Changes DSAR VRBA      0.168382
# Median Value DSAR VRBA          0.148695
# Sum_LP                          0.132432
# Delta_Max_Min_LP                0.126319
# Avg Value RSAM VRBA             0.091817
# Max peak RSAM VRBA              0.080346
# Avg drop RSAM VRBA              0.063618
# Sum_VT                          0.034986
# Mean Min Values RSAM VRBA       0.032519
# Var Value RSAM VRBA             0.027074
# Delta_Max_Min_Precipitations    0.024824
# Avg Prominence DSAR VRBA        0.022954
# Mean Min Values DSAR VRBA       0.011465
# Std Prominence RSAM VRBA        0.009486
# Last_tornillo                   0.008400
# Number of drops DSAR VRBA       0.004493
# Std h Width DSAR VRBA           0.004350
# Std h Width RSAM VRBA           0.003350
# Max h Width DSAR VRBA           0.002780
# Max l Width DSAR VRBA           0.000963
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.03 ± 0.88
# Mean Magnitude (Missed - FN):   3.04 ± 0.98
# Low magnitude events were more detected
#  length of time array: 147
# Detected Lahars (TP): 2 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 20 | Mean VORI RSAM Coverage: 94.26±5.83% | Mean VORI DSAR Coverage: 94.26±5.83% | Mean VRBA Coverage: 63.14±9.59%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 79.05±28.39% | Mean VORI DSAR Coverage: 79.15±28.48% | Mean VRBA Coverage: 39.17±36.35%
# Both False Positives (FP): 8 | Mean VORI RSAM Coverage: 91.21±11.38% | Mean VORI DSAR Coverage: 95.73±3.52% | Mean VRBA Coverage: 60.36±16.07%
# Both True Negatives (TN): 67 | Mean VORI RSAM Coverage: 98.51±6.12% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 88.04±16.60%
# VORI Detected Without VRBA (TP): 18 | Mean VORI RSAM Coverage: 98.16+-5.25% | Mean VORI DSAR Coverage: 98.18+-5.26% | Mean VRBA Coverage: 64.87+-5.95%
# VRBA Detected Without VORI (TP): 1 | Mean VORI RSAM Coverage: 64.92+-nan% | Mean VORI DSAR Coverage: 69.68+-nan% | Mean VRBA Coverage: 70.92+-nan%
# VORI Detected Without VRBA (TN): 5 | Mean VORI RSAM Coverage: 96.30+-7.95% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 99.72+-0.59%
# VRBA Detected Without VORI (TN): 23 | Mean VORI RSAM Coverage: 96.80+-5.68% | Mean VORI DSAR Coverage: 98.23+-3.43% | Mean VRBA Coverage: 88.66+-18.23%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[112  60]
#  [ 25 145]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.82      0.65      0.72       172
#            1       0.71      0.85      0.77       170
#
#     accuracy                           0.75       342
#    macro avg       0.76      0.75      0.75       342
# weighted avg       0.76      0.75      0.75       342
#
#
#  Top Features (VORI)
# Avg drop DSAR VORI            0.075655
# Median Value DSAR VORI        0.058387
# Avg peak DSAR VORI            0.053269
# Max peak DSAR VORI            0.048454
# Std Value DSAR VORI           0.042858
# Var Value DSAR VORI           0.042455
# Quantile Changes RSAM VORI    0.030431
# Sum_LP                        0.028238
# Max_LP                        0.027070
# Max_tornillo                  0.026753
# Max peak RSAM VORI            0.025099
# Delta_Max_Min_tornillo        0.024291
# Avg Prominence RSAM VORI      0.024287
# Sum_VT                        0.023552
# Max_Precipitations            0.023166
# Avg peak RSAM VORI            0.021978
# Sum_tornillo                  0.021338
# Max Prominence RSAM VORI      0.019339
# Avg Value RSAM VORI           0.019191
# Var Value RSAM VORI           0.019117
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.61 ± 0.56
# Mean Magnitude (Missed - FN):   3.12 ± 0.54
# Low magnitude events were more detected
#  length of time array: 342
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[103  69]
#  [ 19 151]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.60      0.70       172
#            1       0.69      0.89      0.77       170
#
#     accuracy                           0.74       342
#    macro avg       0.77      0.74      0.74       342
# weighted avg       0.77      0.74      0.74       342
#
#
#  Top Features (VRBA)
# Max peak DSAR VRBA            0.204852
# Median Value DSAR VRBA        0.149068
# Mean Min Values RSAM VRBA     0.057751
# Std Value DSAR VRBA           0.050953
# Quantile Changes DSAR VRBA    0.041118
# Std peak RSAM VRBA            0.033855
# Quantile Changes RSAM VRBA    0.033336
# Max_LP                        0.031357
# Avg Value RSAM VRBA           0.024303
# Avg Drop Depth DSAR VRBA      0.024064
# Sum_VT                        0.023130
# Delta_Max_Min_LP              0.023042
# Sum_tornillo                  0.017535
# Max drop RSAM VRBA            0.016331
# Avg drop DSAR VRBA            0.016155
# Mean Min Values DSAR VRBA     0.015682
# Sum_LP                        0.014467
# Max_tornillo                  0.014039
# Avg peak RSAM VRBA            0.013780
# Avg drop RSAM VRBA            0.013447
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.66 ± 0.58
# Mean Magnitude (Missed - FN):   2.90 ± 0.56
# Low magnitude events were more detected
#  length of time array: 342
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 134 | Mean VORI RSAM Coverage: 96.72±6.99% | Mean VORI DSAR Coverage: 99.16±4.73% | Mean VRBA Coverage: 66.69±20.13%
# Both Missed (FN): 8 | Mean VORI RSAM Coverage: 99.88±0.05% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 78.49±37.61%
# Both False Positives (FP): 49 | Mean VORI RSAM Coverage: 99.13±3.21% | Mean VORI DSAR Coverage: 99.22±3.11% | Mean VRBA Coverage: 57.24±41.53%
# Both True Negatives (TN): 92 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 84.35±20.84%
# VORI Detected Without VRBA (TP): 11 | Mean VORI RSAM Coverage: 95.52+-5.29% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 78.37+-35.18%
# VRBA Detected Without VORI (TP): 17 | Mean VORI RSAM Coverage: 99.85+-0.02% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 98.64+-1.72%
# VORI Detected Without VRBA (TN): 20 | Mean VORI RSAM Coverage: 99.90+-0.04% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 84.48+-23.58%
# VRBA Detected Without VORI (TN): 11 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 80.62+-22.27%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[78 21]
#  [28 33]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76        99
#            1       0.61      0.54      0.57        61
#
#     accuracy                           0.69       160
#    macro avg       0.67      0.66      0.67       160
# weighted avg       0.69      0.69      0.69       160
#
#
#  Top Features (VORI)
# Sum_LP                        0.117672
# Mean Min Values DSAR VORI     0.099972
# Avg drop DSAR VORI            0.096202
# Max drop DSAR VORI            0.088632
# Delta_Max_Min_LP              0.053688
# Avg peak DSAR VORI            0.048142
# Quantile Changes RSAM VORI    0.047683
# Var Value RSAM VORI           0.043844
# Quantile Changes DSAR VORI    0.037468
# Sum_Precipitations            0.030553
# Var Value DSAR VORI           0.030373
# Max_Precipitations            0.029639
# Mean Min Values RSAM VORI     0.028165
# Avg peak RSAM VORI            0.023952
# Sum_tornillo                  0.023830
# Max drop RSAM VORI            0.023167
# Sum_VT                        0.023017
# Avg drop RSAM VORI            0.022088
# Max Prominence RSAM VORI      0.018865
# Std Drop Depth RSAM VORI      0.015931
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.45 ± 0.64
# Mean Magnitude (Missed - FN):   3.04 ± 0.68
# Low magnitude events were more detected
#  length of time array: 160
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[79 20]
#  [32 29]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.80      0.75        99
#            1       0.59      0.48      0.53        61
#
#     accuracy                           0.68       160
#    macro avg       0.65      0.64      0.64       160
# weighted avg       0.67      0.68      0.67       160
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.284293
# Quantile Changes DSAR VRBA    0.108721
# Max_LP                        0.108339
# Std Value DSAR VRBA           0.069591
# Delta_Max_Min_LP              0.060255
# Var Value DSAR VRBA           0.056336
# Max drop RSAM VRBA            0.043908
# Max peak RSAM VRBA            0.033386
# Avg Value RSAM VRBA           0.030660
# Delta_Max_Min_tornillo        0.026606
# Avg Prominence RSAM VRBA      0.026503
# Mean Min Values RSAM VRBA     0.026072
# Var Value RSAM VRBA           0.019313
# Std Value RSAM VRBA           0.018520
# Sum_Precipitations            0.018059
# Max Drop Depth RSAM VRBA      0.015441
# Max Prominence DSAR VRBA      0.013726
# Last_tornillo                 0.011612
# Std h Width DSAR VRBA         0.007148
# Std drop RSAM VRBA            0.007140
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.70 ± 0.73
# Mean Magnitude (Missed - FN):   2.74 ± 0.72
# Low magnitude events were more detected
#  length of time array: 160
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 19 | Mean VORI RSAM Coverage: 86.42±24.78% | Mean VORI DSAR Coverage: 87.57±25.25% | Mean VRBA Coverage: 81.96±20.95%
# Both Missed (FN): 18 | Mean VORI RSAM Coverage: 97.97±6.24% | Mean VORI DSAR Coverage: 98.94±4.26% | Mean VRBA Coverage: 87.36±16.41%
# Both False Positives (FP): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both True Negatives (TN): 58 | Mean VORI RSAM Coverage: 91.75±19.36% | Mean VORI DSAR Coverage: 93.69±16.18% | Mean VRBA Coverage: 95.47±9.54%
# VORI Detected Without VRBA (TP): 14 | Mean VORI RSAM Coverage: 91.80+-11.48% | Mean VORI DSAR Coverage: 94.71+-11.98% | Mean VRBA Coverage: 88.51+-18.04%
# VRBA Detected Without VORI (TP): 10 | Mean VORI RSAM Coverage: 99.87+-0.04% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 98.71+-2.18%
# VORI Detected Without VRBA (TN): 20 | Mean VORI RSAM Coverage: 68.45+-28.84% | Mean VORI DSAR Coverage: 68.63+-29.04% | Mean VRBA Coverage: 71.52+-24.23%
# VRBA Detected Without VORI (TN): 21 | Mean VORI RSAM Coverage: 61.32+-49.34% | Mean VORI DSAR Coverage: 62.81+-48.68% | Mean VRBA Coverage: 99.38+-2.13%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[37 19]
#  [14 38]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.66      0.69        56
#            1       0.67      0.73      0.70        52
#
#     accuracy                           0.69       108
#    macro avg       0.70      0.70      0.69       108
# weighted avg       0.70      0.69      0.69       108
#
#
#  Top Features (VORI)
# Sum_tornillo                  0.094637
# Max_LP                        0.058416
# Delta_Max_Min_LP              0.052747
# Quantile Changes RSAM VORI    0.051737
# Mean Min Values RSAM VORI     0.051210
# Max drop DSAR VORI            0.043457
# Max peak RSAM VORI            0.041993
# Avg drop DSAR VORI            0.040887
# Median Value RSAM VORI        0.040849
# Avg peak RSAM VORI            0.038927
# Quantile Changes DSAR VORI    0.037228
# Max peak DSAR VORI            0.035425
# Last_Precipitations           0.034159
# season                        0.034111
# Max drop RSAM VORI            0.032297
# Var Value DSAR VORI           0.032080
# Std Value RSAM VORI           0.031895
# Max_VT                        0.030795
# Avg drop RSAM VORI            0.030378
# Std drop RSAM VORI            0.027792
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.96 ± 0.96
# Mean Magnitude (Missed - FN):   2.81 ± 1.09
# High magnitude events were more detected
#  length of time array: 108
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682000000
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000000000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132000000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[37 19]
#  [23 29]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.66      0.64        56
#            1       0.60      0.56      0.58        52
#
#     accuracy                           0.61       108
#    macro avg       0.61      0.61      0.61       108
# weighted avg       0.61      0.61      0.61       108
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA           0.228323
# Quantile Changes DSAR VRBA       0.124735
# Mean Min Values DSAR VRBA        0.108797
# Mean Min Values RSAM VRBA        0.093889
# season                           0.089380
# Max_tornillo                     0.047168
# Std Value RSAM VRBA              0.041091
# Delta_Max_Min_LP                 0.040214
# Sum_LP                           0.038291
# Max drop RSAM VRBA               0.037420
# Median Value RSAM VRBA           0.035117
# Sum_VT                           0.033252
# Last_Precipitations              0.023502
# Std Prominence RSAM VRBA         0.016404
# Std drop RSAM VRBA               0.015831
# Delta_Max_Min_tornillo           0.005414
# Avg l Width RSAM VRBA            0.004129
# Std Drop Depth DSAR VRBA         0.003888
# is_possible_seal_failure VRBA    0.003675
# Std Drop Depth RSAM VRBA         0.002818
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.78 ± 0.87
# Mean Magnitude (Missed - FN):   3.08 ± 1.11
# Low magnitude events were more detected
#  length of time array: 108
# Detected Lahars (TP): 1 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000000000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132000000
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682000000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 25 | Mean VORI RSAM Coverage: 51.92±45.89% | Mean VORI DSAR Coverage: 57.51±48.20% | Mean VRBA Coverage: 49.12±17.39%
# Both Missed (FN): 10 | Mean VORI RSAM Coverage: 85.11±22.34% | Mean VORI DSAR Coverage: 85.60±21.91% | Mean VRBA Coverage: 54.05±39.47%
# Both False Positives (FP): 7 | Mean VORI RSAM Coverage: 95.14±6.02% | Mean VORI DSAR Coverage: 99.40±1.43% | Mean VRBA Coverage: 65.42±5.17%
# Both True Negatives (TN): 25 | Mean VORI RSAM Coverage: 94.90±14.07% | Mean VORI DSAR Coverage: 95.37±12.91% | Mean VRBA Coverage: 59.85±17.03%
# VORI Detected Without VRBA (TP): 13 | Mean VORI RSAM Coverage: 82.51+-37.35% | Mean VORI DSAR Coverage: 83.18+-37.25% | Mean VRBA Coverage: 61.88+-14.77%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 32.33+-45.61% | Mean VORI DSAR Coverage: 32.33+-45.61% | Mean VRBA Coverage: 43.27+-8.61%
# VORI Detected Without VRBA (TN): 12 | Mean VORI RSAM Coverage: 93.75+-8.39% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 64.14+-7.06%
# VRBA Detected Without VORI (TN): 12 | Mean VORI RSAM Coverage: 82.07+-18.03% | Mean VORI DSAR Coverage: 84.27+-15.96% | Mean VRBA Coverage: 57.22+-4.36%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[68 38]
#  [42 41]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.64      0.63       106
#            1       0.52      0.49      0.51        83
#
#     accuracy                           0.58       189
#    macro avg       0.57      0.57      0.57       189
# weighted avg       0.57      0.58      0.58       189
#
#
#  Top Features (VORI)
# Delta_Max_Min_tornillo        0.077536
# Delta_Max_Min_LP              0.074422
# Quantile Changes RSAM VORI    0.061828
# Max_Precipitations            0.059663
# Mean Min Values DSAR VORI     0.056375
# Avg drop DSAR VORI            0.053673
# Median Value DSAR VORI        0.045921
# Mean Min Values RSAM VORI     0.036310
# Avg Value RSAM VORI           0.036081
# Avg peak DSAR VORI            0.035379
# Std Value DSAR VORI           0.032647
# Max drop RSAM VORI            0.031528
# Avg peak RSAM VORI            0.031315
# Median Value RSAM VORI        0.030847
# Max peak RSAM VORI            0.030780
# Var Value DSAR VORI           0.030753
# Quantile Changes DSAR VORI    0.026868
# season                        0.026867
# Avg Prominence RSAM VORI      0.021870
# Sum_VT                        0.019974
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.45 ± 0.83
# Mean Magnitude (Missed - FN):   3.38 ± 0.75
# High magnitude events were more detected
#  length of time array: 189
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[94 12]
#  [25 58]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       106
#            1       0.83      0.70      0.76        83
#
#     accuracy                           0.80       189
#    macro avg       0.81      0.79      0.80       189
# weighted avg       0.81      0.80      0.80       189
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.216610
# Sum_LP                          0.143367
# Median Value DSAR VRBA          0.140511
# Delta_Max_Min_tornillo          0.043586
# Quantile Changes DSAR VRBA      0.039832
# Avg Value DSAR VRBA             0.039608
# Mean Min Values RSAM VRBA       0.032171
# Delta_Max_Min_LP                0.028277
# Avg Value RSAM VRBA             0.027682
# Max drop RSAM VRBA              0.026663
# Mean Min Values DSAR VRBA       0.022915
# Var Value DSAR VRBA             0.017887
# season                          0.017722
# Max Drop Depth RSAM VRBA        0.017411
# Sum_tornillo                    0.015000
# Delta_Max_Min_Precipitations    0.014141
# Avg peak RSAM VRBA              0.013831
# Max peak RSAM VRBA              0.013143
# Max drop DSAR VRBA              0.011708
# Avg drop DSAR VRBA              0.011081
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.40 ± 0.77
# Mean Magnitude (Missed - FN):   3.46 ± 0.82
# Low magnitude events were more detected
#  length of time array: 189
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 38 | Mean VORI RSAM Coverage: 96.44±7.10% | Mean VORI DSAR Coverage: 99.20±3.48% | Mean VRBA Coverage: 88.54±15.60%
# Both Missed (FN): 22 | Mean VORI RSAM Coverage: 87.52±13.82% | Mean VORI DSAR Coverage: 92.14±15.34% | Mean VRBA Coverage: 79.09±23.46%
# Both False Positives (FP): 2 | Mean VORI RSAM Coverage: 86.87±12.28% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 99.96±0.00%
# Both True Negatives (TN): 58 | Mean VORI RSAM Coverage: 98.23±9.17% | Mean VORI DSAR Coverage: 99.57±2.86% | Mean VRBA Coverage: 94.26±10.30%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 97.22+-2.15% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 97.87+-3.43%
# VRBA Detected Without VORI (TP): 20 | Mean VORI RSAM Coverage: 95.78+-7.24% | Mean VORI DSAR Coverage: 97.67+-5.88% | Mean VRBA Coverage: 80.76+-19.19%
# VORI Detected Without VRBA (TN): 10 | Mean VORI RSAM Coverage: 99.90+-0.05% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 79.45+-23.18%
# VRBA Detected Without VORI (TN): 36 | Mean VORI RSAM Coverage: 94.02+-14.00% | Mean VORI DSAR Coverage: 99.67+-1.63% | Mean VRBA Coverage: 99.03+-1.46%

# %% [markdown]
# The Backwards Selection Wrapper produces better results and does not become lazy when processing the entire set of features. The only issue is that it takes too long to produce results. With a view to improving the pipeline, this processing time is a factor that must be taken seriously into account.

# %% [markdown]
# #### SelectFromModel Feature Selection

# %%
# Use internal logic to extract the best features
def select_important_features(best_features_VORI, best_features_VRBA, best_models_VORI, best_models_VRBA, x_train_VORI, x_train_VRBA):
    for key in train_test_years_splits.keys():
        print(f"\n" + "="*50)
        print(f"FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: {key}")
        print("="*50)

    # Loop through both stations
        for station, best_models_dict, x_train_dict, best_features_dict in [
            ("VORI", best_models_VORI, x_train_VORI, best_features_VORI),
            ("VRBA", best_models_VRBA, x_train_VRBA, best_features_VRBA)
            ]:

            best_model = best_models_dict[key]
        
            # Configure the selector 
            # prefit=True: uses existing feature importances 
            # threshold='mean': keeps features with importance > average
            selector = SelectFromModel(best_model, threshold='mean', prefit=True)
        
            # Get the boolean selection mask
            selection_mask = selector.get_support()
        
            # Extract physical feature names
            original_columns = x_train_dict[key].columns
            selected_columns = original_columns[selection_mask].tolist()
        
            # Store for final evaluation
            best_features_dict[key] = selected_columns
        
            print(f"\n[ STATION {station} ]")
            print(f"Features kept: {len(selected_columns)} out of {len(original_columns)}")
        
            # Display the top features 
            surviving_importances = pd.Series(
            best_model.feature_importances_[selection_mask], 
            index=selected_columns
            ).sort_values(ascending=False)
        
            print(f"Top selected features:\n{surviving_importances}")
    return best_features_VORI, best_features_VRBA

# %%
# Dictionaries to store the selected feature names
best_features_VORI_train, best_features_VRBA_train = select_important_features({}, {}, best_models_VORI_train, best_models_VRBA_train, x_train_VORI, x_train_VRBA)
# Out:
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2019
# ==================================================
#
# [ STATION VORI ]
# Features kept: 36 out of 85
# Top selected features:
# Sum_LP                          0.052273
# Quantile Changes RSAM VORI      0.046619
# slope_ratio VORI                0.037030
# Max drop DSAR VORI              0.031075
# Mean Min Values RSAM VORI       0.029244
# Quantile Changes DSAR VORI      0.028574
# Max l Width DSAR VORI           0.025626
# Mean Min Values DSAR VORI       0.025040
# Sum_Precipitations              0.023493
# Max_LP                          0.022152
# Delta_Max_Min_Precipitations    0.022137
# Max drop RSAM VORI              0.020598
# Median Value DSAR VORI          0.020380
# Avg h Width DSAR VORI           0.019671
# Var Value RSAM VORI             0.019303
# Max peak DSAR VORI              0.018458
# Avg Value RSAM VORI             0.018347
# Max Drop Depth DSAR VORI        0.018303
# Avg l Width DSAR VORI           0.018094
# Avg Drop Depth DSAR VORI        0.017503
# Last_LP                         0.017144
# Avg Prominence DSAR VORI        0.016942
# Std Value RSAM VORI             0.016705
# Max Prominence RSAM VORI        0.016153
# Avg h Width RSAM VORI           0.016002
# Avg drop DSAR VORI              0.015970
# Avg peak DSAR VORI              0.015966
# Avg Value DSAR VORI             0.015831
# Max h Width RSAM VORI           0.015739
# Avg drop RSAM VORI              0.015537
# Avg Prominence RSAM VORI        0.015352
# Median Value RSAM VORI          0.014180
# Max Prominence DSAR VORI        0.013340
# Avg l Width RSAM VORI           0.013036
# Delta_Max_Min_LP                0.012986
# Avg Drop Depth RSAM VORI        0.011928
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 42 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA      0.039112
# Mean Min Values RSAM VRBA       0.030633
# Sum_LP                          0.030145
# Avg Value DSAR VRBA             0.028656
# Max_LP                          0.027542
# Max peak DSAR VRBA              0.027427
# Std Value RSAM VRBA             0.026601
# Max l Width RSAM VRBA           0.026529
# Var Value RSAM VRBA             0.024169
# Sum_Precipitations              0.024162
# Std Value DSAR VRBA             0.022845
# Max Prominence RSAM VRBA        0.022553
# Delta_Max_Min_LP                0.021692
# Avg Value RSAM VRBA             0.021353
# Avg peak RSAM VRBA              0.021256
# Median Value DSAR VRBA          0.021251
# Median Value RSAM VRBA          0.020921
# Max l Width DSAR VRBA           0.020829
# Var Value DSAR VRBA             0.020526
# Max Drop Depth RSAM VRBA        0.020508
# Delta_Max_Min_Precipitations    0.020090
# Mean Min Values DSAR VRBA       0.020011
# Max peak RSAM VRBA              0.019947
# Avg peak DSAR VRBA              0.019784
# Avg Drop Depth RSAM VRBA        0.019462
# Max h Width RSAM VRBA           0.018708
# Avg l Width DSAR VRBA           0.018308
# Avg Drop Depth DSAR VRBA        0.018174
# Last_LP                         0.017952
# Avg l Width RSAM VRBA           0.017943
# Quantile Changes DSAR VRBA      0.017936
# Avg Prominence RSAM VRBA        0.017822
# Avg h Width RSAM VRBA           0.017767
# Max h Width DSAR VRBA           0.017333
# Max Prominence DSAR VRBA        0.017193
# Max drop RSAM VRBA              0.016864
# slope_ratio VRBA                0.015235
# Max Drop Depth DSAR VRBA        0.014697
# Avg Prominence DSAR VRBA        0.014678
# Avg h Width DSAR VRBA           0.014587
# Avg drop DSAR VRBA              0.014524
# Avg drop RSAM VRBA              0.013501
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2020
# ==================================================
#
# [ STATION VORI ]
# Features kept: 39 out of 85
# Top selected features:
# Max_tornillo                  0.031815
# Median Value DSAR VORI        0.031737
# Delta_Max_Min_tornillo        0.029437
# Avg Prominence RSAM VORI      0.027995
# Max l Width RSAM VORI         0.027280
# Sum_tornillo                  0.027178
# Var Value RSAM VORI           0.025685
# Avg drop DSAR VORI            0.025204
# Avg h Width RSAM VORI         0.024880
# Max Prominence RSAM VORI      0.024653
# Quantile Changes DSAR VORI    0.024281
# Avg l Width RSAM VORI         0.023972
# Sum_LP                        0.022295
# Sum_Precipitations            0.021722
# Mean Min Values DSAR VORI     0.021654
# Max h Width RSAM VORI         0.021031
# Quantile Changes RSAM VORI    0.020660
# Std Value RSAM VORI           0.020630
# slope_ratio VORI              0.019638
# Avg Value DSAR VORI           0.019590
# Max drop DSAR VORI            0.019180
# Avg peak DSAR VORI            0.018495
# Max peak DSAR VORI            0.018000
# Max Drop Depth DSAR VORI      0.017894
# Avg peak RSAM VORI            0.017590
# Avg Drop Depth RSAM VORI      0.017141
# Max Drop Depth RSAM VORI      0.016944
# Std drop DSAR VORI            0.015900
# Max drop RSAM VORI            0.015384
# Avg drop RSAM VORI            0.014982
# Std Value DSAR VORI           0.014388
# Max l Width DSAR VORI         0.014089
# Avg Drop Depth DSAR VORI      0.014002
# Max peak RSAM VORI            0.013473
# Avg Value RSAM VORI           0.013259
# Max h Width DSAR VORI         0.013145
# Avg Prominence DSAR VORI      0.012993
# Avg l Width DSAR VORI         0.012742
# Mean Min Values RSAM VORI     0.012476
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 41 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA    0.068343
# Var Value DSAR VRBA           0.054277
# Std Value DSAR VRBA           0.043400
# slope_ratio VRBA              0.031966
# Quantile Changes DSAR VRBA    0.026367
# Avg Prominence RSAM VRBA      0.024923
# Avg peak DSAR VRBA            0.022623
# Sum_LP                        0.022536
# Max Drop Depth DSAR VRBA      0.022282
# Max Prominence RSAM VRBA      0.022078
# Std Value RSAM VRBA           0.021916
# Var Value RSAM VRBA           0.021712
# Max_tornillo                  0.021039
# Sum_tornillo                  0.020681
# Delta_Max_Min_tornillo        0.020498
# Avg Drop Depth DSAR VRBA      0.020162
# Median Value DSAR VRBA        0.020078
# Mean Min Values DSAR VRBA     0.019993
# Max Prominence DSAR VRBA      0.019792
# Sum_Precipitations            0.018797
# Avg Value RSAM VRBA           0.018786
# Avg Value DSAR VRBA           0.018247
# Avg Prominence DSAR VRBA      0.017413
# Avg Drop Depth RSAM VRBA      0.017327
# Max drop RSAM VRBA            0.017157
# Max l Width RSAM VRBA         0.016602
# Mean Min Values RSAM VRBA     0.016198
# Avg l Width RSAM VRBA         0.016186
# Max peak DSAR VRBA            0.016175
# Avg drop RSAM VRBA            0.015637
# Max l Width DSAR VRBA         0.015167
# Avg drop DSAR VRBA            0.015072
# Max Drop Depth RSAM VRBA      0.014907
# Max peak RSAM VRBA            0.014389
# Max h Width DSAR VRBA         0.014281
# Median Value RSAM VRBA        0.013392
# Last_LP                       0.013240
# Max h Width RSAM VRBA         0.012603
# Avg peak RSAM VRBA            0.012533
# Max drop DSAR VRBA            0.012416
# Max_Precipitations            0.012315
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2021
# ==================================================
#
# [ STATION VORI ]
# Features kept: 36 out of 85
# Top selected features:
# Quantile Changes RSAM VORI         0.062054
# Avg drop DSAR VORI                 0.038014
# Mean Min Values DSAR VORI          0.037439
# Max peak DSAR VORI                 0.036766
# Max drop DSAR VORI                 0.036122
# slope_ratio VORI                   0.033770
# Median Value DSAR VORI             0.028239
# Avg Prominence RSAM VORI           0.027292
# Max drop RSAM VORI                 0.025709
# Sum_tornillo                       0.024995
# Avg Value RSAM VORI                0.024735
# Max Prominence RSAM VORI           0.023083
# Avg l Width RSAM VORI              0.022271
# Avg drop RSAM VORI                 0.021772
# Last_tornillo                      0.020485
# num_state_changes_inv_rsam VORI    0.020118
# Avg peak DSAR VORI                 0.019271
# Std Value RSAM VORI                0.019196
# Median Value RSAM VORI             0.016726
# Sum_VT                             0.016595
# Sum_LP                             0.016520
# Avg h Width RSAM VORI              0.015897
# Delta_Max_Min_tornillo             0.015638
# Max Drop Depth DSAR VORI           0.015627
# Avg Drop Depth DSAR VORI           0.015316
# Mean Min Values RSAM VORI          0.015283
# Max Drop Depth RSAM VORI           0.015279
# Max_tornillo                       0.015199
# Var Value RSAM VORI                0.014974
# Max l Width DSAR VORI              0.014957
# Max l Width RSAM VORI              0.014434
# Std Value DSAR VORI                0.013993
# Sum_Precipitations                 0.013593
# Max h Width RSAM VORI              0.013366
# Var Value DSAR VORI                0.012711
# Std peak DSAR VORI                 0.012536
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 42 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA    0.053522
# Median Value DSAR VRBA        0.037588
# Avg Value DSAR VRBA           0.033844
# Avg peak DSAR VRBA            0.030044
# Mean Min Values RSAM VRBA     0.029108
# Std Value RSAM VRBA           0.026339
# Max peak DSAR VRBA            0.026034
# Quantile Changes DSAR VRBA    0.023845
# Var Value DSAR VRBA           0.023693
# Median Value RSAM VRBA        0.023029
# Std Value DSAR VRBA           0.022664
# Avg drop RSAM VRBA            0.022314
# Max drop RSAM VRBA            0.022000
# Avg Prominence RSAM VRBA      0.020985
# Max drop DSAR VRBA            0.020803
# Avg l Width RSAM VRBA         0.020321
# Mean Min Values DSAR VRBA     0.020134
# Sum_tornillo                  0.019659
# Max l Width RSAM VRBA         0.019644
# Max Prominence DSAR VRBA      0.019372
# Max peak RSAM VRBA            0.019371
# Var Value RSAM VRBA           0.018258
# Sum_LP                        0.017867
# Avg drop DSAR VRBA            0.017752
# Avg l Width DSAR VRBA         0.017306
# Avg peak RSAM VRBA            0.017151
# Avg Value RSAM VRBA           0.017005
# Max Drop Depth DSAR VRBA      0.016841
# Max l Width DSAR VRBA         0.016746
# Avg Drop Depth DSAR VRBA      0.016677
# Max Prominence RSAM VRBA      0.015980
# Delta_Max_Min_tornillo        0.015959
# Max h Width DSAR VRBA         0.015637
# slope_ratio VRBA              0.015477
# Avg h Width RSAM VRBA         0.015396
# Avg h Width DSAR VRBA         0.015080
# Max h Width RSAM VRBA         0.014919
# Avg Prominence DSAR VRBA      0.014395
# Max Drop Depth RSAM VRBA      0.013859
# Max_LP                        0.013541
# Avg Drop Depth RSAM VRBA      0.012934
# Sum_VT                        0.012029
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2022
# ==================================================
#
# [ STATION VORI ]
# Features kept: 24 out of 85
# Top selected features:
# Quantile Changes RSAM VORI         0.102434
# Max peak DSAR VORI                 0.092480
# Var Value RSAM VORI                0.067093
# Std Value RSAM VORI                0.066051
# Last_tornillo                      0.055292
# Sum_VT                             0.047297
# Max Prominence RSAM VORI           0.040019
# is_raising_tornillo                0.033871
# Avg l Width RSAM VORI              0.026774
# Sum_LP                             0.026490
# Avg Drop Depth RSAM VORI           0.026420
# Avg peak DSAR VORI                 0.024026
# num_state_changes_log_dsar VORI    0.023194
# Avg Prominence DSAR VORI           0.022659
# Max l Width RSAM VORI              0.022339
# Max drop RSAM VORI                 0.021629
# Avg Drop Depth DSAR VORI           0.019656
# num_state_changes_inv_rsam VORI    0.017463
# Sum_tornillo                       0.017364
# Median Value RSAM VORI             0.017357
# Mean Min Values DSAR VORI          0.016560
# Avg drop DSAR VORI                 0.016158
# Avg Prominence RSAM VORI           0.015847
# Delta_Max_Min_Precipitations       0.013706
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 37 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA         0.058862
# Avg peak DSAR VRBA                 0.050143
# Max peak DSAR VRBA                 0.041018
# Var Value DSAR VRBA                0.038647
# Var Value RSAM VRBA                0.033508
# Quantile Changes DSAR VRBA         0.032810
# Std Value DSAR VRBA                0.030522
# Std Value RSAM VRBA                0.027774
# Max h Width DSAR VRBA              0.026776
# Max l Width RSAM VRBA              0.026559
# Median Value DSAR VRBA             0.025806
# Avg Value DSAR VRBA                0.023761
# Avg Value RSAM VRBA                0.023506
# Max drop DSAR VRBA                 0.022553
# Avg Prominence RSAM VRBA           0.022317
# Avg h Width DSAR VRBA              0.020912
# Sum_Precipitations                 0.019935
# Max_LP                             0.019576
# Mean Min Values DSAR VRBA          0.019264
# Avg Prominence DSAR VRBA           0.018493
# Avg drop DSAR VRBA                 0.018436
# Avg Drop Depth RSAM VRBA           0.016858
# Sum_LP                             0.016611
# Max Prominence DSAR VRBA           0.016460
# Avg l Width RSAM VRBA              0.016459
# Mean Min Values RSAM VRBA          0.016405
# Delta_Max_Min_LP                   0.016141
# Max Drop Depth RSAM VRBA           0.015427
# num_state_changes_log_dsar VRBA    0.015395
# Avg peak RSAM VRBA                 0.015208
# Max l Width DSAR VRBA              0.014935
# Avg Drop Depth DSAR VRBA           0.014859
# Delta_Max_Min_Precipitations       0.014276
# Max Prominence RSAM VRBA           0.014073
# Max Drop Depth DSAR VRBA           0.013979
# Sum_VT                             0.013424
# is_pressurizing VRBA               0.012689
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2023
# ==================================================
#
# [ STATION VORI ]
# Features kept: 25 out of 85
# Top selected features:
# Max l Width RSAM VORI         0.108774
# Mean Min Values DSAR VORI     0.067445
# Avg h Width DSAR VORI         0.062630
# Quantile Changes RSAM VORI    0.056237
# Avg drop RSAM VORI            0.051914
# Max drop DSAR VORI            0.048356
# slope_ratio VORI              0.046407
# Std Value RSAM VORI           0.045024
# Max Drop Depth DSAR VORI      0.040363
# Avg drop DSAR VORI            0.038406
# Avg Prominence DSAR VORI      0.034925
# Avg Drop Depth DSAR VORI      0.032164
# Max l Width DSAR VORI         0.027952
# is_pressurizing VORI          0.023720
# Max h Width DSAR VORI         0.020843
# Avg Drop Depth RSAM VORI      0.020840
# Median Value RSAM VORI        0.020595
# Avg Value RSAM VORI           0.020253
# Max_Precipitations            0.018180
# Delta_Max_Min_tornillo        0.016263
# is_raising_tornillo           0.015051
# Last_Precipitations           0.014473
# Avg peak DSAR VORI            0.014166
# Max Prominence DSAR VORI      0.013920
# Delta_Max_Min_LP              0.012737
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 16 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA      0.243982
# Mean Min Values RSAM VRBA       0.147453
# Var Value DSAR VRBA             0.099884
# Std Value DSAR VRBA             0.091059
# Avg Drop Depth DSAR VRBA        0.060815
# Avg Value RSAM VRBA             0.041726
# Max Drop Depth DSAR VRBA        0.028646
# Max peak RSAM VRBA              0.026633
# Mean Min Values DSAR VRBA       0.023554
# Avg peak RSAM VRBA              0.022740
# Median Value DSAR VRBA          0.015023
# Std Value RSAM VRBA             0.014715
# Max peak DSAR VRBA              0.014013
# Delta_Max_Min_Precipitations    0.013750
# Avg peak DSAR VRBA              0.013370
# Sum_Precipitations              0.012726
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2024
# ==================================================
#
# [ STATION VORI ]
# Features kept: 35 out of 85
# Top selected features:
# Var Value RSAM VORI             0.054534
# Delta_Max_Min_Precipitations    0.049222
# Quantile Changes RSAM VORI      0.047714
# Max_Precipitations              0.044924
# Std Value RSAM VORI             0.038182
# Max drop RSAM VORI              0.037739
# Max l Width RSAM VORI           0.033365
# Sum_Precipitations              0.033280
# Mean Min Values RSAM VORI       0.029823
# Max h Width DSAR VORI           0.028865
# Last_Precipitations             0.028676
# Avg h Width RSAM VORI           0.025863
# Max Prominence RSAM VORI        0.024191
# Avg Drop Depth RSAM VORI        0.023719
# Avg Prominence RSAM VORI        0.021145
# Std Value DSAR VORI             0.020233
# Max h Width RSAM VORI           0.020001
# Max Drop Depth RSAM VORI        0.019591
# Avg l Width RSAM VORI           0.019562
# Max Drop Depth DSAR VORI        0.018772
# Avg h Width DSAR VORI           0.018495
# Max drop DSAR VORI              0.017966
# Avg Value DSAR VORI             0.017926
# Max peak RSAM VORI              0.017183
# Avg drop DSAR VORI              0.016404
# Sum_LP                          0.016401
# Median Value RSAM VORI          0.015430
# Avg drop RSAM VORI              0.015168
# Max peak DSAR VORI              0.014663
# Mean Min Values DSAR VORI       0.014494
# slope_ratio VORI                0.014241
# Var Value DSAR VORI             0.013508
# Avg peak DSAR VORI              0.013187
# Sum_tornillo                    0.012356
# Avg l Width DSAR VORI           0.011910
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 35 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA      0.056966
# Max_Precipitations              0.044481
# Max peak DSAR VRBA              0.042892
# Avg l Width DSAR VRBA           0.041724
# Delta_Max_Min_Precipitations    0.039772
# Std Value RSAM VRBA             0.031906
# Avg Prominence RSAM VRBA        0.031382
# Median Value DSAR VRBA          0.030984
# Avg peak DSAR VRBA              0.030877
# Std Value DSAR VRBA             0.029720
# Mean Min Values RSAM VRBA       0.028563
# Last_Precipitations             0.028504
# slope_ratio VRBA                0.027551
# Avg Value DSAR VRBA             0.023949
# Median Value RSAM VRBA          0.023187
# Sum_Precipitations              0.022251
# Avg Value RSAM VRBA             0.021299
# Avg Drop Depth DSAR VRBA        0.019207
# Var Value RSAM VRBA             0.018987
# Max drop DSAR VRBA              0.018661
# Max peak RSAM VRBA              0.017405
# Var Value DSAR VRBA             0.017341
# Max l Width DSAR VRBA           0.017076
# Delta_Max_Min_LP                0.016923
# Avg h Width DSAR VRBA           0.016655
# Avg drop DSAR VRBA              0.016233
# Avg Prominence DSAR VRBA        0.014818
# Avg drop RSAM VRBA              0.014083
# Max l Width RSAM VRBA           0.013964
# Max Drop Depth DSAR VRBA        0.013859
# Quantile Changes DSAR VRBA      0.013648
# Max Prominence RSAM VRBA        0.013324
# Max drop RSAM VRBA              0.013200
# Max_tornillo                    0.012895
# Avg h Width RSAM VRBA           0.012480
# dtype: float64

# %%
# Dictionaries to store the selected feature names
best_features_5days_VORI_train, best_features_5days_VRBA_train = select_important_features({}, {}, best_5days_models_VORI_train, best_5days_models_VRBA_train, x_train_5_VORI, x_train_5_VRBA)
# Out:
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2019
# ==================================================
#
# [ STATION VORI ]
# Features kept: 29 out of 85
# Top selected features:
# Sum_LP                          0.124930
# Max_LP                          0.075099
# Delta_Max_Min_LP                0.064100
# Delta_Max_Min_tornillo          0.041511
# Max_tornillo                    0.039233
# Mean Min Values DSAR VORI       0.033437
# Last_LP                         0.032485
# Sum_tornillo                    0.028481
# Quantile Changes RSAM VORI      0.027434
# Avg drop DSAR VORI              0.023451
# Max drop DSAR VORI              0.022079
# Mean Min Values RSAM VORI       0.021273
# Sum_Precipitations              0.021137
# Max_Precipitations              0.019150
# Median Value DSAR VORI          0.018523
# season                          0.017497
# Delta_Max_Min_Precipitations    0.017062
# Median Value RSAM VORI          0.016961
# Max peak RSAM VORI              0.016949
# Max drop RSAM VORI              0.015926
# Max peak DSAR VORI              0.015879
# Avg peak DSAR VORI              0.015148
# Avg Value RSAM VORI             0.015086
# Var Value RSAM VORI             0.014591
# Avg drop RSAM VORI              0.014510
# Quantile Changes DSAR VORI      0.013548
# Std Value RSAM VORI             0.013484
# Avg peak RSAM VORI              0.012970
# Sum_VT                          0.012235
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 14 out of 85
# Top selected features:
# Sum_LP                        0.375312
# Quantile Changes RSAM VRBA    0.098192
# Max_LP                        0.054075
# Delta_Max_Min_tornillo        0.047189
# Sum_VT                        0.037754
# Max_tornillo                  0.035825
# Var Value DSAR VRBA           0.030741
# Last_LP                       0.029012
# Std Value RSAM VRBA           0.020648
# Mean Min Values RSAM VRBA     0.020252
# Avg Value DSAR VRBA           0.018874
# Quantile Changes DSAR VRBA    0.016905
# Std Value DSAR VRBA           0.012926
# Sum_Precipitations            0.012849
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2020
# ==================================================
#
# [ STATION VORI ]
# Features kept: 32 out of 85
# Top selected features:
# Sum_LP                          0.069590
# Mean Min Values DSAR VORI       0.042592
# Max_LP                          0.040517
# Median Value DSAR VORI          0.040076
# Max drop DSAR VORI              0.038768
# Avg drop DSAR VORI              0.035988
# Max_tornillo                    0.034454
# Delta_Max_Min_tornillo          0.032162
# Avg peak DSAR VORI              0.031558
# Max peak DSAR VORI              0.030677
# Delta_Max_Min_LP                0.030259
# Quantile Changes RSAM VORI      0.027572
# Var Value RSAM VORI             0.025382
# Max peak RSAM VORI              0.023812
# Sum_tornillo                    0.023062
# Std Value RSAM VORI             0.020940
# Avg peak RSAM VORI              0.020900
# Mean Min Values RSAM VORI       0.020235
# Avg Value RSAM VORI             0.019652
# Last_LP                         0.019576
# Median Value RSAM VORI          0.019230
# Max drop RSAM VORI              0.017899
# Avg drop RSAM VORI              0.016342
# Var Value DSAR VORI             0.016094
# Delta_Max_Min_Precipitations    0.016086
# Max_Precipitations              0.015992
# Sum_Precipitations              0.014047
# Std Value DSAR VORI             0.013727
# Quantile Changes DSAR VORI      0.013023
# Avg Value DSAR VORI             0.012447
# Avg Drop Depth RSAM VORI        0.012396
# Max Drop Depth RSAM VORI        0.012117
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 21 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA    0.120814
# Var Value DSAR VRBA           0.098081
# Max_LP                        0.091138
# Avg Value DSAR VRBA           0.068098
# Sum_LP                        0.065437
# Avg peak DSAR VRBA            0.043076
# Avg Drop Depth DSAR VRBA      0.041623
# Std Value DSAR VRBA           0.040680
# Quantile Changes DSAR VRBA    0.032234
# Max drop DSAR VRBA            0.030438
# Var Value RSAM VRBA           0.026175
# Delta_Max_Min_LP              0.025841
# Mean Min Values RSAM VRBA     0.023559
# Last_LP                       0.023071
# Avg drop RSAM VRBA            0.022671
# Mean Min Values DSAR VRBA     0.020076
# Median Value DSAR VRBA        0.018877
# Std Value RSAM VRBA           0.014216
# Max peak DSAR VRBA            0.012466
# Avg drop DSAR VRBA            0.012060
# Delta_Max_Min_tornillo        0.011788
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2021
# ==================================================
#
# [ STATION VORI ]
# Features kept: 31 out of 85
# Top selected features:
# Mean Min Values DSAR VORI       0.070739
# Max drop DSAR VORI              0.057904
# Avg drop DSAR VORI              0.054353
# Median Value DSAR VORI          0.044119
# Avg peak DSAR VORI              0.038814
# Max peak DSAR VORI              0.036130
# Std Value DSAR VORI             0.030747
# Var Value DSAR VORI             0.030724
# Delta_Max_Min_tornillo          0.028256
# Max_tornillo                    0.027999
# Sum_LP                          0.024301
# Quantile Changes DSAR VORI      0.023550
# Max_LP                          0.022910
# Avg Prominence RSAM VORI        0.022247
# Quantile Changes RSAM VORI      0.022060
# Sum_VT                          0.021357
# Max peak RSAM VORI              0.019485
# Max_Precipitations              0.019413
# Max Prominence RSAM VORI        0.018281
# Var Value RSAM VORI             0.017425
# Sum_tornillo                    0.017333
# Delta_Max_Min_Precipitations    0.016542
# Avg peak RSAM VORI              0.016037
# Sum_Precipitations              0.015429
# Std Value RSAM VORI             0.015340
# Delta_Max_Min_LP                0.015242
# Avg Value RSAM VORI             0.014776
# Max Drop Depth RSAM VORI        0.014565
# Avg Value DSAR VORI             0.014186
# Max_VT                          0.013076
# Mean Min Values RSAM VORI       0.012454
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 21 out of 85
# Top selected features:
# Avg peak DSAR VRBA            0.147926
# Max peak DSAR VRBA            0.090794
# Median Value DSAR VRBA        0.090592
# Avg Value DSAR VRBA           0.079966
# Mean Min Values RSAM VRBA     0.069073
# Std peak RSAM VRBA            0.038120
# Quantile Changes RSAM VRBA    0.029808
# Quantile Changes DSAR VRBA    0.029175
# Max_LP                        0.021714
# Delta_Max_Min_LP              0.020918
# Std Value DSAR VRBA           0.019604
# Sum_VT                        0.018887
# Sum_tornillo                  0.017112
# Var Value DSAR VRBA           0.016922
# Sum_LP                        0.016813
# Max drop RSAM VRBA            0.015484
# Avg Drop Depth DSAR VRBA      0.015377
# Avg Value RSAM VRBA           0.014568
# Std Prominence RSAM VRBA      0.013777
# Delta_Max_Min_tornillo        0.013060
# Avg drop RSAM VRBA            0.012421
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2022
# ==================================================
#
# [ STATION VORI ]
# Features kept: 26 out of 85
# Top selected features:
# Sum_LP                          0.062219
# Mean Min Values DSAR VORI       0.057154
# Max drop DSAR VORI              0.049000
# Median Value DSAR VORI          0.048070
# Max_LP                          0.040965
# Avg peak DSAR VORI              0.040567
# Quantile Changes RSAM VORI      0.038606
# Delta_Max_Min_LP                0.038325
# Max peak DSAR VORI              0.036152
# Avg drop DSAR VORI              0.034132
# Last_LP                         0.030140
# Var Value RSAM VORI             0.029642
# Std Value DSAR VORI             0.029333
# Avg Value RSAM VORI             0.024573
# Var Value DSAR VORI             0.021736
# Median Value RSAM VORI          0.021636
# Max_Precipitations              0.021270
# Max peak RSAM VORI              0.021204
# Std Value RSAM VORI             0.021025
# Avg Value DSAR VORI             0.020490
# Quantile Changes DSAR VORI      0.018646
# Avg drop RSAM VORI              0.016928
# Delta_Max_Min_Precipitations    0.016126
# Sum_VT                          0.014899
# Max_tornillo                    0.014361
# Sum_Precipitations              0.011914
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 16 out of 85
# Top selected features:
# Median Value DSAR VRBA        0.251751
# Sum_LP                        0.129189
# Quantile Changes DSAR VRBA    0.069722
# Quantile Changes RSAM VRBA    0.061990
# Var Value DSAR VRBA           0.050146
# Std Value DSAR VRBA           0.037124
# Mean Min Values DSAR VRBA     0.033818
# Delta_Max_Min_LP              0.031365
# Median Value RSAM VRBA        0.028926
# Sum_VT                        0.025624
# Avg drop RSAM VRBA            0.025408
# Mean Min Values RSAM VRBA     0.023805
# Sum_Precipitations            0.019417
# Avg Drop Depth DSAR VRBA      0.016045
# Max_LP                        0.015764
# Max drop RSAM VRBA            0.013108
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2023
# ==================================================
#
# [ STATION VORI ]
# Features kept: 35 out of 85
# Top selected features:
# Max_Precipitations              0.067116
# Delta_Max_Min_Precipitations    0.043875
# Sum_Precipitations              0.042938
# Max_tornillo                    0.037701
# Delta_Max_Min_tornillo          0.037291
# Quantile Changes RSAM VORI      0.035040
# Sum_tornillo                    0.034870
# Sum_LP                          0.034147
# Mean Min Values RSAM VORI       0.026453
# Mean Min Values DSAR VORI       0.021639
# Max_LP                          0.020909
# Delta_Max_Min_LP                0.020461
# Max drop DSAR VORI              0.019448
# Quantile Changes DSAR VORI      0.018640
# Avg Value DSAR VORI             0.018074
# Median Value RSAM VORI          0.017554
# Avg drop DSAR VORI              0.016805
# Avg drop RSAM VORI              0.016286
# Max peak RSAM VORI              0.015893
# Std drop RSAM VORI              0.015869
# Max drop RSAM VORI              0.015841
# Var Value RSAM VORI             0.015455
# Sum_VT                          0.015125
# Avg Value RSAM VORI             0.015084
# Std Value DSAR VORI             0.014951
# Avg peak DSAR VORI              0.014906
# Avg peak RSAM VORI              0.014680
# Max peak DSAR VORI              0.014496
# Std Value RSAM VORI             0.014481
# Var Value DSAR VORI             0.013840
# Median Value DSAR VORI          0.012778
# Max Drop Depth RSAM VORI        0.012103
# Max_VT                          0.012066
# Avg Prominence RSAM VORI        0.012015
# Last_Precipitations             0.011799
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 16 out of 85
# Top selected features:
# Median Value DSAR VRBA        0.167572
# Quantile Changes RSAM VRBA    0.111700
# Quantile Changes DSAR VRBA    0.087640
# Mean Min Values DSAR VRBA     0.059924
# season                        0.056745
# Mean Min Values RSAM VRBA     0.056688
# Max_Precipitations            0.050225
# Avg peak DSAR VRBA            0.042629
# Delta_Max_Min_LP              0.031706
# Avg Value DSAR VRBA           0.031509
# Max drop RSAM VRBA            0.024810
# Avg drop DSAR VRBA            0.021997
# Sum_Precipitations            0.020151
# Sum_LP                        0.017621
# Avg peak RSAM VRBA            0.013187
# Avg drop RSAM VRBA            0.012095
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2024
# ==================================================
#
# [ STATION VORI ]
# Features kept: 31 out of 85
# Top selected features:
# Sum_LP                          0.079865
# Max_LP                          0.045932
# Quantile Changes RSAM VORI      0.041380
# Mean Min Values DSAR VORI       0.038908
# Delta_Max_Min_LP                0.037169
# Delta_Max_Min_tornillo          0.034971
# Max_tornillo                    0.033379
# Max drop DSAR VORI              0.030958
# Max_Precipitations              0.030902
# Var Value RSAM VORI             0.029349
# Avg drop DSAR VORI              0.027221
# Median Value DSAR VORI          0.026593
# Std Value RSAM VORI             0.025714
# Delta_Max_Min_Precipitations    0.023745
# Mean Min Values RSAM VORI       0.021747
# Sum_tornillo                    0.021232
# Sum_Precipitations              0.020648
# Max peak RSAM VORI              0.020257
# Max peak DSAR VORI              0.019480
# Max drop RSAM VORI              0.019425
# Avg Value RSAM VORI             0.019074
# Var Value DSAR VORI             0.018362
# Avg drop RSAM VORI              0.018309
# Avg peak RSAM VORI              0.017986
# Median Value RSAM VORI          0.017733
# Avg peak DSAR VORI              0.017071
# Std Value DSAR VORI             0.016815
# Quantile Changes DSAR VORI      0.014118
# season                          0.012874
# Avg Prominence RSAM VORI        0.012490
# Max Prominence RSAM VORI        0.011950
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 16 out of 85
# Top selected features:
# Median Value DSAR VRBA        0.181619
# Quantile Changes RSAM VRBA    0.151961
# Sum_LP                        0.138960
# Quantile Changes DSAR VRBA    0.053536
# Max_tornillo                  0.040036
# season                        0.033722
# Avg Value DSAR VRBA           0.030590
# Mean Min Values DSAR VRBA     0.030233
# Mean Min Values RSAM VRBA     0.029564
# Avg Value RSAM VRBA           0.028422
# Max drop RSAM VRBA            0.021373
# Sum_VT                        0.019893
# Delta_Max_Min_tornillo        0.019700
# Max peak RSAM VRBA            0.018918
# Median Value RSAM VRBA        0.018914
# Max_LP                        0.014407
# dtype: float64

# %%
print_report_best_model_per_year_out_of_dataset(
    best_models_VORI_train, best_features_VORI_train, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA_train, best_features_VRBA_train, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits,
    best_features='selected',
    time=time_val, coverage=coverage_val, time_5days=time_5days_val, coverage_5days=coverage_5days_val
)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 8  8]
#  [ 4 20]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57        16
#            1       0.71      0.83      0.77        24
#
#     accuracy                           0.70        40
#    macro avg       0.69      0.67      0.67        40
# weighted avg       0.70      0.70      0.69        40
#
#
#  Top Features (VORI)
# Sum_LP                          0.058658
# Quantile Changes RSAM VORI      0.057157
# slope_ratio VORI                0.045375
# Quantile Changes DSAR VORI      0.043688
# Max drop DSAR VORI              0.037985
# Mean Min Values RSAM VORI       0.035918
# Sum_Precipitations              0.035234
# Mean Min Values DSAR VORI       0.032458
# Delta_Max_Min_Precipitations    0.031490
# Max l Width DSAR VORI           0.030725
# Max drop RSAM VORI              0.029150
# Median Value DSAR VORI          0.028679
# Avg h Width DSAR VORI           0.026810
# Avg l Width RSAM VORI           0.026452
# Max_LP                          0.026011
# Avg Value RSAM VORI             0.025672
# Avg drop DSAR VORI              0.025218
# Avg Drop Depth RSAM VORI        0.024908
# Median Value RSAM VORI          0.024535
# Avg Prominence RSAM VORI        0.024107
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.77 ± 0.92
# Mean Magnitude (Missed - FN):   3.48 ± 0.70
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9  7]
#  [ 3 21]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64        16
#            1       0.75      0.88      0.81        24
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.72      0.73        40
# weighted avg       0.75      0.75      0.74        40
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.044898
# Sum_LP                          0.042981
# Mean Min Values RSAM VRBA       0.038002
# Max_LP                          0.031950
# Var Value RSAM VRBA             0.031772
# Mean Min Values DSAR VRBA       0.030800
# Std Value RSAM VRBA             0.030366
# Avg Prominence RSAM VRBA        0.029477
# Var Value DSAR VRBA             0.029367
# Std Value DSAR VRBA             0.028534
# Max Drop Depth RSAM VRBA        0.027806
# Max h Width RSAM VRBA           0.027156
# Quantile Changes DSAR VRBA      0.026656
# Delta_Max_Min_Precipitations    0.026082
# Median Value DSAR VRBA          0.025151
# Max peak DSAR VRBA              0.025142
# Max l Width DSAR VRBA           0.024969
# Max Drop Depth DSAR VRBA        0.023114
# Avg Value DSAR VRBA             0.022378
# Avg l Width DSAR VRBA           0.022141
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.88 ± 0.93
# Mean Magnitude (Missed - FN):   2.93 ± 1.01
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 19 | Mean VORI RSAM Coverage: 86.84±23.79% | Mean VORI DSAR Coverage: 93.56±22.92% | Mean VRBA Coverage: 71.85±22.14%
# Both Missed (FN): 2 | Mean VORI RSAM Coverage: 99.87±0.11% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 50.43±22.43%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 99.88±0.07% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 78.24±21.01%
# Both True Negatives (TN): 6 | Mean VORI RSAM Coverage: 82.33±28.80% | Mean VORI DSAR Coverage: 82.61±29.00% | Mean VRBA Coverage: 66.82±19.48%
# VORI Detected Without VRBA (TP): 1 | Mean VORI RSAM Coverage: 0.00+-nan% | Mean VORI DSAR Coverage: 0.00+-nan% | Mean VRBA Coverage: 78.95+-nan%
# VRBA Detected Without VORI (TP): 2 | Mean VORI RSAM Coverage: 83.18+-23.46% | Mean VORI DSAR Coverage: 83.27+-23.59% | Mean VRBA Coverage: 66.95+-8.05%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 79.11+-7.74% | Mean VORI DSAR Coverage: 86.80+-18.61% | Mean VRBA Coverage: 74.61+-35.94%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 66.59+-57.67% | Mean VORI DSAR Coverage: 73.20+-46.34% | Mean VRBA Coverage: 88.51+-19.95%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[13  8]
#  [ 8 14]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        21
#            1       0.64      0.64      0.64        22
#
#     accuracy                           0.63        43
#    macro avg       0.63      0.63      0.63        43
# weighted avg       0.63      0.63      0.63        43
#
#
#  Top Features (VORI)
# Median Value DSAR VORI        0.041094
# Quantile Changes DSAR VORI    0.039058
# Max_tornillo                  0.037350
# Max Prominence RSAM VORI      0.036800
# Var Value RSAM VORI           0.035567
# Sum_Precipitations            0.032423
# Avg Prominence RSAM VORI      0.031312
# Std Value RSAM VORI           0.030590
# Max h Width RSAM VORI         0.030464
# Mean Min Values DSAR VORI     0.030331
# Avg Value DSAR VORI           0.029416
# Delta_Max_Min_tornillo        0.029072
# Avg l Width RSAM VORI         0.028993
# Max l Width RSAM VORI         0.028701
# Quantile Changes RSAM VORI    0.028343
# Sum_LP                        0.028319
# Sum_tornillo                  0.027718
# Max drop DSAR VORI            0.027605
# Avg h Width RSAM VORI         0.027251
# Avg drop DSAR VORI            0.027145
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.36 ± 0.51
# Mean Magnitude (Missed - FN):   3.34 ± 1.05
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[15  6]
#  [ 6 16]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71        21
#            1       0.73      0.73      0.73        22
#
#     accuracy                           0.72        43
#    macro avg       0.72      0.72      0.72        43
# weighted avg       0.72      0.72      0.72        43
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.076570
# Std Value DSAR VRBA           0.060326
# Var Value DSAR VRBA           0.053660
# slope_ratio VRBA              0.043639
# Var Value RSAM VRBA           0.031942
# Median Value DSAR VRBA        0.030135
# Sum_LP                        0.028463
# Max Drop Depth DSAR VRBA      0.026662
# Mean Min Values RSAM VRBA     0.026075
# Sum_tornillo                  0.025924
# Sum_Precipitations            0.025098
# Mean Min Values DSAR VRBA     0.024766
# Avg Prominence RSAM VRBA      0.024275
# Max Prominence DSAR VRBA      0.023917
# Quantile Changes DSAR VRBA    0.023724
# Max drop RSAM VRBA            0.023419
# Std Value RSAM VRBA           0.023083
# Delta_Max_Min_tornillo        0.022431
# Avg Drop Depth DSAR VRBA      0.022211
# Avg peak DSAR VRBA            0.021207
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.67
# Mean Magnitude (Missed - FN):   3.18 ± 1.23
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 13 | Mean VORI RSAM Coverage: 86.93±27.65% | Mean VORI DSAR Coverage: 87.42±27.84% | Mean VRBA Coverage: 69.36±21.56%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 96.99±5.15% | Mean VORI DSAR Coverage: 97.54±5.39% | Mean VRBA Coverage: 70.42±7.89%
# Both False Positives (FP): 4 | Mean VORI RSAM Coverage: 96.84±6.23% | Mean VORI DSAR Coverage: 96.85±6.23% | Mean VRBA Coverage: 46.83±17.35%
# Both True Negatives (TN): 11 | Mean VORI RSAM Coverage: 96.79±10.47% | Mean VORI DSAR Coverage: 96.80±10.47% | Mean VRBA Coverage: 91.59±14.47%
# VORI Detected Without VRBA (TP): 1 | Mean VORI RSAM Coverage: 99.95+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 69.14+-nan%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 94.40+-9.62% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 31.96+-29.12%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 87.87+-17.08% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 77.97+-31.18%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 99.30+-1.30% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 78.03+-16.09%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 9  7]
#  [ 6 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58        16
#            1       0.71      0.74      0.72        23
#
#     accuracy                           0.67        39
#    macro avg       0.65      0.65      0.65        39
# weighted avg       0.66      0.67      0.66        39
#
#
#  Top Features (VORI)
# Quantile Changes RSAM VORI         0.094641
# Mean Min Values DSAR VORI          0.046746
# Avg drop DSAR VORI                 0.045540
# Max drop DSAR VORI                 0.040420
# Avg Prominence RSAM VORI           0.039260
# Avg peak DSAR VORI                 0.038161
# Median Value DSAR VORI             0.037152
# Delta_Max_Min_tornillo             0.035961
# Max l Width RSAM VORI              0.035315
# Max peak DSAR VORI                 0.034697
# Avg Value RSAM VORI                0.034671
# slope_ratio VORI                   0.034614
# Avg drop RSAM VORI                 0.029977
# Max drop RSAM VORI                 0.027475
# Max Prominence RSAM VORI           0.026927
# num_state_changes_inv_rsam VORI    0.026695
# Sum_Precipitations                 0.026032
# Sum_LP                             0.025873
# Sum_VT                             0.025787
# Std Value DSAR VORI                0.023599
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.66 ± 0.83
# Mean Magnitude (Missed - FN):   2.84 ± 0.59
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9  7]
#  [ 6 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58        16
#            1       0.71      0.74      0.72        23
#
#     accuracy                           0.67        39
#    macro avg       0.65      0.65      0.65        39
# weighted avg       0.66      0.67      0.66        39
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.063394
# Median Value DSAR VRBA        0.050624
# Avg Value DSAR VRBA           0.037039
# Max peak DSAR VRBA            0.031736
# Var Value RSAM VRBA           0.030361
# Quantile Changes DSAR VRBA    0.030225
# Std Value DSAR VRBA           0.029468
# Avg peak DSAR VRBA            0.028762
# Mean Min Values RSAM VRBA     0.027371
# Var Value DSAR VRBA           0.027289
# Std Value RSAM VRBA           0.026556
# Max drop RSAM VRBA            0.026211
# Avg drop RSAM VRBA            0.024632
# Sum_LP                        0.024334
# Median Value RSAM VRBA        0.024146
# Mean Min Values DSAR VRBA     0.023480
# Avg drop DSAR VRBA            0.023026
# Max Prominence RSAM VRBA      0.022424
# Max l Width RSAM VRBA         0.021807
# Avg Value RSAM VRBA           0.021769
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.57 ± 0.80
# Mean Magnitude (Missed - FN):   3.11 ± 0.53
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 14 | Mean VORI RSAM Coverage: 85.28±36.15% | Mean VORI DSAR Coverage: 85.39±36.19% | Mean VRBA Coverage: 60.14±27.51%
# Both Missed (FN): 3 | Mean VORI RSAM Coverage: 93.39±11.36% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 85.46±23.67%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 92.99±15.52% | Mean VORI DSAR Coverage: 93.01±15.53% | Mean VRBA Coverage: 61.26±28.30%
# Both True Negatives (TN): 7 | Mean VORI RSAM Coverage: 99.86±0.24% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 94.67±9.50%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 99.92+-0.05% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.57+-32.71%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 53.57+-6.66%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 99.17+-1.11% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 63.70+-7.98%
# VRBA Detected Without VORI (TN): 2 | Mean VORI RSAM Coverage: 99.94+-0.02% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 84.71+-21.56%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 5 17]
#  [ 9 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.36      0.23      0.28        22
#            1       0.39      0.55      0.46        20
#
#     accuracy                           0.38        42
#    macro avg       0.38      0.39      0.37        42
# weighted avg       0.37      0.38      0.36        42
#
#
#  Top Features (VORI)
# Max peak DSAR VORI                 0.109601
# Var Value RSAM VORI                0.108804
# Std Value RSAM VORI                0.103802
# Last_tornillo                      0.091780
# Max Prominence RSAM VORI           0.057309
# Avg Drop Depth DSAR VORI           0.052409
# num_state_changes_log_dsar VORI    0.047956
# Avg Drop Depth RSAM VORI           0.046327
# Sum_LP                             0.045868
# Quantile Changes RSAM VORI         0.038461
# Avg l Width RSAM VORI              0.036960
# Avg peak DSAR VORI                 0.033322
# Sum_VT                             0.031966
# Median Value RSAM VORI             0.030625
# Avg Prominence RSAM VORI           0.028618
# Avg Prominence DSAR VORI           0.023132
# is_raising_tornillo                0.020739
# Mean Min Values DSAR VORI          0.018158
# Max drop RSAM VORI                 0.016983
# Delta_Max_Min_Precipitations       0.015168
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.68 ± 0.91
# Mean Magnitude (Missed - FN):   3.57 ± 0.97
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9 13]
#  [ 7 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.56      0.41      0.47        22
#            1       0.50      0.65      0.57        20
#
#     accuracy                           0.52        42
#    macro avg       0.53      0.53      0.52        42
# weighted avg       0.53      0.52      0.52        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.080831
# Max peak DSAR VRBA            0.060174
# Var Value DSAR VRBA           0.059503
# Avg peak DSAR VRBA            0.048727
# Std Value DSAR VRBA           0.045635
# Quantile Changes DSAR VRBA    0.042341
# Avg Value DSAR VRBA           0.037893
# Var Value RSAM VRBA           0.037509
# Max h Width DSAR VRBA         0.034573
# Max Drop Depth RSAM VRBA      0.028650
# Avg Prominence DSAR VRBA      0.028153
# Avg h Width DSAR VRBA         0.027274
# Std Value RSAM VRBA           0.026750
# Max_LP                        0.025606
# Max Prominence RSAM VRBA      0.025252
# Max drop DSAR VRBA            0.025204
# Sum_VT                        0.025037
# Avg Value RSAM VRBA           0.024183
# Max Prominence DSAR VRBA      0.023924
# Median Value DSAR VRBA        0.022049
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.04 ± 0.80
# Mean Magnitude (Missed - FN):   3.17 ± 1.42
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 9 | Mean VORI RSAM Coverage: 80.72±32.11% | Mean VORI DSAR Coverage: 83.02±32.81% | Mean VRBA Coverage: 59.61±30.26%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 94.49±8.60% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 85.52±18.58%
# Both False Positives (FP): 12 | Mean VORI RSAM Coverage: 88.61±29.63% | Mean VORI DSAR Coverage: 90.37±24.40% | Mean VRBA Coverage: 68.96±34.19%
# Both True Negatives (TN): 4 | Mean VORI RSAM Coverage: 99.56±0.79% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 90.42±14.49%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 99.91+-0.07% | Mean VORI DSAR Coverage: 99.94+-0.02% | Mean VRBA Coverage: 49.98+-70.68%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 95.91+-7.80% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.00+-30.92%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 96.73+-nan% | Mean VORI DSAR Coverage: 96.73+-nan% | Mean VRBA Coverage: 53.03+-nan%
# VRBA Detected Without VORI (TN): 5 | Mean VORI RSAM Coverage: 99.26+-1.11% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 71.88+-16.06%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[12 10]
#  [10 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55        22
#            1       0.57      0.57      0.57        23
#
#     accuracy                           0.56        45
#    macro avg       0.56      0.56      0.56        45
# weighted avg       0.56      0.56      0.56        45
#
#
#  Top Features (VORI)
# Max l Width RSAM VORI         0.109300
# Mean Min Values DSAR VORI     0.095355
# Avg h Width DSAR VORI         0.086559
# Avg drop RSAM VORI            0.082572
# Std Value RSAM VORI           0.062886
# slope_ratio VORI              0.052215
# Max drop DSAR VORI            0.048836
# Max l Width DSAR VORI         0.046593
# Avg Drop Depth RSAM VORI      0.045956
# Quantile Changes RSAM VORI    0.038619
# is_pressurizing VORI          0.037397
# Delta_Max_Min_tornillo        0.036455
# Median Value RSAM VORI        0.035362
# Avg Drop Depth DSAR VORI      0.032683
# Max Drop Depth DSAR VORI      0.031168
# Avg drop DSAR VORI            0.026567
# Max h Width DSAR VORI         0.021772
# Avg peak DSAR VORI            0.021034
# Max Prominence DSAR VORI      0.018252
# Avg Value RSAM VORI           0.016445
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.97 ± 0.96
# Mean Magnitude (Missed - FN):   2.55 ± 0.92
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[15  7]
#  [13 10]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.54      0.68      0.60        22
#            1       0.59      0.43      0.50        23
#
#     accuracy                           0.56        45
#    macro avg       0.56      0.56      0.55        45
# weighted avg       0.56      0.56      0.55        45
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.255501
# Mean Min Values RSAM VRBA       0.152026
# Var Value DSAR VRBA             0.102467
# Std Value DSAR VRBA             0.101464
# Avg Drop Depth DSAR VRBA        0.057086
# Sum_Precipitations              0.048304
# Avg Value RSAM VRBA             0.045015
# Max Drop Depth DSAR VRBA        0.037339
# Max peak RSAM VRBA              0.036959
# Std Value RSAM VRBA             0.031513
# Median Value DSAR VRBA          0.028487
# Mean Min Values DSAR VRBA       0.028013
# Avg peak RSAM VRBA              0.024862
# Max peak DSAR VRBA              0.018790
# Avg peak DSAR VRBA              0.018571
# Delta_Max_Min_Precipitations    0.013604
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.84 ± 1.02
# Mean Magnitude (Missed - FN):   2.75 ± 0.93
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 6 | Mean VORI RSAM Coverage: 97.29±6.41% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 60.54±33.21%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 99.95±0.02% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 82.71±17.53%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.95±0.00% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 48.66±25.23%
# Both True Negatives (TN): 8 | Mean VORI RSAM Coverage: 99.61±0.91% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 87.46±26.57%
# VORI Detected Without VRBA (TP): 7 | Mean VORI RSAM Coverage: 79.22+-36.55% | Mean VORI DSAR Coverage: 82.04+-37.39% | Mean VRBA Coverage: 66.45+-34.27%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 51.26+-10.67%
# VORI Detected Without VRBA (TN): 4 | Mean VORI RSAM Coverage: 99.89+-0.06% | Mean VORI DSAR Coverage: 99.96+-0.01% | Mean VRBA Coverage: 68.58+-21.07%
# VRBA Detected Without VORI (TN): 7 | Mean VORI RSAM Coverage: 70.65+-41.08% | Mean VORI DSAR Coverage: 75.42+-33.47% | Mean VRBA Coverage: 84.88+-37.49%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[11 11]
#  [ 9 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52        22
#            1       0.50      0.55      0.52        20
#
#     accuracy                           0.52        42
#    macro avg       0.53      0.53      0.52        42
# weighted avg       0.53      0.52      0.52        42
#
#
#  Top Features (VORI)
# Sum_Precipitations              0.065778
# Std Value RSAM VORI             0.065672
# Var Value RSAM VORI             0.065597
# Delta_Max_Min_Precipitations    0.054824
# Avg Prominence RSAM VORI        0.043883
# Max l Width RSAM VORI           0.041161
# Mean Min Values RSAM VORI       0.035917
# Quantile Changes RSAM VORI      0.032308
# Avg drop RSAM VORI              0.031563
# Max_Precipitations              0.028048
# Max Prominence RSAM VORI        0.027290
# Avg Value DSAR VORI             0.026684
# Avg drop DSAR VORI              0.026438
# Median Value RSAM VORI          0.026381
# Max drop RSAM VORI              0.025910
# Last_Precipitations             0.025508
# Avg l Width RSAM VORI           0.025396
# Sum_LP                          0.024069
# Max Drop Depth DSAR VORI        0.023777
# Max h Width RSAM VORI           0.023626
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.46 ± 0.55
# Mean Magnitude (Missed - FN):   2.73 ± 0.57
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[16  6]
#  [11  9]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.59      0.73      0.65        22
#            1       0.60      0.45      0.51        20
#
#     accuracy                           0.60        42
#    macro avg       0.60      0.59      0.58        42
# weighted avg       0.60      0.60      0.59        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.083220
# Mean Min Values RSAM VRBA       0.073464
# Avg peak DSAR VRBA              0.061577
# Sum_Precipitations              0.052756
# Delta_Max_Min_Precipitations    0.043995
# Avg l Width DSAR VRBA           0.043608
# Avg Value RSAM VRBA             0.040214
# Avg Value DSAR VRBA             0.039208
# Max Prominence RSAM VRBA        0.036613
# Max_Precipitations              0.034284
# Median Value DSAR VRBA          0.033696
# Std Value DSAR VRBA             0.031418
# Var Value DSAR VRBA             0.028920
# Last_Precipitations             0.026532
# Max l Width DSAR VRBA           0.025114
# slope_ratio VRBA                0.022788
# Max peak DSAR VRBA              0.022704
# Avg h Width DSAR VRBA           0.021658
# Max peak RSAM VRBA              0.021565
# Avg h Width RSAM VRBA           0.021387
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.35 ± 0.51
# Mean Magnitude (Missed - FN):   2.77 ± 0.56
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 7 | Mean VORI RSAM Coverage: 99.82±0.17% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 71.11±22.61%
# Both Missed (FN): 7 | Mean VORI RSAM Coverage: 87.03±26.52% | Mean VORI DSAR Coverage: 90.49±25.03% | Mean VRBA Coverage: 63.29±38.25%
# Both False Positives (FP): 6 | Mean VORI RSAM Coverage: 94.23±13.90% | Mean VORI DSAR Coverage: 94.39±13.62% | Mean VRBA Coverage: 90.18±17.24%
# Both True Negatives (TN): 11 | Mean VORI RSAM Coverage: 99.66±0.60% | Mean VORI DSAR Coverage: 99.96±0.01% | Mean VRBA Coverage: 69.27±21.81%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 95.03+-9.79% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 83.63+-19.06%
# VRBA Detected Without VORI (TP): 2 | Mean VORI RSAM Coverage: 60.61+-55.64% | Mean VORI DSAR Coverage: 72.51+-38.81% | Mean VRBA Coverage: 77.39+-24.79%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 5 | Mean VORI RSAM Coverage: 99.70+-0.36% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.05+-18.47%

# %%
print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI_train, best_features_5days_VORI_train, x_train_5_VORI, x_val_5_VORI, y_train_5_VORI, y_val_5_VORI,
    best_5days_models_VRBA_train, best_features_5days_VRBA_train, x_train_5_VRBA, x_val_5_VRBA, y_train_5_VRBA, y_val_5_VRBA,
    train_test_years_splits,
    best_features='selected' ,
    five_days=True,
    time=time_val, coverage=coverage_val, time_5days=time_5days_val, coverage_5days=coverage_5days_val

)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[66 73]
#  [43 42]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      0.47      0.53       139
#            1       0.37      0.49      0.42        85
#
#     accuracy                           0.48       224
#    macro avg       0.49      0.48      0.48       224
# weighted avg       0.51      0.48      0.49       224
#
#
#  Top Features (VORI)
# Sum_LP                        0.159730
# Max_LP                        0.099088
# Delta_Max_Min_LP              0.064915
# Max_tornillo                  0.050677
# Delta_Max_Min_tornillo        0.049917
# Mean Min Values DSAR VORI     0.040371
# Quantile Changes RSAM VORI    0.038394
# Last_LP                       0.034467
# Mean Min Values RSAM VORI     0.029019
# Avg drop DSAR VORI            0.026715
# Max drop DSAR VORI            0.026403
# Median Value RSAM VORI        0.025747
# Sum_tornillo                  0.025499
# Quantile Changes DSAR VORI    0.024881
# Median Value DSAR VORI        0.024670
# Max peak RSAM VORI            0.022772
# Std Value RSAM VORI           0.022160
# Sum_Precipitations            0.021523
# Var Value RSAM VORI           0.021309
# Avg Value RSAM VORI           0.020896
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.22 ± 0.81
# Mean Magnitude (Missed - FN):   3.67 ± 0.58
# Low magnitude events were more detected
#  length of time array: 224
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[77 62]
#  [34 51]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.55      0.62       139
#            1       0.45      0.60      0.52        85
#
#     accuracy                           0.57       224
#    macro avg       0.57      0.58      0.57       224
# weighted avg       0.60      0.57      0.58       224
#
#
#  Top Features (VRBA)
# Sum_LP                        0.328474
# Quantile Changes RSAM VRBA    0.130855
# Max_LP                        0.125049
# Delta_Max_Min_tornillo        0.077567
# Std Value DSAR VRBA           0.044107
# Avg Value DSAR VRBA           0.041851
# Mean Min Values RSAM VRBA     0.041758
# Sum_VT                        0.039724
# Quantile Changes DSAR VRBA    0.035114
# Sum_Precipitations            0.033944
# Last_LP                       0.033167
# Max_tornillo                  0.029808
# Var Value DSAR VRBA           0.021707
# Std Value RSAM VRBA           0.016874
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.40 ± 0.75
# Mean Magnitude (Missed - FN):   3.52 ± 0.73
# Low magnitude events were more detected
#  length of time array: 224
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 37 | Mean VORI RSAM Coverage: 96.31±6.79% | Mean VORI DSAR Coverage: 98.72±4.42% | Mean VRBA Coverage: 78.39±22.35%
# Both Missed (FN): 29 | Mean VORI RSAM Coverage: 90.03±12.90% | Mean VORI DSAR Coverage: 94.03±13.72% | Mean VRBA Coverage: 89.14±20.17%
# Both False Positives (FP): 53 | Mean VORI RSAM Coverage: 99.94±0.01% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 50.56±28.80%
# Both True Negatives (TN): 57 | Mean VORI RSAM Coverage: 99.76±0.25% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 85.17±22.61%
# VORI Detected Without VRBA (TP): 5 | Mean VORI RSAM Coverage: 66.06+-38.33% | Mean VORI DSAR Coverage: 75.95+-43.33% | Mean VRBA Coverage: 75.16+-22.77%
# VRBA Detected Without VORI (TP): 14 | Mean VORI RSAM Coverage: 99.33+-1.33% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 89.36+-16.05%
# VORI Detected Without VRBA (TN): 9 | Mean VORI RSAM Coverage: 99.62+-0.45% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 64.46+-9.43%
# VRBA Detected Without VORI (TN): 20 | Mean VORI RSAM Coverage: 98.73+-1.94% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 55.05+-39.74%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[75 28]
#  [ 6 38]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.73      0.82       103
#            1       0.58      0.86      0.69        44
#
#     accuracy                           0.77       147
#    macro avg       0.75      0.80      0.75       147
# weighted avg       0.82      0.77      0.78       147
#
#
#  Top Features (VORI)
# Sum_LP                        0.095385
# Avg drop DSAR VORI            0.055593
# Max drop DSAR VORI            0.053069
# Mean Min Values DSAR VORI     0.050529
# Max_LP                        0.046176
# Max_tornillo                  0.041444
# Delta_Max_Min_tornillo        0.037233
# Quantile Changes RSAM VORI    0.036506
# Delta_Max_Min_LP              0.035415
# Max peak DSAR VORI            0.035079
# Median Value DSAR VORI        0.034841
# Avg peak DSAR VORI            0.033620
# Max peak RSAM VORI            0.029165
# Var Value RSAM VORI           0.028848
# Std Value RSAM VORI           0.028669
# Sum_tornillo                  0.028290
# Mean Min Values RSAM VORI     0.028001
# Median Value RSAM VORI        0.027045
# Avg peak RSAM VORI            0.025229
# Avg Value RSAM VORI           0.023753
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.96 ± 0.85
# Mean Magnitude (Missed - FN):   3.55 ± 1.27
# Low magnitude events were more detected
#  length of time array: 147
# Detected Lahars (TP): 2 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[90 13]
#  [19 25]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       103
#            1       0.66      0.57      0.61        44
#
#     accuracy                           0.78       147
#    macro avg       0.74      0.72      0.73       147
# weighted avg       0.78      0.78      0.78       147
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.154210
# Sum_LP                        0.146367
# Avg peak DSAR VRBA            0.105476
# Std Value DSAR VRBA           0.098129
# Median Value DSAR VRBA        0.088280
# Quantile Changes DSAR VRBA    0.056036
# Var Value DSAR VRBA           0.046828
# Avg drop DSAR VRBA            0.036139
# Mean Min Values DSAR VRBA     0.034311
# Delta_Max_Min_tornillo        0.033738
# Mean Min Values RSAM VRBA     0.029769
# Avg Drop Depth DSAR VRBA      0.028497
# Var Value RSAM VRBA           0.021673
# Std Value RSAM VRBA           0.021260
# Avg Value DSAR VRBA           0.019533
# Delta_Max_Min_LP              0.018739
# Max_LP                        0.017839
# Max peak DSAR VRBA            0.015037
# Last_LP                       0.014097
# Avg drop RSAM VRBA            0.007782
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.82 ± 0.79
# Mean Magnitude (Missed - FN):   3.32 ± 1.02
# Low magnitude events were more detected
#  length of time array: 147
# Detected Lahars (TP): 1 | Missed Lahars (FN): 3
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 25 | Mean VORI RSAM Coverage: 95.64±5.16% | Mean VORI DSAR Coverage: 95.64±5.16% | Mean VRBA Coverage: 63.39±8.22%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 76.70±26.04% | Mean VORI DSAR Coverage: 77.57±25.76% | Mean VRBA Coverage: 46.50±36.27%
# Both False Positives (FP): 13 | Mean VORI RSAM Coverage: 91.95±6.38% | Mean VORI DSAR Coverage: 95.19±3.32% | Mean VRBA Coverage: 61.88±16.95%
# Both True Negatives (TN): 75 | Mean VORI RSAM Coverage: 99.31±1.77% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 89.59±15.73%
# VORI Detected Without VRBA (TP): 13 | Mean VORI RSAM Coverage: 97.01+-7.09% | Mean VORI DSAR Coverage: 97.04+-7.10% | Mean VRBA Coverage: 64.11+-7.89%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 15 | Mean VORI RSAM Coverage: 92.95+-14.80% | Mean VORI DSAR Coverage: 99.19+-2.94% | Mean VRBA Coverage: 93.04+-14.41%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[115  57]
#  [ 18 152]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75       172
#            1       0.73      0.89      0.80       170
#
#     accuracy                           0.78       342
#    macro avg       0.80      0.78      0.78       342
# weighted avg       0.80      0.78      0.78       342
#
#
#  Top Features (VORI)
# Mean Min Values DSAR VORI       0.079522
# Max drop DSAR VORI              0.072590
# Avg drop DSAR VORI              0.071459
# Median Value DSAR VORI          0.047327
# Avg peak DSAR VORI              0.043266
# Var Value DSAR VORI             0.040213
# Max peak DSAR VORI              0.037930
# Sum_VT                          0.035420
# Std Value DSAR VORI             0.035361
# Max_tornillo                    0.033611
# Avg Prominence RSAM VORI        0.033118
# Delta_Max_Min_tornillo          0.032850
# Quantile Changes DSAR VORI      0.032637
# Quantile Changes RSAM VORI      0.032045
# Sum_LP                          0.030257
# Max peak RSAM VORI              0.027134
# Max_Precipitations              0.025935
# Delta_Max_Min_Precipitations    0.023479
# Max_LP                          0.023381
# Max Prominence RSAM VORI        0.022341
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.62 ± 0.56
# Mean Magnitude (Missed - FN):   3.25 ± 0.51
# Low magnitude events were more detected
#  length of time array: 342
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[105  67]
#  [ 18 152]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.61      0.71       172
#            1       0.69      0.89      0.78       170
#
#     accuracy                           0.75       342
#    macro avg       0.77      0.75      0.75       342
# weighted avg       0.77      0.75      0.75       342
#
#
#  Top Features (VRBA)
# Max peak DSAR VRBA            0.143314
# Avg peak DSAR VRBA            0.142342
# Median Value DSAR VRBA        0.120972
# Mean Min Values RSAM VRBA     0.071430
# Std peak RSAM VRBA            0.047730
# Quantile Changes RSAM VRBA    0.046352
# Avg Value DSAR VRBA           0.046073
# Quantile Changes DSAR VRBA    0.041187
# Max_LP                        0.034159
# Sum_VT                        0.033614
# Avg Drop Depth DSAR VRBA      0.031969
# Avg Value RSAM VRBA           0.028647
# Delta_Max_Min_LP              0.028357
# Var Value DSAR VRBA           0.026543
# Delta_Max_Min_tornillo        0.025522
# Max drop RSAM VRBA            0.024315
# Avg drop RSAM VRBA            0.023299
# Sum_tornillo                  0.023182
# Sum_LP                        0.022333
# Std Prominence RSAM VRBA      0.021407
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.67 ± 0.57
# Mean Magnitude (Missed - FN):   2.89 ± 0.64
# Low magnitude events were more detected
#  length of time array: 342
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 136 | Mean VORI RSAM Coverage: 96.92±6.77% | Mean VORI DSAR Coverage: 99.18±4.70% | Mean VRBA Coverage: 68.16±20.35%
# Both Missed (FN): 2 | Mean VORI RSAM Coverage: 99.87±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 98.85±0.15%
# Both False Positives (FP): 47 | Mean VORI RSAM Coverage: 99.09±3.27% | Mean VORI DSAR Coverage: 99.19±3.17% | Mean VRBA Coverage: 63.06±40.42%
# Both True Negatives (TN): 95 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 87.93±15.56%
# VORI Detected Without VRBA (TP): 16 | Mean VORI RSAM Coverage: 95.58+-6.50% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 71.41+-36.49%
# VRBA Detected Without VORI (TP): 16 | Mean VORI RSAM Coverage: 99.85+-0.04% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 93.33+-20.34%
# VORI Detected Without VRBA (TN): 20 | Mean VORI RSAM Coverage: 99.92+-0.03% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 82.66+-18.66%
# VRBA Detected Without VORI (TN): 10 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 17.17+-14.00%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[76 23]
#  [22 39]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77        99
#            1       0.63      0.64      0.63        61
#
#     accuracy                           0.72       160
#    macro avg       0.70      0.70      0.70       160
# weighted avg       0.72      0.72      0.72       160
#
#
#  Top Features (VORI)
# Mean Min Values DSAR VORI     0.100957
# Sum_LP                        0.083446
# Max drop DSAR VORI            0.068929
# Avg drop DSAR VORI            0.064750
# Median Value DSAR VORI        0.064171
# Max_LP                        0.060174
# Delta_Max_Min_LP              0.045397
# Avg peak DSAR VORI            0.039515
# Quantile Changes RSAM VORI    0.039150
# Max peak RSAM VORI            0.035902
# Max_Precipitations            0.035576
# Var Value RSAM VORI           0.034585
# Max peak DSAR VORI            0.032609
# Std Value RSAM VORI           0.032503
# Std Value DSAR VORI           0.031060
# Quantile Changes DSAR VORI    0.029014
# Var Value DSAR VORI           0.027828
# Sum_VT                        0.024873
# Max_tornillo                  0.023378
# Avg Value DSAR VORI           0.020395
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.66 ± 0.66
# Mean Magnitude (Missed - FN):   2.83 ± 0.81
# Low magnitude events were more detected
#  length of time array: 160
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[86 13]
#  [32 29]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79        99
#            1       0.69      0.48      0.56        61
#
#     accuracy                           0.72       160
#    macro avg       0.71      0.67      0.68       160
# weighted avg       0.71      0.72      0.71       160
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.261162
# Sum_LP                        0.133422
# Quantile Changes DSAR VRBA    0.083938
# Quantile Changes RSAM VRBA    0.075150
# Var Value DSAR VRBA           0.061770
# Std Value DSAR VRBA           0.058755
# Sum_VT                        0.050775
# Mean Min Values DSAR VRBA     0.046325
# Median Value RSAM VRBA        0.034466
# Avg drop RSAM VRBA            0.033369
# Mean Min Values RSAM VRBA     0.033068
# Delta_Max_Min_LP              0.030466
# Avg Drop Depth DSAR VRBA      0.030263
# Sum_Precipitations            0.025186
# Max_LP                        0.022830
# Max drop RSAM VRBA            0.019057
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.75 ± 0.63
# Mean Magnitude (Missed - FN):   2.70 ± 0.79
# High magnitude events were more detected
#  length of time array: 160
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 23 | Mean VORI RSAM Coverage: 87.94±23.49% | Mean VORI DSAR Coverage: 88.91±23.85% | Mean VRBA Coverage: 86.88±18.42%
# Both Missed (FN): 16 | Mean VORI RSAM Coverage: 95.76±9.86% | Mean VORI DSAR Coverage: 96.83±8.86% | Mean VRBA Coverage: 82.22±18.19%
# Both False Positives (FP): 1 | Mean VORI RSAM Coverage: 99.92±nan% | Mean VORI DSAR Coverage: 99.94±nan% | Mean VRBA Coverage: 100.00±nan%
# Both True Negatives (TN): 64 | Mean VORI RSAM Coverage: 94.22±18.76% | Mean VORI DSAR Coverage: 95.99±14.65% | Mean VRBA Coverage: 97.88±4.15%
# VORI Detected Without VRBA (TP): 16 | Mean VORI RSAM Coverage: 95.95+-5.47% | Mean VORI DSAR Coverage: 98.52+-4.31% | Mean VRBA Coverage: 90.24+-17.70%
# VRBA Detected Without VORI (TP): 6 | Mean VORI RSAM Coverage: 99.89+-0.04% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 99.72+-0.42%
# VORI Detected Without VRBA (TN): 12 | Mean VORI RSAM Coverage: 50.55+-21.81% | Mean VORI DSAR Coverage: 50.55+-21.81% | Mean VRBA Coverage: 55.43+-14.68%
# VRBA Detected Without VORI (TN): 22 | Mean VORI RSAM Coverage: 56.45+-43.92% | Mean VORI DSAR Coverage: 57.97+-44.39% | Mean VRBA Coverage: 92.04+-15.24%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[47  9]
#  [20 32]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76        56
#            1       0.78      0.62      0.69        52
#
#     accuracy                           0.73       108
#    macro avg       0.74      0.73      0.73       108
# weighted avg       0.74      0.73      0.73       108
#
#
#  Top Features (VORI)
# Max_Precipitations              0.061403
# Sum_Precipitations              0.060971
# Delta_Max_Min_Precipitations    0.054411
# Quantile Changes RSAM VORI      0.048451
# Sum_tornillo                    0.046707
# Max_tornillo                    0.043589
# Delta_Max_Min_tornillo          0.041177
# Mean Min Values RSAM VORI       0.036300
# Sum_LP                          0.036289
# Max_LP                          0.030935
# Quantile Changes DSAR VORI      0.030840
# Mean Min Values DSAR VORI       0.026865
# Std drop RSAM VORI              0.026249
# Avg Value DSAR VORI             0.026243
# Max drop DSAR VORI              0.025356
# Delta_Max_Min_LP                0.024608
# Avg Value RSAM VORI             0.023823
# Max peak RSAM VORI              0.023719
# Std Value RSAM VORI             0.022976
# Avg drop DSAR VORI              0.022849
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.90 ± 1.06
# Mean Magnitude (Missed - FN):   2.95 ± 0.87
# Low magnitude events were more detected
#  length of time array: 108
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132000000
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000000000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682000000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[39 17]
#  [24 28]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.70      0.66        56
#            1       0.62      0.54      0.58        52
#
#     accuracy                           0.62       108
#    macro avg       0.62      0.62      0.62       108
# weighted avg       0.62      0.62      0.62       108
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.185145
# Quantile Changes RSAM VRBA    0.117129
# Quantile Changes DSAR VRBA    0.102890
# Mean Min Values RSAM VRBA     0.092363
# Avg peak DSAR VRBA            0.091745
# Mean Min Values DSAR VRBA     0.072037
# Max_Precipitations            0.055496
# season                        0.047745
# Avg peak RSAM VRBA            0.041962
# Sum_LP                        0.039010
# Max drop RSAM VRBA            0.036350
# Sum_Precipitations            0.033497
# Delta_Max_Min_LP              0.031904
# Avg drop DSAR VRBA            0.021878
# Avg Value DSAR VRBA           0.016196
# Avg drop RSAM VRBA            0.014654
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.82 ± 0.90
# Mean Magnitude (Missed - FN):   3.03 ± 1.09
# Low magnitude events were more detected
#  length of time array: 108
# Detected Lahars (TP): 1 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000000000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132000000
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682000000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 24 | Mean VORI RSAM Coverage: 42.37±45.81% | Mean VORI DSAR Coverage: 48.19±49.40% | Mean VRBA Coverage: 49.77±16.91%
# Both Missed (FN): 16 | Mean VORI RSAM Coverage: 88.83±29.00% | Mean VORI DSAR Coverage: 88.83±29.00% | Mean VRBA Coverage: 61.67±23.15%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 96.11±7.09% | Mean VORI DSAR Coverage: 96.65±7.36% | Mean VRBA Coverage: 59.32±2.49%
# Both True Negatives (TN): 35 | Mean VORI RSAM Coverage: 89.98±16.78% | Mean VORI DSAR Coverage: 92.80±14.91% | Mean VRBA Coverage: 60.91±15.05%
# VORI Detected Without VRBA (TP): 8 | Mean VORI RSAM Coverage: 77.16+-34.07% | Mean VORI DSAR Coverage: 78.84+-33.84% | Mean VRBA Coverage: 54.60+-23.80%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 73.95+-30.02% | Mean VORI DSAR Coverage: 73.95+-30.02% | Mean VRBA Coverage: 32.04+-37.00%
# VORI Detected Without VRBA (TN): 12 | Mean VORI RSAM Coverage: 93.66+-7.47% | Mean VORI DSAR Coverage: 96.63+-7.03% | Mean VRBA Coverage: 63.27+-5.89%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 98.61+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 55.73+-3.91%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[76 30]
#  [35 48]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70       106
#            1       0.62      0.58      0.60        83
#
#     accuracy                           0.66       189
#    macro avg       0.65      0.65      0.65       189
# weighted avg       0.65      0.66      0.65       189
#
#
#  Top Features (VORI)
# Sum_LP                          0.105815
# Max_LP                          0.062412
# Mean Min Values DSAR VORI       0.051691
# Quantile Changes RSAM VORI      0.050950
# Max drop DSAR VORI              0.043380
# Delta_Max_Min_tornillo          0.043307
# Delta_Max_Min_LP                0.042655
# Max_tornillo                    0.038954
# Avg drop DSAR VORI              0.034963
# Var Value RSAM VORI             0.033881
# Std Value RSAM VORI             0.033252
# Max_Precipitations              0.030188
# Mean Min Values RSAM VORI       0.028428
# Avg Value RSAM VORI             0.028333
# Median Value DSAR VORI          0.028205
# Delta_Max_Min_Precipitations    0.026545
# Sum_Precipitations              0.025145
# Max peak RSAM VORI              0.024612
# Avg drop RSAM VORI              0.024533
# Max drop RSAM VORI              0.024492
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.37 ± 0.80
# Mean Magnitude (Missed - FN):   3.48 ± 0.77
# Low magnitude events were more detected
#  length of time array: 189
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[85 21]
#  [20 63]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81       106
#            1       0.75      0.76      0.75        83
#
#     accuracy                           0.78       189
#    macro avg       0.78      0.78      0.78       189
# weighted avg       0.78      0.78      0.78       189
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.171482
# Median Value DSAR VRBA        0.158847
# Sum_LP                        0.139285
# Avg Value DSAR VRBA           0.075208
# Avg Value RSAM VRBA           0.067349
# Quantile Changes DSAR VRBA    0.059708
# season                        0.058812
# Mean Min Values DSAR VRBA     0.053047
# Delta_Max_Min_tornillo        0.040014
# Max drop RSAM VRBA            0.039641
# Mean Min Values RSAM VRBA     0.035109
# Max_LP                        0.027068
# Max peak RSAM VRBA            0.024899
# Sum_VT                        0.019004
# Median Value RSAM VRBA        0.016440
# Max_tornillo                  0.014086
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.41 ± 0.80
# Mean Magnitude (Missed - FN):   3.42 ± 0.74
# Low magnitude events were more detected
#  length of time array: 189
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 46 | Mean VORI RSAM Coverage: 95.74±7.49% | Mean VORI DSAR Coverage: 98.89±4.27% | Mean VRBA Coverage: 86.62±16.87%
# Both Missed (FN): 18 | Mean VORI RSAM Coverage: 85.78±14.68% | Mean VORI DSAR Coverage: 90.41±16.53% | Mean VRBA Coverage: 77.57±24.50%
# Both False Positives (FP): 11 | Mean VORI RSAM Coverage: 99.67±0.22% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 99.11±0.85%
# Both True Negatives (TN): 66 | Mean VORI RSAM Coverage: 95.22±13.54% | Mean VORI DSAR Coverage: 99.47±2.92% | Mean VRBA Coverage: 95.87±7.96%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 97.36+-0.06% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 94.12+-0.00%
# VRBA Detected Without VORI (TP): 17 | Mean VORI RSAM Coverage: 97.33+-4.81% | Mean VORI DSAR Coverage: 98.45+-4.48% | Mean VRBA Coverage: 84.95+-18.37%
# VORI Detected Without VRBA (TN): 10 | Mean VORI RSAM Coverage: 97.84+-3.95% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 82.15+-18.83%
# VRBA Detected Without VORI (TN): 19 | Mean VORI RSAM Coverage: 99.78+-0.24% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 94.06+-16.35%

# %% [markdown]
# Here, the results are almost instantaneous and yield essentially the same results as the Backward Selection Wrapper.

# %% [markdown]
# ### Comparison of the different models and feature selection techniques

# %% [markdown]
# In order to compare the various results obtained using the feature selection approach, they will be evaluated based on their average recall, precision, and accuracy for each station, as well as other indicators that facilitate their interpretation.

# %%
# Function to evaluate cross-validation performance with normalized metrics
def get_crossval_summary_normalized(
    best_models_VORI, best_features_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA, best_features_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits, best_features=None, model_name="Current_Model"
):
    # Store the per-year individual results for each station
    results_individual = []
    # Store the combined station agreement/disagreement metrics
    results_combined = []

    # Iterate over each test year
    for key in train_test_years_splits.keys():
        # Ground truth labels for the validation set of the VORI data
        y_true = np.asarray(y_val_VORI[key]["Type"].values).ravel()

        # Total number of real negatives and positives for this test year
        support_0 = (y_true == 0).sum()
        support_1 = (y_true == 1).sum()

        # Configuration for the two stations
        configs = [
            ("VORI", best_models_VORI, best_features_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI),
            ("VRBA", best_models_VRBA, best_features_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA)
        ]

        # Dictionary holding predictions for each station
        y_pred_summary = {}

        # Evaluate each station separately
        for station, models, features_dict, x_train, x_val, y_train, y_val in configs:
            if best_features is not None:
                # Apply selected feature subset if provided
                selected_features = features_dict[key]
                model = clone(models[key])
                model.fit(x_train[key][selected_features], y_train[key]["Type"].values)
                y_pred = model.predict(x_val[key][selected_features])
            else:
                # Use the full feature set
                model = models[key]
                y_pred = model.predict(x_val[key])

            # Normalize predictions to a 1D numpy array
            y_pred = np.asarray(y_pred).ravel()
            y_pred_summary[station] = y_pred

            # Confusion matrix for this station
            tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()

            # Standard classification metrics
            accuracy = accuracy_score(y_true, y_pred)
            precision, recall, f1, _ = precision_recall_fscore_support(
                y_true, y_pred, average="binary", zero_division=0
            )

            # Normalized rates within each class support
            true_positive_rate = tp / support_1 if support_1 > 0 else 0
            false_negative_rate = fn / support_1 if support_1 > 0 else 0
            true_negative_rate = tn / support_0 if support_0 > 0 else 0
            false_positive_rate = fp / support_0 if support_0 > 0 else 0

            # Save all individual performance metrics for this year
            results_individual.append({
                "Model_Name": model_name,
                "Test_Year": key,
                f"Accuracy {station}": accuracy,
                f"Precision {station}": precision,
                f"Recall {station}": recall,
                f"F1_Score {station}": f1,
                f"TP {station}": tp,
                f"TN {station}": tn,
                f"FP {station}": fp,
                f"FN {station}": fn,
                f"TP_{station}_%": true_positive_rate * 100,
                f"FN_{station}_%": false_negative_rate * 100,
                f"TN_{station}_%": true_negative_rate * 100,
                f"FP_{station}_%": false_positive_rate * 100
            })

        # Combined agreement metrics:
        # both stations detect the event, both miss it, one station detects it, etc.
        idx_both_tp = (y_pred_summary["VORI"] == 1) & (y_pred_summary["VRBA"] == 1) & (y_true == 1)
        idx_both_tn = (y_pred_summary["VORI"] == 0) & (y_pred_summary["VRBA"] == 0) & (y_true == 0)
        idx_both_fp = (y_pred_summary["VORI"] == 1) & (y_pred_summary["VRBA"] == 1) & (y_true == 0)
        idx_both_fn = (y_pred_summary["VORI"] == 0) & (y_pred_summary["VRBA"] == 0) & (y_true == 1)

        idx_vori_only_tp = (y_pred_summary["VORI"] == 1) & (y_pred_summary["VRBA"] == 0) & (y_true == 1)
        idx_vrba_only_tp = (y_pred_summary["VORI"] == 0) & (y_pred_summary["VRBA"] == 1) & (y_true == 1)
        idx_vrba_only_tn = (y_pred_summary["VORI"] == 1) & (y_pred_summary["VRBA"] == 0) & (y_true == 0)
        idx_vori_only_tn = (y_pred_summary["VORI"] == 0) & (y_pred_summary["VRBA"] == 1) & (y_true == 0)

        # Store the combined normalized percentages relative to the correct support
        results_combined.append({
            "Model_Name": model_name,
            "Test_Year": key,
            "Both_TP_%": (idx_both_tp.sum() / support_1) * 100 if support_1 > 0 else 0,
            "Both_FN_%": (idx_both_fn.sum() / support_1) * 100 if support_1 > 0 else 0,
            "VORI_only_Rate_%": (idx_vori_only_tp.sum() / support_1) * 100 if support_1 > 0 else 0,
            "VRBA_only_Rate_%": (idx_vrba_only_tp.sum() / support_1) * 100 if support_1 > 0 else 0,

            "Both_TN_Rate_%": (idx_both_tn.sum() / support_0) * 100 if support_0 > 0 else 0,
            "Both_FP_Rate_%": (idx_both_fp.sum() / support_0) * 100 if support_0 > 0 else 0,
            "VORI_only_TN_Rate_%": (idx_vori_only_tn.sum() / support_0) * 100 if support_0 > 0 else 0,
            "VRBA_only_TN_Rate_%": (idx_vrba_only_tn.sum() / support_0) * 100 if support_0 > 0 else 0
        })

    # Convert per-year results to DataFrames
    df_indiv = pd.DataFrame(results_individual)
    df_comb = pd.DataFrame(results_combined)

    # Compute average performance across validation years for the given model
    df_indiv_means = df_indiv.groupby(["Model_Name"]).mean(numeric_only=True).reset_index()
    df_indiv_means = df_indiv_means.drop(columns=["Test_Year"])

    df_comb_means = df_comb.groupby(["Model_Name"]).mean(numeric_only=True).reset_index()
    df_comb_means = df_comb_means.drop(columns=["Test_Year"])

    # Merge individual and combined summaries into one final summary table
    df_summary = pd.merge(df_indiv_means, df_comb_means, on="Model_Name", how="left")
    return df_summary

# %%
all_summaries = []

# Random Forest + No Feature Selection
summary_rf = get_crossval_summary_normalized(best_models_VORI_train, None, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA_train, None, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits,
    best_features=None , model_name="RF_NO_FS")
all_summaries.append(summary_rf)

# Random Forest + SelectFromModel
summary_rf_sfm = get_crossval_summary_normalized(best_models_VORI_train, best_features_VORI_train, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA_train, best_features_VRBA_train, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits,
    best_features='selected' , model_name="RF_SFM")
all_summaries.append(summary_rf_sfm)

# Random Forest + Backward Elimination
summary_rf_bckw = get_crossval_summary_normalized(best_models_VORI_train, best_features_bckw_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA_train, best_features_bckw_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits,
    best_features='selected' , model_name="RF_BCKW")
all_summaries.append(summary_rf_bckw)


leaderboard_train = pd.concat(all_summaries, ignore_index=True)
# leaderboard.to_csv("leaderboard_summary_3days.csv", index=False)
# leaderboard2 = pd.read_csv("leaderboard_summary_3days.csv")

leaderboard_train

# %%
all_summaries = []

# Random Forest + No Feature Selection
summary_rf = get_crossval_summary_normalized(best_5days_models_VORI_train, None, x_train_5_VORI, x_val_5_VORI, y_train_5_VORI, y_val_5_VORI,
    best_5days_models_VRBA_train, None, x_train_5_VRBA, x_val_5_VRBA, y_train_5_VRBA, y_val_5_VRBA,
    train_test_years_splits,
    best_features=None , model_name="RF_NO_FS")
all_summaries.append(summary_rf)

# Random Forest + SelectFromModel
summary_rf_sfm = get_crossval_summary_normalized(best_5days_models_VORI_train, best_features_5days_VORI_train, x_train_5_VORI, x_val_5_VORI, y_train_5_VORI, y_val_5_VORI,
    best_5days_models_VRBA_train, best_features_5days_VRBA_train, x_train_5_VRBA, x_val_5_VRBA, y_train_5_VRBA, y_val_5_VRBA,
    train_test_years_splits,
    best_features='selected' , model_name="RF_SFM")
all_summaries.append(summary_rf_sfm)

# Random Forest + Backward Elimination
summary_rf_bckw = get_crossval_summary_normalized(best_5days_models_VORI_train, best_features_bckw_5days_VORI, x_train_5_VORI, x_val_5_VORI, y_train_5_VORI, y_val_5_VORI,
    best_5days_models_VRBA_train, best_features_bckw_5days_VRBA, x_train_5_VRBA, x_val_5_VRBA, y_train_5_VRBA, y_val_5_VRBA,
    train_test_years_splits,
    best_features='selected' , model_name="RF_BCKW")
all_summaries.append(summary_rf_bckw)


leaderboard = pd.concat(all_summaries, ignore_index=True)
# leaderboard = pd.read_csv("leaderboard_summary.csv")

leaderboard


# # Trier par Recall pour voir le modèle qui rate le moins d'événements
# leaderboard_sorted = leaderboard.sort_values(by=['Recall VRBA'], ascending=[True, False])
# print(leaderboard_sorted)
# Out:
#   Model_Name  Accuracy VORI  Precision VORI  Recall VORI  F1_Score VORI  \
# 0   RF_NO_FS       0.677028        0.612731     0.614699       0.603107
# 1     RF_SFM       0.689645        0.615525     0.680819       0.638602
# 2    RF_BCKW       0.692029        0.604604     0.696071       0.641815
#
#      TP VORI    TN VORI    FP VORI    FN VORI  TP_VORI_%  FN_VORI_%  \
# 0  53.666667  78.333333  34.166667  28.833333  61.469870  38.530130
# 1  58.500000  75.833333  36.666667  24.000000  68.081896  31.918104
# 2  59.000000  77.000000  35.500000  23.500000  69.607065  30.392935
#
#    TN_VORI_%  FP_VORI_%  Accuracy VRBA  Precision VRBA  Recall VRBA  \
# 0  71.693022  28.306978       0.690941        0.645762     0.621984
# 1  69.925396  30.074604       0.704565        0.644331     0.639201
# 2  68.729128  31.270872       0.692517        0.630745     0.637803
#
#    F1_Score VRBA    TP VRBA    TN VRBA    FP VRBA    FN VRBA  TP_VRBA_%  \
# 0       0.623193  56.333333  77.333333  35.166667  26.166667  62.198363
# 1       0.633553  58.000000  80.333333  32.166667  24.500000  63.920116
# 2       0.623225  58.333333  78.000000  34.500000  24.166667  63.780285
#
#    FN_VRBA_%  TN_VRBA_%  FP_VRBA_%  Both_TP_%  Both_FN_%  VORI_only_Rate_%  \
# 0  37.801637  72.451885  27.548115  48.552767  24.884534         12.917103
# 1  36.079884  73.420177  26.579823  53.271341  21.269328         14.810556
# 2  36.219715  71.428934  28.571066  51.155455  17.768104         18.451610
#
#    VRBA_only_Rate_%  Both_TN_Rate_%  Both_FP_Rate_%  VORI_only_TN_Rate_%  \
# 0         13.645596       61.611015       17.466107            10.082007
# 1         10.648776       59.744317       16.398745            10.181079
# 2         12.624830       50.396982       10.238920            18.332145
#
#    VRBA_only_TN_Rate_%
# 0            10.840870
# 1            13.675860
# 2            21.031952

# %% [markdown]
# ## Correlation

# %% [markdown]
# It is also important to consider that some features may be highly correlated with each other. In
# such cases, several features may provide similar information to the model, potentially introducing
# redundancy in the feature set.

# %%
def get_top_correlations(df, station_name):
  
    corr_matrix = df.corr().abs()
    
    upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    
    # Convertir la matrice en une liste, supprimer les valeurs vides, et trier
    sorted_corrs = upper_tri.unstack().dropna().sort_values(ascending=False)
    
    # Convertir en DataFrame pour un affichage propre
    df_corrs = pd.DataFrame(sorted_corrs).reset_index()
    df_corrs.columns = ['Feature 1', 'Feature 2', 'Correlation']
    
    # Afficher le top 20 des plus fortes corrélations
    print(df_corrs[df_corrs['Correlation'] > 0.9])
    print("\n")
    
    return df_corrs



# Sinon, si ce sont déjà des DataFrames complets :
correlations_vori = get_top_correlations(x_train_5_VORI[key], "VORI")
correlations_vrba = get_top_correlations(x_train_5_VRBA[key], "VRBA")
# Out:
#                                 Feature 1                          Feature 2  \
# 0                        Delta_Max_Min_VT                             Max_VT
# 1                     Var Value DSAR VORI         Quantile Changes DSAR VORI
# 2                     Std Value DSAR VORI         Quantile Changes DSAR VORI
# 3                  Delta_Max_Min_tornillo                       Max_tornillo
# 4                     Var Value DSAR VORI                Std Value DSAR VORI
# 5   falling_rsam_mean_abs_derivative VORI  falling_rsam_mean_derivative VORI
# 6   falling_rsam_mean_abs_derivative VORI     falling_rsam_acceleration VORI
# 7                        Delta_Max_Min_LP                             Max_LP
# 8                      Max drop DSAR VORI                 Avg drop DSAR VORI
# 9                      Max peak DSAR VORI                 Avg peak DSAR VORI
# 10        quiescence_rsam_drop_ratio VORI          is_hydrothermal_seal VORI
# 11      falling_rsam_mean_derivative VORI     falling_rsam_acceleration VORI
# 12                     Max peak RSAM VORI                 Avg peak RSAM VORI
# 13           Delta_Max_Min_Precipitations                 Max_Precipitations
# 14                 Median Value RSAM VORI                Avg Value RSAM VORI
# 15      falling_rsam_mean_derivative VORI            falling_rsam_slope VORI
# 16                     Max drop RSAM VORI                 Avg drop RSAM VORI
# 17  falling_rsam_mean_abs_derivative VORI            falling_rsam_slope VORI
# 18               Max Drop Depth DSAR VORI           Avg Drop Depth DSAR VORI
# 19                falling_rsam_slope VORI     falling_rsam_acceleration VORI
# 20               Max Prominence DSAR VORI           Avg Prominence DSAR VORI
# 21               Std Drop Depth DSAR VORI           Max Drop Depth DSAR VORI
# 22                  Max l Width DSAR VORI              Avg l Width DSAR VORI
# 23              Mean Min Values RSAM VORI                 Max drop RSAM VORI
# 24                    Std Value DSAR VORI                Avg Value DSAR VORI
# 25               Std Prominence DSAR VORI           Max Prominence DSAR VORI
# 26                  Max h Width DSAR VORI              Avg h Width DSAR VORI
# 27               Max Drop Depth RSAM VORI           Avg Drop Depth RSAM VORI
# 28                                 Max_VT                             Sum_VT
# 29                    Avg Value RSAM VORI                 Avg peak RSAM VORI
# 30                  Std l Width DSAR VORI              Max l Width DSAR VORI
# 31               Max Prominence RSAM VORI           Avg Prominence RSAM VORI
# 32                  Max l Width RSAM VORI              Avg l Width RSAM VORI
# 33                           Max_tornillo                       Sum_tornillo
# 34                    Var Value RSAM VORI                Std Value RSAM VORI
# 35                       Delta_Max_Min_VT                             Sum_VT
# 36                                 Max_LP                             Sum_LP
# 37                    Avg Value DSAR VORI         Quantile Changes DSAR VORI
# 38              Mean Min Values RSAM VORI                 Avg drop RSAM VORI
# 39                 Median Value RSAM VORI                 Avg drop RSAM VORI
# 40                  Max h Width RSAM VORI              Avg h Width RSAM VORI
# 41              Number of drops DSAR VORI          Number of peaks DSAR VORI
# 42                    Avg Value RSAM VORI                 Max peak RSAM VORI
# 43                 Delta_Max_Min_tornillo                       Sum_tornillo
# 44                     Max_Precipitations                 Sum_Precipitations
# 45                 Median Value RSAM VORI                 Avg peak RSAM VORI
# 46                    Var Value DSAR VORI                Avg Value DSAR VORI
# 47                  Std h Width DSAR VORI              Max h Width DSAR VORI
# 48                 Median Value DSAR VORI                 Avg drop DSAR VORI
# 49                    Avg Value RSAM VORI                 Avg drop RSAM VORI
# 50              Mean Min Values DSAR VORI                 Max drop DSAR VORI
# 51              Mean Min Values DSAR VORI                 Avg drop DSAR VORI
# 52                 Median Value DSAR VORI                 Avg peak DSAR VORI
#
#     Correlation
# 0      0.999202
# 1      0.998982
# 2      0.998279
# 3      0.995477
# 4      0.994927
# 5      0.994710
# 6      0.994647
# 7      0.993179
# 8      0.991537
# 9      0.989187
# 10     0.988655
# 11     0.988223
# 12     0.987994
# 13     0.987869
# 14     0.987296
# 15     0.983963
# 16     0.980831
# 17     0.975848
# 18     0.971924
# 19     0.971541
# 20     0.971183
# 21     0.963911
# 22     0.960960
# 23     0.952625
# 24     0.951281
# 25     0.950103
# 26     0.947675
# 27     0.945918
# 28     0.943166
# 29     0.942998
# 30     0.942324
# 31     0.938925
# 32     0.936539
# 33     0.936346
# 34     0.935444
# 35     0.933724
# 36     0.932885
# 37     0.932705
# 38     0.932451
# 39     0.926957
# 40     0.926085
# 41     0.925402
# 42     0.923503
# 43     0.921214
# 44     0.919829
# 45     0.919408
# 46     0.917351
# 47     0.913592
# 48     0.911721
# 49     0.905240
# 50     0.903279
# 51     0.902954
# 52     0.901596
#
#
#                                 Feature 1                          Feature 2  \
# 0                        Delta_Max_Min_VT                             Max_VT
# 1   falling_rsam_mean_abs_derivative VRBA  falling_rsam_mean_derivative VRBA
# 2                      Max peak DSAR VRBA                 Avg peak DSAR VRBA
# 3                  Delta_Max_Min_tornillo                       Max_tornillo
# 4                      Max drop RSAM VRBA                 Avg drop RSAM VRBA
# 5                      Max drop DSAR VRBA                 Avg drop DSAR VRBA
# 6                        Delta_Max_Min_LP                             Max_LP
# 7         quiescence_rsam_drop_ratio VRBA          is_hydrothermal_seal VRBA
# 8                      Max peak RSAM VRBA                 Avg peak RSAM VRBA
# 9   falling_rsam_mean_abs_derivative VRBA     falling_rsam_acceleration VRBA
# 10      falling_rsam_mean_derivative VRBA            falling_rsam_slope VRBA
# 11                 Median Value DSAR VRBA                Avg Value DSAR VRBA
# 12      falling_rsam_mean_derivative VRBA     falling_rsam_acceleration VRBA
# 13           Delta_Max_Min_Precipitations                 Max_Precipitations
# 14  falling_rsam_mean_abs_derivative VRBA            falling_rsam_slope VRBA
# 15                falling_rsam_slope VRBA     falling_rsam_acceleration VRBA
# 16                    Var Value DSAR VRBA                Std Value DSAR VRBA
# 17                    Avg Value DSAR VRBA                 Avg peak DSAR VRBA
# 18                    Avg Value DSAR VRBA                 Max peak DSAR VRBA
# 19                 Median Value RSAM VRBA                Avg Value RSAM VRBA
# 20               Max Prominence RSAM VRBA           Avg Prominence RSAM VRBA
# 21                 Median Value DSAR VRBA                 Avg drop DSAR VRBA
# 22               Max Drop Depth RSAM VRBA           Avg Drop Depth RSAM VRBA
# 23               Max Drop Depth DSAR VRBA           Avg Drop Depth DSAR VRBA
# 24                 Median Value DSAR VRBA                 Avg peak DSAR VRBA
# 25                                 Max_VT                             Sum_VT
# 26                 Median Value DSAR VRBA                 Max peak DSAR VRBA
# 27               Max Prominence DSAR VRBA           Avg Prominence DSAR VRBA
# 28                 Median Value DSAR VRBA                 Max drop DSAR VRBA
# 29                           Max_tornillo                       Sum_tornillo
# 30                    Avg Value RSAM VRBA                 Avg peak RSAM VRBA
# 31                       Delta_Max_Min_VT                             Sum_VT
# 32                                 Max_LP                             Sum_LP
# 33                    Avg Value DSAR VRBA                 Avg drop DSAR VRBA
# 34                    Std Value DSAR VRBA                 Avg peak DSAR VRBA
# 35              Mean Min Values RSAM VRBA                 Max drop RSAM VRBA
# 36                    Std Value DSAR VRBA                 Max peak DSAR VRBA
# 37              Mean Min Values RSAM VRBA                 Avg drop RSAM VRBA
# 38                    Avg Value RSAM VRBA                 Max peak RSAM VRBA
# 39                 Delta_Max_Min_tornillo                       Sum_tornillo
# 40                     Max_Precipitations                 Sum_Precipitations
# 41                 Median Value RSAM VRBA                 Avg drop RSAM VRBA
# 42                  Max h Width DSAR VRBA              Avg h Width DSAR VRBA
# 43                    Avg Value DSAR VRBA                 Max drop DSAR VRBA
# 44                    Std Value RSAM VRBA         Quantile Changes RSAM VRBA
# 45                    Std Value DSAR VRBA                Avg Value DSAR VRBA
# 46                    Var Value RSAM VRBA                Std Value RSAM VRBA
# 47                    Var Value DSAR VRBA                 Avg peak DSAR VRBA
# 48                  Max l Width RSAM VRBA              Avg l Width RSAM VRBA
# 49                  Max l Width DSAR VRBA              Avg l Width DSAR VRBA
# 50                    Var Value DSAR VRBA                 Max peak DSAR VRBA
# 51                 Median Value RSAM VRBA                 Max drop RSAM VRBA
# 52                  Max h Width RSAM VRBA              Avg h Width RSAM VRBA
#
#     Correlation
# 0      0.999202
# 1      0.997800
# 2      0.996719
# 3      0.995477
# 4      0.994030
# 5      0.994024
# 6      0.993179
# 7      0.992621
# 8      0.991538
# 9      0.991240
# 10     0.990993
# 11     0.990158
# 12     0.989117
# 13     0.987869
# 14     0.984825
# 15     0.982847
# 16     0.971398
# 17     0.970192
# 18     0.967749
# 19     0.965561
# 20     0.962873
# 21     0.951488
# 22     0.951367
# 23     0.947034
# 24     0.946840
# 25     0.943166
# 26     0.942681
# 27     0.940437
# 28     0.939040
# 29     0.936346
# 30     0.934725
# 31     0.933724
# 32     0.932885
# 33     0.931597
# 34     0.931430
# 35     0.931114
# 36     0.928989
# 37     0.927881
# 38     0.923537
# 39     0.921214
# 40     0.919829
# 41     0.919388
# 42     0.918657
# 43     0.918195
# 44     0.915920
# 45     0.913745
# 46     0.913695
# 47     0.909922
# 48     0.909840
# 49     0.907308
# 50     0.906978
# 51     0.906304
# 52     0.902974

# %% [markdown]
# #### Random Forest Classifier optimization

# %%
coverage_analysis_train, time_analysis_results_train, features_classement_train = print_report_best_model_per_year_out_of_dataset(
    best_models_VORI_train, best_features_VORI_train, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA_train, best_features_VRBA_train, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    train_test_years_splits,
    best_features='selected' ,
    five_days=False, return_time=True,
    time = time_val,time_5days = time_5days_val,
    coverage = coverage_val, coverage_5days = coverage_5days_val
)

coverage_analysis_5days_train, time_analysis_results_5days_train, features_classement_5days_train = print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI_train, best_features_5days_VORI_train, x_train_5_VORI, x_val_5_VORI, y_train_5_VORI, y_val_5_VORI,
    best_5days_models_VRBA_train, best_features_5days_VRBA_train, x_train_5_VRBA, x_val_5_VRBA, y_train_5_VRBA, y_val_5_VRBA,
    train_test_years_splits,
    best_features='selected' ,
    five_days=True , return_time=True,
    time = time_val,time_5days = time_5days_val,
    coverage = coverage_val, coverage_5days = coverage_5days_val
)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 8  8]
#  [ 4 20]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57        16
#            1       0.71      0.83      0.77        24
#
#     accuracy                           0.70        40
#    macro avg       0.69      0.67      0.67        40
# weighted avg       0.70      0.70      0.69        40
#
#
#  Top Features (VORI)
# Sum_LP                          0.058658
# Quantile Changes RSAM VORI      0.057157
# slope_ratio VORI                0.045375
# Quantile Changes DSAR VORI      0.043688
# Max drop DSAR VORI              0.037985
# Mean Min Values RSAM VORI       0.035918
# Sum_Precipitations              0.035234
# Mean Min Values DSAR VORI       0.032458
# Delta_Max_Min_Precipitations    0.031490
# Max l Width DSAR VORI           0.030725
# Max drop RSAM VORI              0.029150
# Median Value DSAR VORI          0.028679
# Avg h Width DSAR VORI           0.026810
# Avg l Width RSAM VORI           0.026452
# Max_LP                          0.026011
# Avg Value RSAM VORI             0.025672
# Avg drop DSAR VORI              0.025218
# Avg Drop Depth RSAM VORI        0.024908
# Median Value RSAM VORI          0.024535
# Avg Prominence RSAM VORI        0.024107
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.77 ± 0.92
# Mean Magnitude (Missed - FN):   3.48 ± 0.70
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9  7]
#  [ 3 21]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64        16
#            1       0.75      0.88      0.81        24
#
#     accuracy                           0.75        40
#    macro avg       0.75      0.72      0.73        40
# weighted avg       0.75      0.75      0.74        40
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.044898
# Sum_LP                          0.042981
# Mean Min Values RSAM VRBA       0.038002
# Max_LP                          0.031950
# Var Value RSAM VRBA             0.031772
# Mean Min Values DSAR VRBA       0.030800
# Std Value RSAM VRBA             0.030366
# Avg Prominence RSAM VRBA        0.029477
# Var Value DSAR VRBA             0.029367
# Std Value DSAR VRBA             0.028534
# Max Drop Depth RSAM VRBA        0.027806
# Max h Width RSAM VRBA           0.027156
# Quantile Changes DSAR VRBA      0.026656
# Delta_Max_Min_Precipitations    0.026082
# Median Value DSAR VRBA          0.025151
# Max peak DSAR VRBA              0.025142
# Max l Width DSAR VRBA           0.024969
# Max Drop Depth DSAR VRBA        0.023114
# Avg Value DSAR VRBA             0.022378
# Avg l Width DSAR VRBA           0.022141
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.88 ± 0.93
# Mean Magnitude (Missed - FN):   2.93 ± 1.01
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 19 | Mean VORI RSAM Coverage: 86.84±23.79% | Mean VORI DSAR Coverage: 93.56±22.92% | Mean VRBA Coverage: 71.85±22.14%
# Both Missed (FN): 2 | Mean VORI RSAM Coverage: 99.87±0.11% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 50.43±22.43%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 99.88±0.07% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 78.24±21.01%
# Both True Negatives (TN): 6 | Mean VORI RSAM Coverage: 82.33±28.80% | Mean VORI DSAR Coverage: 82.61±29.00% | Mean VRBA Coverage: 66.82±19.48%
# VORI Detected Without VRBA (TP): 1 | Mean VORI RSAM Coverage: 0.00+-nan% | Mean VORI DSAR Coverage: 0.00+-nan% | Mean VRBA Coverage: 78.95+-nan%
# VRBA Detected Without VORI (TP): 2 | Mean VORI RSAM Coverage: 83.18+-23.46% | Mean VORI DSAR Coverage: 83.27+-23.59% | Mean VRBA Coverage: 66.95+-8.05%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 79.11+-7.74% | Mean VORI DSAR Coverage: 86.80+-18.61% | Mean VRBA Coverage: 74.61+-35.94%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 66.59+-57.67% | Mean VORI DSAR Coverage: 73.20+-46.34% | Mean VRBA Coverage: 88.51+-19.95%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[13  8]
#  [ 8 14]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        21
#            1       0.64      0.64      0.64        22
#
#     accuracy                           0.63        43
#    macro avg       0.63      0.63      0.63        43
# weighted avg       0.63      0.63      0.63        43
#
#
#  Top Features (VORI)
# Median Value DSAR VORI        0.041094
# Quantile Changes DSAR VORI    0.039058
# Max_tornillo                  0.037350
# Max Prominence RSAM VORI      0.036800
# Var Value RSAM VORI           0.035567
# Sum_Precipitations            0.032423
# Avg Prominence RSAM VORI      0.031312
# Std Value RSAM VORI           0.030590
# Max h Width RSAM VORI         0.030464
# Mean Min Values DSAR VORI     0.030331
# Avg Value DSAR VORI           0.029416
# Delta_Max_Min_tornillo        0.029072
# Avg l Width RSAM VORI         0.028993
# Max l Width RSAM VORI         0.028701
# Quantile Changes RSAM VORI    0.028343
# Sum_LP                        0.028319
# Sum_tornillo                  0.027718
# Max drop DSAR VORI            0.027605
# Avg h Width RSAM VORI         0.027251
# Avg drop DSAR VORI            0.027145
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.36 ± 0.51
# Mean Magnitude (Missed - FN):   3.34 ± 1.05
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[15  6]
#  [ 6 16]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71        21
#            1       0.73      0.73      0.73        22
#
#     accuracy                           0.72        43
#    macro avg       0.72      0.72      0.72        43
# weighted avg       0.72      0.72      0.72        43
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.076570
# Std Value DSAR VRBA           0.060326
# Var Value DSAR VRBA           0.053660
# slope_ratio VRBA              0.043639
# Var Value RSAM VRBA           0.031942
# Median Value DSAR VRBA        0.030135
# Sum_LP                        0.028463
# Max Drop Depth DSAR VRBA      0.026662
# Mean Min Values RSAM VRBA     0.026075
# Sum_tornillo                  0.025924
# Sum_Precipitations            0.025098
# Mean Min Values DSAR VRBA     0.024766
# Avg Prominence RSAM VRBA      0.024275
# Max Prominence DSAR VRBA      0.023917
# Quantile Changes DSAR VRBA    0.023724
# Max drop RSAM VRBA            0.023419
# Std Value RSAM VRBA           0.023083
# Delta_Max_Min_tornillo        0.022431
# Avg Drop Depth DSAR VRBA      0.022211
# Avg peak DSAR VRBA            0.021207
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.67
# Mean Magnitude (Missed - FN):   3.18 ± 1.23
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 13 | Mean VORI RSAM Coverage: 86.93±27.65% | Mean VORI DSAR Coverage: 87.42±27.84% | Mean VRBA Coverage: 69.36±21.56%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 96.99±5.15% | Mean VORI DSAR Coverage: 97.54±5.39% | Mean VRBA Coverage: 70.42±7.89%
# Both False Positives (FP): 4 | Mean VORI RSAM Coverage: 96.84±6.23% | Mean VORI DSAR Coverage: 96.85±6.23% | Mean VRBA Coverage: 46.83±17.35%
# Both True Negatives (TN): 11 | Mean VORI RSAM Coverage: 96.79±10.47% | Mean VORI DSAR Coverage: 96.80±10.47% | Mean VRBA Coverage: 91.59±14.47%
# VORI Detected Without VRBA (TP): 1 | Mean VORI RSAM Coverage: 99.95+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 69.14+-nan%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 94.40+-9.62% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 31.96+-29.12%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 87.87+-17.08% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 77.97+-31.18%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 99.30+-1.30% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 78.03+-16.09%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 9  7]
#  [ 6 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58        16
#            1       0.71      0.74      0.72        23
#
#     accuracy                           0.67        39
#    macro avg       0.65      0.65      0.65        39
# weighted avg       0.66      0.67      0.66        39
#
#
#  Top Features (VORI)
# Quantile Changes RSAM VORI         0.094641
# Mean Min Values DSAR VORI          0.046746
# Avg drop DSAR VORI                 0.045540
# Max drop DSAR VORI                 0.040420
# Avg Prominence RSAM VORI           0.039260
# Avg peak DSAR VORI                 0.038161
# Median Value DSAR VORI             0.037152
# Delta_Max_Min_tornillo             0.035961
# Max l Width RSAM VORI              0.035315
# Max peak DSAR VORI                 0.034697
# Avg Value RSAM VORI                0.034671
# slope_ratio VORI                   0.034614
# Avg drop RSAM VORI                 0.029977
# Max drop RSAM VORI                 0.027475
# Max Prominence RSAM VORI           0.026927
# num_state_changes_inv_rsam VORI    0.026695
# Sum_Precipitations                 0.026032
# Sum_LP                             0.025873
# Sum_VT                             0.025787
# Std Value DSAR VORI                0.023599
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.66 ± 0.83
# Mean Magnitude (Missed - FN):   2.84 ± 0.59
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9  7]
#  [ 6 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58        16
#            1       0.71      0.74      0.72        23
#
#     accuracy                           0.67        39
#    macro avg       0.65      0.65      0.65        39
# weighted avg       0.66      0.67      0.66        39
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.063394
# Median Value DSAR VRBA        0.050624
# Avg Value DSAR VRBA           0.037039
# Max peak DSAR VRBA            0.031736
# Var Value RSAM VRBA           0.030361
# Quantile Changes DSAR VRBA    0.030225
# Std Value DSAR VRBA           0.029468
# Avg peak DSAR VRBA            0.028762
# Mean Min Values RSAM VRBA     0.027371
# Var Value DSAR VRBA           0.027289
# Std Value RSAM VRBA           0.026556
# Max drop RSAM VRBA            0.026211
# Avg drop RSAM VRBA            0.024632
# Sum_LP                        0.024334
# Median Value RSAM VRBA        0.024146
# Mean Min Values DSAR VRBA     0.023480
# Avg drop DSAR VRBA            0.023026
# Max Prominence RSAM VRBA      0.022424
# Max l Width RSAM VRBA         0.021807
# Avg Value RSAM VRBA           0.021769
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.57 ± 0.80
# Mean Magnitude (Missed - FN):   3.11 ± 0.53
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 14 | Mean VORI RSAM Coverage: 85.28±36.15% | Mean VORI DSAR Coverage: 85.39±36.19% | Mean VRBA Coverage: 60.14±27.51%
# Both Missed (FN): 3 | Mean VORI RSAM Coverage: 93.39±11.36% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 85.46±23.67%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 92.99±15.52% | Mean VORI DSAR Coverage: 93.01±15.53% | Mean VRBA Coverage: 61.26±28.30%
# Both True Negatives (TN): 7 | Mean VORI RSAM Coverage: 99.86±0.24% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 94.67±9.50%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 99.92+-0.05% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.57+-32.71%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 53.57+-6.66%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 99.17+-1.11% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 63.70+-7.98%
# VRBA Detected Without VORI (TN): 2 | Mean VORI RSAM Coverage: 99.94+-0.02% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 84.71+-21.56%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 5 17]
#  [ 9 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.36      0.23      0.28        22
#            1       0.39      0.55      0.46        20
#
#     accuracy                           0.38        42
#    macro avg       0.38      0.39      0.37        42
# weighted avg       0.37      0.38      0.36        42
#
#
#  Top Features (VORI)
# Max peak DSAR VORI                 0.109601
# Var Value RSAM VORI                0.108804
# Std Value RSAM VORI                0.103802
# Last_tornillo                      0.091780
# Max Prominence RSAM VORI           0.057309
# Avg Drop Depth DSAR VORI           0.052409
# num_state_changes_log_dsar VORI    0.047956
# Avg Drop Depth RSAM VORI           0.046327
# Sum_LP                             0.045868
# Quantile Changes RSAM VORI         0.038461
# Avg l Width RSAM VORI              0.036960
# Avg peak DSAR VORI                 0.033322
# Sum_VT                             0.031966
# Median Value RSAM VORI             0.030625
# Avg Prominence RSAM VORI           0.028618
# Avg Prominence DSAR VORI           0.023132
# is_raising_tornillo                0.020739
# Mean Min Values DSAR VORI          0.018158
# Max drop RSAM VORI                 0.016983
# Delta_Max_Min_Precipitations       0.015168
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.68 ± 0.91
# Mean Magnitude (Missed - FN):   3.57 ± 0.97
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9 13]
#  [ 7 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.56      0.41      0.47        22
#            1       0.50      0.65      0.57        20
#
#     accuracy                           0.52        42
#    macro avg       0.53      0.53      0.52        42
# weighted avg       0.53      0.52      0.52        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.080831
# Max peak DSAR VRBA            0.060174
# Var Value DSAR VRBA           0.059503
# Avg peak DSAR VRBA            0.048727
# Std Value DSAR VRBA           0.045635
# Quantile Changes DSAR VRBA    0.042341
# Avg Value DSAR VRBA           0.037893
# Var Value RSAM VRBA           0.037509
# Max h Width DSAR VRBA         0.034573
# Max Drop Depth RSAM VRBA      0.028650
# Avg Prominence DSAR VRBA      0.028153
# Avg h Width DSAR VRBA         0.027274
# Std Value RSAM VRBA           0.026750
# Max_LP                        0.025606
# Max Prominence RSAM VRBA      0.025252
# Max drop DSAR VRBA            0.025204
# Sum_VT                        0.025037
# Avg Value RSAM VRBA           0.024183
# Max Prominence DSAR VRBA      0.023924
# Median Value DSAR VRBA        0.022049
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.04 ± 0.80
# Mean Magnitude (Missed - FN):   3.17 ± 1.42
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 9 | Mean VORI RSAM Coverage: 80.72±32.11% | Mean VORI DSAR Coverage: 83.02±32.81% | Mean VRBA Coverage: 59.61±30.26%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 94.49±8.60% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 85.52±18.58%
# Both False Positives (FP): 12 | Mean VORI RSAM Coverage: 88.61±29.63% | Mean VORI DSAR Coverage: 90.37±24.40% | Mean VRBA Coverage: 68.96±34.19%
# Both True Negatives (TN): 4 | Mean VORI RSAM Coverage: 99.56±0.79% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 90.42±14.49%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 99.91+-0.07% | Mean VORI DSAR Coverage: 99.94+-0.02% | Mean VRBA Coverage: 49.98+-70.68%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 95.91+-7.80% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.00+-30.92%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 96.73+-nan% | Mean VORI DSAR Coverage: 96.73+-nan% | Mean VRBA Coverage: 53.03+-nan%
# VRBA Detected Without VORI (TN): 5 | Mean VORI RSAM Coverage: 99.26+-1.11% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 71.88+-16.06%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[12 10]
#  [10 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55        22
#            1       0.57      0.57      0.57        23
#
#     accuracy                           0.56        45
#    macro avg       0.56      0.56      0.56        45
# weighted avg       0.56      0.56      0.56        45
#
#
#  Top Features (VORI)
# Max l Width RSAM VORI         0.109300
# Mean Min Values DSAR VORI     0.095355
# Avg h Width DSAR VORI         0.086559
# Avg drop RSAM VORI            0.082572
# Std Value RSAM VORI           0.062886
# slope_ratio VORI              0.052215
# Max drop DSAR VORI            0.048836
# Max l Width DSAR VORI         0.046593
# Avg Drop Depth RSAM VORI      0.045956
# Quantile Changes RSAM VORI    0.038619
# is_pressurizing VORI          0.037397
# Delta_Max_Min_tornillo        0.036455
# Median Value RSAM VORI        0.035362
# Avg Drop Depth DSAR VORI      0.032683
# Max Drop Depth DSAR VORI      0.031168
# Avg drop DSAR VORI            0.026567
# Max h Width DSAR VORI         0.021772
# Avg peak DSAR VORI            0.021034
# Max Prominence DSAR VORI      0.018252
# Avg Value RSAM VORI           0.016445
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.97 ± 0.96
# Mean Magnitude (Missed - FN):   2.55 ± 0.92
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[15  7]
#  [13 10]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.54      0.68      0.60        22
#            1       0.59      0.43      0.50        23
#
#     accuracy                           0.56        45
#    macro avg       0.56      0.56      0.55        45
# weighted avg       0.56      0.56      0.55        45
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.255501
# Mean Min Values RSAM VRBA       0.152026
# Var Value DSAR VRBA             0.102467
# Std Value DSAR VRBA             0.101464
# Avg Drop Depth DSAR VRBA        0.057086
# Sum_Precipitations              0.048304
# Avg Value RSAM VRBA             0.045015
# Max Drop Depth DSAR VRBA        0.037339
# Max peak RSAM VRBA              0.036959
# Std Value RSAM VRBA             0.031513
# Median Value DSAR VRBA          0.028487
# Mean Min Values DSAR VRBA       0.028013
# Avg peak RSAM VRBA              0.024862
# Max peak DSAR VRBA              0.018790
# Avg peak DSAR VRBA              0.018571
# Delta_Max_Min_Precipitations    0.013604
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.84 ± 1.02
# Mean Magnitude (Missed - FN):   2.75 ± 0.93
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 6 | Mean VORI RSAM Coverage: 97.29±6.41% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 60.54±33.21%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 99.95±0.02% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 82.71±17.53%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.95±0.00% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 48.66±25.23%
# Both True Negatives (TN): 8 | Mean VORI RSAM Coverage: 99.61±0.91% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 87.46±26.57%
# VORI Detected Without VRBA (TP): 7 | Mean VORI RSAM Coverage: 79.22+-36.55% | Mean VORI DSAR Coverage: 82.04+-37.39% | Mean VRBA Coverage: 66.45+-34.27%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 51.26+-10.67%
# VORI Detected Without VRBA (TN): 4 | Mean VORI RSAM Coverage: 99.89+-0.06% | Mean VORI DSAR Coverage: 99.96+-0.01% | Mean VRBA Coverage: 68.58+-21.07%
# VRBA Detected Without VORI (TN): 7 | Mean VORI RSAM Coverage: 70.65+-41.08% | Mean VORI DSAR Coverage: 75.42+-33.47% | Mean VRBA Coverage: 84.88+-37.49%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[11 11]
#  [ 9 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52        22
#            1       0.50      0.55      0.52        20
#
#     accuracy                           0.52        42
#    macro avg       0.53      0.53      0.52        42
# weighted avg       0.53      0.52      0.52        42
#
#
#  Top Features (VORI)
# Sum_Precipitations              0.065778
# Std Value RSAM VORI             0.065672
# Var Value RSAM VORI             0.065597
# Delta_Max_Min_Precipitations    0.054824
# Avg Prominence RSAM VORI        0.043883
# Max l Width RSAM VORI           0.041161
# Mean Min Values RSAM VORI       0.035917
# Quantile Changes RSAM VORI      0.032308
# Avg drop RSAM VORI              0.031563
# Max_Precipitations              0.028048
# Max Prominence RSAM VORI        0.027290
# Avg Value DSAR VORI             0.026684
# Avg drop DSAR VORI              0.026438
# Median Value RSAM VORI          0.026381
# Max drop RSAM VORI              0.025910
# Last_Precipitations             0.025508
# Avg l Width RSAM VORI           0.025396
# Sum_LP                          0.024069
# Max Drop Depth DSAR VORI        0.023777
# Max h Width RSAM VORI           0.023626
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.46 ± 0.55
# Mean Magnitude (Missed - FN):   2.73 ± 0.57
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[16  6]
#  [11  9]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.59      0.73      0.65        22
#            1       0.60      0.45      0.51        20
#
#     accuracy                           0.60        42
#    macro avg       0.60      0.59      0.58        42
# weighted avg       0.60      0.60      0.59        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA      0.083220
# Mean Min Values RSAM VRBA       0.073464
# Avg peak DSAR VRBA              0.061577
# Sum_Precipitations              0.052756
# Delta_Max_Min_Precipitations    0.043995
# Avg l Width DSAR VRBA           0.043608
# Avg Value RSAM VRBA             0.040214
# Avg Value DSAR VRBA             0.039208
# Max Prominence RSAM VRBA        0.036613
# Max_Precipitations              0.034284
# Median Value DSAR VRBA          0.033696
# Std Value DSAR VRBA             0.031418
# Var Value DSAR VRBA             0.028920
# Last_Precipitations             0.026532
# Max l Width DSAR VRBA           0.025114
# slope_ratio VRBA                0.022788
# Max peak DSAR VRBA              0.022704
# Avg h Width DSAR VRBA           0.021658
# Max peak RSAM VRBA              0.021565
# Avg h Width RSAM VRBA           0.021387
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.35 ± 0.51
# Mean Magnitude (Missed - FN):   2.77 ± 0.56
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 7 | Mean VORI RSAM Coverage: 99.82±0.17% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 71.11±22.61%
# Both Missed (FN): 7 | Mean VORI RSAM Coverage: 87.03±26.52% | Mean VORI DSAR Coverage: 90.49±25.03% | Mean VRBA Coverage: 63.29±38.25%
# Both False Positives (FP): 6 | Mean VORI RSAM Coverage: 94.23±13.90% | Mean VORI DSAR Coverage: 94.39±13.62% | Mean VRBA Coverage: 90.18±17.24%
# Both True Negatives (TN): 11 | Mean VORI RSAM Coverage: 99.66±0.60% | Mean VORI DSAR Coverage: 99.96±0.01% | Mean VRBA Coverage: 69.27±21.81%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 95.03+-9.79% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 83.63+-19.06%
# VRBA Detected Without VORI (TP): 2 | Mean VORI RSAM Coverage: 60.61+-55.64% | Mean VORI DSAR Coverage: 72.51+-38.81% | Mean VRBA Coverage: 77.39+-24.79%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 5 | Mean VORI RSAM Coverage: 99.70+-0.36% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 66.05+-18.47%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[66 73]
#  [43 42]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      0.47      0.53       139
#            1       0.37      0.49      0.42        85
#
#     accuracy                           0.48       224
#    macro avg       0.49      0.48      0.48       224
# weighted avg       0.51      0.48      0.49       224
#
#
#  Top Features (VORI)
# Sum_LP                        0.159730
# Max_LP                        0.099088
# Delta_Max_Min_LP              0.064915
# Max_tornillo                  0.050677
# Delta_Max_Min_tornillo        0.049917
# Mean Min Values DSAR VORI     0.040371
# Quantile Changes RSAM VORI    0.038394
# Last_LP                       0.034467
# Mean Min Values RSAM VORI     0.029019
# Avg drop DSAR VORI            0.026715
# Max drop DSAR VORI            0.026403
# Median Value RSAM VORI        0.025747
# Sum_tornillo                  0.025499
# Quantile Changes DSAR VORI    0.024881
# Median Value DSAR VORI        0.024670
# Max peak RSAM VORI            0.022772
# Std Value RSAM VORI           0.022160
# Sum_Precipitations            0.021523
# Var Value RSAM VORI           0.021309
# Avg Value RSAM VORI           0.020896
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.22 ± 0.81
# Mean Magnitude (Missed - FN):   3.67 ± 0.58
# Low magnitude events were more detected
#  length of time array: 224
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[77 62]
#  [34 51]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.55      0.62       139
#            1       0.45      0.60      0.52        85
#
#     accuracy                           0.57       224
#    macro avg       0.57      0.58      0.57       224
# weighted avg       0.60      0.57      0.58       224
#
#
#  Top Features (VRBA)
# Sum_LP                        0.328474
# Quantile Changes RSAM VRBA    0.130855
# Max_LP                        0.125049
# Delta_Max_Min_tornillo        0.077567
# Std Value DSAR VRBA           0.044107
# Avg Value DSAR VRBA           0.041851
# Mean Min Values RSAM VRBA     0.041758
# Sum_VT                        0.039724
# Quantile Changes DSAR VRBA    0.035114
# Sum_Precipitations            0.033944
# Last_LP                       0.033167
# Max_tornillo                  0.029808
# Var Value DSAR VRBA           0.021707
# Std Value RSAM VRBA           0.016874
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.40 ± 0.75
# Mean Magnitude (Missed - FN):   3.52 ± 0.73
# Low magnitude events were more detected
#  length of time array: 224
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 37 | Mean VORI RSAM Coverage: 96.31±6.79% | Mean VORI DSAR Coverage: 98.72±4.42% | Mean VRBA Coverage: 78.39±22.35%
# Both Missed (FN): 29 | Mean VORI RSAM Coverage: 90.03±12.90% | Mean VORI DSAR Coverage: 94.03±13.72% | Mean VRBA Coverage: 89.14±20.17%
# Both False Positives (FP): 53 | Mean VORI RSAM Coverage: 99.94±0.01% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 50.56±28.80%
# Both True Negatives (TN): 57 | Mean VORI RSAM Coverage: 99.76±0.25% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 85.17±22.61%
# VORI Detected Without VRBA (TP): 5 | Mean VORI RSAM Coverage: 66.06+-38.33% | Mean VORI DSAR Coverage: 75.95+-43.33% | Mean VRBA Coverage: 75.16+-22.77%
# VRBA Detected Without VORI (TP): 14 | Mean VORI RSAM Coverage: 99.33+-1.33% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 89.36+-16.05%
# VORI Detected Without VRBA (TN): 9 | Mean VORI RSAM Coverage: 99.62+-0.45% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 64.46+-9.43%
# VRBA Detected Without VORI (TN): 20 | Mean VORI RSAM Coverage: 98.73+-1.94% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 55.05+-39.74%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[75 28]
#  [ 6 38]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.73      0.82       103
#            1       0.58      0.86      0.69        44
#
#     accuracy                           0.77       147
#    macro avg       0.75      0.80      0.75       147
# weighted avg       0.82      0.77      0.78       147
#
#
#  Top Features (VORI)
# Sum_LP                        0.095385
# Avg drop DSAR VORI            0.055593
# Max drop DSAR VORI            0.053069
# Mean Min Values DSAR VORI     0.050529
# Max_LP                        0.046176
# Max_tornillo                  0.041444
# Delta_Max_Min_tornillo        0.037233
# Quantile Changes RSAM VORI    0.036506
# Delta_Max_Min_LP              0.035415
# Max peak DSAR VORI            0.035079
# Median Value DSAR VORI        0.034841
# Avg peak DSAR VORI            0.033620
# Max peak RSAM VORI            0.029165
# Var Value RSAM VORI           0.028848
# Std Value RSAM VORI           0.028669
# Sum_tornillo                  0.028290
# Mean Min Values RSAM VORI     0.028001
# Median Value RSAM VORI        0.027045
# Avg peak RSAM VORI            0.025229
# Avg Value RSAM VORI           0.023753
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.96 ± 0.85
# Mean Magnitude (Missed - FN):   3.55 ± 1.27
# Low magnitude events were more detected
#  length of time array: 147
# Detected Lahars (TP): 2 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[90 13]
#  [19 25]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       103
#            1       0.66      0.57      0.61        44
#
#     accuracy                           0.78       147
#    macro avg       0.74      0.72      0.73       147
# weighted avg       0.78      0.78      0.78       147
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.154210
# Sum_LP                        0.146367
# Avg peak DSAR VRBA            0.105476
# Std Value DSAR VRBA           0.098129
# Median Value DSAR VRBA        0.088280
# Quantile Changes DSAR VRBA    0.056036
# Var Value DSAR VRBA           0.046828
# Avg drop DSAR VRBA            0.036139
# Mean Min Values DSAR VRBA     0.034311
# Delta_Max_Min_tornillo        0.033738
# Mean Min Values RSAM VRBA     0.029769
# Avg Drop Depth DSAR VRBA      0.028497
# Var Value RSAM VRBA           0.021673
# Std Value RSAM VRBA           0.021260
# Avg Value DSAR VRBA           0.019533
# Delta_Max_Min_LP              0.018739
# Max_LP                        0.017839
# Max peak DSAR VRBA            0.015037
# Last_LP                       0.014097
# Avg drop RSAM VRBA            0.007782
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.82 ± 0.79
# Mean Magnitude (Missed - FN):   3.32 ± 1.02
# Low magnitude events were more detected
#  length of time array: 147
# Detected Lahars (TP): 1 | Missed Lahars (FN): 3
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 25 | Mean VORI RSAM Coverage: 95.64±5.16% | Mean VORI DSAR Coverage: 95.64±5.16% | Mean VRBA Coverage: 63.39±8.22%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 76.70±26.04% | Mean VORI DSAR Coverage: 77.57±25.76% | Mean VRBA Coverage: 46.50±36.27%
# Both False Positives (FP): 13 | Mean VORI RSAM Coverage: 91.95±6.38% | Mean VORI DSAR Coverage: 95.19±3.32% | Mean VRBA Coverage: 61.88±16.95%
# Both True Negatives (TN): 75 | Mean VORI RSAM Coverage: 99.31±1.77% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 89.59±15.73%
# VORI Detected Without VRBA (TP): 13 | Mean VORI RSAM Coverage: 97.01+-7.09% | Mean VORI DSAR Coverage: 97.04+-7.10% | Mean VRBA Coverage: 64.11+-7.89%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 15 | Mean VORI RSAM Coverage: 92.95+-14.80% | Mean VORI DSAR Coverage: 99.19+-2.94% | Mean VRBA Coverage: 93.04+-14.41%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[115  57]
#  [ 18 152]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75       172
#            1       0.73      0.89      0.80       170
#
#     accuracy                           0.78       342
#    macro avg       0.80      0.78      0.78       342
# weighted avg       0.80      0.78      0.78       342
#
#
#  Top Features (VORI)
# Mean Min Values DSAR VORI       0.079522
# Max drop DSAR VORI              0.072590
# Avg drop DSAR VORI              0.071459
# Median Value DSAR VORI          0.047327
# Avg peak DSAR VORI              0.043266
# Var Value DSAR VORI             0.040213
# Max peak DSAR VORI              0.037930
# Sum_VT                          0.035420
# Std Value DSAR VORI             0.035361
# Max_tornillo                    0.033611
# Avg Prominence RSAM VORI        0.033118
# Delta_Max_Min_tornillo          0.032850
# Quantile Changes DSAR VORI      0.032637
# Quantile Changes RSAM VORI      0.032045
# Sum_LP                          0.030257
# Max peak RSAM VORI              0.027134
# Max_Precipitations              0.025935
# Delta_Max_Min_Precipitations    0.023479
# Max_LP                          0.023381
# Max Prominence RSAM VORI        0.022341
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.62 ± 0.56
# Mean Magnitude (Missed - FN):   3.25 ± 0.51
# Low magnitude events were more detected
#  length of time array: 342
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[105  67]
#  [ 18 152]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.61      0.71       172
#            1       0.69      0.89      0.78       170
#
#     accuracy                           0.75       342
#    macro avg       0.77      0.75      0.75       342
# weighted avg       0.77      0.75      0.75       342
#
#
#  Top Features (VRBA)
# Max peak DSAR VRBA            0.143314
# Avg peak DSAR VRBA            0.142342
# Median Value DSAR VRBA        0.120972
# Mean Min Values RSAM VRBA     0.071430
# Std peak RSAM VRBA            0.047730
# Quantile Changes RSAM VRBA    0.046352
# Avg Value DSAR VRBA           0.046073
# Quantile Changes DSAR VRBA    0.041187
# Max_LP                        0.034159
# Sum_VT                        0.033614
# Avg Drop Depth DSAR VRBA      0.031969
# Avg Value RSAM VRBA           0.028647
# Delta_Max_Min_LP              0.028357
# Var Value DSAR VRBA           0.026543
# Delta_Max_Min_tornillo        0.025522
# Max drop RSAM VRBA            0.024315
# Avg drop RSAM VRBA            0.023299
# Sum_tornillo                  0.023182
# Sum_LP                        0.022333
# Std Prominence RSAM VRBA      0.021407
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.67 ± 0.57
# Mean Magnitude (Missed - FN):   2.89 ± 0.64
# Low magnitude events were more detected
#  length of time array: 342
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 136 | Mean VORI RSAM Coverage: 96.92±6.77% | Mean VORI DSAR Coverage: 99.18±4.70% | Mean VRBA Coverage: 68.16±20.35%
# Both Missed (FN): 2 | Mean VORI RSAM Coverage: 99.87±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 98.85±0.15%
# Both False Positives (FP): 47 | Mean VORI RSAM Coverage: 99.09±3.27% | Mean VORI DSAR Coverage: 99.19±3.17% | Mean VRBA Coverage: 63.06±40.42%
# Both True Negatives (TN): 95 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 87.93±15.56%
# VORI Detected Without VRBA (TP): 16 | Mean VORI RSAM Coverage: 95.58+-6.50% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 71.41+-36.49%
# VRBA Detected Without VORI (TP): 16 | Mean VORI RSAM Coverage: 99.85+-0.04% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 93.33+-20.34%
# VORI Detected Without VRBA (TN): 20 | Mean VORI RSAM Coverage: 99.92+-0.03% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 82.66+-18.66%
# VRBA Detected Without VORI (TN): 10 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 17.17+-14.00%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[76 23]
#  [22 39]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77        99
#            1       0.63      0.64      0.63        61
#
#     accuracy                           0.72       160
#    macro avg       0.70      0.70      0.70       160
# weighted avg       0.72      0.72      0.72       160
#
#
#  Top Features (VORI)
# Mean Min Values DSAR VORI     0.100957
# Sum_LP                        0.083446
# Max drop DSAR VORI            0.068929
# Avg drop DSAR VORI            0.064750
# Median Value DSAR VORI        0.064171
# Max_LP                        0.060174
# Delta_Max_Min_LP              0.045397
# Avg peak DSAR VORI            0.039515
# Quantile Changes RSAM VORI    0.039150
# Max peak RSAM VORI            0.035902
# Max_Precipitations            0.035576
# Var Value RSAM VORI           0.034585
# Max peak DSAR VORI            0.032609
# Std Value RSAM VORI           0.032503
# Std Value DSAR VORI           0.031060
# Quantile Changes DSAR VORI    0.029014
# Var Value DSAR VORI           0.027828
# Sum_VT                        0.024873
# Max_tornillo                  0.023378
# Avg Value DSAR VORI           0.020395
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.66 ± 0.66
# Mean Magnitude (Missed - FN):   2.83 ± 0.81
# Low magnitude events were more detected
#  length of time array: 160
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[86 13]
#  [32 29]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79        99
#            1       0.69      0.48      0.56        61
#
#     accuracy                           0.72       160
#    macro avg       0.71      0.67      0.68       160
# weighted avg       0.71      0.72      0.71       160
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.261162
# Sum_LP                        0.133422
# Quantile Changes DSAR VRBA    0.083938
# Quantile Changes RSAM VRBA    0.075150
# Var Value DSAR VRBA           0.061770
# Std Value DSAR VRBA           0.058755
# Sum_VT                        0.050775
# Mean Min Values DSAR VRBA     0.046325
# Median Value RSAM VRBA        0.034466
# Avg drop RSAM VRBA            0.033369
# Mean Min Values RSAM VRBA     0.033068
# Delta_Max_Min_LP              0.030466
# Avg Drop Depth DSAR VRBA      0.030263
# Sum_Precipitations            0.025186
# Max_LP                        0.022830
# Max drop RSAM VRBA            0.019057
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.75 ± 0.63
# Mean Magnitude (Missed - FN):   2.70 ± 0.79
# High magnitude events were more detected
#  length of time array: 160
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 23 | Mean VORI RSAM Coverage: 87.94±23.49% | Mean VORI DSAR Coverage: 88.91±23.85% | Mean VRBA Coverage: 86.88±18.42%
# Both Missed (FN): 16 | Mean VORI RSAM Coverage: 95.76±9.86% | Mean VORI DSAR Coverage: 96.83±8.86% | Mean VRBA Coverage: 82.22±18.19%
# Both False Positives (FP): 1 | Mean VORI RSAM Coverage: 99.92±nan% | Mean VORI DSAR Coverage: 99.94±nan% | Mean VRBA Coverage: 100.00±nan%
# Both True Negatives (TN): 64 | Mean VORI RSAM Coverage: 94.22±18.76% | Mean VORI DSAR Coverage: 95.99±14.65% | Mean VRBA Coverage: 97.88±4.15%
# VORI Detected Without VRBA (TP): 16 | Mean VORI RSAM Coverage: 95.95+-5.47% | Mean VORI DSAR Coverage: 98.52+-4.31% | Mean VRBA Coverage: 90.24+-17.70%
# VRBA Detected Without VORI (TP): 6 | Mean VORI RSAM Coverage: 99.89+-0.04% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 99.72+-0.42%
# VORI Detected Without VRBA (TN): 12 | Mean VORI RSAM Coverage: 50.55+-21.81% | Mean VORI DSAR Coverage: 50.55+-21.81% | Mean VRBA Coverage: 55.43+-14.68%
# VRBA Detected Without VORI (TN): 22 | Mean VORI RSAM Coverage: 56.45+-43.92% | Mean VORI DSAR Coverage: 57.97+-44.39% | Mean VRBA Coverage: 92.04+-15.24%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[47  9]
#  [20 32]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76        56
#            1       0.78      0.62      0.69        52
#
#     accuracy                           0.73       108
#    macro avg       0.74      0.73      0.73       108
# weighted avg       0.74      0.73      0.73       108
#
#
#  Top Features (VORI)
# Max_Precipitations              0.061403
# Sum_Precipitations              0.060971
# Delta_Max_Min_Precipitations    0.054411
# Quantile Changes RSAM VORI      0.048451
# Sum_tornillo                    0.046707
# Max_tornillo                    0.043589
# Delta_Max_Min_tornillo          0.041177
# Mean Min Values RSAM VORI       0.036300
# Sum_LP                          0.036289
# Max_LP                          0.030935
# Quantile Changes DSAR VORI      0.030840
# Mean Min Values DSAR VORI       0.026865
# Std drop RSAM VORI              0.026249
# Avg Value DSAR VORI             0.026243
# Max drop DSAR VORI              0.025356
# Delta_Max_Min_LP                0.024608
# Avg Value RSAM VORI             0.023823
# Max peak RSAM VORI              0.023719
# Std Value RSAM VORI             0.022976
# Avg drop DSAR VORI              0.022849
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.90 ± 1.06
# Mean Magnitude (Missed - FN):   2.95 ± 0.87
# Low magnitude events were more detected
#  length of time array: 108
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132000000
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000000000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682000000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[39 17]
#  [24 28]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.70      0.66        56
#            1       0.62      0.54      0.58        52
#
#     accuracy                           0.62       108
#    macro avg       0.62      0.62      0.62       108
# weighted avg       0.62      0.62      0.62       108
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.185145
# Quantile Changes RSAM VRBA    0.117129
# Quantile Changes DSAR VRBA    0.102890
# Mean Min Values RSAM VRBA     0.092363
# Avg peak DSAR VRBA            0.091745
# Mean Min Values DSAR VRBA     0.072037
# Max_Precipitations            0.055496
# season                        0.047745
# Avg peak RSAM VRBA            0.041962
# Sum_LP                        0.039010
# Max drop RSAM VRBA            0.036350
# Sum_Precipitations            0.033497
# Delta_Max_Min_LP              0.031904
# Avg drop DSAR VRBA            0.021878
# Avg Value DSAR VRBA           0.016196
# Avg drop RSAM VRBA            0.014654
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.82 ± 0.90
# Mean Magnitude (Missed - FN):   3.03 ± 1.09
# Low magnitude events were more detected
#  length of time array: 108
# Detected Lahars (TP): 1 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000000000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132000000
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682000000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 24 | Mean VORI RSAM Coverage: 42.37±45.81% | Mean VORI DSAR Coverage: 48.19±49.40% | Mean VRBA Coverage: 49.77±16.91%
# Both Missed (FN): 16 | Mean VORI RSAM Coverage: 88.83±29.00% | Mean VORI DSAR Coverage: 88.83±29.00% | Mean VRBA Coverage: 61.67±23.15%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 96.11±7.09% | Mean VORI DSAR Coverage: 96.65±7.36% | Mean VRBA Coverage: 59.32±2.49%
# Both True Negatives (TN): 35 | Mean VORI RSAM Coverage: 89.98±16.78% | Mean VORI DSAR Coverage: 92.80±14.91% | Mean VRBA Coverage: 60.91±15.05%
# VORI Detected Without VRBA (TP): 8 | Mean VORI RSAM Coverage: 77.16+-34.07% | Mean VORI DSAR Coverage: 78.84+-33.84% | Mean VRBA Coverage: 54.60+-23.80%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 73.95+-30.02% | Mean VORI DSAR Coverage: 73.95+-30.02% | Mean VRBA Coverage: 32.04+-37.00%
# VORI Detected Without VRBA (TN): 12 | Mean VORI RSAM Coverage: 93.66+-7.47% | Mean VORI DSAR Coverage: 96.63+-7.03% | Mean VRBA Coverage: 63.27+-5.89%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 98.61+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 55.73+-3.91%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[76 30]
#  [35 48]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70       106
#            1       0.62      0.58      0.60        83
#
#     accuracy                           0.66       189
#    macro avg       0.65      0.65      0.65       189
# weighted avg       0.65      0.66      0.65       189
#
#
#  Top Features (VORI)
# Sum_LP                          0.105815
# Max_LP                          0.062412
# Mean Min Values DSAR VORI       0.051691
# Quantile Changes RSAM VORI      0.050950
# Max drop DSAR VORI              0.043380
# Delta_Max_Min_tornillo          0.043307
# Delta_Max_Min_LP                0.042655
# Max_tornillo                    0.038954
# Avg drop DSAR VORI              0.034963
# Var Value RSAM VORI             0.033881
# Std Value RSAM VORI             0.033252
# Max_Precipitations              0.030188
# Mean Min Values RSAM VORI       0.028428
# Avg Value RSAM VORI             0.028333
# Median Value DSAR VORI          0.028205
# Delta_Max_Min_Precipitations    0.026545
# Sum_Precipitations              0.025145
# Max peak RSAM VORI              0.024612
# Avg drop RSAM VORI              0.024533
# Max drop RSAM VORI              0.024492
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.37 ± 0.80
# Mean Magnitude (Missed - FN):   3.48 ± 0.77
# Low magnitude events were more detected
#  length of time array: 189
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[85 21]
#  [20 63]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81       106
#            1       0.75      0.76      0.75        83
#
#     accuracy                           0.78       189
#    macro avg       0.78      0.78      0.78       189
# weighted avg       0.78      0.78      0.78       189
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.171482
# Median Value DSAR VRBA        0.158847
# Sum_LP                        0.139285
# Avg Value DSAR VRBA           0.075208
# Avg Value RSAM VRBA           0.067349
# Quantile Changes DSAR VRBA    0.059708
# season                        0.058812
# Mean Min Values DSAR VRBA     0.053047
# Delta_Max_Min_tornillo        0.040014
# Max drop RSAM VRBA            0.039641
# Mean Min Values RSAM VRBA     0.035109
# Max_LP                        0.027068
# Max peak RSAM VRBA            0.024899
# Sum_VT                        0.019004
# Median Value RSAM VRBA        0.016440
# Max_tornillo                  0.014086
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.41 ± 0.80
# Mean Magnitude (Missed - FN):   3.42 ± 0.74
# Low magnitude events were more detected
#  length of time array: 189
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 46 | Mean VORI RSAM Coverage: 95.74±7.49% | Mean VORI DSAR Coverage: 98.89±4.27% | Mean VRBA Coverage: 86.62±16.87%
# Both Missed (FN): 18 | Mean VORI RSAM Coverage: 85.78±14.68% | Mean VORI DSAR Coverage: 90.41±16.53% | Mean VRBA Coverage: 77.57±24.50%
# Both False Positives (FP): 11 | Mean VORI RSAM Coverage: 99.67±0.22% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 99.11±0.85%
# Both True Negatives (TN): 66 | Mean VORI RSAM Coverage: 95.22±13.54% | Mean VORI DSAR Coverage: 99.47±2.92% | Mean VRBA Coverage: 95.87±7.96%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 97.36+-0.06% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 94.12+-0.00%
# VRBA Detected Without VORI (TP): 17 | Mean VORI RSAM Coverage: 97.33+-4.81% | Mean VORI DSAR Coverage: 98.45+-4.48% | Mean VRBA Coverage: 84.95+-18.37%
# VORI Detected Without VRBA (TN): 10 | Mean VORI RSAM Coverage: 97.84+-3.95% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 82.15+-18.83%
# VRBA Detected Without VORI (TN): 19 | Mean VORI RSAM Coverage: 99.78+-0.24% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 94.06+-16.35%

# %%
def remove_correlated_features(df_train, feature_importances, threshold=0.85):
    """
    Remove redundant features while keeping the one with the highest importance.

    df_train: Training DataFrame.
    feature_importances: Dictionary or Series with importance scores: {feature_name: score}.
    threshold: Correlation threshold (e.g., 0.85).
    """
    # Compute the absolute correlation matrix
    corr_matrix = df_train.corr().abs()

    # Keep only the upper triangle to avoid processing duplicate pairs
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

    features_to_drop = set()

    # Iterate over each column
    for col in upper.columns:
        # Find variables that are strongly correlated with this feature
        highly_correlated = upper.index[upper[col] > threshold].tolist()

        for row in highly_correlated:
            # If one of the two features is already marked for removal, ignore it
            if col in features_to_drop or row in features_to_drop:
                continue

            # Retrieve importance scores (default to 0 if not found)
            score_col = feature_importances.get(col, 0)
            score_row = feature_importances.get(row, 0)

            # Keep the more important feature and remove the weaker one
            if score_col > score_row:
                features_to_drop.add(row)
            else:
                features_to_drop.add(col)

    print(f"Number of features removed: {len(features_to_drop)}")
    print(f"Removed features: {list(features_to_drop)}")

    return list(features_to_drop)

X_Train_5_VORI_cleaned = {}
X_Train_5_VRBA_cleaned = {}
X_Test_5_VORI_cleaned = {}
X_Test_5_VRBA_cleaned = {}

X_Train_VORI_cleaned = {}
X_Train_VRBA_cleaned = {}
X_Test_VORI_cleaned = {}
X_Test_VRBA_cleaned = {}

for key in train_test_years_splits.keys():
    print(f"\nProcessing test year: {key}")

    # Clean correlated features for VORI
    dropped_cols_5days_VORI = remove_correlated_features(
        x_train_5_VORI[key],
        features_classement_5days_train[key]['VORI'],
        threshold=0.85
    )
    X_Train_5_VORI_cleaned[key] = X_Train_5_VORI[key].drop(columns=dropped_cols_5days_VORI)
    X_Test_5_VORI_cleaned[key] = X_Test_5_VORI[key].drop(columns=dropped_cols_5days_VORI)

    # Clean correlated features for VRBA
    dropped_cols_5days_VRBA = remove_correlated_features(
        x_train_5_VRBA[key],
        features_classement_5days_train[key]['VRBA'],
        threshold=0.85
    )
    X_Train_5_VRBA_cleaned[key] = X_Train_5_VRBA[key].drop(columns=dropped_cols_5days_VRBA)
    X_Test_5_VRBA_cleaned[key] = X_Test_5_VRBA[key].drop(columns=dropped_cols_5days_VRBA)

    # Clean correlated features for VORI (3-day window)
    dropped_cols_VORI = remove_correlated_features(
        x_train_VORI[key],
        features_classement_train[key]['VORI'],
        threshold=0.85
    )
    X_Train_VORI_cleaned[key] = X_Train_VORI[key].drop(columns=dropped_cols_VORI)
    X_Test_VORI_cleaned[key] = X_Test_VORI[key].drop(columns=dropped_cols_VORI)

    # Clean correlated features for VRBA (3-day window)
    dropped_cols_VRBA = remove_correlated_features(
        x_train_VRBA[key],
        features_classement_train[key]['VRBA'],
        threshold=0.85
    )
    X_Train_VRBA_cleaned[key] = X_Train_VRBA[key].drop(columns=dropped_cols_VRBA)
    X_Test_VRBA_cleaned[key] = X_Test_VRBA[key].drop(columns=dropped_cols_VRBA)
# Out:
# Processing test year: 2019
# Number of features removed: 37
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Max Drop Depth RSAM VORI', 'Max peak RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'Max_Precipitations', 'Var Value RSAM VORI', 'falling_rsam_mean_derivative VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Max l Width RSAM VORI', 'Max Drop Depth DSAR VORI', 'Sum_tornillo', 'Delta_Max_Min_Precipitations', 'Avg peak DSAR VORI', 'Max peak DSAR VORI', 'Delta_Max_Min_LP', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Avg Value DSAR VORI', 'Avg Value RSAM VORI', 'Median Value DSAR VORI', 'Delta_Max_Min_tornillo', 'Max Prominence RSAM VORI', 'Avg drop RSAM VORI', 'Median Value RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Delta_Max_Min_VT', 'Max Prominence DSAR VORI', 'Number of drops DSAR VORI', 'Max h Width RSAM VORI', 'Std Value DSAR VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std Drop Depth DSAR VORI']
# Number of features removed: 33
# Removed features: ['Max drop RSAM VRBA', 'Max l Width RSAM VRBA', 'Max Prominence RSAM VRBA', 'Max Drop Depth DSAR VRBA', 'Max_Precipitations', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Max l Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Sum_tornillo', 'Max_tornillo', 'Delta_Max_Min_Precipitations', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Max h Width RSAM VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Var Value DSAR VRBA', 'Max_LP', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'Avg drop DSAR VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Delta_Max_Min_VT', 'Avg Value DSAR VRBA', 'Avg Value RSAM VRBA', 'Max drop DSAR VRBA', 'Median Value DSAR VRBA', 'Max h Width DSAR VRBA', 'Std Value RSAM VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Median Value RSAM VRBA']
# Number of features removed: 35
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Max Drop Depth RSAM VORI', 'Max peak RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'Max_Precipitations', 'Last_LP', 'Avg l Width DSAR VORI', 'falling_rsam_mean_derivative VORI', 'Avg Drop Depth DSAR VORI', 'Max l Width RSAM VORI', 'Max_tornillo', 'Avg peak DSAR VORI', 'Delta_Max_Min_LP', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Std Value RSAM VORI', 'Avg Value RSAM VORI', 'Median Value DSAR VORI', 'Delta_Max_Min_tornillo', 'Max Prominence RSAM VORI', 'Avg drop RSAM VORI', 'Median Value RSAM VORI', 'Std l Width RSAM VORI', 'Max_LP', 'Max_VT', 'Delta_Max_Min_VT', 'Avg h Width RSAM VORI', 'Std h Width RSAM VORI', 'Max Prominence DSAR VORI', 'Std Value DSAR VORI', 'Std l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std h Width DSAR VORI', 'Mean Min Values DSAR VORI']
# Number of features removed: 42
# Removed features: ['Max drop RSAM VRBA', 'quiescence_rsam_duration VRBA', 'Avg h Width DSAR VRBA', 'Std peak DSAR VRBA', 'Max Prominence RSAM VRBA', 'Avg l Width DSAR VRBA', 'Max_Precipitations', 'falling_rsam_mean_derivative VRBA', 'Last_LP', 'Std Value DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Avg peak DSAR VRBA', 'Avg peak RSAM VRBA', 'Max_tornillo', 'Avg l Width RSAM VRBA', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Var Value RSAM VRBA', 'Quantile Changes DSAR VRBA', 'Avg Drop Depth RSAM VRBA', 'Avg Drop Depth DSAR VRBA', 'Delta_Max_Min_tornillo', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Max_LP', 'Max_VT', 'Avg drop DSAR VRBA', 'Delta_Max_Min_VT', 'quiescence_rsam_drop_ratio VRBA', 'Std h Width DSAR VRBA', 'Std l Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg Value DSAR VRBA', 'Avg Value RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max drop DSAR VRBA', 'Median Value DSAR VRBA', 'Std Value RSAM VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Std drop RSAM VRBA', 'Median Value RSAM VRBA']
#
# Processing test year: 2020
# Number of features removed: 35
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'quiescence_rsam_drop_ratio VORI', 'Max_Precipitations', 'falling_rsam_mean_derivative VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Max l Width RSAM VORI', 'Max Drop Depth DSAR VORI', 'Sum_tornillo', 'Sum_Precipitations', 'Avg peak DSAR VORI', 'Delta_Max_Min_LP', 'Delta_Max_Min_tornillo', 'Std Value RSAM VORI', 'Avg Value RSAM VORI', 'Avg Value DSAR VORI', 'Median Value DSAR VORI', 'Max Prominence RSAM VORI', 'Median Value RSAM VORI', 'Avg drop RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Delta_Max_Min_VT', 'Max Prominence DSAR VORI', 'Avg Prominence DSAR VORI', 'Number of drops DSAR VORI', 'Max h Width RSAM VORI', 'Std Value DSAR VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std Drop Depth DSAR VORI', 'Mean Min Values DSAR VORI']
# Number of features removed: 33
# Removed features: ['Max drop RSAM VRBA', 'Max l Width RSAM VRBA', 'Max Prominence RSAM VRBA', 'Max Drop Depth DSAR VRBA', 'Max_Precipitations', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Std Value DSAR VRBA', 'Max l Width DSAR VRBA', 'Sum_tornillo', 'Max_tornillo', 'Delta_Max_Min_Precipitations', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Max h Width RSAM VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Var Value DSAR VRBA', 'Max_LP', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'Avg drop DSAR VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Delta_Max_Min_VT', 'Avg Value DSAR VRBA', 'Avg Value RSAM VRBA', 'Max drop DSAR VRBA', 'Median Value DSAR VRBA', 'Max h Width DSAR VRBA', 'Std Value RSAM VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Median Value RSAM VRBA']
# Number of features removed: 37
# Removed features: ['falling_rsam_slope VORI', 'Quantile Changes RSAM VORI', 'Max Drop Depth RSAM VORI', 'Max peak RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'Max_Precipitations', 'Last_LP', 'falling_rsam_mean_derivative VORI', 'Avg h Width DSAR VORI', 'Avg Drop Depth DSAR VORI', 'Avg Prominence RSAM VORI', 'Max l Width RSAM VORI', 'Sum_tornillo', 'Avg peak DSAR VORI', 'Std drop RSAM VORI', 'Max peak DSAR VORI', 'Delta_Max_Min_LP', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Std Value RSAM VORI', 'Avg Value RSAM VORI', 'Avg Value DSAR VORI', 'Delta_Max_Min_tornillo', 'Avg drop RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Mean Min Values RSAM VORI', 'Avg h Width RSAM VORI', 'Std h Width RSAM VORI', 'Max Prominence DSAR VORI', 'Std Value DSAR VORI', 'Std l Width DSAR VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std h Width DSAR VORI', 'Mean Min Values DSAR VORI']
# Number of features removed: 37
# Removed features: ['quiescence_rsam_duration VRBA', 'Avg h Width DSAR VRBA', 'Max l Width RSAM VRBA', 'Max Prominence RSAM VRBA', 'Avg l Width DSAR VRBA', 'Max_Precipitations', 'falling_rsam_mean_derivative VRBA', 'Last_LP', 'Mean Min Values DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Avg peak DSAR VRBA', 'Avg peak RSAM VRBA', 'Max_tornillo', 'falling_rsam_acceleration VRBA', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Var Value RSAM VRBA', 'Avg Drop Depth DSAR VRBA', 'Delta_Max_Min_tornillo', 'Avg drop RSAM VRBA', 'Var Value DSAR VRBA', 'Max_LP', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Std l Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg Value DSAR VRBA', 'Std Drop Depth RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max drop DSAR VRBA', 'Std Value RSAM VRBA', 'Std l Width DSAR VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Quantile Changes DSAR VRBA', 'Median Value RSAM VRBA']
#
# Processing test year: 2021
# Number of features removed: 33
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'quiescence_rsam_drop_ratio VORI', 'Var Value RSAM VORI', 'falling_rsam_mean_derivative VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Max l Width RSAM VORI', 'Max Drop Depth DSAR VORI', 'Sum_tornillo', 'Delta_Max_Min_Precipitations', 'Sum_Precipitations', 'Max peak DSAR VORI', 'Delta_Max_Min_LP', 'Avg drop DSAR VORI', 'Delta_Max_Min_tornillo', 'Avg Value DSAR VORI', 'Avg Value RSAM VORI', 'Median Value DSAR VORI', 'Max Prominence RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Delta_Max_Min_VT', 'Max Prominence DSAR VORI', 'Avg Prominence DSAR VORI', 'Number of drops DSAR VORI', 'Max h Width RSAM VORI', 'Std Value DSAR VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std Drop Depth DSAR VORI']
# Number of features removed: 33
# Removed features: ['Max drop RSAM VRBA', 'Max l Width RSAM VRBA', 'Max Prominence RSAM VRBA', 'Max Drop Depth DSAR VRBA', 'Max_Precipitations', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Mean Min Values DSAR VRBA', 'Std Value DSAR VRBA', 'Avg peak DSAR VRBA', 'Max l Width DSAR VRBA', 'Avg peak RSAM VRBA', 'Sum_tornillo', 'Max_tornillo', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Var Value RSAM VRBA', 'Max h Width RSAM VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Var Value DSAR VRBA', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'Avg drop DSAR VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Delta_Max_Min_VT', 'Avg Value DSAR VRBA', 'Max drop DSAR VRBA', 'Median Value DSAR VRBA', 'Max h Width DSAR VRBA', 'Sum_LP', 'falling_rsam_slope VRBA', 'Median Value RSAM VRBA']
# Number of features removed: 37
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Max peak RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'Avg l Width RSAM VORI', 'Max_Precipitations', 'Last_LP', 'Avg l Width DSAR VORI', 'falling_rsam_mean_derivative VORI', 'Avg Drop Depth DSAR VORI', 'falling_rsam_acceleration VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Sum_tornillo', 'Max_tornillo', 'Max peak DSAR VORI', 'Delta_Max_Min_LP', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Std Value RSAM VORI', 'Avg Value DSAR VORI', 'Median Value DSAR VORI', 'quiescence_rsam_duration VORI', 'Max Prominence RSAM VORI', 'Median Value RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Mean Min Values RSAM VORI', 'Delta_Max_Min_VT', 'Max Prominence DSAR VORI', 'Max h Width RSAM VORI', 'Std l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std h Width DSAR VORI', 'Quantile Changes DSAR VORI']
# Number of features removed: 40
# Removed features: ['Max drop RSAM VRBA', 'quiescence_rsam_duration VRBA', 'Max Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max_Precipitations', 'falling_rsam_mean_derivative VRBA', 'Last_LP', 'Mean Min Values DSAR VRBA', 'Std Value DSAR VRBA', 'Avg Prominence DSAR VRBA', 'Avg peak DSAR VRBA', 'Avg peak RSAM VRBA', 'Max_tornillo', 'Avg l Width RSAM VRBA', 'falling_rsam_acceleration VRBA', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Delta_Max_Min_tornillo', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Var Value DSAR VRBA', 'Max_LP', 'Max_VT', 'Avg drop DSAR VRBA', 'Delta_Max_Min_VT', 'quiescence_rsam_drop_ratio VRBA', 'Std l Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg Value DSAR VRBA', 'Avg Value RSAM VRBA', 'Avg h Width RSAM VRBA', 'Max drop DSAR VRBA', 'Max h Width DSAR VRBA', 'Mean Min Values RSAM VRBA', 'Std Value RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Median Value RSAM VRBA']
#
# Processing test year: 2022
# Number of features removed: 35
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Max Drop Depth RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'falling_rsam_mean_derivative VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Max l Width RSAM VORI', 'Max Drop Depth DSAR VORI', 'Sum_tornillo', 'Delta_Max_Min_Precipitations', 'Sum_Precipitations', 'Max peak DSAR VORI', 'Delta_Max_Min_LP', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Std Value RSAM VORI', 'Avg Value RSAM VORI', 'Avg Value DSAR VORI', 'Median Value DSAR VORI', 'Max Prominence RSAM VORI', 'Median Value RSAM VORI', 'Delta_Max_Min_tornillo', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Mean Min Values RSAM VORI', 'Delta_Max_Min_VT', 'Max Prominence DSAR VORI', 'Avg Prominence DSAR VORI', 'Number of drops DSAR VORI', 'Max h Width RSAM VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std Drop Depth DSAR VORI']
# Number of features removed: 33
# Removed features: ['Max drop RSAM VRBA', 'Max l Width RSAM VRBA', 'Max Prominence RSAM VRBA', 'Max Drop Depth DSAR VRBA', 'Max_Precipitations', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Mean Min Values DSAR VRBA', 'Std Value DSAR VRBA', 'Max l Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Avg peak RSAM VRBA', 'Max_tornillo', 'Delta_Max_Min_Precipitations', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Max h Width RSAM VRBA', 'Delta_Max_Min_tornillo', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Max_LP', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'Avg drop DSAR VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Delta_Max_Min_VT', 'Avg Value DSAR VRBA', 'Avg Value RSAM VRBA', 'Max drop DSAR VRBA', 'Max h Width DSAR VRBA', 'Std Value RSAM VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA']
# Number of features removed: 36
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Quantile Changes RSAM VORI', 'Max Drop Depth RSAM VORI', 'Max peak RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'Max_Precipitations', 'Last_LP', 'falling_rsam_mean_derivative VORI', 'Avg Prominence RSAM VORI', 'Max l Width RSAM VORI', 'Max Drop Depth DSAR VORI', 'Max_tornillo', 'Avg peak DSAR VORI', 'Delta_Max_Min_LP', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Std Value RSAM VORI', 'Avg Value RSAM VORI', 'Avg Value DSAR VORI', 'Median Value DSAR VORI', 'quiescence_rsam_duration VORI', 'Avg drop RSAM VORI', 'Delta_Max_Min_tornillo', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Mean Min Values RSAM VORI', 'Delta_Max_Min_VT', 'Max Prominence DSAR VORI', 'Std Value DSAR VORI', 'Max h Width RSAM VORI', 'Std l Width DSAR VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std h Width DSAR VORI']
# Number of features removed: 40
# Removed features: ['Max drop RSAM VRBA', 'quiescence_rsam_duration VRBA', 'Avg h Width DSAR VRBA', 'Std peak DSAR VRBA', 'Max Drop Depth DSAR VRBA', 'Avg l Width DSAR VRBA', 'Max_Precipitations', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Last_LP', 'Std Value DSAR VRBA', 'Avg peak DSAR VRBA', 'Avg peak RSAM VRBA', 'Max_tornillo', 'Avg l Width RSAM VRBA', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Avg Drop Depth RSAM VRBA', 'Max h Width RSAM VRBA', 'Delta_Max_Min_tornillo', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Var Value DSAR VRBA', 'Max_VT', 'Avg drop DSAR VRBA', 'Delta_Max_Min_VT', 'quiescence_rsam_drop_ratio VRBA', 'Std h Width DSAR VRBA', 'Std l Width RSAM VRBA', 'Std h Width RSAM VRBA', 'Avg Value DSAR VRBA', 'Avg Value RSAM VRBA', 'Max drop DSAR VRBA', 'Median Value DSAR VRBA', 'Mean Min Values RSAM VRBA', 'Std Value RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Sum_LP', 'falling_rsam_slope VRBA', 'Median Value RSAM VRBA']
#
# Processing test year: 2023
# Number of features removed: 37
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Max peak RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'Var Value RSAM VORI', 'falling_rsam_mean_derivative VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Max l Width RSAM VORI', 'Max Drop Depth DSAR VORI', 'Max_tornillo', 'Delta_Max_Min_Precipitations', 'Sum_Precipitations', 'Avg peak DSAR VORI', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Avg Value DSAR VORI', 'Avg Value RSAM VORI', 'Median Value DSAR VORI', 'Delta_Max_Min_tornillo', 'Max Prominence RSAM VORI', 'Std Drop Depth RSAM VORI', 'Avg drop RSAM VORI', 'Avg Drop Depth RSAM VORI', 'Median Value RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Delta_Max_Min_VT', 'Max Prominence DSAR VORI', 'Avg Prominence DSAR VORI', 'Number of drops DSAR VORI', 'Max h Width RSAM VORI', 'Std Value DSAR VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std Drop Depth DSAR VORI']
# Number of features removed: 33
# Removed features: ['Max drop RSAM VRBA', 'quiescence_rsam_duration VRBA', 'Max l Width RSAM VRBA', 'Max Prominence RSAM VRBA', 'Max Drop Depth DSAR VRBA', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Mean Min Values DSAR VRBA', 'Std Value DSAR VRBA', 'Max l Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Max_tornillo', 'Delta_Max_Min_Precipitations', 'Sum_Precipitations', 'Max peak RSAM VRBA', 'Max h Width RSAM VRBA', 'Delta_Max_Min_tornillo', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Max_LP', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'Avg drop DSAR VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Delta_Max_Min_VT', 'Avg Value DSAR VRBA', 'Avg Value RSAM VRBA', 'Max drop DSAR VRBA', 'Max h Width DSAR VRBA', 'Std Value RSAM VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Median Value RSAM VRBA']
# Number of features removed: 34
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Quantile Changes RSAM VORI', 'Max Drop Depth RSAM VORI', 'Max peak RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'Avg l Width RSAM VORI', 'Var Value RSAM VORI', 'Avg l Width DSAR VORI', 'falling_rsam_mean_derivative VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Max Drop Depth DSAR VORI', 'Max_tornillo', 'Delta_Max_Min_Precipitations', 'Sum_Precipitations', 'Max peak DSAR VORI', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Avg Value RSAM VORI', 'Median Value DSAR VORI', 'Max Prominence RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Mean Min Values RSAM VORI', 'Delta_Max_Min_VT', 'Std h Width RSAM VORI', 'Avg Prominence DSAR VORI', 'Std Value DSAR VORI', 'Max h Width RSAM VORI', 'Std l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std h Width DSAR VORI']
# Number of features removed: 34
# Removed features: ['Max drop RSAM VRBA', 'quiescence_rsam_duration VRBA', 'Max l Width RSAM VRBA', 'Max Prominence RSAM VRBA', 'Max Drop Depth DSAR VRBA', 'Max_Precipitations', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Std Value DSAR VRBA', 'Avg peak DSAR VRBA', 'Max l Width DSAR VRBA', 'Avg peak RSAM VRBA', 'Max_tornillo', 'Max peak RSAM VRBA', 'Var Value RSAM VRBA', 'Max h Width RSAM VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Max_LP', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'Avg drop DSAR VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Delta_Max_Min_VT', 'Std h Width RSAM VRBA', 'Avg Value DSAR VRBA', 'Max drop DSAR VRBA', 'Median Value DSAR VRBA', 'Max h Width DSAR VRBA', 'Std Value RSAM VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Quantile Changes DSAR VRBA', 'Median Value RSAM VRBA']
#
# Processing test year: 2024
# Number of features removed: 35
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Max Drop Depth RSAM VORI', 'Max peak RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'falling_rsam_mean_derivative VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Max l Width RSAM VORI', 'Max Drop Depth DSAR VORI', 'Sum_tornillo', 'Max_tornillo', 'Delta_Max_Min_Precipitations', 'Sum_Precipitations', 'Avg peak DSAR VORI', 'Delta_Max_Min_LP', 'Avg drop DSAR VORI', 'Var Value DSAR VORI', 'Std Value RSAM VORI', 'Avg Value DSAR VORI', 'Median Value DSAR VORI', 'Max Prominence RSAM VORI', 'Avg drop RSAM VORI', 'Median Value RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Delta_Max_Min_VT', 'Max Prominence DSAR VORI', 'Avg Prominence DSAR VORI', 'Number of drops DSAR VORI', 'Max h Width RSAM VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std Drop Depth DSAR VORI']
# Number of features removed: 33
# Removed features: ['Max l Width RSAM VRBA', 'Max Prominence RSAM VRBA', 'Max Drop Depth DSAR VRBA', 'Max_Precipitations', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Mean Min Values DSAR VRBA', 'Std Value DSAR VRBA', 'Max l Width DSAR VRBA', 'Avg peak DSAR VRBA', 'Avg peak RSAM VRBA', 'Sum_tornillo', 'Max_tornillo', 'Delta_Max_Min_Precipitations', 'Delta_Max_Min_LP', 'Max peak RSAM VRBA', 'Max h Width RSAM VRBA', 'falling_rsam_mean_abs_derivative VRBA', 'Avg drop RSAM VRBA', 'Max_LP', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'Avg drop DSAR VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Delta_Max_Min_VT', 'Avg Value DSAR VRBA', 'Max drop DSAR VRBA', 'Mean Min Values RSAM VRBA', 'Max h Width DSAR VRBA', 'Std Value RSAM VRBA', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Median Value RSAM VRBA']
# Number of features removed: 36
# Removed features: ['Max h Width DSAR VORI', 'falling_rsam_slope VORI', 'Max Drop Depth RSAM VORI', 'quiescence_rsam_drop_ratio VORI', 'Avg l Width RSAM VORI', 'Max_Precipitations', 'Var Value RSAM VORI', 'Last_LP', 'falling_rsam_mean_derivative VORI', 'Avg Drop Depth DSAR VORI', 'Avg peak RSAM VORI', 'Max drop RSAM VORI', 'Max_tornillo', 'Max peak DSAR VORI', 'Delta_Max_Min_LP', 'quiescence_rsam_duration VORI', 'Var Value DSAR VORI', 'Delta_Max_Min_tornillo', 'Avg Value RSAM VORI', 'Median Value DSAR VORI', 'Max Prominence RSAM VORI', 'Median Value RSAM VORI', 'Avg drop RSAM VORI', 'Max drop DSAR VORI', 'Max_LP', 'Max_VT', 'Avg h Width RSAM VORI', 'Std h Width RSAM VORI', 'Max Prominence DSAR VORI', 'Std Value DSAR VORI', 'Std l Width DSAR VORI', 'Max l Width DSAR VORI', 'falling_rsam_mean_abs_derivative VORI', 'Std h Width DSAR VORI', 'Mean Min Values DSAR VORI', 'Quantile Changes DSAR VORI']
# Number of features removed: 32
# Removed features: ['Max drop RSAM VRBA', 'quiescence_rsam_duration VRBA', 'Max Drop Depth DSAR VRBA', 'Max_Precipitations', 'Max Prominence DSAR VRBA', 'falling_rsam_mean_derivative VRBA', 'Last_LP', 'Mean Min Values DSAR VRBA', 'Max l Width DSAR VRBA', 'Avg peak RSAM VRBA', 'Sum_tornillo', 'Avg l Width RSAM VRBA', 'falling_rsam_acceleration VRBA', 'Max h Width RSAM VRBA', 'Delta_Max_Min_tornillo', 'falling_rsam_mean_abs_derivative VRBA', 'Var Value DSAR VRBA', 'Max_LP', 'Max_VT', 'Max Drop Depth RSAM VRBA', 'Avg drop DSAR VRBA', 'quiescence_rsam_drop_ratio VRBA', 'Std h Width RSAM VRBA', 'Median Value DSAR VRBA', 'Max h Width DSAR VRBA', 'Std Value RSAM VRBA', 'Avg Prominence RSAM VRBA', 'Sum_LP', 'Max peak DSAR VRBA', 'falling_rsam_slope VRBA', 'Quantile Changes DSAR VRBA', 'Median Value RSAM VRBA']

# %% [markdown]
# ## Test

# %% [markdown]
# Now that we have identified the best models, we have also determined that SelectFromModel yields results similar to those of the Backwards Selection Wrapper, while being much faster in producing its results. In addition, a list of features that are highly correlated and less important to the models has been created. With this, we will be able to assess the true performance of our model on the test data. We will compare the approach without feature selection to the one using SelectFromModel, and then compare it after removing the highly correlated features.

# %%
best_models_VORI, best_5days_models_VORI, best_models_VRBA, best_5days_models_VRBA = train_and_optimize_rf_models(
    train_test_years_splits=train_test_years_splits,
    x_train_VORI=X_Train_VORI, y_train_VORI=Y_Train_VORI, 
    x_train_5_VORI=X_Train_5_VORI, y_train_5_VORI=Y_Train_5_VORI,
    x_train_VRBA=X_Train_VRBA, y_train_VRBA=Y_Train_VRBA, 
    x_train_5_VRBA=X_Train_5_VRBA, y_train_5_VRBA=Y_Train_5_VRBA,
    n_iter_search=200 
)
best_features_VORI, best_features_VRBA = select_important_features({}, {}, best_models_VORI, best_models_VRBA, X_Train_VORI, X_Train_VRBA)
best_features_5days_VORI, best_features_5days_VRBA = select_important_features({}, {}, best_5days_models_VORI, best_5days_models_VRBA, X_Train_5_VORI, X_Train_5_VRBA)
# Out:
# Optimizing Random Forest for test year: 2019
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2019): {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2019): {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2019): {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2019): {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
#
# Optimizing Random Forest for test year: 2020
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2020): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 3, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2020): {'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2020): {'n_estimators': 10, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 0.5, 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2020): {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
#
# Optimizing Random Forest for test year: 2021
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2021): {'n_estimators': 10, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2021): {'n_estimators': 10, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2021): {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2021): {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 3, 'class_weight': 'balanced', 'bootstrap': True}
#
# Optimizing Random Forest for test year: 2022
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2022): {'n_estimators': 50, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2022): {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2022): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 5, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2022): {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
#
# Optimizing Random Forest for test year: 2023
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2023): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 3, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2023): {'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2023): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 3, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2023): {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
#
# Optimizing Random Forest for test year: 2024
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2024): {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 0.8, 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2024): {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2024): {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.8, 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2024): {'n_estimators': 10, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': False}
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2019
# ==================================================
#
# [ STATION VORI ]
# Features kept: 35 out of 85
# Top selected features:
# Sum_LP                          0.054098
# Max drop RSAM VORI              0.034180
# Quantile Changes RSAM VORI      0.033746
# slope_ratio VORI                0.033421
# Std Value RSAM VORI             0.031811
# Mean Min Values RSAM VORI       0.029522
# Avg drop DSAR VORI              0.028312
# Max drop DSAR VORI              0.025563
# Mean Min Values DSAR VORI       0.024309
# Delta_Max_Min_Precipitations    0.022349
# Max l Width RSAM VORI           0.021824
# Max_LP                          0.021298
# Max Drop Depth DSAR VORI        0.021085
# Avg h Width DSAR VORI           0.021072
# Var Value RSAM VORI             0.021039
# Max h Width RSAM VORI           0.020870
# Max h Width DSAR VORI           0.019302
# Avg Value RSAM VORI             0.019279
# Max l Width DSAR VORI           0.019129
# Avg Prominence DSAR VORI        0.018865
# Avg drop RSAM VORI              0.018747
# Avg Drop Depth DSAR VORI        0.018715
# Quantile Changes DSAR VORI      0.018021
# Avg peak RSAM VORI              0.017485
# Avg l Width DSAR VORI           0.016498
# Last_LP                         0.016162
# Max peak RSAM VORI              0.014577
# Median Value RSAM VORI          0.014544
# Var Value DSAR VORI             0.014415
# Last_Precipitations             0.014199
# Avg peak DSAR VORI              0.013333
# Max Prominence RSAM VORI        0.012791
# Max peak DSAR VORI              0.012234
# Median Value DSAR VORI          0.011938
# Avg Prominence RSAM VORI        0.011918
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 45 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA    0.051281
# Mean Min Values RSAM VRBA     0.041222
# Sum_LP                        0.037131
# Avg Drop Depth RSAM VRBA      0.029191
# Avg peak DSAR VRBA            0.026687
# Avg Prominence RSAM VRBA      0.024398
# Max Drop Depth RSAM VRBA      0.023692
# Max peak DSAR VRBA            0.023257
# Avg Value DSAR VRBA           0.023105
# Std Value RSAM VRBA           0.022183
# Quantile Changes DSAR VRBA    0.022055
# Median Value RSAM VRBA        0.021737
# Max_LP                        0.021720
# Max Prominence RSAM VRBA      0.021137
# Max Drop Depth DSAR VRBA      0.020726
# Max drop RSAM VRBA            0.020389
# Var Value DSAR VRBA           0.020219
# Avg peak RSAM VRBA            0.020024
# Avg l Width DSAR VRBA         0.020001
# Mean Min Values DSAR VRBA     0.019763
# Median Value DSAR VRBA        0.019129
# Var Value RSAM VRBA           0.018071
# Avg Prominence DSAR VRBA      0.017948
# Max Prominence DSAR VRBA      0.017619
# Sum_Precipitations            0.017485
# Avg Drop Depth DSAR VRBA      0.017426
# slope_ratio VRBA              0.017317
# Avg Value RSAM VRBA           0.017096
# Avg drop RSAM VRBA            0.017002
# Avg drop DSAR VRBA            0.016754
# Max drop DSAR VRBA            0.016569
# Std Value DSAR VRBA           0.016385
# Max l Width DSAR VRBA         0.016220
# Delta_Max_Min_LP              0.015347
# Avg l Width RSAM VRBA         0.015234
# Max peak RSAM VRBA            0.015114
# Delta_Max_Min_tornillo        0.015076
# Sum_tornillo                  0.014545
# Avg h Width RSAM VRBA         0.014116
# Max l Width RSAM VRBA         0.013612
# Max h Width RSAM VRBA         0.013446
# Last_LP                       0.013396
# Max_Precipitations            0.013180
# Avg h Width DSAR VRBA         0.012807
# Max h Width DSAR VRBA         0.012618
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2020
# ==================================================
#
# [ STATION VORI ]
# Features kept: 30 out of 85
# Top selected features:
# Max Drop Depth DSAR VORI           0.096300
# Max l Width RSAM VORI              0.073569
# Avg l Width DSAR VORI              0.073467
# Max peak RSAM VORI                 0.058221
# Mean Min Values DSAR VORI          0.043023
# Mean Min Values RSAM VORI          0.039130
# Median Value RSAM VORI             0.037118
# Avg drop DSAR VORI                 0.033943
# Max Drop Depth RSAM VORI           0.033895
# Delta_Max_Min_Precipitations       0.033121
# Max_tornillo                       0.029538
# Max l Width DSAR VORI              0.029227
# Std drop RSAM VORI                 0.028882
# Avg peak DSAR VORI                 0.028238
# Std Drop Depth DSAR VORI           0.025633
# Avg peak RSAM VORI                 0.025340
# Median Value DSAR VORI             0.025197
# Quantile Changes RSAM VORI         0.024882
# num_state_changes_inv_rsam VORI    0.023930
# Avg Drop Depth DSAR VORI           0.022688
# is_raising_VT                      0.022334
# Max drop RSAM VORI                 0.022203
# Avg l Width RSAM VORI              0.021936
# Avg h Width RSAM VORI              0.018115
# Var Value RSAM VORI                0.017923
# Sum_Precipitations                 0.015034
# Max h Width RSAM VORI              0.014588
# Delta_Max_Min_tornillo             0.013720
# Var Value DSAR VORI                0.012705
# Last_LP                            0.012377
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 26 out of 85
# Top selected features:
# Std Value DSAR VRBA           0.161404
# Quantile Changes RSAM VRBA    0.080801
# Var Value DSAR VRBA           0.073525
# Avg Prominence DSAR VRBA      0.055938
# Avg Drop Depth DSAR VRBA      0.055455
# Max Drop Depth DSAR VRBA      0.037840
# slope_ratio VRBA              0.033744
# Max Drop Depth RSAM VRBA      0.032401
# Var Value RSAM VRBA           0.031656
# Avg Drop Depth RSAM VRBA      0.030452
# Avg h Width DSAR VRBA         0.028163
# Max_Precipitations            0.027180
# Avg drop DSAR VRBA            0.026680
# Sum_LP                        0.025414
# Max h Width RSAM VRBA         0.020702
# Avg l Width RSAM VRBA         0.018403
# Max Prominence DSAR VRBA      0.018386
# Max peak DSAR VRBA            0.018017
# Sum_tornillo                  0.017439
# Avg Value DSAR VRBA           0.016802
# Avg peak DSAR VRBA            0.016761
# Std Value RSAM VRBA           0.015660
# Last_Precipitations           0.012685
# Mean Min Values RSAM VRBA     0.012430
# Sum_Precipitations            0.011989
# Max drop DSAR VRBA            0.011949
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2021
# ==================================================
#
# [ STATION VORI ]
# Features kept: 28 out of 85
# Top selected features:
# Max peak DSAR VORI                 0.063257
# slope_ratio VORI                   0.047823
# Last_Precipitations                0.046560
# Max drop DSAR VORI                 0.039392
# Quantile Changes RSAM VORI         0.035146
# Quantile Changes DSAR VORI         0.033858
# Avg peak DSAR VORI                 0.031399
# Mean Min Values DSAR VORI          0.031061
# Avg Prominence RSAM VORI           0.030776
# Delta_Max_Min_Precipitations       0.030710
# Avg Value DSAR VORI                0.029891
# Mean Min Values RSAM VORI          0.026178
# Max Drop Depth DSAR VORI           0.025352
# Var Value DSAR VORI                0.025306
# Avg peak RSAM VORI                 0.024523
# Std Value RSAM VORI                0.023280
# Median Value DSAR VORI             0.023171
# Max l Width RSAM VORI              0.022372
# Avg Prominence DSAR VORI           0.022114
# Avg Drop Depth DSAR VORI           0.020484
# Avg Value RSAM VORI                0.020215
# Var Value RSAM VORI                0.018606
# Avg l Width RSAM VORI              0.018417
# Max_tornillo                       0.016565
# Avg l Width DSAR VORI              0.015955
# num_state_changes_inv_rsam VORI    0.015929
# Max h Width RSAM VORI              0.013531
# Sum_Precipitations                 0.011937
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 41 out of 85
# Top selected features:
# Median Value DSAR VRBA        0.053016
# Avg Value DSAR VRBA           0.048999
# Avg peak DSAR VRBA            0.046384
# Quantile Changes RSAM VRBA    0.042761
# Max peak DSAR VRBA            0.032228
# Var Value DSAR VRBA           0.027562
# Mean Min Values RSAM VRBA     0.024192
# Std Value DSAR VRBA           0.023671
# Max drop DSAR VRBA            0.023640
# Max Prominence RSAM VRBA      0.022316
# Avg Prominence RSAM VRBA      0.022027
# Max l Width RSAM VRBA         0.021902
# Max drop RSAM VRBA            0.021680
# Quantile Changes DSAR VRBA    0.021366
# Avg Drop Depth DSAR VRBA      0.019049
# Median Value RSAM VRBA        0.018721
# Max Drop Depth DSAR VRBA      0.018673
# Avg drop RSAM VRBA            0.017850
# Mean Min Values DSAR VRBA     0.017769
# Std Value RSAM VRBA           0.017641
# Var Value RSAM VRBA           0.017124
# Avg l Width RSAM VRBA         0.017071
# Avg Value RSAM VRBA           0.016938
# Avg Drop Depth RSAM VRBA      0.016806
# Avg Prominence DSAR VRBA      0.016475
# Max Prominence DSAR VRBA      0.016122
# Avg drop DSAR VRBA            0.016008
# Max h Width DSAR VRBA         0.015982
# Max h Width RSAM VRBA         0.015833
# Avg h Width RSAM VRBA         0.015490
# Max Drop Depth RSAM VRBA      0.015438
# Max l Width DSAR VRBA         0.015127
# slope_ratio VRBA              0.015067
# Sum_tornillo                  0.014578
# Max_LP                        0.013823
# Avg h Width DSAR VRBA         0.013325
# Max peak RSAM VRBA            0.013025
# Avg peak RSAM VRBA            0.013005
# Sum_Precipitations            0.012834
# Avg l Width DSAR VRBA         0.012351
# Sum_LP                        0.011769
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2022
# ==================================================
#
# [ STATION VORI ]
# Features kept: 37 out of 85
# Top selected features:
# Avg l Width RSAM VORI         0.041148
# Median Value DSAR VORI        0.037662
# Sum_LP                        0.032300
# Max Drop Depth RSAM VORI      0.031090
# Std Value RSAM VORI           0.030309
# Mean Min Values DSAR VORI     0.029534
# Max drop DSAR VORI            0.029015
# Max l Width RSAM VORI         0.028035
# Avg drop DSAR VORI            0.026909
# Avg peak DSAR VORI            0.026127
# Var Value RSAM VORI           0.026042
# Max_LP                        0.023757
# Quantile Changes DSAR VORI    0.022785
# Max Drop Depth DSAR VORI      0.022719
# Max peak DSAR VORI            0.022617
# Avg Drop Depth RSAM VORI      0.019708
# Max drop RSAM VORI            0.019653
# Max_VT                        0.019194
# Last_LP                       0.019193
# Max Prominence DSAR VORI      0.019084
# Max Prominence RSAM VORI      0.017531
# Avg Value DSAR VORI           0.016689
# Mean Min Values RSAM VORI     0.016239
# Sum_Precipitations            0.016010
# Quantile Changes RSAM VORI    0.015775
# Avg peak RSAM VORI            0.015412
# Avg drop RSAM VORI            0.015059
# Delta_Max_Min_tornillo        0.015016
# Avg Drop Depth DSAR VORI      0.014688
# Max_Precipitations            0.013927
# Var Value DSAR VORI           0.013667
# Avg h Width DSAR VORI         0.013329
# Max peak RSAM VORI            0.013217
# Std Value DSAR VORI           0.013067
# Max h Width DSAR VORI         0.012410
# Last_Precipitations           0.012348
# Avg Value RSAM VORI           0.012062
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 29 out of 85
# Top selected features:
# Var Value DSAR VRBA                0.084477
# Quantile Changes RSAM VRBA         0.080764
# Std Value DSAR VRBA                0.062960
# Max Prominence RSAM VRBA           0.044739
# Mean Min Values RSAM VRBA          0.044272
# Avg Prominence RSAM VRBA           0.037225
# Avg peak DSAR VRBA                 0.036793
# Max_LP                             0.029675
# Avg Value RSAM VRBA                0.029304
# Sum_tornillo                       0.026604
# Avg drop DSAR VRBA                 0.022678
# Max drop RSAM VRBA                 0.022420
# Avg Prominence DSAR VRBA           0.022169
# Avg h Width DSAR VRBA              0.021831
# Sum_LP                             0.021765
# Avg Value DSAR VRBA                0.021703
# Max Drop Depth RSAM VRBA           0.021566
# num_state_changes_inv_rsam VRBA    0.021510
# Avg l Width RSAM VRBA              0.018204
# Avg Drop Depth DSAR VRBA           0.018047
# Avg drop RSAM VRBA                 0.017320
# Var Value RSAM VRBA                0.016129
# Std Value RSAM VRBA                0.014917
# Delta_Max_Min_VT                   0.014653
# Last_LP                            0.013126
# Max h Width RSAM VRBA              0.013120
# Max drop DSAR VRBA                 0.013097
# Sum_Precipitations                 0.012888
# Max Drop Depth DSAR VRBA           0.011886
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2023
# ==================================================
#
# [ STATION VORI ]
# Features kept: 35 out of 85
# Top selected features:
# Max peak RSAM VORI               0.071451
# Max l Width RSAM VORI            0.057679
# Last_Precipitations              0.053208
# Sum_Precipitations               0.049539
# Var Value RSAM VORI              0.042471
# Max_LP                           0.036190
# Avg l Width RSAM VORI            0.035654
# Max drop RSAM VORI               0.033993
# Delta_Max_Min_Precipitations     0.032316
# Median Value RSAM VORI           0.032015
# Max h Width RSAM VORI            0.031834
# Avg peak RSAM VORI               0.031049
# Sum_VT                           0.028198
# Avg Drop Depth DSAR VORI         0.026520
# Max Prominence DSAR VORI         0.026306
# Std Value RSAM VORI              0.026256
# Std Drop Depth DSAR VORI         0.025533
# Avg Value RSAM VORI              0.024629
# Avg l Width DSAR VORI            0.024083
# Delta_Max_Min_VT                 0.022148
# Max Drop Depth RSAM VORI         0.021900
# Mean Min Values DSAR VORI        0.021749
# Avg h Width RSAM VORI            0.020169
# quiescence_rsam_duration VORI    0.018957
# Avg drop RSAM VORI               0.017440
# Avg drop DSAR VORI               0.017148
# Var Value DSAR VORI              0.015421
# Avg Drop Depth RSAM VORI         0.014888
# Mean Min Values RSAM VORI        0.014701
# Quantile Changes RSAM VORI       0.014646
# Max h Width DSAR VORI            0.014494
# Avg peak DSAR VORI               0.014373
# Std Prominence RSAM VORI         0.014143
# Max peak DSAR VORI               0.013816
# Max Drop Depth DSAR VORI         0.011903
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 25 out of 85
# Top selected features:
# Var Value DSAR VRBA             0.115789
# Quantile Changes RSAM VRBA      0.080599
# Mean Min Values DSAR VRBA       0.070599
# Avg peak DSAR VRBA              0.059871
# Median Value DSAR VRBA          0.052273
# Max peak DSAR VRBA              0.051819
# Sum_tornillo                    0.051057
# Mean Min Values RSAM VRBA       0.047759
# Max Prominence RSAM VRBA        0.038455
# Delta_Max_Min_Precipitations    0.037838
# Avg h Width RSAM VRBA           0.036087
# Quantile Changes DSAR VRBA      0.032318
# Std Value DSAR VRBA             0.029497
# Max Drop Depth DSAR VRBA        0.028819
# Avg Prominence RSAM VRBA        0.028428
# Avg l Width RSAM VRBA           0.028151
# Avg Value DSAR VRBA             0.023475
# Max h Width DSAR VRBA           0.022018
# Max_LP                          0.019302
# Delta_Max_Min_LP                0.018409
# Avg Drop Depth DSAR VRBA        0.017921
# Sum_VT                          0.016980
# Std Value RSAM VRBA             0.014761
# Avg drop RSAM VRBA              0.014326
# Avg Prominence DSAR VRBA        0.012019
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2024
# ==================================================
#
# [ STATION VORI ]
# Features kept: 18 out of 85
# Top selected features:
# Sum_LP                             0.156312
# Sum_tornillo                       0.086501
# Std Value RSAM VORI                0.079062
# Var Value RSAM VORI                0.066753
# num_state_changes_log_dsar VORI    0.060418
# Quantile Changes RSAM VORI         0.054960
# Max l Width RSAM VORI              0.050213
# Max_Precipitations                 0.044151
# Sum_Precipitations                 0.043540
# Avg Prominence RSAM VORI           0.042527
# Mean Min Values DSAR VORI          0.040801
# Avg l Width DSAR VORI              0.038197
# Avg Value RSAM VORI                0.033873
# Max Prominence RSAM VORI           0.024105
# Avg Prominence DSAR VORI           0.017090
# Last_LP                            0.015979
# Max peak RSAM VORI                 0.014871
# slope_ratio VORI                   0.014294
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 28 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA    0.131790
# Avg Value DSAR VRBA           0.058104
# Max l Width RSAM VRBA         0.046375
# Mean Min Values RSAM VRBA     0.042545
# Quantile Changes DSAR VRBA    0.038124
# Sum_tornillo                  0.037097
# Var Value DSAR VRBA           0.036296
# Std Value DSAR VRBA           0.035207
# Max Drop Depth RSAM VRBA      0.033597
# Max peak RSAM VRBA            0.028249
# Median Value DSAR VRBA        0.027832
# Mean Min Values DSAR VRBA     0.027718
# Avg peak RSAM VRBA            0.025828
# Sum_LP                        0.025587
# Avg l Width DSAR VRBA         0.025232
# Last_LP                       0.022280
# Max h Width RSAM VRBA         0.022267
# Avg Prominence RSAM VRBA      0.018556
# Avg Prominence DSAR VRBA      0.017772
# Max l Width DSAR VRBA         0.017010
# Sum_VT                        0.016946
# slope_ratio VRBA              0.016016
# Delta_Max_Min_LP              0.015685
# Avg h Width RSAM VRBA         0.014751
# Std l Width DSAR VRBA         0.014355
# Avg l Width RSAM VRBA         0.013927
# Avg Drop Depth RSAM VRBA      0.012408
# Avg Value RSAM VRBA           0.011891
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2019
# ==================================================
#
# [ STATION VORI ]
# Features kept: 31 out of 85
# Top selected features:
# Sum_LP                          0.113218
# Max_LP                          0.073067
# Delta_Max_Min_LP                0.062004
# Quantile Changes RSAM VORI      0.038523
# Last_LP                         0.035642
# Mean Min Values RSAM VORI       0.029821
# Mean Min Values DSAR VORI       0.029221
# Max drop DSAR VORI              0.023406
# season                          0.023043
# Avg drop DSAR VORI              0.022264
# Delta_Max_Min_Precipitations    0.021908
# Max_Precipitations              0.021800
# Max drop RSAM VORI              0.020939
# Avg Value RSAM VORI             0.020908
# Median Value RSAM VORI          0.020774
# Max peak RSAM VORI              0.020415
# Delta_Max_Min_tornillo          0.020308
# Sum_Precipitations              0.019944
# Max_tornillo                    0.019838
# Median Value DSAR VORI          0.018792
# Avg drop RSAM VORI              0.017921
# Avg peak RSAM VORI              0.017610
# Var Value RSAM VORI             0.017380
# Max peak DSAR VORI              0.014984
# Avg peak DSAR VORI              0.013614
# Std Value RSAM VORI             0.013591
# Sum_tornillo                    0.013514
# Quantile Changes DSAR VORI      0.013397
# Avg Prominence RSAM VORI        0.012503
# Avg Value DSAR VORI             0.012096
# Var Value DSAR VORI             0.011796
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 31 out of 85
# Top selected features:
# Sum_LP                          0.100237
# Max_LP                          0.081097
# Quantile Changes RSAM VRBA      0.064424
# Delta_Max_Min_LP                0.062548
# Median Value DSAR VRBA          0.031968
# Last_LP                         0.029468
# Mean Min Values RSAM VRBA       0.028285
# Quantile Changes DSAR VRBA      0.027443
# Var Value DSAR VRBA             0.025132
# Avg peak DSAR VRBA              0.024412
# Mean Min Values DSAR VRBA       0.023945
# Std Value DSAR VRBA             0.022919
# Avg peak RSAM VRBA              0.021511
# Avg Value DSAR VRBA             0.021449
# Max peak DSAR VRBA              0.020663
# Max peak RSAM VRBA              0.020563
# Max Drop Depth DSAR VRBA        0.019450
# Var Value RSAM VRBA             0.017570
# Max_tornillo                    0.016676
# season                          0.015831
# Avg Value RSAM VRBA             0.015529
# Median Value RSAM VRBA          0.015248
# Avg Drop Depth DSAR VRBA        0.015150
# Std Value RSAM VRBA             0.015122
# Max_Precipitations              0.014997
# Delta_Max_Min_tornillo          0.014839
# Max drop RSAM VRBA              0.014569
# Avg drop DSAR VRBA              0.014543
# Sum_tornillo                    0.014095
# Avg drop RSAM VRBA              0.012282
# Delta_Max_Min_Precipitations    0.012062
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2020
# ==================================================
#
# [ STATION VORI ]
# Features kept: 29 out of 85
# Top selected features:
# Sum_LP                          0.079654
# Mean Min Values DSAR VORI       0.044394
# Delta_Max_Min_tornillo          0.044087
# Max_LP                          0.043290
# Max drop DSAR VORI              0.041636
# Avg drop DSAR VORI              0.039313
# Max_tornillo                    0.039038
# Median Value DSAR VORI          0.034298
# Delta_Max_Min_LP                0.034278
# Max peak DSAR VORI              0.030020
# Quantile Changes RSAM VORI      0.027171
# Sum_tornillo                    0.025340
# Avg peak DSAR VORI              0.024679
# Var Value RSAM VORI             0.024646
# Max peak RSAM VORI              0.021086
# Std Value RSAM VORI             0.020650
# Avg peak RSAM VORI              0.020199
# Last_LP                         0.019341
# Median Value RSAM VORI          0.018623
# Avg Value RSAM VORI             0.018398
# Mean Min Values RSAM VORI       0.017120
# Sum_Precipitations              0.015993
# Max drop RSAM VORI              0.015261
# Avg drop RSAM VORI              0.014925
# Max_Precipitations              0.014836
# Quantile Changes DSAR VORI      0.014401
# Var Value DSAR VORI             0.013332
# Delta_Max_Min_Precipitations    0.012868
# Avg Value DSAR VORI             0.012645
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 20 out of 85
# Top selected features:
# Sum_LP                        0.156778
# Quantile Changes RSAM VRBA    0.107610
# Median Value DSAR VRBA        0.086237
# Std Value DSAR VRBA           0.077324
# Quantile Changes DSAR VRBA    0.060919
# Var Value DSAR VRBA           0.047188
# Max_LP                        0.029011
# Delta_Max_Min_tornillo        0.023535
# Max_tornillo                  0.022753
# Max drop RSAM VRBA            0.020167
# Avg peak DSAR VRBA            0.018967
# Avg drop RSAM VRBA            0.017231
# Mean Min Values DSAR VRBA     0.016828
# Avg Value RSAM VRBA           0.016807
# Avg Value DSAR VRBA           0.016341
# Mean Min Values RSAM VRBA     0.015772
# Sum_tornillo                  0.015480
# Max peak RSAM VRBA            0.014905
# Avg peak RSAM VRBA            0.014670
# Delta_Max_Min_LP              0.013020
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2021
# ==================================================
#
# [ STATION VORI ]
# Features kept: 28 out of 85
# Top selected features:
# Max drop DSAR VORI            0.079899
# Avg peak DSAR VORI            0.074351
# Var Value DSAR VORI           0.065505
# Max_Precipitations            0.052597
# Sum_LP                        0.046348
# Avg drop DSAR VORI            0.040966
# Max_tornillo                  0.037074
# Std Value DSAR VORI           0.035363
# Quantile Changes DSAR VORI    0.031476
# Quantile Changes RSAM VORI    0.026067
# Sum_Precipitations            0.025075
# Max Prominence RSAM VORI      0.023072
# Median Value DSAR VORI        0.021119
# Sum_VT                        0.020812
# Avg Value DSAR VORI           0.018805
# Mean Min Values DSAR VORI     0.018784
# Avg Value RSAM VORI           0.018703
# Std Value RSAM VORI           0.017404
# Std Drop Depth RSAM VORI      0.016688
# Max peak DSAR VORI            0.015720
# Max drop RSAM VORI            0.015561
# Avg peak RSAM VORI            0.015098
# Avg Drop Depth RSAM VORI      0.014752
# Median Value RSAM VORI        0.014559
# Delta_Max_Min_tornillo        0.014247
# Max_LP                        0.013798
# Max Drop Depth RSAM VORI      0.013273
# Delta_Max_Min_VT              0.012351
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 20 out of 85
# Top selected features:
# Avg peak DSAR VRBA            0.097835
# Max peak DSAR VRBA            0.086986
# Avg Value DSAR VRBA           0.078173
# Median Value DSAR VRBA        0.072600
# Max drop DSAR VRBA            0.068066
# Std Value DSAR VRBA           0.067356
# Mean Min Values RSAM VRBA     0.048405
# Avg drop DSAR VRBA            0.038304
# Quantile Changes DSAR VRBA    0.037051
# Var Value DSAR VRBA           0.036190
# Quantile Changes RSAM VRBA    0.030994
# Sum_LP                        0.029797
# Delta_Max_Min_LP              0.027206
# Max_LP                        0.026023
# Avg Drop Depth DSAR VRBA      0.021489
# Max_Precipitations            0.018044
# Avg drop RSAM VRBA            0.016254
# Max Drop Depth DSAR VRBA      0.014726
# Std peak RSAM VRBA            0.013676
# Avg Value RSAM VRBA           0.013131
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2022
# ==================================================
#
# [ STATION VORI ]
# Features kept: 31 out of 85
# Top selected features:
# Sum_LP                          0.082877
# Mean Min Values DSAR VORI       0.054865
# Max_LP                          0.047852
# Max drop DSAR VORI              0.041944
# Delta_Max_Min_LP                0.035458
# Median Value DSAR VORI          0.034541
# Quantile Changes RSAM VORI      0.032561
# Avg drop DSAR VORI              0.030716
# Avg peak DSAR VORI              0.024992
# Max peak DSAR VORI              0.024435
# Var Value DSAR VORI             0.023902
# Max_Precipitations              0.023085
# Var Value RSAM VORI             0.022591
# Quantile Changes DSAR VORI      0.022423
# Std Value DSAR VORI             0.022270
# Avg Value RSAM VORI             0.021883
# Max peak RSAM VORI              0.020338
# Sum_Precipitations              0.019599
# Delta_Max_Min_Precipitations    0.018912
# Avg Value DSAR VORI             0.018151
# Median Value RSAM VORI          0.018121
# Std Value RSAM VORI             0.018058
# Last_LP                         0.016598
# Avg peak RSAM VORI              0.016182
# Mean Min Values RSAM VORI       0.014957
# Avg drop RSAM VORI              0.013968
# Sum_VT                          0.013381
# Max drop RSAM VORI              0.013043
# Max_tornillo                    0.012489
# Sum_tornillo                    0.012460
# Avg Prominence RSAM VORI        0.011950
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 27 out of 85
# Top selected features:
# Sum_LP                        0.077696
# Quantile Changes RSAM VRBA    0.064904
# Median Value DSAR VRBA        0.059801
# Avg Value DSAR VRBA           0.046272
# Max_LP                        0.044138
# Avg peak DSAR VRBA            0.042193
# Max peak DSAR VRBA            0.042078
# Quantile Changes DSAR VRBA    0.040716
# Delta_Max_Min_LP              0.035245
# Var Value DSAR VRBA           0.031674
# Std Value DSAR VRBA           0.029525
# Mean Min Values DSAR VRBA     0.020862
# Mean Min Values RSAM VRBA     0.020467
# Max drop DSAR VRBA            0.020250
# Avg Value RSAM VRBA           0.019737
# Max peak RSAM VRBA            0.018729
# Last_LP                       0.016612
# Avg peak RSAM VRBA            0.016238
# Var Value RSAM VRBA           0.015611
# Avg drop DSAR VRBA            0.015464
# Std Value RSAM VRBA           0.015339
# Avg Drop Depth DSAR VRBA      0.015269
# Median Value RSAM VRBA        0.015190
# Max drop RSAM VRBA            0.014359
# Avg drop RSAM VRBA            0.014002
# Sum_VT                        0.013699
# Max Drop Depth DSAR VRBA      0.012140
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2023
# ==================================================
#
# [ STATION VORI ]
# Features kept: 33 out of 85
# Top selected features:
# Max_Precipitations              0.045445
# Sum_Precipitations              0.039402
# Quantile Changes RSAM VORI      0.039026
# Max_tornillo                    0.038502
# Delta_Max_Min_tornillo          0.037431
# Sum_LP                          0.033144
# Sum_tornillo                    0.029291
# Mean Min Values RSAM VORI       0.028843
# Delta_Max_Min_Precipitations    0.028615
# Delta_Max_Min_LP                0.025486
# Avg Value DSAR VORI             0.022918
# Max_LP                          0.021321
# Quantile Changes DSAR VORI      0.020996
# Avg drop RSAM VORI              0.020020
# Mean Min Values DSAR VORI       0.019631
# Avg drop DSAR VORI              0.019349
# Std Value DSAR VORI             0.019156
# Var Value RSAM VORI             0.019106
# Avg Value RSAM VORI             0.019012
# Median Value RSAM VORI          0.018722
# Std Value RSAM VORI             0.018542
# Max drop RSAM VORI              0.018366
# Max peak RSAM VORI              0.018002
# Max drop DSAR VORI              0.017824
# Var Value DSAR VORI             0.017252
# Avg peak RSAM VORI              0.016767
# Std drop RSAM VORI              0.016716
# Max peak DSAR VORI              0.015274
# Avg peak DSAR VORI              0.014287
# Median Value DSAR VORI          0.013411
# Max Drop Depth RSAM VORI        0.012540
# Std Drop Depth RSAM VORI        0.012141
# Sum_VT                          0.012021
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 28 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA    0.164675
# Median Value DSAR VRBA        0.074585
# Sum_LP                        0.072350
# Quantile Changes DSAR VRBA    0.049699
# Mean Min Values RSAM VRBA     0.049400
# Mean Min Values DSAR VRBA     0.034226
# Sum_tornillo                  0.032084
# Avg peak DSAR VRBA            0.026643
# Delta_Max_Min_LP              0.024084
# Max drop DSAR VRBA            0.022258
# Max drop RSAM VRBA            0.021304
# Max_tornillo                  0.020223
# Sum_Precipitations            0.018971
# Max_LP                        0.017530
# Avg drop RSAM VRBA            0.016757
# Delta_Max_Min_tornillo        0.016641
# Var Value DSAR VRBA           0.016169
# Avg Value RSAM VRBA           0.015935
# Sum_VT                        0.015786
# Max peak RSAM VRBA            0.014981
# Avg peak RSAM VRBA            0.014948
# Max_Precipitations            0.014864
# Max peak DSAR VRBA            0.013268
# Avg drop DSAR VRBA            0.012790
# Median Value RSAM VRBA        0.012737
# Std Value DSAR VRBA           0.011952
# season                        0.011944
# Avg Value DSAR VRBA           0.011841
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2024
# ==================================================
#
# [ STATION VORI ]
# Features kept: 20 out of 85
# Top selected features:
# Sum_LP                          0.193202
# Quantile Changes RSAM VORI      0.089535
# Max drop DSAR VORI              0.073992
# Mean Min Values DSAR VORI       0.062926
# Max_tornillo                    0.051627
# Avg drop DSAR VORI              0.035477
# Mean Min Values RSAM VORI       0.034376
# Quantile Changes DSAR VORI      0.031140
# Sum_Precipitations              0.027684
# Avg peak RSAM VORI              0.022551
# Std Value RSAM VORI             0.022351
# Max_LP                          0.018234
# Delta_Max_Min_LP                0.016322
# Var Value DSAR VORI             0.016053
# Max peak RSAM VORI              0.015133
# Avg Prominence RSAM VORI        0.012999
# Delta_Max_Min_Precipitations    0.012996
# Std Value DSAR VORI             0.011946
# Sum_tornillo                    0.011817
# Delta_Max_Min_tornillo          0.011782
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 28 out of 85
# Top selected features:
# Quantile Changes RSAM VRBA      0.104007
# Avg Value DSAR VRBA             0.090219
# Sum_LP                          0.087195
# Avg peak DSAR VRBA              0.060787
# Median Value DSAR VRBA          0.053413
# Var Value DSAR VRBA             0.042765
# season                          0.039913
# Max_LP                          0.036692
# Quantile Changes DSAR VRBA      0.030847
# Avg drop DSAR VRBA              0.027723
# Avg Drop Depth DSAR VRBA        0.025047
# Max drop RSAM VRBA              0.022216
# Var Value RSAM VRBA             0.020014
# Sum_Precipitations              0.019681
# Avg peak RSAM VRBA              0.017907
# Median Value RSAM VRBA          0.017123
# Max drop DSAR VRBA              0.017102
# Max_tornillo                    0.016595
# Sum_tornillo                    0.015327
# Avg Value RSAM VRBA             0.014576
# Mean Min Values RSAM VRBA       0.014469
# Max_Precipitations              0.014025
# Avg drop RSAM VRBA              0.013592
# Delta_Max_Min_LP                0.013011
# Max Prominence RSAM VRBA        0.012895
# Delta_Max_Min_Precipitations    0.012672
# Std Value DSAR VRBA             0.012328
# Mean Min Values DSAR VRBA       0.012318
# dtype: float64

# %%
def generate_leaderboard(
    train_test_years_splits,
    best_models_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
    best_models_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
    best_features_VORI=None, best_features_VRBA=None,
    output_csv="leaderboard_summary_3days.csv"
):
    """
    Generates a summary leaderboard for models with and without feature selection,
    saves it to a CSV file, and returns the sorted DataFrame.
    """
    all_summaries = []

    # Random Forest + No Feature Selection
    summary_rf = get_crossval_summary_normalized(
        best_models_VORI, None, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
        best_models_VRBA, None, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
        train_test_years_splits,
        best_features=None, model_name="RF_NO_FS"
    )
    all_summaries.append(summary_rf)

    # Random Forest + SelectFromModel
    # Only executes if you provide the selected features
    if best_features_VORI is not None and best_features_VRBA is not None:
        summary_rf_sfm = get_crossval_summary_normalized(
            best_models_VORI, best_features_VORI, x_train_VORI, x_val_VORI, y_train_VORI, y_val_VORI,
            best_models_VRBA, best_features_VRBA, x_train_VRBA, x_val_VRBA, y_train_VRBA, y_val_VRBA,
            train_test_years_splits,
            best_features='selected', model_name="RF_SFM"
        )
        all_summaries.append(summary_rf_sfm)

    # Note: Forward and Backward Selection blocks can be added here following the same 'if' logic 
    # when you are ready to evaluate your 5-day models.

    # Combine all summaries into a single DataFrame
    leaderboard = pd.concat(all_summaries, ignore_index=True)
    
    # Save the layout to CSV
    leaderboard.to_csv(output_csv, index=False)
    
    # Sort by Recall VRBA (Descending) to see the model that misses the fewest events
    if 'Recall VRBA' in leaderboard.columns:
        leaderboard_sorted = leaderboard.sort_values(by='Recall VRBA', ascending=False)
    else:
        leaderboard_sorted = leaderboard
        
    return leaderboard_sorted

# %%
leaderboard_sorted = generate_leaderboard(
    train_test_years_splits=train_test_years_splits,
    best_models_VORI=best_models_VORI, 
    x_train_VORI=X_Train_VORI, x_val_VORI=X_Test_VORI, y_train_VORI=Y_Train_VORI, y_val_VORI=Y_Test_VORI,
    best_models_VRBA=best_models_VRBA, 
    x_train_VRBA=X_Train_VRBA, x_val_VRBA=X_Test_VRBA, y_train_VRBA=Y_Train_VRBA, y_val_VRBA=Y_Test_VRBA,
    best_features_VORI=best_features_VORI, 
    best_features_VRBA=best_features_VRBA,
    output_csv="MSc_Bryan_Rincon/Test Results/leaderboard_summary_head_test.csv"
)

leaderboard_sorted.head()
# Out:
#   Model_Name  Accuracy VORI  Precision VORI  Recall VORI  F1_Score VORI  \
# 1     RF_SFM       0.472201        0.557208     0.519865       0.492840
# 0   RF_NO_FS       0.500782        0.578685     0.576416       0.542071
#
#      TP VORI   TN VORI    FP VORI    FN VORI  TP_VORI_%  FN_VORI_%  TN_VORI_%  \
# 1  11.333333  8.333333  11.666667  10.500000  51.986537  48.013463  45.926573
# 0  12.500000  8.166667  11.833333   9.333333  57.641575  42.358425  44.029720
#
#    FP_VORI_%  Accuracy VRBA  Precision VRBA  Recall VRBA  F1_Score VRBA  \
# 1  54.073427       0.562293        0.621481     0.639592       0.591810
# 0  55.970280       0.534719        0.619187     0.596819       0.562082
#
#      TP VRBA   TN VRBA    FP VRBA   FN VRBA  TP_VRBA_%  FN_VRBA_%  TN_VRBA_%  \
# 1  13.666667  9.333333  10.666667  8.166667  63.959193  36.040807  50.062160
# 0  12.666667  9.166667  10.833333  9.166667  59.681875  40.318125  54.579448
#
#    FP_VRBA_%  Both_TP_%  Both_FN_%  VORI_only_Rate_%  VRBA_only_Rate_%  \
# 1  49.937840  36.496478  20.550747         15.490059         27.462715
# 0  45.420552  40.360051  23.036601         17.281524         19.321824
#
#    Both_TN_Rate_%  Both_FP_Rate_%  VORI_only_TN_Rate_%  VRBA_only_TN_Rate_%
# 1       30.139860       34.151127            15.786713            19.922300
# 0       28.184732       29.575563            15.844988            26.394716

# %%
leaderboard_sorted = generate_leaderboard(
    train_test_years_splits=train_test_years_splits,
    best_models_VORI=best_5days_models_VORI, 
    x_train_VORI=X_Train_5_VORI, x_val_VORI=X_Test_5_VORI, y_train_VORI=Y_Train_5_VORI, y_val_VORI=Y_Test_5_VORI,
    best_models_VRBA=best_5days_models_VRBA, 
    x_train_VRBA=X_Train_5_VRBA, x_val_VRBA=X_Test_5_VRBA, y_train_VRBA=Y_Train_5_VRBA, y_val_VRBA=Y_Test_5_VRBA,
    best_features_VORI=best_features_5days_VORI, 
    best_features_VRBA=best_features_5days_VRBA,
    output_csv="MSc_Bryan_Rincon/Test Results/leaderboard_summary_five_days_test.csv"
)

leaderboard_sorted
# Out:
#   Model_Name  Accuracy VORI  Precision VORI  Recall VORI  F1_Score VORI  \
# 1     RF_SFM       0.556482        0.624467     0.638725       0.551615
# 0   RF_NO_FS       0.553997        0.632439     0.590614       0.539568
#
#       TP VORI    TN VORI    FP VORI    FN VORI  TP_VORI_%  FN_VORI_%  \
# 1  109.000000  38.833333  50.833333  52.833333  63.872455  36.127545
# 0  104.166667  41.500000  48.166667  57.666667  59.061417  40.938583
#
#    TN_VORI_%  FP_VORI_%  Accuracy VRBA  Precision VRBA  Recall VRBA  \
# 1  46.850474  53.149526       0.649346        0.641468     0.717633
# 0  55.032112  44.967888       0.665087        0.648720     0.715891
#
#    F1_Score VRBA     TP VRBA    TN VRBA    FP VRBA    FN VRBA  TP_VRBA_%  \
# 1       0.624323  128.500000  43.833333  45.833333  33.333333  71.763329
# 0       0.628809  129.833333  46.333333  43.333333  32.000000  71.589054
#
#    FN_VRBA_%  TN_VRBA_%  FP_VRBA_%  Both_TP_%  Both_FN_%  VORI_only_Rate_%  \
# 1  28.236671  55.358029  44.641971  51.887172  16.251388         11.985283
# 0  28.410946  55.106197  44.893803  48.456110  17.805639         10.605307
#
#    VRBA_only_Rate_%  Both_TN_Rate_%  Both_FP_Rate_%  VORI_only_TN_Rate_%  \
# 1         19.876157       33.113389       30.904886            13.737085
# 0         23.132944       41.858749       31.720440            13.173363
#
#    VRBA_only_TN_Rate_%
# 1            22.244640
# 0            13.247448

# %%
# Model Head Window (3 days) without feature selection
print_report_best_model_per_year_out_of_dataset(
    best_models_VORI, None, X_Train_VORI, X_Test_VORI, Y_Train_VORI, Y_Test_VORI,
    best_models_VRBA, None, X_Train_VRBA, X_Test_VRBA, Y_Train_VRBA, Y_Test_VRBA,
    train_test_years_splits,
    best_features=None,  # Set to None to use the full feature set for evaluation
    five_days=False,
    time = time_Test,time_5days = time_5days_Test,
    coverage = coverage_Test, coverage_5days = coverage_5days_Test

)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[11 28]
#  [ 4  9]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.73      0.28      0.41        39
#            1       0.24      0.69      0.36        13
#
#     accuracy                           0.38        52
#    macro avg       0.49      0.49      0.38        52
# weighted avg       0.61      0.38      0.40        52
#
#
#  Top Features (VORI)
# Sum_LP                          0.054098
# Max drop RSAM VORI              0.034180
# Quantile Changes RSAM VORI      0.033746
# slope_ratio VORI                0.033421
# Std Value RSAM VORI             0.031811
# Mean Min Values RSAM VORI       0.029522
# Avg drop DSAR VORI              0.028312
# Max drop DSAR VORI              0.025563
# Mean Min Values DSAR VORI       0.024309
# Delta_Max_Min_Precipitations    0.022349
# Max l Width RSAM VORI           0.021824
# Max_LP                          0.021298
# Max Drop Depth DSAR VORI        0.021085
# Avg h Width DSAR VORI           0.021072
# Var Value RSAM VORI             0.021039
# Max h Width RSAM VORI           0.020870
# Max h Width DSAR VORI           0.019302
# Avg Value RSAM VORI             0.019279
# Max l Width DSAR VORI           0.019129
# Avg Prominence DSAR VORI        0.018865
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.45 ± 0.82
# Mean Magnitude (Missed - FN):   3.46 ± 0.94
# Low magnitude events were more detected
#  length of time array: 52
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[14 25]
#  [ 5  8]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.36      0.48        39
#            1       0.24      0.62      0.35        13
#
#     accuracy                           0.42        52
#    macro avg       0.49      0.49      0.42        52
# weighted avg       0.61      0.42      0.45        52
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.051281
# Mean Min Values RSAM VRBA     0.041222
# Sum_LP                        0.037131
# Avg Drop Depth RSAM VRBA      0.029191
# Avg peak DSAR VRBA            0.026687
# Avg Prominence RSAM VRBA      0.024398
# Max Drop Depth RSAM VRBA      0.023692
# Max peak DSAR VRBA            0.023257
# Avg Value DSAR VRBA           0.023105
# Std Value RSAM VRBA           0.022183
# Quantile Changes DSAR VRBA    0.022055
# Median Value RSAM VRBA        0.021737
# Max_LP                        0.021720
# Max Prominence RSAM VRBA      0.021137
# Max Drop Depth DSAR VRBA      0.020726
# Max drop RSAM VRBA            0.020389
# Var Value DSAR VRBA           0.020219
# Avg peak RSAM VRBA            0.020024
# Avg l Width DSAR VRBA         0.020001
# Mean Min Values DSAR VRBA     0.019763
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.46 ± 0.82
# Mean Magnitude (Missed - FN):   3.25 ± 1.04
# Low magnitude events were more detected
#  length of time array: 52
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 7 | Mean VORI RSAM Coverage: 88.86±26.42% | Mean VORI DSAR Coverage: 90.49±25.03% | Mean VRBA Coverage: 53.17±33.14%
# Both Missed (FN): 3 | Mean VORI RSAM Coverage: 92.28±13.29% | Mean VORI DSAR Coverage: 92.28±13.29% | Mean VRBA Coverage: 91.33±6.63%
# Both False Positives (FP): 21 | Mean VORI RSAM Coverage: 98.97±3.82% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 90.60±19.24%
# Both True Negatives (TN): 7 | Mean VORI RSAM Coverage: 99.96±0.02% | Mean VORI DSAR Coverage: 99.96±0.01% | Mean VRBA Coverage: 90.98±9.96%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 99.15+-1.13% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 93.91+-8.54%
# VRBA Detected Without VORI (TP): 1 | Mean VORI RSAM Coverage: 99.95+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 76.95+-nan%
# VORI Detected Without VRBA (TN): 4 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 83.90+-19.16%
# VRBA Detected Without VORI (TN): 7 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 88.39+-13.65%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 9  4]
#  [12 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.43      0.69      0.53        13
#            1       0.73      0.48      0.58        23
#
#     accuracy                           0.56        36
#    macro avg       0.58      0.59      0.55        36
# weighted avg       0.62      0.56      0.56        36
#
#
#  Top Features (VORI)
# Max Drop Depth DSAR VORI           0.096300
# Max l Width RSAM VORI              0.073569
# Avg l Width DSAR VORI              0.073467
# Max peak RSAM VORI                 0.058221
# Mean Min Values DSAR VORI          0.043023
# Mean Min Values RSAM VORI          0.039130
# Median Value RSAM VORI             0.037118
# Avg drop DSAR VORI                 0.033943
# Max Drop Depth RSAM VORI           0.033895
# Delta_Max_Min_Precipitations       0.033121
# Max_tornillo                       0.029538
# Max l Width DSAR VORI              0.029227
# Std drop RSAM VORI                 0.028882
# Avg peak DSAR VORI                 0.028238
# Std Drop Depth DSAR VORI           0.025633
# Avg peak RSAM VORI                 0.025340
# Median Value DSAR VORI             0.025197
# Quantile Changes RSAM VORI         0.024882
# num_state_changes_inv_rsam VORI    0.023930
# Avg Drop Depth DSAR VORI           0.022688
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.15 ± 0.89
# Mean Magnitude (Missed - FN):   3.57 ± 0.43
# Low magnitude events were more detected
#  length of time array: 36
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9  4]
#  [14  9]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.39      0.69      0.50        13
#            1       0.69      0.39      0.50        23
#
#     accuracy                           0.50        36
#    macro avg       0.54      0.54      0.50        36
# weighted avg       0.58      0.50      0.50        36
#
#
#  Top Features (VRBA)
# Std Value DSAR VRBA           0.161404
# Quantile Changes RSAM VRBA    0.080801
# Var Value DSAR VRBA           0.073525
# Avg Prominence DSAR VRBA      0.055938
# Avg Drop Depth DSAR VRBA      0.055455
# Max Drop Depth DSAR VRBA      0.037840
# slope_ratio VRBA              0.033744
# Max Drop Depth RSAM VRBA      0.032401
# Var Value RSAM VRBA           0.031656
# Avg Drop Depth RSAM VRBA      0.030452
# Avg h Width DSAR VRBA         0.028163
# Max_Precipitations            0.027180
# Avg drop DSAR VRBA            0.026680
# Sum_LP                        0.025414
# Max h Width RSAM VRBA         0.020702
# Avg l Width RSAM VRBA         0.018403
# Max Prominence DSAR VRBA      0.018386
# Max peak DSAR VRBA            0.018017
# Sum_tornillo                  0.017439
# Avg Value DSAR VRBA           0.016802
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.26 ± 0.92
# Mean Magnitude (Missed - FN):   3.43 ± 0.56
# Low magnitude events were more detected
#  length of time array: 36
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 7 | Mean VORI RSAM Coverage: 94.75±13.57% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 84.92±16.50%
# Both Missed (FN): 10 | Mean VORI RSAM Coverage: 89.27±11.60% | Mean VORI DSAR Coverage: 97.17±8.81% | Mean VRBA Coverage: 84.65±28.11%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 76.14±40.52% | Mean VORI DSAR Coverage: 80.58±33.56% | Mean VRBA Coverage: 79.32±35.70%
# Both True Negatives (TN): 8 | Mean VORI RSAM Coverage: 96.17±10.41% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 97.20±7.80%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 93.19+-12.90% | Mean VORI DSAR Coverage: 93.45+-13.01% | Mean VRBA Coverage: 93.25+-12.88%
# VRBA Detected Without VORI (TP): 2 | Mean VORI RSAM Coverage: 96.92+-4.20% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 99.80+-0.21%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 99.81+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 99.95+-nan%
# VRBA Detected Without VORI (TN): 1 | Mean VORI RSAM Coverage: 99.91+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 99.77+-nan%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[17 23]
#  [ 7  9]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.42      0.53        40
#            1       0.28      0.56      0.38        16
#
#     accuracy                           0.46        56
#    macro avg       0.49      0.49      0.45        56
# weighted avg       0.59      0.46      0.49        56
#
#
#  Top Features (VORI)
# Max peak DSAR VORI              0.063257
# slope_ratio VORI                0.047823
# Last_Precipitations             0.046560
# Max drop DSAR VORI              0.039392
# Quantile Changes RSAM VORI      0.035146
# Quantile Changes DSAR VORI      0.033858
# Avg peak DSAR VORI              0.031399
# Mean Min Values DSAR VORI       0.031061
# Avg Prominence RSAM VORI        0.030776
# Delta_Max_Min_Precipitations    0.030710
# Avg Value DSAR VORI             0.029891
# Mean Min Values RSAM VORI       0.026178
# Max Drop Depth DSAR VORI        0.025352
# Var Value DSAR VORI             0.025306
# Avg peak RSAM VORI              0.024523
# Std Value RSAM VORI             0.023280
# Median Value DSAR VORI          0.023171
# Max l Width RSAM VORI           0.022372
# Avg Prominence DSAR VORI        0.022114
# Avg Drop Depth DSAR VORI        0.020484
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.16 ± 1.18
# Mean Magnitude (Missed - FN):   3.31 ± 0.80
# Low magnitude events were more detected
#  length of time array: 56
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[15 25]
#  [ 3 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.38      0.52        40
#            1       0.34      0.81      0.48        16
#
#     accuracy                           0.50        56
#    macro avg       0.59      0.59      0.50        56
# weighted avg       0.69      0.50      0.51        56
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.053016
# Avg Value DSAR VRBA           0.048999
# Avg peak DSAR VRBA            0.046384
# Quantile Changes RSAM VRBA    0.042761
# Max peak DSAR VRBA            0.032228
# Var Value DSAR VRBA           0.027562
# Mean Min Values RSAM VRBA     0.024192
# Std Value DSAR VRBA           0.023671
# Max drop DSAR VRBA            0.023640
# Max Prominence RSAM VRBA      0.022316
# Avg Prominence RSAM VRBA      0.022027
# Max l Width RSAM VRBA         0.021902
# Max drop RSAM VRBA            0.021680
# Quantile Changes DSAR VRBA    0.021366
# Avg Drop Depth DSAR VRBA      0.019049
# Median Value RSAM VRBA        0.018721
# Max Drop Depth DSAR VRBA      0.018673
# Avg drop RSAM VRBA            0.017850
# Mean Min Values DSAR VRBA     0.017769
# Std Value RSAM VRBA           0.017641
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.15 ± 0.79
# Mean Magnitude (Missed - FN):   3.54 ± 1.91
# Low magnitude events were more detected
#  length of time array: 56
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 6 | Mean VORI RSAM Coverage: 93.16±12.15% | Mean VORI DSAR Coverage: 94.77±12.69% | Mean VRBA Coverage: 77.44±39.24%
# Both Missed (FN): 0 | Mean VORI RSAM Coverage: nan±nan% | Mean VORI DSAR Coverage: nan±nan% | Mean VRBA Coverage: nan±nan%
# Both False Positives (FP): 19 | Mean VORI RSAM Coverage: 80.86±32.65% | Mean VORI DSAR Coverage: 91.18±26.85% | Mean VRBA Coverage: 71.59±32.97%
# Both True Negatives (TN): 11 | Mean VORI RSAM Coverage: 90.30±22.44% | Mean VORI DSAR Coverage: 93.17±20.80% | Mean VRBA Coverage: 70.06±30.25%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 96.75+-3.92% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 79.25+-16.40%
# VRBA Detected Without VORI (TP): 7 | Mean VORI RSAM Coverage: 91.19+-16.75% | Mean VORI DSAR Coverage: 93.66+-16.66% | Mean VRBA Coverage: 34.21+-32.06%
# VORI Detected Without VRBA (TN): 6 | Mean VORI RSAM Coverage: 99.83+-0.21% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 83.41+-18.06%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 98.09+-3.61% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 85.32+-17.77%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 4  7]
#  [12 17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.25      0.36      0.30        11
#            1       0.71      0.59      0.64        29
#
#     accuracy                           0.53        40
#    macro avg       0.48      0.47      0.47        40
# weighted avg       0.58      0.53      0.55        40
#
#
#  Top Features (VORI)
# Avg l Width RSAM VORI         0.041148
# Median Value DSAR VORI        0.037662
# Sum_LP                        0.032300
# Max Drop Depth RSAM VORI      0.031090
# Std Value RSAM VORI           0.030309
# Mean Min Values DSAR VORI     0.029534
# Max drop DSAR VORI            0.029015
# Max l Width RSAM VORI         0.028035
# Avg drop DSAR VORI            0.026909
# Avg peak DSAR VORI            0.026127
# Var Value RSAM VORI           0.026042
# Max_LP                        0.023757
# Quantile Changes DSAR VORI    0.022785
# Max Drop Depth DSAR VORI      0.022719
# Max peak DSAR VORI            0.022617
# Avg Drop Depth RSAM VORI      0.019708
# Max drop RSAM VORI            0.019653
# Max_VT                        0.019194
# Last_LP                       0.019193
# Max Prominence DSAR VORI      0.019084
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.79 ± 0.73
# Mean Magnitude (Missed - FN):   3.01 ± 0.50
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 7  4]
#  [14 15]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      0.64      0.44        11
#            1       0.79      0.52      0.62        29
#
#     accuracy                           0.55        40
#    macro avg       0.56      0.58      0.53        40
# weighted avg       0.66      0.55      0.57        40
#
#
#  Top Features (VRBA)
# Var Value DSAR VRBA                0.084477
# Quantile Changes RSAM VRBA         0.080764
# Std Value DSAR VRBA                0.062960
# Max Prominence RSAM VRBA           0.044739
# Mean Min Values RSAM VRBA          0.044272
# Avg Prominence RSAM VRBA           0.037225
# Avg peak DSAR VRBA                 0.036793
# Max_LP                             0.029675
# Avg Value RSAM VRBA                0.029304
# Sum_tornillo                       0.026604
# Avg drop DSAR VRBA                 0.022678
# Max drop RSAM VRBA                 0.022420
# Avg Prominence DSAR VRBA           0.022169
# Avg h Width DSAR VRBA              0.021831
# Sum_LP                             0.021765
# Avg Value DSAR VRBA                0.021703
# Max Drop Depth RSAM VRBA           0.021566
# num_state_changes_inv_rsam VRBA    0.021510
# Avg l Width RSAM VRBA              0.018204
# Avg Drop Depth DSAR VRBA           0.018047
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.82 ± 0.77
# Mean Magnitude (Missed - FN):   2.95 ± 0.49
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 13 | Mean VORI RSAM Coverage: 99.95±0.00% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 59.52±23.57%
# Both Missed (FN): 10 | Mean VORI RSAM Coverage: 91.63±22.48% | Mean VORI DSAR Coverage: 92.81±22.59% | Mean VRBA Coverage: 66.01±23.47%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.95±0.00% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 59.90±39.52%
# Both True Negatives (TN): 3 | Mean VORI RSAM Coverage: 99.95±0.00% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 60.43±3.79%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 67.04+-25.13%
# VRBA Detected Without VORI (TP): 2 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 79.69+-28.69%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 99.95+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 63.18+-nan%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 57.67+-16.04%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 2  4]
#  [ 9 10]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.18      0.33      0.24         6
#            1       0.71      0.53      0.61        19
#
#     accuracy                           0.48        25
#    macro avg       0.45      0.43      0.42        25
# weighted avg       0.59      0.48      0.52        25
#
#
#  Top Features (VORI)
# Max peak RSAM VORI              0.071451
# Max l Width RSAM VORI           0.057679
# Last_Precipitations             0.053208
# Sum_Precipitations              0.049539
# Var Value RSAM VORI             0.042471
# Max_LP                          0.036190
# Avg l Width RSAM VORI           0.035654
# Max drop RSAM VORI              0.033993
# Delta_Max_Min_Precipitations    0.032316
# Median Value RSAM VORI          0.032015
# Max h Width RSAM VORI           0.031834
# Avg peak RSAM VORI              0.031049
# Sum_VT                          0.028198
# Avg Drop Depth DSAR VORI        0.026520
# Max Prominence DSAR VORI        0.026306
# Std Value RSAM VORI             0.026256
# Std Drop Depth DSAR VORI        0.025533
# Avg Value RSAM VORI             0.024629
# Avg l Width DSAR VORI           0.024083
# Delta_Max_Min_VT                0.022148
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.35 ± 0.57
# Mean Magnitude (Missed - FN):   3.27 ± 0.83
# Low magnitude events were more detected
#  length of time array: 25
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 4  2]
#  [ 7 12]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.36      0.67      0.47         6
#            1       0.86      0.63      0.73        19
#
#     accuracy                           0.64        25
#    macro avg       0.61      0.65      0.60        25
# weighted avg       0.74      0.64      0.67        25
#
#
#  Top Features (VRBA)
# Var Value DSAR VRBA             0.115789
# Quantile Changes RSAM VRBA      0.080599
# Mean Min Values DSAR VRBA       0.070599
# Avg peak DSAR VRBA              0.059871
# Median Value DSAR VRBA          0.052273
# Max peak DSAR VRBA              0.051819
# Sum_tornillo                    0.051057
# Mean Min Values RSAM VRBA       0.047759
# Max Prominence RSAM VRBA        0.038455
# Delta_Max_Min_Precipitations    0.037838
# Avg h Width RSAM VRBA           0.036087
# Quantile Changes DSAR VRBA      0.032318
# Std Value DSAR VRBA             0.029497
# Max Drop Depth DSAR VRBA        0.028819
# Avg Prominence RSAM VRBA        0.028428
# Avg l Width RSAM VRBA           0.028151
# Avg Value DSAR VRBA             0.023475
# Max h Width DSAR VRBA           0.022018
# Max_LP                          0.019302
# Delta_Max_Min_LP                0.018409
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.61 ± 0.85
# Mean Magnitude (Missed - FN):   3.08 ± 0.76
# Low magnitude events were more detected
#  length of time array: 25
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 7 | Mean VORI RSAM Coverage: 96.64±7.22% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 69.76±17.20%
# Both Missed (FN): 4 | Mean VORI RSAM Coverage: 83.77±31.63% | Mean VORI DSAR Coverage: 84.06±31.79% | Mean VRBA Coverage: 70.56±35.25%
# Both False Positives (FP): 1 | Mean VORI RSAM Coverage: 99.79±nan% | Mean VORI DSAR Coverage: 99.95±nan% | Mean VRBA Coverage: 68.12±nan%
# Both True Negatives (TN): 1 | Mean VORI RSAM Coverage: 98.38±nan% | Mean VORI DSAR Coverage: 99.95±nan% | Mean VRBA Coverage: 69.35±nan%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 73.44+-45.19% | Mean VORI DSAR Coverage: 81.66+-31.69% | Mean VRBA Coverage: 60.80+-52.79%
# VRBA Detected Without VORI (TP): 5 | Mean VORI RSAM Coverage: 99.80+-0.03% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 69.13+-3.72%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 99.44+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 66.06+-nan%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 99.81+-0.13% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 80.11+-16.89%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 6  5]
#  [12 19]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      0.55      0.41        11
#            1       0.79      0.61      0.69        31
#
#     accuracy                           0.60        42
#    macro avg       0.56      0.58      0.55        42
# weighted avg       0.67      0.60      0.62        42
#
#
#  Top Features (VORI)
# Sum_LP                             0.156312
# Sum_tornillo                       0.086501
# Std Value RSAM VORI                0.079062
# Var Value RSAM VORI                0.066753
# num_state_changes_log_dsar VORI    0.060418
# Quantile Changes RSAM VORI         0.054960
# Max l Width RSAM VORI              0.050213
# Max_Precipitations                 0.044151
# Sum_Precipitations                 0.043540
# Avg Prominence RSAM VORI           0.042527
# Mean Min Values DSAR VORI          0.040801
# Avg l Width DSAR VORI              0.038197
# Avg Value RSAM VORI                0.033873
# Max Prominence RSAM VORI           0.024105
# Avg Prominence DSAR VORI           0.017090
# Last_LP                            0.015979
# Max peak RSAM VORI                 0.014871
# slope_ratio VORI                   0.014294
# Max_LP                             0.010120
# Delta_Max_Min_tornillo             0.009672
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.09 ± 0.49
# Mean Magnitude (Missed - FN):   2.00 ± 0.73
# High magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 6  5]
#  [12 19]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      0.55      0.41        11
#            1       0.79      0.61      0.69        31
#
#     accuracy                           0.60        42
#    macro avg       0.56      0.58      0.55        42
# weighted avg       0.67      0.60      0.62        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.131790
# Avg Value DSAR VRBA           0.058104
# Max l Width RSAM VRBA         0.046375
# Mean Min Values RSAM VRBA     0.042545
# Quantile Changes DSAR VRBA    0.038124
# Sum_tornillo                  0.037097
# Var Value DSAR VRBA           0.036296
# Std Value DSAR VRBA           0.035207
# Max Drop Depth RSAM VRBA      0.033597
# Max peak RSAM VRBA            0.028249
# Median Value DSAR VRBA        0.027832
# Mean Min Values DSAR VRBA     0.027718
# Avg peak RSAM VRBA            0.025828
# Sum_LP                        0.025587
# Avg l Width DSAR VRBA         0.025232
# Last_LP                       0.022280
# Max h Width RSAM VRBA         0.022267
# Avg Prominence RSAM VRBA      0.018556
# Avg Prominence DSAR VRBA      0.017772
# Max l Width DSAR VRBA         0.017010
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 1.96 ± 0.58
# Mean Magnitude (Missed - FN):   2.20 ± 0.58
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 12 | Mean VORI RSAM Coverage: 79.83±26.36% | Mean VORI DSAR Coverage: 82.12±27.05% | Mean VRBA Coverage: 54.71±6.51%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 36.36±37.64% | Mean VORI DSAR Coverage: 39.24±39.94% | Mean VRBA Coverage: 59.62±20.92%
# Both False Positives (FP): 1 | Mean VORI RSAM Coverage: 96.73±nan% | Mean VORI DSAR Coverage: 96.73±nan% | Mean VRBA Coverage: 53.03±nan%
# Both True Negatives (TN): 2 | Mean VORI RSAM Coverage: 66.02±34.58% | Mean VORI DSAR Coverage: 66.02±34.58% | Mean VRBA Coverage: 54.52±15.26%
# VORI Detected Without VRBA (TP): 7 | Mean VORI RSAM Coverage: 59.40+-45.81% | Mean VORI DSAR Coverage: 59.39+-45.81% | Mean VRBA Coverage: 52.86+-28.30%
# VRBA Detected Without VORI (TP): 7 | Mean VORI RSAM Coverage: 67.20+-46.78% | Mean VORI DSAR Coverage: 67.20+-46.78% | Mean VRBA Coverage: 55.03+-8.40%
# VORI Detected Without VRBA (TN): 4 | Mean VORI RSAM Coverage: 75.71+-28.71% | Mean VORI DSAR Coverage: 75.72+-28.73% | Mean VRBA Coverage: 55.79+-3.67%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 81.58+-15.31% | Mean VORI DSAR Coverage: 81.58+-15.32% | Mean VRBA Coverage: 56.40+-8.35%

# %%
# Model Eruption Window (5 days) without feature selection
print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI, None, X_Train_5_VORI, X_Test_5_VORI, Y_Train_5_VORI, Y_Test_5_VORI,
    best_5days_models_VRBA, None, X_Train_5_VRBA, X_Test_5_VRBA, Y_Train_5_VRBA, Y_Test_5_VRBA,
    train_test_years_splits,
    best_features=None , # Set to None to use the full feature set for evaluation
    five_days=True,
    time = time_Test, coverage = coverage_Test,
    time_5days = time_5days_Test, coverage_5days = coverage_5days_Test
)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 87 109]
#  [ 12  23]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.44      0.59       196
#            1       0.17      0.66      0.28        35
#
#     accuracy                           0.48       231
#    macro avg       0.53      0.55      0.43       231
# weighted avg       0.77      0.48      0.54       231
#
#
#  Top Features (VORI)
# Sum_LP                          0.113218
# Max_LP                          0.073067
# Delta_Max_Min_LP                0.062004
# Quantile Changes RSAM VORI      0.038523
# Last_LP                         0.035642
# Mean Min Values RSAM VORI       0.029821
# Mean Min Values DSAR VORI       0.029221
# Max drop DSAR VORI              0.023406
# season                          0.023043
# Avg drop DSAR VORI              0.022264
# Delta_Max_Min_Precipitations    0.021908
# Max_Precipitations              0.021800
# Max drop RSAM VORI              0.020939
# Avg Value RSAM VORI             0.020908
# Median Value RSAM VORI          0.020774
# Max peak RSAM VORI              0.020415
# Delta_Max_Min_tornillo          0.020308
# Sum_Precipitations              0.019944
# Max_tornillo                    0.019838
# Median Value DSAR VORI          0.018792
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.59 ± 0.69
# Mean Magnitude (Missed - FN):   2.59 ± 0.94
# High magnitude events were more detected
#  length of time array: 231
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[107  89]
#  [ 17  18]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.55      0.67       196
#            1       0.17      0.51      0.25        35
#
#     accuracy                           0.54       231
#    macro avg       0.52      0.53      0.46       231
# weighted avg       0.76      0.54      0.61       231
#
#
#  Top Features (VRBA)
# Sum_LP                        0.100237
# Max_LP                        0.081097
# Quantile Changes RSAM VRBA    0.064424
# Delta_Max_Min_LP              0.062548
# Median Value DSAR VRBA        0.031968
# Last_LP                       0.029468
# Mean Min Values RSAM VRBA     0.028285
# Quantile Changes DSAR VRBA    0.027443
# Var Value DSAR VRBA           0.025132
# Avg peak DSAR VRBA            0.024412
# Mean Min Values DSAR VRBA     0.023945
# Std Value DSAR VRBA           0.022919
# Avg peak RSAM VRBA            0.021511
# Avg Value DSAR VRBA           0.021449
# Max peak DSAR VRBA            0.020663
# Max peak RSAM VRBA            0.020563
# Max Drop Depth DSAR VRBA      0.019450
# Var Value RSAM VRBA           0.017570
# Max_tornillo                  0.016676
# season                        0.015831
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.63
# Mean Magnitude (Missed - FN):   2.62 ± 0.91
# Low magnitude events were more detected
#  length of time array: 231
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 18 | Mean VORI RSAM Coverage: 94.62±19.27% | Mean VORI DSAR Coverage: 97.82±9.02% | Mean VRBA Coverage: 54.14±29.51%
# Both Missed (FN): 12 | Mean VORI RSAM Coverage: 81.35±29.42% | Mean VORI DSAR Coverage: 87.77±18.72% | Mean VRBA Coverage: 52.27±44.44%
# Both False Positives (FP): 81 | Mean VORI RSAM Coverage: 99.02±2.76% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 89.89±15.13%
# Both True Negatives (TN): 79 | Mean VORI RSAM Coverage: 99.88±0.26% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 92.77±14.23%
# VORI Detected Without VRBA (TP): 5 | Mean VORI RSAM Coverage: 99.62+-0.45% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 80.95+-16.59%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 8 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 78.77+-14.75%
# VRBA Detected Without VORI (TN): 28 | Mean VORI RSAM Coverage: 99.42+-1.61% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 94.58+-10.08%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 41  11]
#  [112  56]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.27      0.79      0.40        52
#            1       0.84      0.33      0.48       168
#
#     accuracy                           0.44       220
#    macro avg       0.55      0.56      0.44       220
# weighted avg       0.70      0.44      0.46       220
#
#
#  Top Features (VORI)
# Sum_LP                        0.079654
# Mean Min Values DSAR VORI     0.044394
# Delta_Max_Min_tornillo        0.044087
# Max_LP                        0.043290
# Max drop DSAR VORI            0.041636
# Avg drop DSAR VORI            0.039313
# Max_tornillo                  0.039038
# Median Value DSAR VORI        0.034298
# Delta_Max_Min_LP              0.034278
# Max peak DSAR VORI            0.030020
# Quantile Changes RSAM VORI    0.027171
# Sum_tornillo                  0.025340
# Avg peak DSAR VORI            0.024679
# Var Value RSAM VORI           0.024646
# Max peak RSAM VORI            0.021086
# Std Value RSAM VORI           0.020650
# Avg peak RSAM VORI            0.020199
# Last_LP                       0.019341
# Median Value RSAM VORI        0.018623
# Avg Value RSAM VORI           0.018398
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.35 ± 0.78
# Mean Magnitude (Missed - FN):   3.29 ± 0.68
# High magnitude events were more detected
#  length of time array: 220
# Detected Lahars (TP): 1 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2020-01-30 18:13:42.427
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 47   5]
#  [ 68 100]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.41      0.90      0.56        52
#            1       0.95      0.60      0.73       168
#
#     accuracy                           0.67       220
#    macro avg       0.68      0.75      0.65       220
# weighted avg       0.82      0.67      0.69       220
#
#
#  Top Features (VRBA)
# Sum_LP                        0.156778
# Quantile Changes RSAM VRBA    0.107610
# Median Value DSAR VRBA        0.086237
# Std Value DSAR VRBA           0.077324
# Quantile Changes DSAR VRBA    0.060919
# Var Value DSAR VRBA           0.047188
# Max_LP                        0.029011
# Delta_Max_Min_tornillo        0.023535
# Max_tornillo                  0.022753
# Max drop RSAM VRBA            0.020167
# Avg peak DSAR VRBA            0.018967
# Avg drop RSAM VRBA            0.017231
# Mean Min Values DSAR VRBA     0.016828
# Avg Value RSAM VRBA           0.016807
# Avg Value DSAR VRBA           0.016341
# Mean Min Values RSAM VRBA     0.015772
# Sum_tornillo                  0.015480
# Max peak RSAM VRBA            0.014905
# Avg peak RSAM VRBA            0.014670
# Delta_Max_Min_LP              0.013020
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.31 ± 0.74
# Mean Magnitude (Missed - FN):   3.30 ± 0.68
# High magnitude events were more detected
#  length of time array: 220
# Detected Lahars (TP): 2 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2020-01-30 18:13:42.427
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 41 | Mean VORI RSAM Coverage: 92.84±13.74% | Mean VORI DSAR Coverage: 99.20±3.34% | Mean VRBA Coverage: 91.86±10.48%
# Both Missed (FN): 53 | Mean VORI RSAM Coverage: 92.50±12.52% | Mean VORI DSAR Coverage: 96.03±12.53% | Mean VRBA Coverage: 91.00±16.47%
# Both False Positives (FP): 2 | Mean VORI RSAM Coverage: 99.88±0.01% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 99.89±0.08%
# Both True Negatives (TN): 38 | Mean VORI RSAM Coverage: 89.69±25.49% | Mean VORI DSAR Coverage: 93.97±17.49% | Mean VRBA Coverage: 96.18±12.14%
# VORI Detected Without VRBA (TP): 15 | Mean VORI RSAM Coverage: 97.79+-4.60% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 97.85+-2.24%
# VRBA Detected Without VORI (TP): 59 | Mean VORI RSAM Coverage: 98.15+-5.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 94.64+-11.11%
# VORI Detected Without VRBA (TN): 3 | Mean VORI RSAM Coverage: 99.85+-0.02% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 99.94+-0.00%
# VRBA Detected Without VORI (TN): 9 | Mean VORI RSAM Coverage: 88.69+-33.26% | Mean VORI DSAR Coverage: 90.49+-28.37% | Mean VRBA Coverage: 85.27+-19.67%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 62 132]
#  [ 13  12]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.32      0.46       194
#            1       0.08      0.48      0.14        25
#
#     accuracy                           0.34       219
#    macro avg       0.46      0.40      0.30       219
# weighted avg       0.74      0.34      0.42       219
#
#
#  Top Features (VORI)
# Max drop DSAR VORI            0.079899
# Avg peak DSAR VORI            0.074351
# Var Value DSAR VORI           0.065505
# Max_Precipitations            0.052597
# Sum_LP                        0.046348
# Avg drop DSAR VORI            0.040966
# Max_tornillo                  0.037074
# Std Value DSAR VORI           0.035363
# Quantile Changes DSAR VORI    0.031476
# Quantile Changes RSAM VORI    0.026067
# Sum_Precipitations            0.025075
# Max Prominence RSAM VORI      0.023072
# Median Value DSAR VORI        0.021119
# Sum_VT                        0.020812
# Avg Value DSAR VORI           0.018805
# Mean Min Values DSAR VORI     0.018784
# Avg Value RSAM VORI           0.018703
# Std Value RSAM VORI           0.017404
# Std Drop Depth RSAM VORI      0.016688
# Max peak DSAR VORI            0.015720
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.90 ± 0.81
# Mean Magnitude (Missed - FN):   3.09 ± 1.01
# Low magnitude events were more detected
#  length of time array: 219
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 78 116]
#  [  8  17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.91      0.40      0.56       194
#            1       0.13      0.68      0.22        25
#
#     accuracy                           0.43       219
#    macro avg       0.52      0.54      0.39       219
# weighted avg       0.82      0.43      0.52       219
#
#
#  Top Features (VRBA)
# Avg peak DSAR VRBA            0.097835
# Max peak DSAR VRBA            0.086986
# Avg Value DSAR VRBA           0.078173
# Median Value DSAR VRBA        0.072600
# Max drop DSAR VRBA            0.068066
# Std Value DSAR VRBA           0.067356
# Mean Min Values RSAM VRBA     0.048405
# Avg drop DSAR VRBA            0.038304
# Quantile Changes DSAR VRBA    0.037051
# Var Value DSAR VRBA           0.036190
# Quantile Changes RSAM VRBA    0.030994
# Sum_LP                        0.029797
# Delta_Max_Min_LP              0.027206
# Max_LP                        0.026023
# Avg Drop Depth DSAR VRBA      0.021489
# Max_Precipitations            0.018044
# Avg drop RSAM VRBA            0.016254
# Max Drop Depth DSAR VRBA      0.014726
# Std peak RSAM VRBA            0.013676
# Avg Value RSAM VRBA           0.013131
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.93 ± 0.78
# Mean Magnitude (Missed - FN):   3.14 ± 1.17
# Low magnitude events were more detected
#  length of time array: 219
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 8 | Mean VORI RSAM Coverage: 97.33±4.23% | Mean VORI DSAR Coverage: 98.06±3.52% | Mean VRBA Coverage: 71.19±16.55%
# Both Missed (FN): 4 | Mean VORI RSAM Coverage: 61.02±16.85% | Mean VORI DSAR Coverage: 66.38±24.61% | Mean VRBA Coverage: 17.73±35.46%
# Both False Positives (FP): 92 | Mean VORI RSAM Coverage: 84.71±30.05% | Mean VORI DSAR Coverage: 89.73±25.58% | Mean VRBA Coverage: 81.41±23.92%
# Both True Negatives (TN): 38 | Mean VORI RSAM Coverage: 93.95±15.57% | Mean VORI DSAR Coverage: 98.24±7.50% | Mean VRBA Coverage: 71.39±27.05%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 94.80+-9.03% | Mean VORI DSAR Coverage: 95.28+-9.32% | Mean VRBA Coverage: 58.48+-30.71%
# VRBA Detected Without VORI (TP): 9 | Mean VORI RSAM Coverage: 99.49+-0.64% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 77.30+-20.25%
# VORI Detected Without VRBA (TN): 24 | Mean VORI RSAM Coverage: 99.53+-1.18% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 65.14+-22.78%
# VRBA Detected Without VORI (TN): 40 | Mean VORI RSAM Coverage: 91.91+-19.47% | Mean VORI DSAR Coverage: 95.29+-17.40% | Mean VRBA Coverage: 67.71+-28.92%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 25  19]
#  [ 59 191]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.30      0.57      0.39        44
#            1       0.91      0.76      0.83       250
#
#     accuracy                           0.73       294
#    macro avg       0.60      0.67      0.61       294
# weighted avg       0.82      0.73      0.76       294
#
#
#  Top Features (VORI)
# Sum_LP                          0.082877
# Mean Min Values DSAR VORI       0.054865
# Max_LP                          0.047852
# Max drop DSAR VORI              0.041944
# Delta_Max_Min_LP                0.035458
# Median Value DSAR VORI          0.034541
# Quantile Changes RSAM VORI      0.032561
# Avg drop DSAR VORI              0.030716
# Avg peak DSAR VORI              0.024992
# Max peak DSAR VORI              0.024435
# Var Value DSAR VORI             0.023902
# Max_Precipitations              0.023085
# Var Value RSAM VORI             0.022591
# Quantile Changes DSAR VORI      0.022423
# Std Value DSAR VORI             0.022270
# Avg Value RSAM VORI             0.021883
# Max peak RSAM VORI              0.020338
# Sum_Precipitations              0.019599
# Delta_Max_Min_Precipitations    0.018912
# Avg Value DSAR VORI             0.018151
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.71 ± 0.58
# Mean Magnitude (Missed - FN):   3.23 ± 0.67
# Low magnitude events were more detected
#  length of time array: 294
# Detected Lahars (TP): 1 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Missed Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 24  20]
#  [ 42 208]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.36      0.55      0.44        44
#            1       0.91      0.83      0.87       250
#
#     accuracy                           0.79       294
#    macro avg       0.64      0.69      0.65       294
# weighted avg       0.83      0.79      0.81       294
#
#
#  Top Features (VRBA)
# Sum_LP                        0.077696
# Quantile Changes RSAM VRBA    0.064904
# Median Value DSAR VRBA        0.059801
# Avg Value DSAR VRBA           0.046272
# Max_LP                        0.044138
# Avg peak DSAR VRBA            0.042193
# Max peak DSAR VRBA            0.042078
# Quantile Changes DSAR VRBA    0.040716
# Delta_Max_Min_LP              0.035245
# Var Value DSAR VRBA           0.031674
# Std Value DSAR VRBA           0.029525
# Mean Min Values DSAR VRBA     0.020862
# Mean Min Values RSAM VRBA     0.020467
# Max drop DSAR VRBA            0.020250
# Avg Value RSAM VRBA           0.019737
# Max peak RSAM VRBA            0.018729
# Last_LP                       0.016612
# Avg peak RSAM VRBA            0.016238
# Var Value RSAM VRBA           0.015611
# Avg drop DSAR VRBA            0.015464
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.78 ± 0.62
# Mean Magnitude (Missed - FN):   3.09 ± 0.67
# Low magnitude events were more detected
#  length of time array: 294
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 178 | Mean VORI RSAM Coverage: 97.85±4.85% | Mean VORI DSAR Coverage: 99.50±1.77% | Mean VRBA Coverage: 66.86±19.75%
# Both Missed (FN): 29 | Mean VORI RSAM Coverage: 97.07±15.38% | Mean VORI DSAR Coverage: 97.09±15.38% | Mean VRBA Coverage: 58.50±19.91%
# Both False Positives (FP): 11 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 33.47±24.09%
# Both True Negatives (TN): 16 | Mean VORI RSAM Coverage: 99.54±1.63% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 54.20±10.64%
# VORI Detected Without VRBA (TP): 13 | Mean VORI RSAM Coverage: 98.46+-3.81% | Mean VORI DSAR Coverage: 98.47+-3.80% | Mean VRBA Coverage: 54.95+-17.95%
# VRBA Detected Without VORI (TP): 30 | Mean VORI RSAM Coverage: 96.06+-11.31% | Mean VORI DSAR Coverage: 96.16+-11.34% | Mean VRBA Coverage: 56.44+-16.49%
# VORI Detected Without VRBA (TN): 9 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 39.75+-26.52%
# VRBA Detected Without VORI (TN): 8 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 45.65+-17.28%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[  4   4]
#  [109 285]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.04      0.50      0.07         8
#            1       0.99      0.72      0.83       394
#
#     accuracy                           0.72       402
#    macro avg       0.51      0.61      0.45       402
# weighted avg       0.97      0.72      0.82       402
#
#
#  Top Features (VORI)
# Max_Precipitations              0.045445
# Sum_Precipitations              0.039402
# Quantile Changes RSAM VORI      0.039026
# Max_tornillo                    0.038502
# Delta_Max_Min_tornillo          0.037431
# Sum_LP                          0.033144
# Sum_tornillo                    0.029291
# Mean Min Values RSAM VORI       0.028843
# Delta_Max_Min_Precipitations    0.028615
# Delta_Max_Min_LP                0.025486
# Avg Value DSAR VORI             0.022918
# Max_LP                          0.021321
# Quantile Changes DSAR VORI      0.020996
# Avg drop RSAM VORI              0.020020
# Mean Min Values DSAR VORI       0.019631
# Avg drop DSAR VORI              0.019349
# Std Value DSAR VORI             0.019156
# Var Value RSAM VORI             0.019106
# Avg Value RSAM VORI             0.019012
# Median Value RSAM VORI          0.018722
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.83 ± 0.73
# Mean Magnitude (Missed - FN):   2.71 ± 0.62
# High magnitude events were more detected
#  length of time array: 402
# Detected Lahars (TP): 7 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# Detected Lahar Event - Magnitude: 5.20, Time: 2023-04-21 21:50:10.251
# Detected Lahar Event - Magnitude: 4.79, Time: 2023-05-14 08:58:05.785
# Detected Lahar Event - Magnitude: 4.98, Time: 2023-05-25 20:35:31.649
# Detected Lahar Event - Magnitude: 5.11, Time: 2023-05-28 03:34:53.507
# Detected Lahar Event - Magnitude: 4.74, Time: 2023-05-29 08:44:09.899
# Detected Lahar Event - Magnitude: 4.40, Time: 2023-11-05 21:17:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.97, Time: 2023-04-14 15:35:36.445
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[  4   4]
#  [ 33 361]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.11      0.50      0.18         8
#            1       0.99      0.92      0.95       394
#
#     accuracy                           0.91       402
#    macro avg       0.55      0.71      0.56       402
# weighted avg       0.97      0.91      0.94       402
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.164675
# Median Value DSAR VRBA        0.074585
# Sum_LP                        0.072350
# Quantile Changes DSAR VRBA    0.049699
# Mean Min Values RSAM VRBA     0.049400
# Mean Min Values DSAR VRBA     0.034226
# Sum_tornillo                  0.032084
# Avg peak DSAR VRBA            0.026643
# Delta_Max_Min_LP              0.024084
# Max drop DSAR VRBA            0.022258
# Max drop RSAM VRBA            0.021304
# Max_tornillo                  0.020223
# Sum_Precipitations            0.018971
# Max_LP                        0.017530
# Avg drop RSAM VRBA            0.016757
# Delta_Max_Min_tornillo        0.016641
# Var Value DSAR VRBA           0.016169
# Avg Value RSAM VRBA           0.015935
# Sum_VT                        0.015786
# Max peak RSAM VRBA            0.014981
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.81 ± 0.71
# Mean Magnitude (Missed - FN):   2.63 ± 0.62
# High magnitude events were more detected
#  length of time array: 402
# Detected Lahars (TP): 7 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.97, Time: 2023-04-14 15:35:36.445
# Detected Lahar Event - Magnitude: 5.20, Time: 2023-04-21 21:50:10.251
# Detected Lahar Event - Magnitude: 4.79, Time: 2023-05-14 08:58:05.785
# Detected Lahar Event - Magnitude: 4.98, Time: 2023-05-25 20:35:31.649
# Detected Lahar Event - Magnitude: 5.11, Time: 2023-05-28 03:34:53.507
# Detected Lahar Event - Magnitude: 4.74, Time: 2023-05-29 08:44:09.899
# Detected Lahar Event - Magnitude: 4.40, Time: 2023-11-05 21:17:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 265 | Mean VORI RSAM Coverage: 91.65±18.38% | Mean VORI DSAR Coverage: 95.21±15.39% | Mean VRBA Coverage: 72.94±11.14%
# Both Missed (FN): 13 | Mean VORI RSAM Coverage: 65.05±33.13% | Mean VORI DSAR Coverage: 70.69±30.61% | Mean VRBA Coverage: 71.32±27.65%
# Both False Positives (FP): 4 | Mean VORI RSAM Coverage: 99.81±0.06% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 68.29±2.66%
# Both True Negatives (TN): 4 | Mean VORI RSAM Coverage: 98.96±0.01% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 73.97±5.58%
# VORI Detected Without VRBA (TP): 20 | Mean VORI RSAM Coverage: 96.54+-11.38% | Mean VORI DSAR Coverage: 97.67+-10.16% | Mean VRBA Coverage: 81.87+-8.37%
# VRBA Detected Without VORI (TP): 96 | Mean VORI RSAM Coverage: 91.48+-21.73% | Mean VORI DSAR Coverage: 93.37+-21.18% | Mean VRBA Coverage: 68.60+-15.01%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[30 14]
#  [41 58]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.42      0.68      0.52        44
#            1       0.81      0.59      0.68        99
#
#     accuracy                           0.62       143
#    macro avg       0.61      0.63      0.60       143
# weighted avg       0.69      0.62      0.63       143
#
#
#  Top Features (VORI)
# Sum_LP                          0.193202
# Quantile Changes RSAM VORI      0.089535
# Max drop DSAR VORI              0.073992
# Mean Min Values DSAR VORI       0.062926
# Max_tornillo                    0.051627
# Avg drop DSAR VORI              0.035477
# Mean Min Values RSAM VORI       0.034376
# Quantile Changes DSAR VORI      0.031140
# Sum_Precipitations              0.027684
# Avg peak RSAM VORI              0.022551
# Std Value RSAM VORI             0.022351
# Max_LP                          0.018234
# Delta_Max_Min_LP                0.016322
# Var Value DSAR VORI             0.016053
# Max peak RSAM VORI              0.015133
# Avg Prominence RSAM VORI        0.012999
# Delta_Max_Min_Precipitations    0.012996
# Std Value DSAR VORI             0.011946
# Sum_tornillo                    0.011817
# Delta_Max_Min_tornillo          0.011782
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.22 ± 0.54
# Mean Magnitude (Missed - FN):   2.03 ± 0.45
# High magnitude events were more detected
#  length of time array: 143
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[18 26]
#  [24 75]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.43      0.41      0.42        44
#            1       0.74      0.76      0.75        99
#
#     accuracy                           0.65       143
#    macro avg       0.59      0.58      0.58       143
# weighted avg       0.65      0.65      0.65       143
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.104007
# Avg Value DSAR VRBA           0.090219
# Sum_LP                        0.087195
# Avg peak DSAR VRBA            0.060787
# Median Value DSAR VRBA        0.053413
# Var Value DSAR VRBA           0.042765
# season                        0.039913
# Max_LP                        0.036692
# Quantile Changes DSAR VRBA    0.030847
# Avg drop DSAR VRBA            0.027723
# Avg Drop Depth DSAR VRBA      0.025047
# Max drop RSAM VRBA            0.022216
# Var Value RSAM VRBA           0.020014
# Sum_Precipitations            0.019681
# Avg peak RSAM VRBA            0.017907
# Median Value RSAM VRBA        0.017123
# Max drop DSAR VRBA            0.017102
# Max_tornillo                  0.016595
# Sum_tornillo                  0.015327
# Avg Value RSAM VRBA           0.014576
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.15 ± 0.52
# Mean Magnitude (Missed - FN):   2.11 ± 0.51
# High magnitude events were more detected
#  length of time array: 143
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 44 | Mean VORI RSAM Coverage: 68.00±38.29% | Mean VORI DSAR Coverage: 68.00±38.29% | Mean VRBA Coverage: 61.11±10.28%
# Both Missed (FN): 10 | Mean VORI RSAM Coverage: 58.98±43.48% | Mean VORI DSAR Coverage: 58.98±43.48% | Mean VRBA Coverage: 52.17±16.71%
# Both False Positives (FP): 10 | Mean VORI RSAM Coverage: 84.52±10.35% | Mean VORI DSAR Coverage: 84.52±10.35% | Mean VRBA Coverage: 53.79±3.51%
# Both True Negatives (TN): 14 | Mean VORI RSAM Coverage: 58.82±18.64% | Mean VORI DSAR Coverage: 58.82±18.64% | Mean VRBA Coverage: 53.20±2.14%
# VORI Detected Without VRBA (TP): 14 | Mean VORI RSAM Coverage: 27.94+-37.67% | Mean VORI DSAR Coverage: 28.56+-38.53% | Mean VRBA Coverage: 48.08+-23.62%
# VRBA Detected Without VORI (TP): 31 | Mean VORI RSAM Coverage: 64.54+-40.78% | Mean VORI DSAR Coverage: 64.54+-40.78% | Mean VRBA Coverage: 53.16+-13.23%
# VORI Detected Without VRBA (TN): 16 | Mean VORI RSAM Coverage: 76.51+-16.49% | Mean VORI DSAR Coverage: 76.52+-16.50% | Mean VRBA Coverage: 55.42+-3.39%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 77.20+-16.43% | Mean VORI DSAR Coverage: 77.20+-16.43% | Mean VRBA Coverage: 54.41+-1.46%

# %%
# Model Head Window (3 days) with feature selection
print_report_best_model_per_year_out_of_dataset(
    best_models_VORI, best_features_VORI, X_Train_VORI, X_Test_VORI, Y_Train_VORI, Y_Test_VORI,
    best_models_VRBA, best_features_VRBA, X_Train_VRBA, X_Test_VRBA, Y_Train_VRBA, Y_Test_VRBA,
    train_test_years_splits,
    best_features='selected',
    time = time_Test,time_5days = time_5days_Test,
    coverage = coverage_Test, coverage_5days = coverage_5days_Test  
)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 8  8]
#  [ 4 20]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57        16
#            1       0.71      0.83      0.77        24
#
#     accuracy                           0.70        40
#    macro avg       0.69      0.67      0.67        40
# weighted avg       0.70      0.70      0.69        40
#
#
#  Top Features (VORI)
# Quantile Changes RSAM VORI      0.058466
# Sum_LP                          0.053305
# Max l Width DSAR VORI           0.042205
# Max drop DSAR VORI              0.041329
# slope_ratio VORI                0.040996
# Avg drop DSAR VORI              0.040082
# Delta_Max_Min_Precipitations    0.036044
# Max_LP                          0.034255
# Avg Value RSAM VORI             0.032758
# Max peak DSAR VORI              0.031442
# Avg Drop Depth DSAR VORI        0.029916
# Quantile Changes DSAR VORI      0.029814
# Max h Width RSAM VORI           0.029511
# Max l Width RSAM VORI           0.028677
# Avg h Width DSAR VORI           0.028631
# Max drop RSAM VORI              0.028386
# Std Value RSAM VORI             0.027594
# Max h Width DSAR VORI           0.026879
# Avg peak DSAR VORI              0.026297
# Median Value RSAM VORI          0.025330
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.81 ± 0.94
# Mean Magnitude (Missed - FN):   3.29 ± 0.73
# Low magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 8  8]
#  [ 4 20]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57        16
#            1       0.71      0.83      0.77        24
#
#     accuracy                           0.70        40
#    macro avg       0.69      0.67      0.67        40
# weighted avg       0.70      0.70      0.69        40
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.045594
# Mean Min Values RSAM VRBA     0.040324
# Sum_LP                        0.035685
# Var Value RSAM VRBA           0.032318
# Quantile Changes DSAR VRBA    0.031142
# Std Value RSAM VRBA           0.030704
# Avg Value DSAR VRBA           0.027746
# Max peak DSAR VRBA            0.026647
# Std Value DSAR VRBA           0.026477
# Median Value DSAR VRBA        0.026374
# Max Drop Depth RSAM VRBA      0.025662
# Avg Drop Depth RSAM VRBA      0.025385
# Avg Prominence DSAR VRBA      0.024373
# Var Value DSAR VRBA           0.023910
# Max_LP                        0.023899
# Max h Width RSAM VRBA         0.023350
# Median Value RSAM VRBA        0.022859
# Avg Prominence RSAM VRBA      0.022641
# Avg Drop Depth DSAR VRBA      0.022461
# Avg peak RSAM VRBA            0.021788
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.94 ± 0.96
# Mean Magnitude (Missed - FN):   2.64 ± 0.71
# High magnitude events were more detected
#  length of time array: 40
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 17 | Mean VORI RSAM Coverage: 84.68±25.10% | Mean VORI DSAR Coverage: 90.84±24.91% | Mean VRBA Coverage: 71.07±22.10%
# Both Missed (FN): 1 | Mean VORI RSAM Coverage: 99.95±nan% | Mean VORI DSAR Coverage: 99.95±nan% | Mean VRBA Coverage: 34.57±nan%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 99.92±0.04% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 67.36±17.82%
# Both True Negatives (TN): 5 | Mean VORI RSAM Coverage: 58.80±43.40% | Mean VORI DSAR Coverage: 63.09±37.61% | Mean VRBA Coverage: 71.19±21.48%
# VORI Detected Without VRBA (TP): 3 | Mean VORI RSAM Coverage: 66.57+-57.65% | Mean VORI DSAR Coverage: 66.64+-57.71% | Mean VRBA Coverage: 71.40+-8.23%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 92.29+-13.14% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 73.95+-22.84%
# VORI Detected Without VRBA (TN): 3 | Mean VORI RSAM Coverage: 86.06+-13.22% | Mean VORI DSAR Coverage: 91.18+-15.19% | Mean VRBA Coverage: 71.34+-26.03%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 99.86+-0.04% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 100.02+-0.00%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[11 10]
#  [ 9 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.52      0.54        21
#            1       0.57      0.59      0.58        22
#
#     accuracy                           0.56        43
#    macro avg       0.56      0.56      0.56        43
# weighted avg       0.56      0.56      0.56        43
#
#
#  Top Features (VORI)
# Delta_Max_Min_tornillo          0.080107
# Median Value DSAR VORI          0.070505
# Avg l Width DSAR VORI           0.070407
# Avg h Width RSAM VORI           0.064108
# Avg l Width RSAM VORI           0.057498
# Max h Width RSAM VORI           0.056661
# Delta_Max_Min_Precipitations    0.055363
# Avg drop DSAR VORI              0.054258
# Avg peak DSAR VORI              0.053228
# Max l Width RSAM VORI           0.052298
# Max Drop Depth DSAR VORI        0.046435
# Avg Drop Depth DSAR VORI        0.046172
# Var Value DSAR VORI             0.045001
# Quantile Changes RSAM VORI      0.044280
# Var Value RSAM VORI             0.044258
# Max Drop Depth RSAM VORI        0.033501
# Mean Min Values DSAR VORI       0.028143
# Std drop RSAM VORI              0.023707
# Max l Width DSAR VORI           0.020794
# Max_tornillo                    0.020620
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.54 ± 0.74
# Mean Magnitude (Missed - FN):   2.99 ± 1.02
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[14  7]
#  [ 6 16]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.67      0.68        21
#            1       0.70      0.73      0.71        22
#
#     accuracy                           0.70        43
#    macro avg       0.70      0.70      0.70        43
# weighted avg       0.70      0.70      0.70        43
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.144113
# Var Value DSAR VRBA           0.140631
# Std Value DSAR VRBA           0.107142
# Avg Drop Depth RSAM VRBA      0.067269
# Mean Min Values RSAM VRBA     0.062287
# Var Value RSAM VRBA           0.055864
# Avg drop DSAR VRBA            0.046834
# Max Drop Depth RSAM VRBA      0.044853
# Std Value RSAM VRBA           0.041454
# slope_ratio VRBA              0.037074
# Sum_tornillo                  0.036049
# Max h Width RSAM VRBA         0.034529
# Max Prominence DSAR VRBA      0.026829
# Avg Value DSAR VRBA           0.025955
# Max Drop Depth DSAR VRBA      0.019478
# Max peak DSAR VRBA            0.016206
# Avg Drop Depth DSAR VRBA      0.016143
# Sum_Precipitations            0.014023
# Avg l Width RSAM VRBA         0.013417
# Avg peak DSAR VRBA            0.011627
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.71 ± 0.83
# Mean Magnitude (Missed - FN):   2.75 ± 1.06
# Low magnitude events were more detected
#  length of time array: 43
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 12 | Mean VORI RSAM Coverage: 85.86±28.60% | Mean VORI DSAR Coverage: 86.38±28.81% | Mean VRBA Coverage: 65.91±20.55%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 99.40±0.89% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 70.16±21.82%
# Both False Positives (FP): 6 | Mean VORI RSAM Coverage: 92.09±14.07% | Mean VORI DSAR Coverage: 92.09±14.08% | Mean VRBA Coverage: 55.01±17.97%
# Both True Negatives (TN): 10 | Mean VORI RSAM Coverage: 97.53±7.64% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 89.75±16.87%
# VORI Detected Without VRBA (TP): 1 | Mean VORI RSAM Coverage: 87.90+-nan% | Mean VORI DSAR Coverage: 87.90+-nan% | Mean VRBA Coverage: 81.68+-nan%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 95.75+-8.31% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 48.83+-32.63%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 99.95+-nan% | Mean VORI DSAR Coverage: 99.95+-nan% | Mean VRBA Coverage: 55.92+-nan%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 99.30+-1.30% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 94.86+-10.24%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 9  7]
#  [ 9 14]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53        16
#            1       0.67      0.61      0.64        23
#
#     accuracy                           0.59        39
#    macro avg       0.58      0.59      0.58        39
# weighted avg       0.60      0.59      0.59        39
#
#
#  Top Features (VORI)
# Max peak DSAR VORI                 0.091116
# Avg Value RSAM VORI                0.067170
# Quantile Changes DSAR VORI         0.064693
# Quantile Changes RSAM VORI         0.060566
# Avg l Width RSAM VORI              0.059066
# Median Value DSAR VORI             0.052782
# Avg Prominence RSAM VORI           0.049814
# Max h Width RSAM VORI              0.045675
# Max drop DSAR VORI                 0.044574
# Mean Min Values RSAM VORI          0.041030
# Avg Prominence DSAR VORI           0.040837
# Avg Value DSAR VORI                0.039115
# Std Value RSAM VORI                0.037091
# Sum_Precipitations                 0.034345
# Avg peak DSAR VORI                 0.031852
# num_state_changes_inv_rsam VORI    0.030121
# Avg Drop Depth DSAR VORI           0.027458
# Mean Min Values DSAR VORI          0.025876
# Max Drop Depth DSAR VORI           0.025312
# Delta_Max_Min_Precipitations       0.023204
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.46 ± 0.70
# Mean Magnitude (Missed - FN):   3.10 ± 0.74
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 9  7]
#  [ 5 18]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.64      0.56      0.60        16
#            1       0.72      0.78      0.75        23
#
#     accuracy                           0.69        39
#    macro avg       0.68      0.67      0.68        39
# weighted avg       0.69      0.69      0.69        39
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.072119
# Avg Value DSAR VRBA           0.052612
# Median Value DSAR VRBA        0.050296
# Max peak DSAR VRBA            0.034658
# Var Value DSAR VRBA           0.033008
# Avg drop RSAM VRBA            0.032743
# Quantile Changes DSAR VRBA    0.032182
# Max drop RSAM VRBA            0.030054
# Std Value RSAM VRBA           0.029298
# Mean Min Values RSAM VRBA     0.026689
# Avg peak DSAR VRBA            0.026383
# Max drop DSAR VRBA            0.024352
# Avg drop DSAR VRBA            0.024064
# Avg h Width RSAM VRBA         0.022558
# Sum_tornillo                  0.022517
# Avg Drop Depth DSAR VRBA      0.022256
# Avg l Width RSAM VRBA         0.022160
# Avg peak RSAM VRBA            0.021526
# Std Value DSAR VRBA           0.021389
# Max Prominence RSAM VRBA      0.020620
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.57 ± 0.78
# Mean Magnitude (Missed - FN):   3.19 ± 0.54
# Low magnitude events were more detected
#  length of time array: 39
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 14 | Mean VORI RSAM Coverage: 85.29±36.15% | Mean VORI DSAR Coverage: 85.39±36.19% | Mean VRBA Coverage: 59.51±27.46%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 96.02±8.80% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 71.23±27.88%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 99.62±0.70% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 61.45±28.36%
# Both True Negatives (TN): 7 | Mean VORI RSAM Coverage: 99.86±0.24% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 90.31±13.02%
# VORI Detected Without VRBA (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 99.92+-0.06% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 67.37+-23.30%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 82.59+-24.56% | Mean VORI DSAR Coverage: 82.59+-24.56% | Mean VRBA Coverage: 63.24+-7.33%
# VRBA Detected Without VORI (TN): 2 | Mean VORI RSAM Coverage: 99.94+-0.02% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 99.95+-0.00%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 9 13]
#  [ 8 12]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.53      0.41      0.46        22
#            1       0.48      0.60      0.53        20
#
#     accuracy                           0.50        42
#    macro avg       0.50      0.50      0.50        42
# weighted avg       0.51      0.50      0.50        42
#
#
#  Top Features (VORI)
# Std Value RSAM VORI           0.093152
# Var Value RSAM VORI           0.073925
# Quantile Changes RSAM VORI    0.060561
# Avg peak DSAR VORI            0.041323
# Avg Drop Depth RSAM VORI      0.037510
# Avg Drop Depth DSAR VORI      0.033024
# Avg drop RSAM VORI            0.032736
# Quantile Changes DSAR VORI    0.031947
# Max h Width DSAR VORI         0.031790
# Max Drop Depth RSAM VORI      0.031199
# Max Prominence RSAM VORI      0.030973
# Max Prominence DSAR VORI      0.030638
# Median Value DSAR VORI        0.029485
# Avg peak RSAM VORI            0.028921
# Avg l Width RSAM VORI         0.028393
# Max drop DSAR VORI            0.028148
# Max peak DSAR VORI            0.027124
# Max l Width RSAM VORI         0.026699
# Avg Value DSAR VORI           0.025973
# Sum_Precipitations            0.023586
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.11 ± 1.06
# Mean Magnitude (Missed - FN):   3.04 ± 1.03
# High magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[12 10]
#  [ 7 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.63      0.55      0.59        22
#            1       0.57      0.65      0.60        20
#
#     accuracy                           0.60        42
#    macro avg       0.60      0.60      0.60        42
# weighted avg       0.60      0.60      0.59        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.120010
# Std Value DSAR VRBA           0.106473
# Var Value DSAR VRBA           0.065044
# Std Value RSAM VRBA           0.055341
# Avg peak DSAR VRBA            0.050316
# Avg Prominence DSAR VRBA      0.050111
# Mean Min Values RSAM VRBA     0.046067
# Max Prominence RSAM VRBA      0.042702
# Sum_LP                        0.036608
# Avg Prominence RSAM VRBA      0.035612
# Max_LP                        0.035381
# Var Value RSAM VRBA           0.034572
# Avg Value RSAM VRBA           0.034421
# Avg h Width DSAR VRBA         0.029278
# Max drop DSAR VRBA            0.028889
# Avg drop DSAR VRBA            0.027447
# Max h Width RSAM VRBA         0.026630
# Avg Value DSAR VRBA           0.025805
# Sum_Precipitations            0.021584
# Max drop RSAM VRBA            0.020713
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.17 ± 1.04
# Mean Magnitude (Missed - FN):   2.91 ± 1.05
# High magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 10 | Mean VORI RSAM Coverage: 81.88±30.49% | Mean VORI DSAR Coverage: 84.71±31.39% | Mean VRBA Coverage: 66.27±30.02%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 92.86±9.79% | Mean VORI DSAR Coverage: 99.95±0.01% | Mean VRBA Coverage: 64.46±48.22%
# Both False Positives (FP): 7 | Mean VORI RSAM Coverage: 80.56±37.78% | Mean VORI DSAR Coverage: 83.53±30.99% | Mean VRBA Coverage: 63.55±36.17%
# Both True Negatives (TN): 6 | Mean VORI RSAM Coverage: 99.92±0.05% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 74.20±29.24%
# VORI Detected Without VRBA (TP): 2 | Mean VORI RSAM Coverage: 99.91+-0.07% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 82.56+-24.59%
# VRBA Detected Without VORI (TP): 3 | Mean VORI RSAM Coverage: 99.84+-0.10% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 59.27+-17.94%
# VORI Detected Without VRBA (TN): 3 | Mean VORI RSAM Coverage: 98.85+-1.83% | Mean VORI DSAR Coverage: 98.88+-1.86% | Mean VRBA Coverage: 70.60+-25.64%
# VRBA Detected Without VORI (TN): 6 | Mean VORI RSAM Coverage: 99.10+-1.04% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 83.30+-17.93%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[12 10]
#  [12 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52        22
#            1       0.52      0.48      0.50        23
#
#     accuracy                           0.51        45
#    macro avg       0.51      0.51      0.51        45
# weighted avg       0.51      0.51      0.51        45
#
#
#  Top Features (VORI)
# Avg drop DSAR VORI              0.087670
# Mean Min Values DSAR VORI       0.082933
# Avg l Width RSAM VORI           0.082630
# Max drop RSAM VORI              0.068902
# Delta_Max_Min_Precipitations    0.061580
# Avg peak DSAR VORI              0.058897
# Avg Drop Depth RSAM VORI        0.056452
# Std Value RSAM VORI             0.052437
# Avg h Width RSAM VORI           0.047234
# Max Drop Depth DSAR VORI        0.042970
# Avg drop RSAM VORI              0.042482
# Max h Width RSAM VORI           0.039964
# Sum_Precipitations              0.038679
# Max peak RSAM VORI              0.037472
# Max peak DSAR VORI              0.030333
# Median Value RSAM VORI          0.029857
# Max h Width DSAR VORI           0.020346
# Max Drop Depth RSAM VORI        0.019409
# Max l Width RSAM VORI           0.017983
# Var Value RSAM VORI             0.016283
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.93 ± 0.86
# Mean Magnitude (Missed - FN):   2.66 ± 1.04
# High magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[14  8]
#  [10 13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61        22
#            1       0.62      0.57      0.59        23
#
#     accuracy                           0.60        45
#    macro avg       0.60      0.60      0.60        45
# weighted avg       0.60      0.60      0.60        45
#
#
#  Top Features (VRBA)
# Std Value DSAR VRBA             0.181501
# Quantile Changes DSAR VRBA      0.098467
# Avg Drop Depth DSAR VRBA        0.087960
# Std Value RSAM VRBA             0.084462
# Avg drop RSAM VRBA              0.061158
# Max peak DSAR VRBA              0.060253
# Median Value DSAR VRBA          0.058449
# Avg peak DSAR VRBA              0.044402
# Avg l Width RSAM VRBA           0.041845
# Avg Value DSAR VRBA             0.040610
# Max Drop Depth DSAR VRBA        0.039700
# Sum_VT                          0.037686
# Avg Prominence DSAR VRBA        0.028145
# Sum_tornillo                    0.023465
# Max_LP                          0.022360
# Delta_Max_Min_Precipitations    0.021950
# Quantile Changes RSAM VRBA      0.021759
# Var Value DSAR VRBA             0.021591
# Mean Min Values RSAM VRBA       0.013968
# Max Prominence RSAM VRBA        0.005885
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.78 ± 0.92
# Mean Magnitude (Missed - FN):   2.80 ± 1.02
# Low magnitude events were more detected
#  length of time array: 45
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 7 | Mean VORI RSAM Coverage: 99.92±0.05% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 66.59±25.99%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 96.67±8.03% | Mean VORI DSAR Coverage: 99.95±0.01% | Mean VRBA Coverage: 69.64±39.08%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 66.61±57.69% | Mean VORI DSAR Coverage: 73.20±46.34% | Mean VRBA Coverage: 85.32±25.46%
# Both True Negatives (TN): 7 | Mean VORI RSAM Coverage: 99.94±0.03% | Mean VORI DSAR Coverage: 99.96±0.01% | Mean VRBA Coverage: 89.84±18.11%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 68.59+-47.26% | Mean VORI DSAR Coverage: 68.62+-47.29% | Mean VRBA Coverage: 76.76+-18.38%
# VRBA Detected Without VORI (TP): 6 | Mean VORI RSAM Coverage: 97.33+-6.43% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 56.45+-25.96%
# VORI Detected Without VRBA (TN): 5 | Mean VORI RSAM Coverage: 99.85+-0.05% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 62.79+-39.80%
# VRBA Detected Without VORI (TN): 7 | Mean VORI RSAM Coverage: 84.59+-27.40% | Mean VORI DSAR Coverage: 86.88+-23.44% | Mean VRBA Coverage: 73.61+-36.35%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[13  9]
#  [ 9 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59        22
#            1       0.55      0.55      0.55        20
#
#     accuracy                           0.57        42
#    macro avg       0.57      0.57      0.57        42
# weighted avg       0.57      0.57      0.57        42
#
#
#  Top Features (VORI)
# Sum_Precipitations                 0.198454
# Quantile Changes RSAM VORI         0.113297
# Var Value RSAM VORI                0.085930
# Max peak RSAM VORI                 0.082641
# Std Value RSAM VORI                0.081887
# Sum_LP                             0.065574
# Avg Value RSAM VORI                0.065108
# Max l Width RSAM VORI              0.057865
# Avg Prominence RSAM VORI           0.054381
# Avg Prominence DSAR VORI           0.049115
# Max_Precipitations                 0.044104
# Max Prominence RSAM VORI           0.043260
# Avg l Width DSAR VORI              0.021613
# Sum_tornillo                       0.019640
# slope_ratio VORI                   0.008025
# num_state_changes_log_dsar VORI    0.005293
# Mean Min Values DSAR VORI          0.002342
# Last_LP                            0.001472
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.54 ± 0.67
# Mean Magnitude (Missed - FN):   2.63 ± 0.44
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[12 10]
#  [ 9 11]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.57      0.55      0.56        22
#            1       0.52      0.55      0.54        20
#
#     accuracy                           0.55        42
#    macro avg       0.55      0.55      0.55        42
# weighted avg       0.55      0.55      0.55        42
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.136034
# Avg l Width DSAR VRBA         0.129259
# Mean Min Values RSAM VRBA     0.077269
# Avg Prominence RSAM VRBA      0.048517
# Max l Width DSAR VRBA         0.047954
# Mean Min Values DSAR VRBA     0.047907
# Var Value DSAR VRBA           0.047407
# Avg Value DSAR VRBA           0.047024
# Std Value DSAR VRBA           0.043872
# slope_ratio VRBA              0.041252
# Avg Value RSAM VRBA           0.041032
# Last_LP                       0.038034
# Delta_Max_Min_LP              0.036199
# Avg Prominence DSAR VRBA      0.034292
# Max h Width RSAM VRBA         0.032240
# Median Value DSAR VRBA        0.029721
# Avg h Width RSAM VRBA         0.026748
# Avg Drop Depth RSAM VRBA      0.019777
# Max Drop Depth RSAM VRBA      0.014916
# Quantile Changes DSAR VRBA    0.011808
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.44 ± 0.57
# Mean Magnitude (Missed - FN):   2.76 ± 0.53
# Low magnitude events were more detected
#  length of time array: 42
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 7 | Mean VORI RSAM Coverage: 97.02±7.36% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 73.21±24.37%
# Both Missed (FN): 5 | Mean VORI RSAM Coverage: 99.94±0.03% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 71.13±28.06%
# Both False Positives (FP): 5 | Mean VORI RSAM Coverage: 99.75±0.32% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 78.22±25.79%
# Both True Negatives (TN): 8 | Mean VORI RSAM Coverage: 95.48±11.99% | Mean VORI DSAR Coverage: 95.78±11.80% | Mean VRBA Coverage: 75.50±26.71%
# VORI Detected Without VRBA (TP): 4 | Mean VORI RSAM Coverage: 77.33+-33.37% | Mean VORI DSAR Coverage: 83.40+-33.11% | Mean VRBA Coverage: 64.51+-47.31%
# VRBA Detected Without VORI (TP): 4 | Mean VORI RSAM Coverage: 80.28+-39.35% | Mean VORI DSAR Coverage: 86.23+-27.44% | Mean VRBA Coverage: 75.98+-17.85%
# VORI Detected Without VRBA (TN): 5 | Mean VORI RSAM Coverage: 99.93+-0.05% | Mean VORI DSAR Coverage: 99.96+-0.01% | Mean VRBA Coverage: 76.64+-19.18%
# VRBA Detected Without VORI (TN): 4 | Mean VORI RSAM Coverage: 99.47+-0.67% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 63.77+-4.19%

# %%
# Model Eruption Window (5 days) with feature selection
print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI, best_features_5days_VORI, X_Train_5_VORI, X_Test_5_VORI, Y_Train_5_VORI, Y_Test_5_VORI,
    best_5days_models_VRBA, best_features_5days_VRBA, X_Train_5_VRBA, X_Test_5_VRBA, Y_Train_5_VRBA, Y_Test_5_VRBA,
    train_test_years_splits,
    best_features='selected',
    five_days=True,
    time = time_Test,time_5days = time_5days_Test,
    coverage = coverage_Test, coverage_5days = coverage_5days_Test 
)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 87 109]
#  [ 11  24]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.44      0.59       196
#            1       0.18      0.69      0.29        35
#
#     accuracy                           0.48       231
#    macro avg       0.53      0.56      0.44       231
# weighted avg       0.78      0.48      0.55       231
#
#
#  Top Features (VORI)
# Sum_LP                        0.136751
# Max_LP                        0.095446
# Delta_Max_Min_LP              0.060472
# Quantile Changes RSAM VORI    0.050432
# Mean Min Values DSAR VORI     0.036912
# Mean Min Values RSAM VORI     0.036451
# Last_LP                       0.035285
# Max peak RSAM VORI            0.029263
# Avg drop DSAR VORI            0.028825
# Max drop DSAR VORI            0.028270
# season                        0.026553
# Sum_Precipitations            0.025507
# Median Value RSAM VORI        0.025427
# Var Value RSAM VORI           0.025185
# Max drop RSAM VORI            0.024879
# Avg drop RSAM VORI            0.024462
# Max_Precipitations            0.024375
# Avg Value RSAM VORI           0.024085
# Delta_Max_Min_tornillo        0.023585
# Max_tornillo                  0.023553
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.71
# Mean Magnitude (Missed - FN):   2.66 ± 0.92
# Low magnitude events were more detected
#  length of time array: 231
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 93 103]
#  [ 17  18]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.47      0.61       196
#            1       0.15      0.51      0.23        35
#
#     accuracy                           0.48       231
#    macro avg       0.50      0.49      0.42       231
# weighted avg       0.74      0.48      0.55       231
#
#
#  Top Features (VRBA)
# Sum_LP                        0.145300
# Max_LP                        0.077130
# Quantile Changes RSAM VRBA    0.076301
# Delta_Max_Min_LP              0.064738
# Median Value DSAR VRBA        0.040558
# Quantile Changes DSAR VRBA    0.036386
# Mean Min Values RSAM VRBA     0.035675
# Mean Min Values DSAR VRBA     0.031846
# Var Value DSAR VRBA           0.030434
# Last_LP                       0.030392
# Max peak RSAM VRBA            0.028821
# Std Value DSAR VRBA           0.027713
# Avg peak DSAR VRBA            0.026919
# Max peak DSAR VRBA            0.026450
# Avg Value DSAR VRBA           0.025675
# Avg peak RSAM VRBA            0.023090
# Var Value RSAM VRBA           0.021761
# Avg Value RSAM VRBA           0.021597
# Max Drop Depth DSAR VRBA      0.020245
# Delta_Max_Min_tornillo        0.020202
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.63
# Mean Magnitude (Missed - FN):   2.62 ± 0.91
# Low magnitude events were more detected
#  length of time array: 231
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 18 | Mean VORI RSAM Coverage: 94.62±19.27% | Mean VORI DSAR Coverage: 97.82±9.02% | Mean VRBA Coverage: 54.14±29.51%
# Both Missed (FN): 11 | Mean VORI RSAM Coverage: 92.89±15.64% | Mean VORI DSAR Coverage: 93.62±15.04% | Mean VRBA Coverage: 62.39±38.97%
# Both False Positives (FP): 87 | Mean VORI RSAM Coverage: 99.11±2.65% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 90.16±14.79%
# Both True Negatives (TN): 71 | Mean VORI RSAM Coverage: 99.88±0.27% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 92.83±13.18%
# VORI Detected Without VRBA (TP): 6 | Mean VORI RSAM Coverage: 75.43+-37.61% | Mean VORI DSAR Coverage: 87.19+-19.76% | Mean VRBA Coverage: 57.62+-45.74%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 16 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 83.20+-20.58%
# VRBA Detected Without VORI (TN): 22 | Mean VORI RSAM Coverage: 99.18+-1.91% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 96.46+-6.98%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 39  13]
#  [112  56]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.26      0.75      0.38        52
#            1       0.81      0.33      0.47       168
#
#     accuracy                           0.43       220
#    macro avg       0.53      0.54      0.43       220
# weighted avg       0.68      0.43      0.45       220
#
#
#  Top Features (VORI)
# Sum_LP                        0.103284
# Mean Min Values DSAR VORI     0.054529
# Max_tornillo                  0.053362
# Max_LP                        0.052517
# Max drop DSAR VORI            0.052266
# Avg drop DSAR VORI            0.049962
# Delta_Max_Min_tornillo        0.042756
# Delta_Max_Min_LP              0.037762
# Median Value DSAR VORI        0.037475
# Quantile Changes RSAM VORI    0.036901
# Max peak DSAR VORI            0.036110
# Sum_tornillo                  0.034404
# Avg peak DSAR VORI            0.031513
# Std Value RSAM VORI           0.031141
# Var Value RSAM VORI           0.030148
# Max peak RSAM VORI            0.029888
# Avg peak RSAM VORI            0.029324
# Avg Value RSAM VORI           0.026511
# Mean Min Values RSAM VORI     0.025089
# Median Value RSAM VORI        0.023799
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.41 ± 0.76
# Mean Magnitude (Missed - FN):   3.26 ± 0.69
# High magnitude events were more detected
#  length of time array: 220
# Detected Lahars (TP): 1 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2020-01-30 18:13:42.427
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 45   7]
#  [ 61 107]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.42      0.87      0.57        52
#            1       0.94      0.64      0.76       168
#
#     accuracy                           0.69       220
#    macro avg       0.68      0.75      0.66       220
# weighted avg       0.82      0.69      0.71       220
#
#
#  Top Features (VRBA)
# Sum_LP                        0.172825
# Quantile Changes RSAM VRBA    0.102435
# Median Value DSAR VRBA        0.093221
# Quantile Changes DSAR VRBA    0.088647
# Std Value DSAR VRBA           0.078539
# Var Value DSAR VRBA           0.071286
# Max_LP                        0.038012
# Avg peak DSAR VRBA            0.033303
# Max drop RSAM VRBA            0.032430
# Mean Min Values RSAM VRBA     0.030748
# Max_tornillo                  0.030464
# Avg Value DSAR VRBA           0.028680
# Max peak RSAM VRBA            0.027638
# Delta_Max_Min_tornillo        0.026461
# Avg drop RSAM VRBA            0.025942
# Delta_Max_Min_LP              0.025027
# Mean Min Values DSAR VRBA     0.024709
# Avg Value RSAM VRBA           0.024674
# Avg peak RSAM VRBA            0.024277
# Sum_tornillo                  0.020682
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.30 ± 0.76
# Mean Magnitude (Missed - FN):   3.33 ± 0.63
# Low magnitude events were more detected
#  length of time array: 220
# Detected Lahars (TP): 2 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2020-01-30 18:13:42.427
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 44 | Mean VORI RSAM Coverage: 93.36±13.38% | Mean VORI DSAR Coverage: 99.25±3.23% | Mean VRBA Coverage: 92.05±10.29%
# Both Missed (FN): 49 | Mean VORI RSAM Coverage: 91.96±12.88% | Mean VORI DSAR Coverage: 95.72±12.99% | Mean VRBA Coverage: 91.27±17.08%
# Both False Positives (FP): 2 | Mean VORI RSAM Coverage: 99.87±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 99.94±0.00%
# Both True Negatives (TN): 34 | Mean VORI RSAM Coverage: 85.58±30.65% | Mean VORI DSAR Coverage: 90.77±22.73% | Mean VRBA Coverage: 97.48±7.54%
# VORI Detected Without VRBA (TP): 12 | Mean VORI RSAM Coverage: 97.86+-4.96% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 97.60+-2.78%
# VRBA Detected Without VORI (TP): 63 | Mean VORI RSAM Coverage: 98.07+-4.90% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 94.40+-10.86%
# VORI Detected Without VRBA (TN): 5 | Mean VORI RSAM Coverage: 99.81+-0.14% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 99.94+-0.00%
# VRBA Detected Without VORI (TN): 11 | Mean VORI RSAM Coverage: 99.76+-0.18% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 82.56+-23.70%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 58 136]
#  [  8  17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.30      0.45       194
#            1       0.11      0.68      0.19        25
#
#     accuracy                           0.34       219
#    macro avg       0.49      0.49      0.32       219
# weighted avg       0.79      0.34      0.42       219
#
#
#  Top Features (VORI)
# Max drop DSAR VORI            0.079132
# Median Value DSAR VORI        0.075282
# Avg drop DSAR VORI            0.068890
# Mean Min Values DSAR VORI     0.068601
# Avg peak DSAR VORI            0.057364
# Max_Precipitations            0.056157
# Sum_LP                        0.055887
# Sum_Precipitations            0.043692
# Max_tornillo                  0.041943
# Quantile Changes DSAR VORI    0.039504
# Std Value DSAR VORI           0.039433
# Var Value DSAR VORI           0.038347
# Quantile Changes RSAM VORI    0.031120
# Sum_VT                        0.030685
# Avg Value RSAM VORI           0.029431
# Std Value RSAM VORI           0.028576
# Delta_Max_Min_tornillo        0.028493
# Max Drop Depth RSAM VORI      0.022632
# Max Prominence RSAM VORI      0.021948
# Median Value RSAM VORI        0.018887
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.95 ± 0.99
# Mean Magnitude (Missed - FN):   3.09 ± 0.72
# Low magnitude events were more detected
#  length of time array: 219
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 78 116]
#  [  8  17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.91      0.40      0.56       194
#            1       0.13      0.68      0.22        25
#
#     accuracy                           0.43       219
#    macro avg       0.52      0.54      0.39       219
# weighted avg       0.82      0.43      0.52       219
#
#
#  Top Features (VRBA)
# Max peak DSAR VRBA            0.169415
# Avg peak DSAR VRBA            0.141252
# Median Value DSAR VRBA        0.123168
# Avg Value DSAR VRBA           0.108616
# Quantile Changes DSAR VRBA    0.080983
# Max_LP                        0.048159
# Mean Min Values RSAM VRBA     0.045645
# Sum_LP                        0.042920
# Var Value DSAR VRBA           0.039210
# Std Value DSAR VRBA           0.035888
# Quantile Changes RSAM VRBA    0.029263
# Delta_Max_Min_LP              0.025410
# Avg drop DSAR VRBA            0.022147
# Max drop DSAR VRBA            0.019355
# Std peak RSAM VRBA            0.016361
# Avg drop RSAM VRBA            0.014401
# Max_Precipitations            0.014051
# Max Drop Depth DSAR VRBA      0.010981
# Avg Drop Depth DSAR VRBA      0.007996
# Avg Value RSAM VRBA           0.004780
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.93 ± 0.78
# Mean Magnitude (Missed - FN):   3.14 ± 1.17
# Low magnitude events were more detected
#  length of time array: 219
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 12 | Mean VORI RSAM Coverage: 97.87±3.49% | Mean VORI DSAR Coverage: 98.69±2.95% | Mean VRBA Coverage: 70.54±15.82%
# Both Missed (FN): 3 | Mean VORI RSAM Coverage: 65.28±30.02% | Mean VORI DSAR Coverage: 65.28±30.02% | Mean VRBA Coverage: 31.43±54.44%
# Both False Positives (FP): 92 | Mean VORI RSAM Coverage: 85.58±28.71% | Mean VORI DSAR Coverage: 90.64±23.78% | Mean VRBA Coverage: 76.49±29.17%
# Both True Negatives (TN): 34 | Mean VORI RSAM Coverage: 93.30±16.71% | Mean VORI DSAR Coverage: 96.77±10.61% | Mean VRBA Coverage: 73.67±23.90%
# VORI Detected Without VRBA (TP): 5 | Mean VORI RSAM Coverage: 85.49+-14.23% | Mean VORI DSAR Coverage: 90.16+-14.01% | Mean VRBA Coverage: 42.11+-30.74%
# VRBA Detected Without VORI (TP): 5 | Mean VORI RSAM Coverage: 99.93+-0.02% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 83.76+-22.26%
# VORI Detected Without VRBA (TN): 24 | Mean VORI RSAM Coverage: 99.88+-0.03% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 75.71+-21.08%
# VRBA Detected Without VORI (TN): 44 | Mean VORI RSAM Coverage: 90.58+-22.98% | Mean VORI DSAR Coverage: 94.80+-21.22% | Mean VRBA Coverage: 70.80+-24.05%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 20  24]
#  [ 63 187]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.24      0.45      0.31        44
#            1       0.89      0.75      0.81       250
#
#     accuracy                           0.70       294
#    macro avg       0.56      0.60      0.56       294
# weighted avg       0.79      0.70      0.74       294
#
#
#  Top Features (VORI)
# Sum_LP                        0.103076
# Mean Min Values DSAR VORI     0.068384
# Max_LP                        0.053805
# Max drop DSAR VORI            0.051890
# Avg drop DSAR VORI            0.048938
# Quantile Changes RSAM VORI    0.047692
# Delta_Max_Min_LP              0.036266
# Median Value DSAR VORI        0.033486
# Avg peak DSAR VORI            0.031534
# Max_Precipitations            0.030778
# Std Value DSAR VORI           0.030118
# Max peak DSAR VORI            0.028515
# Max peak RSAM VORI            0.028006
# Quantile Changes DSAR VORI    0.027010
# Mean Min Values RSAM VORI     0.026445
# Sum_Precipitations            0.026147
# Sum_VT                        0.026123
# Var Value DSAR VORI           0.025792
# Avg Value DSAR VORI           0.025238
# Avg peak RSAM VORI            0.024522
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.72 ± 0.60
# Mean Magnitude (Missed - FN):   3.17 ± 0.64
# Low magnitude events were more detected
#  length of time array: 294
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 31  13]
#  [ 58 192]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.35      0.70      0.47        44
#            1       0.94      0.77      0.84       250
#
#     accuracy                           0.76       294
#    macro avg       0.64      0.74      0.66       294
# weighted avg       0.85      0.76      0.79       294
#
#
#  Top Features (VRBA)
# Sum_LP                        0.112524
# Quantile Changes RSAM VRBA    0.095141
# Median Value DSAR VRBA        0.077438
# Avg Value DSAR VRBA           0.063098
# Max peak DSAR VRBA            0.054551
# Quantile Changes DSAR VRBA    0.053494
# Max_LP                        0.051608
# Avg peak DSAR VRBA            0.045762
# Var Value DSAR VRBA           0.040206
# Std Value DSAR VRBA           0.034749
# Delta_Max_Min_LP              0.032661
# Mean Min Values RSAM VRBA     0.028883
# Sum_VT                        0.028187
# Mean Min Values DSAR VRBA     0.028150
# Avg Value RSAM VRBA           0.026333
# Max drop RSAM VRBA            0.024342
# Max peak RSAM VRBA            0.021369
# Std Value RSAM VRBA           0.020526
# Var Value RSAM VRBA           0.020466
# Median Value RSAM VRBA        0.020316
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.80 ± 0.63
# Mean Magnitude (Missed - FN):   2.95 ± 0.67
# Low magnitude events were more detected
#  length of time array: 294
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 154 | Mean VORI RSAM Coverage: 97.68±5.06% | Mean VORI DSAR Coverage: 99.58±1.48% | Mean VRBA Coverage: 67.10±20.39%
# Both Missed (FN): 25 | Mean VORI RSAM Coverage: 96.59±16.56% | Mean VORI DSAR Coverage: 96.63±16.57% | Mean VRBA Coverage: 64.77±24.13%
# Both False Positives (FP): 8 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 41.12±23.74%
# Both True Negatives (TN): 15 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 53.03±13.82%
# VORI Detected Without VRBA (TP): 33 | Mean VORI RSAM Coverage: 98.55+-3.43% | Mean VORI DSAR Coverage: 98.57+-3.42% | Mean VRBA Coverage: 58.86+-17.76%
# VRBA Detected Without VORI (TP): 38 | Mean VORI RSAM Coverage: 96.96+-10.16% | Mean VORI DSAR Coverage: 97.02+-10.18% | Mean VRBA Coverage: 55.52+-10.77%
# VORI Detected Without VRBA (TN): 5 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 45.61+-25.51%
# VRBA Detected Without VORI (TN): 16 | Mean VORI RSAM Coverage: 99.54+-1.63% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 37.86+-21.85%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[  2   6]
#  [ 83 311]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.02      0.25      0.04         8
#            1       0.98      0.79      0.87       394
#
#     accuracy                           0.78       402
#    macro avg       0.50      0.52      0.46       402
# weighted avg       0.96      0.78      0.86       402
#
#
#  Top Features (VORI)
# Max_Precipitations              0.055879
# Quantile Changes RSAM VORI      0.052087
# Max_tornillo                    0.044701
# Delta_Max_Min_Precipitations    0.044336
# Sum_LP                          0.042476
# Sum_Precipitations              0.041739
# Mean Min Values RSAM VORI       0.041487
# Delta_Max_Min_tornillo          0.040636
# Sum_tornillo                    0.031559
# Avg Value DSAR VORI             0.031468
# Quantile Changes DSAR VORI      0.030099
# Avg drop DSAR VORI              0.028535
# Delta_Max_Min_LP                0.028468
# Avg drop RSAM VORI              0.028082
# Max_LP                          0.027819
# Var Value RSAM VORI             0.026961
# Std Value RSAM VORI             0.026738
# Avg Value RSAM VORI             0.026733
# Mean Min Values DSAR VORI       0.026366
# Var Value DSAR VORI             0.026312
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.78 ± 0.72
# Mean Magnitude (Missed - FN):   2.84 ± 0.63
# Low magnitude events were more detected
#  length of time array: 402
# Detected Lahars (TP): 7 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# Detected Lahar Event - Magnitude: 5.20, Time: 2023-04-21 21:50:10.251
# Detected Lahar Event - Magnitude: 4.79, Time: 2023-05-14 08:58:05.785
# Detected Lahar Event - Magnitude: 4.98, Time: 2023-05-25 20:35:31.649
# Detected Lahar Event - Magnitude: 5.11, Time: 2023-05-28 03:34:53.507
# Detected Lahar Event - Magnitude: 4.74, Time: 2023-05-29 08:44:09.899
# Detected Lahar Event - Magnitude: 4.40, Time: 2023-11-05 21:17:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.97, Time: 2023-04-14 15:35:36.445
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[  5   3]
#  [ 36 358]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.12      0.62      0.20         8
#            1       0.99      0.91      0.95       394
#
#     accuracy                           0.90       402
#    macro avg       0.56      0.77      0.58       402
# weighted avg       0.97      0.90      0.93       402
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.171730
# Median Value DSAR VRBA        0.090032
# Sum_LP                        0.073836
# Quantile Changes DSAR VRBA    0.064276
# Mean Min Values RSAM VRBA     0.062195
# Mean Min Values DSAR VRBA     0.050115
# Avg peak DSAR VRBA            0.031777
# Sum_tornillo                  0.030948
# Max drop DSAR VRBA            0.029977
# Delta_Max_Min_LP              0.027794
# Max drop RSAM VRBA            0.027633
# Avg drop RSAM VRBA            0.025794
# Sum_VT                        0.025627
# Sum_Precipitations            0.023816
# Max_tornillo                  0.023704
# Max_Precipitations            0.022613
# Max_LP                        0.022420
# Std Value DSAR VRBA           0.020676
# Avg Value RSAM VRBA           0.020218
# Avg Value DSAR VRBA           0.019334
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.81 ± 0.71
# Mean Magnitude (Missed - FN):   2.67 ± 0.65
# High magnitude events were more detected
#  length of time array: 402
# Detected Lahars (TP): 7 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.97, Time: 2023-04-14 15:35:36.445
# Detected Lahar Event - Magnitude: 5.20, Time: 2023-04-21 21:50:10.251
# Detected Lahar Event - Magnitude: 4.79, Time: 2023-05-14 08:58:05.785
# Detected Lahar Event - Magnitude: 4.98, Time: 2023-05-25 20:35:31.649
# Detected Lahar Event - Magnitude: 5.11, Time: 2023-05-28 03:34:53.507
# Detected Lahar Event - Magnitude: 4.74, Time: 2023-05-29 08:44:09.899
# Detected Lahar Event - Magnitude: 4.40, Time: 2023-11-05 21:17:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 286 | Mean VORI RSAM Coverage: 92.19±17.80% | Mean VORI DSAR Coverage: 95.56±14.86% | Mean VRBA Coverage: 72.98±10.90%
# Both Missed (FN): 11 | Mean VORI RSAM Coverage: 68.63±37.65% | Mean VORI DSAR Coverage: 72.76±34.55% | Mean VRBA Coverage: 63.54±27.48%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.79±0.04% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 69.07±2.63%
# Both True Negatives (TN): 2 | Mean VORI RSAM Coverage: 98.97±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 69.87±3.92%
# VORI Detected Without VRBA (TP): 25 | Mean VORI RSAM Coverage: 92.75+-15.08% | Mean VORI DSAR Coverage: 94.87+-12.47% | Mean VRBA Coverage: 82.07+-9.84%
# VRBA Detected Without VORI (TP): 72 | Mean VORI RSAM Coverage: 88.95+-24.60% | Mean VORI DSAR Coverage: 91.17+-24.10% | Mean VRBA Coverage: 67.49+-16.42%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 99.26+-0.53% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 74.03+-7.37%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[27 17]
#  [40 59]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.40      0.61      0.49        44
#            1       0.78      0.60      0.67        99
#
#     accuracy                           0.60       143
#    macro avg       0.59      0.60      0.58       143
# weighted avg       0.66      0.60      0.62       143
#
#
#  Top Features (VORI)
# Sum_LP                          0.182327
# Max drop DSAR VORI              0.106490
# Quantile Changes RSAM VORI      0.103737
# Mean Min Values RSAM VORI       0.066555
# Max_LP                          0.064063
# Mean Min Values DSAR VORI       0.059937
# Max_tornillo                    0.047054
# Quantile Changes DSAR VORI      0.044847
# Max peak RSAM VORI              0.041500
# Sum_Precipitations              0.038691
# Delta_Max_Min_Precipitations    0.035874
# Avg peak RSAM VORI              0.035824
# Std Value RSAM VORI             0.034131
# Avg Prominence RSAM VORI        0.030980
# Delta_Max_Min_tornillo          0.027095
# Std Value DSAR VORI             0.020183
# Avg drop DSAR VORI              0.019965
# Var Value DSAR VORI             0.018648
# Sum_tornillo                    0.013837
# Delta_Max_Min_LP                0.008263
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.17 ± 0.54
# Mean Magnitude (Missed - FN):   2.11 ± 0.47
# High magnitude events were more detected
#  length of time array: 143
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[11 33]
#  [20 79]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.35      0.25      0.29        44
#            1       0.71      0.80      0.75        99
#
#     accuracy                           0.63       143
#    macro avg       0.53      0.52      0.52       143
# weighted avg       0.60      0.63      0.61       143
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.158934
# Quantile Changes RSAM VRBA    0.128442
# Sum_LP                        0.074288
# Avg Value DSAR VRBA           0.071077
# Std Value DSAR VRBA           0.064788
# Delta_Max_Min_LP              0.046899
# Quantile Changes DSAR VRBA    0.040128
# Max drop DSAR VRBA            0.039346
# season                        0.033056
# Mean Min Values RSAM VRBA     0.030549
# Mean Min Values DSAR VRBA     0.029901
# Max_LP                        0.026312
# Avg Value RSAM VRBA           0.026043
# Max_Precipitations            0.023765
# Avg peak RSAM VRBA            0.023133
# Sum_Precipitations            0.021197
# Avg drop RSAM VRBA            0.021133
# Var Value RSAM VRBA           0.021076
# Median Value RSAM VRBA        0.019535
# Avg Drop Depth DSAR VRBA      0.018116
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.15 ± 0.51
# Mean Magnitude (Missed - FN):   2.12 ± 0.56
# High magnitude events were more detected
#  length of time array: 143
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 51 | Mean VORI RSAM Coverage: 67.79±37.97% | Mean VORI DSAR Coverage: 67.79±37.97% | Mean VRBA Coverage: 59.66±11.76%
# Both Missed (FN): 12 | Mean VORI RSAM Coverage: 30.60±39.79% | Mean VORI DSAR Coverage: 30.60±39.79% | Mean VRBA Coverage: 47.15±20.09%
# Both False Positives (FP): 15 | Mean VORI RSAM Coverage: 84.88±13.63% | Mean VORI DSAR Coverage: 84.89±13.64% | Mean VRBA Coverage: 55.21±3.88%
# Both True Negatives (TN): 9 | Mean VORI RSAM Coverage: 67.70±21.92% | Mean VORI DSAR Coverage: 67.70±21.92% | Mean VRBA Coverage: 53.78±2.72%
# VORI Detected Without VRBA (TP): 8 | Mean VORI RSAM Coverage: 33.66+-39.56% | Mean VORI DSAR Coverage: 34.74+-40.89% | Mean VRBA Coverage: 51.03+-25.20%
# VRBA Detected Without VORI (TP): 28 | Mean VORI RSAM Coverage: 67.15+-40.98% | Mean VORI DSAR Coverage: 67.15+-40.98% | Mean VRBA Coverage: 54.09+-12.56%
# VORI Detected Without VRBA (TN): 18 | Mean VORI RSAM Coverage: 65.61+-16.87% | Mean VORI DSAR Coverage: 65.61+-16.86% | Mean VRBA Coverage: 53.74+-2.40%
# VRBA Detected Without VORI (TN): 2 | Mean VORI RSAM Coverage: 69.07+-10.88% | Mean VORI DSAR Coverage: 69.07+-10.88% | Mean VRBA Coverage: 53.81+-0.15%

# %% [markdown]
# ### Correlation

# %%
best_models_VORI_corr, best_5days_models_VORI_corr, best_models_VRBA_corr, best_5days_models_VRBA_corr = train_and_optimize_rf_models(
    train_test_years_splits=train_test_years_splits,
    x_train_VORI=X_Train_VORI_cleaned, y_train_VORI=Y_Train_VORI, 
    x_train_5_VORI=X_Train_5_VORI_cleaned, y_train_5_VORI=Y_Train_5_VORI,
    x_train_VRBA=X_Train_VRBA_cleaned, y_train_VRBA=Y_Train_VRBA, 
    x_train_5_VRBA=X_Train_5_VRBA_cleaned, y_train_5_VRBA=Y_Train_5_VRBA,
    n_iter_search=200 
)
best_features_VORI_corr, best_features_VRBA_corr = select_important_features({}, {}, best_models_VORI_corr, best_models_VRBA_corr, X_Train_VORI_cleaned, X_Train_VRBA_cleaned)
best_features_5days_VORI_corr, best_features_5days_VRBA_corr = select_important_features({}, {}, best_5days_models_VORI_corr, best_5days_models_VRBA_corr, X_Train_5_VORI_cleaned, X_Train_5_VRBA_cleaned)
# Out:
# Optimizing Random Forest for test year: 2019
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2019): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2019): {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2019): {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 5, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2019): {'n_estimators': 10, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 0.5, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
#
# Optimizing Random Forest for test year: 2020
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2020): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2020): {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2020): {'n_estimators': 50, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 'log2', 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2020): {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
#
# Optimizing Random Forest for test year: 2021
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2021): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2021): {'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2021): {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 5, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2021): {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 3, 'class_weight': 'balanced_subsample', 'bootstrap': False}
#
# Optimizing Random Forest for test year: 2022
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2022): {'n_estimators': 100, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2022): {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2022): {'n_estimators': 50, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2022): {'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': True}
#
# Optimizing Random Forest for test year: 2023
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2023): {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 0.8, 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2023): {'n_estimators': 10, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 3, 'class_weight': 'balanced', 'bootstrap': True}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2023): {'n_estimators': 50, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.8, 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2023): {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.5, 'max_depth': 7, 'class_weight': 'balanced', 'bootstrap': False}
#
# Optimizing Random Forest for test year: 2024
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 3 days (test year 2024): {'n_estimators': 50, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 'log2', 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VORI 5 days (test year 2024): {'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 3 days (test year 2024): {'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.8, 'max_depth': 10, 'class_weight': 'balanced_subsample', 'bootstrap': False}
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for VRBA 5 days (test year 2024): {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.8, 'max_depth': 7, 'class_weight': 'balanced_subsample', 'bootstrap': True}
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2019
# ==================================================
#
# [ STATION VORI ]
# Features kept: 19 out of 50
# Top selected features:
# Sum_LP                          0.107178
# Var Value RSAM VORI             0.058558
# slope_ratio VORI                0.056937
# Sum_Precipitations              0.049770
# Avg Prominence RSAM VORI        0.044549
# Avg l Width RSAM VORI           0.039376
# Max drop DSAR VORI              0.039010
# Avg Drop Depth RSAM VORI        0.036214
# Sum_tornillo                    0.036049
# Avg Value DSAR VORI             0.035650
# Mean Min Values RSAM VORI       0.034969
# Quantile Changes DSAR VORI      0.034643
# Delta_Max_Min_Precipitations    0.034569
# Avg h Width DSAR VORI           0.033385
# Quantile Changes RSAM VORI      0.033094
# Avg peak RSAM VORI              0.031936
# Max peak DSAR VORI              0.030428
# Std drop DSAR VORI              0.029950
# Max l Width DSAR VORI           0.025330
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 18 out of 43
# Top selected features:
# Max Drop Depth RSAM VRBA        0.099160
# Quantile Changes RSAM VRBA      0.093641
# Avg Prominence RSAM VRBA        0.083092
# Sum_LP                          0.075106
# Mean Min Values RSAM VRBA       0.064578
# Max Prominence DSAR VRBA        0.062339
# Mean Min Values DSAR VRBA       0.044764
# Var Value DSAR VRBA             0.039855
# Sum_tornillo                    0.035340
# Last_Precipitations             0.034494
# Max Drop Depth DSAR VRBA        0.034061
# Max l Width RSAM VRBA           0.032151
# Max l Width DSAR VRBA           0.031178
# Sum_Precipitations              0.030732
# Max h Width RSAM VRBA           0.029650
# Max h Width DSAR VRBA           0.029557
# slope_ratio VRBA                0.029035
# Delta_Max_Min_Precipitations    0.027824
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2020
# ==================================================
#
# [ STATION VORI ]
# Features kept: 18 out of 48
# Top selected features:
# Avg l Width RSAM VORI              0.092974
# Quantile Changes DSAR VORI         0.080953
# Var Value RSAM VORI                0.066775
# Median Value DSAR VORI             0.066645
# Max Prominence RSAM VORI           0.057163
# slope_ratio VORI                   0.051406
# Avg peak RSAM VORI                 0.044505
# Max Drop Depth DSAR VORI           0.043177
# Avg Prominence DSAR VORI           0.035597
# Delta_Max_Min_VT                   0.032716
# Last_Precipitations                0.030491
# Avg l Width DSAR VORI              0.029784
# num_state_changes_log_dsar VORI    0.029346
# Avg Drop Depth RSAM VORI           0.029324
# Median Value RSAM VORI             0.025804
# num_state_changes_inv_rsam VORI    0.023964
# Max_tornillo                       0.023233
# Max drop RSAM VORI                 0.020992
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 21 out of 48
# Top selected features:
# Quantile Changes RSAM VRBA         0.110330
# Std Value DSAR VRBA                0.110225
# Median Value DSAR VRBA             0.069109
# slope_ratio VRBA                   0.053290
# Sum_Precipitations                 0.052860
# Max Drop Depth DSAR VRBA           0.051531
# Mean Min Values RSAM VRBA          0.049374
# Avg drop DSAR VRBA                 0.046388
# Avg Value RSAM VRBA                0.043679
# Delta_Max_Min_Precipitations       0.033722
# Max drop RSAM VRBA                 0.033586
# Sum_tornillo                       0.032511
# Avg Prominence RSAM VRBA           0.031839
# Max Prominence DSAR VRBA           0.030422
# Avg Drop Depth RSAM VRBA           0.028272
# Max h Width DSAR VRBA              0.027658
# Sum_LP                             0.026332
# Avg l Width RSAM VRBA              0.025398
# num_state_changes_inv_rsam VRBA    0.023555
# Last_Precipitations                0.022406
# Max l Width DSAR VRBA              0.021635
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2021
# ==================================================
#
# [ STATION VORI ]
# Features kept: 14 out of 48
# Top selected features:
# Mean Min Values DSAR VORI     0.164174
# Quantile Changes RSAM VORI    0.064265
# Max l Width RSAM VORI         0.063821
# Avg Prominence RSAM VORI      0.056037
# slope_ratio VORI              0.051540
# Last_Precipitations           0.046397
# Avg drop RSAM VORI            0.041060
# Max Drop Depth RSAM VORI      0.038122
# Var Value RSAM VORI           0.037489
# Avg peak DSAR VORI            0.035141
# Delta_Max_Min_tornillo        0.034919
# Sum_Precipitations            0.034708
# Avg h Width RSAM VORI         0.033198
# Std drop DSAR VORI            0.032540
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 20 out of 45
# Top selected features:
# Median Value DSAR VRBA          0.129777
# Max Prominence RSAM VRBA        0.081288
# Quantile Changes RSAM VRBA      0.078914
# Quantile Changes DSAR VRBA      0.053110
# Max l Width RSAM VRBA           0.048998
# Var Value RSAM VRBA             0.048764
# Max Prominence DSAR VRBA        0.045976
# Avg Drop Depth DSAR VRBA        0.041418
# Max l Width DSAR VRBA           0.040699
# Sum_VT                          0.033792
# Max Drop Depth RSAM VRBA        0.033146
# slope_ratio VRBA                0.032338
# Sum_tornillo                    0.031469
# Max h Width RSAM VRBA           0.030856
# Sum_Precipitations              0.030665
# Sum_LP                          0.030632
# Delta_Max_Min_Precipitations    0.029449
# Last_Precipitations             0.028274
# Last_tornillo                   0.027727
# Avg h Width DSAR VRBA           0.025012
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2022
# ==================================================
#
# [ STATION VORI ]
# Features kept: 21 out of 49
# Top selected features:
# Sum_LP                          0.084890
# Mean Min Values DSAR VORI       0.078158
# Var Value RSAM VORI             0.069683
# Avg l Width RSAM VORI           0.069044
# Avg Drop Depth RSAM VORI        0.052853
# Max peak DSAR VORI              0.050771
# Max drop RSAM VORI              0.046322
# Sum_Precipitations              0.042310
# Avg Drop Depth DSAR VORI        0.038138
# Avg peak RSAM VORI              0.036514
# Median Value RSAM VORI          0.033884
# Sum_VT                          0.033385
# Avg h Width DSAR VORI           0.033210
# slope_ratio VORI                0.031501
# Quantile Changes DSAR VORI      0.029823
# Delta_Max_Min_Precipitations    0.025439
# Max Prominence RSAM VORI        0.024855
# Avg Prominence DSAR VORI        0.024332
# Last_Precipitations             0.024022
# Avg h Width RSAM VORI           0.023651
# Avg l Width DSAR VORI           0.023450
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 17 out of 45
# Top selected features:
# Quantile Changes RSAM VRBA    0.097183
# Max peak DSAR VRBA            0.086736
# Max Prominence RSAM VRBA      0.070271
# Quantile Changes DSAR VRBA    0.062424
# Max_LP                        0.056084
# Var Value RSAM VRBA           0.053427
# Max Drop Depth RSAM VRBA      0.046079
# slope_ratio VRBA              0.043926
# Avg Drop Depth DSAR VRBA      0.042673
# Max h Width DSAR VRBA         0.041793
# Mean Min Values DSAR VRBA     0.041166
# Sum_VT                        0.034794
# Max l Width DSAR VRBA         0.034649
# Avg h Width RSAM VRBA         0.030718
# Sum_Precipitations            0.027246
# Avg Prominence DSAR VRBA      0.027046
# Sum_tornillo                  0.023050
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2023
# ==================================================
#
# [ STATION VORI ]
# Features kept: 19 out of 51
# Top selected features:
# Max l Width RSAM VORI         0.133500
# Avg drop RSAM VORI            0.089452
# Mean Min Values DSAR VORI     0.085155
# Std Value RSAM VORI           0.063388
# Avg Drop Depth RSAM VORI      0.045420
# Max_Precipitations            0.041894
# Quantile Changes DSAR VORI    0.036625
# Avg Prominence RSAM VORI      0.034745
# Avg peak DSAR VORI            0.034630
# Median Value RSAM VORI        0.034247
# Avg Drop Depth DSAR VORI      0.032261
# Avg Value DSAR VORI           0.031705
# slope_ratio VORI              0.030835
# Delta_Max_Min_tornillo        0.028241
# Last_Precipitations           0.027406
# Sum_VT                        0.023383
# Max Prominence DSAR VORI      0.022045
# Sum_LP                        0.021925
# Max l Width DSAR VORI         0.020444
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 11 out of 51
# Top selected features:
# Var Value DSAR VRBA             0.213557
# Quantile Changes RSAM VRBA      0.132835
# Mean Min Values RSAM VRBA       0.114930
# Sum_Precipitations              0.097353
# Delta_Max_Min_Precipitations    0.078147
# season                          0.068451
# Avg Prominence DSAR VRBA        0.038309
# Avg Drop Depth DSAR VRBA        0.037663
# slope_ratio VRBA                0.034563
# Avg Drop Depth RSAM VRBA        0.030672
# Avg Value RSAM VRBA             0.020420
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2024
# ==================================================
#
# [ STATION VORI ]
# Features kept: 20 out of 49
# Top selected features:
# Std Value RSAM VORI             0.102108
# Quantile Changes RSAM VORI      0.091819
# Max l Width RSAM VORI           0.065353
# Sum_tornillo                    0.057678
# Sum_Precipitations              0.051840
# Mean Min Values RSAM VORI       0.049471
# Avg Drop Depth RSAM VORI        0.045412
# Sum_LP                          0.043491
# Last_Precipitations             0.043338
# Avg Prominence RSAM VORI        0.040994
# Max peak RSAM VORI              0.036719
# slope_ratio VORI                0.035810
# Avg peak DSAR VORI              0.033635
# Delta_Max_Min_Precipitations    0.030960
# Avg drop DSAR VORI              0.030356
# Avg Value DSAR VORI             0.029344
# Max h Width RSAM VORI           0.027231
# Avg Prominence DSAR VORI        0.024301
# Avg l Width DSAR VORI           0.023005
# Max Drop Depth DSAR VORI        0.020713
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 14 out of 53
# Top selected features:
# Quantile Changes RSAM VRBA    0.195799
# Avg Value DSAR VRBA           0.101260
# Mean Min Values RSAM VRBA     0.073961
# Max l Width RSAM VRBA         0.069619
# Avg Drop Depth RSAM VRBA      0.068678
# Max_tornillo                  0.057564
# Std Value DSAR VRBA           0.056818
# Avg Drop Depth DSAR VRBA      0.056244
# season                        0.045348
# Avg h Width RSAM VRBA         0.045218
# Avg l Width DSAR VRBA         0.033304
# Sum_Precipitations            0.025390
# slope_ratio VRBA              0.023939
# Avg Prominence DSAR VRBA      0.021063
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2019
# ==================================================
#
# [ STATION VORI ]
# Features kept: 9 out of 48
# Top selected features:
# Sum_LP                        0.350580
# Mean Min Values RSAM VORI     0.097864
# Mean Min Values DSAR VORI     0.080341
# Quantile Changes RSAM VORI    0.072907
# Max_tornillo                  0.063881
# Sum_Precipitations            0.059427
# season                        0.035459
# Quantile Changes DSAR VORI    0.034061
# Sum_VT                        0.027973
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 10 out of 52
# Top selected features:
# Sum_LP                        0.287344
# Quantile Changes RSAM VRBA    0.159162
# Last_LP                       0.095481
# Avg peak RSAM VRBA            0.075753
# Std Value DSAR VRBA           0.052704
# Quantile Changes DSAR VRBA    0.047053
# Mean Min Values RSAM VRBA     0.039949
# Var Value RSAM VRBA           0.034896
# Mean Min Values DSAR VRBA     0.027858
# Delta_Max_Min_tornillo        0.027185
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2020
# ==================================================
#
# [ STATION VORI ]
# Features kept: 9 out of 50
# Top selected features:
# Sum_LP                          0.270067
# Avg drop DSAR VORI              0.164510
# Max peak RSAM VORI              0.102896
# Max_tornillo                    0.080956
# Quantile Changes RSAM VORI      0.056014
# Mean Min Values RSAM VORI       0.032518
# Delta_Max_Min_Precipitations    0.024056
# Max Drop Depth RSAM VORI        0.020389
# Var Value RSAM VORI             0.020389
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 14 out of 52
# Top selected features:
# Sum_LP                        0.126144
# Quantile Changes RSAM VRBA    0.100537
# Avg peak DSAR VRBA            0.087969
# Quantile Changes DSAR VRBA    0.075613
# Delta_Max_Min_tornillo        0.061197
# Avg peak RSAM VRBA            0.058224
# Avg Drop Depth DSAR VRBA      0.051957
# Mean Min Values RSAM VRBA     0.042251
# Last_LP                       0.041065
# Mean Min Values DSAR VRBA     0.035097
# Var Value RSAM VRBA           0.029613
# Sum_Precipitations            0.025099
# Avg Drop Depth RSAM VRBA      0.021056
# Avg Prominence DSAR VRBA      0.020060
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2021
# ==================================================
#
# [ STATION VORI ]
# Features kept: 16 out of 52
# Top selected features:
# Mean Min Values DSAR VORI     0.120858
# Avg peak DSAR VORI            0.084750
# Sum_LP                        0.065828
# Var Value DSAR VORI           0.063802
# Max_Precipitations            0.063113
# Quantile Changes DSAR VORI    0.052636
# Max_tornillo                  0.048861
# Quantile Changes RSAM VORI    0.040706
# Max peak RSAM VORI            0.036043
# Std Value RSAM VORI           0.033763
# Mean Min Values RSAM VORI     0.031881
# Sum_VT                        0.030490
# Median Value RSAM VORI        0.029748
# Avg drop RSAM VORI            0.027740
# Avg Prominence RSAM VORI      0.027095
# Max Drop Depth RSAM VORI      0.022116
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 7 out of 52
# Top selected features:
# Max peak DSAR VRBA            0.427406
# Quantile Changes DSAR VRBA    0.184823
# Quantile Changes RSAM VRBA    0.069358
# Max_LP                        0.066930
# Mean Min Values RSAM VRBA     0.064807
# Avg Value RSAM VRBA           0.025326
# Avg Drop Depth DSAR VRBA      0.020178
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2022
# ==================================================
#
# [ STATION VORI ]
# Features kept: 15 out of 50
# Top selected features:
# Sum_LP                        0.148512
# Mean Min Values DSAR VORI     0.103924
# Avg peak DSAR VORI            0.063333
# Quantile Changes RSAM VORI    0.058456
# Max_Precipitations            0.046820
# Max peak RSAM VORI            0.043678
# Std Value DSAR VORI           0.041855
# Last_LP                       0.041038
# Quantile Changes DSAR VORI    0.040954
# Var Value RSAM VORI           0.036023
# Avg drop RSAM VORI            0.028442
# Avg Prominence RSAM VORI      0.024999
# Avg Drop Depth RSAM VORI      0.023170
# Max_tornillo                  0.022120
# Sum_VT                        0.021769
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 12 out of 52
# Top selected features:
# Sum_LP                        0.196299
# Median Value DSAR VRBA        0.178037
# Quantile Changes RSAM VRBA    0.144742
# Quantile Changes DSAR VRBA    0.077549
# Var Value DSAR VRBA           0.057718
# Mean Min Values RSAM VRBA     0.033075
# Median Value RSAM VRBA        0.031344
# Sum_VT                        0.029693
# Avg Drop Depth DSAR VRBA      0.023244
# Var Value RSAM VRBA           0.022518
# Sum_tornillo                  0.020858
# Sum_Precipitations            0.020379
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2023
# ==================================================
#
# [ STATION VORI ]
# Features kept: 13 out of 48
# Top selected features:
# Sum_tornillo                  0.166236
# Max_Precipitations            0.091135
# Sum_LP                        0.089640
# Last_tornillo                 0.083181
# Delta_Max_Min_LP              0.079921
# Quantile Changes DSAR VORI    0.074343
# Quantile Changes RSAM VORI    0.053787
# Max peak DSAR VORI            0.052787
# Max Drop Depth RSAM VORI      0.048303
# Avg Prominence RSAM VORI      0.029955
# Mean Min Values DSAR VORI     0.027918
# season                        0.026421
# Last_Precipitations           0.022452
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 13 out of 52
# Top selected features:
# Quantile Changes RSAM VRBA    0.177325
# Median Value DSAR VRBA        0.127374
# Quantile Changes DSAR VRBA    0.081941
# Sum_LP                        0.074233
# Mean Min Values RSAM VRBA     0.074232
# Var Value DSAR VRBA           0.053008
# Avg peak RSAM VRBA            0.051515
# Sum_tornillo                  0.048775
# Delta_Max_Min_LP              0.045880
# Max_Precipitations            0.038763
# Var Value RSAM VRBA           0.028922
# Sum_VT                        0.024405
# Avg Drop Depth DSAR VRBA      0.019903
# dtype: float64
#
# ==================================================
# FEATURE SELECTION (EMBEDDED) FOR TEST YEAR: 2024
# ==================================================
#
# [ STATION VORI ]
# Features kept: 13 out of 50
# Top selected features:
# Sum_LP                        0.229232
# Mean Min Values DSAR VORI     0.116353
# Max_Precipitations            0.075828
# Quantile Changes RSAM VORI    0.066489
# Avg Value RSAM VORI           0.061852
# Delta_Max_Min_tornillo        0.057909
# Mean Min Values RSAM VORI     0.057900
# Std Value DSAR VORI           0.042426
# Max peak DSAR VORI            0.034088
# Var Value RSAM VORI           0.027555
# Quantile Changes DSAR VORI    0.024394
# season                        0.021033
# Avg Drop Depth RSAM VORI      0.020430
# dtype: float64
#
# [ STATION VRBA ]
# Features kept: 10 out of 52
# Top selected features:
# Median Value DSAR VRBA        0.260712
# Quantile Changes RSAM VRBA    0.136038
# Sum_LP                        0.118509
# Var Value DSAR VRBA           0.096921
# Quantile Changes DSAR VRBA    0.060466
# Avg Value RSAM VRBA           0.059754
# Delta_Max_Min_tornillo        0.050607
# season                        0.029661
# Max drop RSAM VRBA            0.027403
# Sum_Precipitations            0.022507
# dtype: float64

# %% [markdown]
# Now that we have the bests models for each station, we are going to do feature selection to see if it is possible to get a better performance with less features.

# %%
leaderboard_sorted_corr = generate_leaderboard(
    train_test_years_splits=train_test_years_splits,
    best_models_VORI=best_models_VORI_corr, 
    x_train_VORI=X_Train_VORI_cleaned, x_val_VORI=X_Test_VORI_cleaned, y_train_VORI=Y_Train_VORI, y_val_VORI=Y_Test_VORI,
    best_models_VRBA=best_models_VRBA_corr, 
    x_train_VRBA=X_Train_VRBA_cleaned, x_val_VRBA=X_Test_VRBA_cleaned, y_train_VRBA=Y_Train_VRBA, y_val_VRBA=Y_Test_VRBA,
    best_features_VORI=best_features_VORI_corr, 
    best_features_VRBA=best_features_VRBA_corr,
    output_csv="MSc_Bryan_Rincon/Training Results/leaderboard_corr_val.csv"
)

leaderboard_sorted_corr.head()
# Out:
#   Model_Name  Accuracy VORI  Precision VORI  Recall VORI  F1_Score VORI  \
# 1     RF_SFM       0.443763        0.562211     0.492224       0.470584
# 0   RF_NO_FS       0.492142        0.583080     0.518203       0.508880
#
#      TP VORI   TN VORI    FP VORI    FN VORI  TP_VORI_%  FN_VORI_%  TN_VORI_%  \
# 1  10.333333  8.166667  11.833333  11.500000  49.222424  50.777576  48.773310
# 0  11.166667  9.500000  10.500000  10.666667  51.820279  48.179721  51.093629
#
#    FP_VORI_%  Accuracy VRBA  Precision VRBA  Recall VRBA  F1_Score VRBA  \
# 1  51.226690       0.543704        0.609434     0.664205       0.592459
# 0  48.906371       0.552773        0.618186     0.608623       0.578262
#
#      TP VRBA   TN VRBA    FP VRBA   FN VRBA  TP_VRBA_%  FN_VRBA_%  TN_VRBA_%  \
# 1  14.166667  8.000000  12.000000  7.666667  66.420503  33.579497  45.093240
# 0  13.166667  9.666667  10.333333  8.666667  60.862272  39.137728  51.499611
#
#    FP_VRBA_%  Both_TP_%  Both_FN_%  VORI_only_Rate_%  VRBA_only_Rate_%  \
# 1  54.906760  36.080978  20.438051         13.141446         30.339525
# 0  48.500389  39.585094  26.902542         12.235186         21.277179
#
#    Both_TN_Rate_%  Both_FP_Rate_%  VORI_only_TN_Rate_%  VRBA_only_TN_Rate_%
# 1       29.968920       36.102370             18.80439            15.124320
# 0       36.986208       34.392968             14.10742            14.513403

# %%
leaderboard_sorted_5days_corr = generate_leaderboard(
    train_test_years_splits=train_test_years_splits,
    best_models_VORI=best_5days_models_VORI_corr, 
    x_train_VORI=X_Train_5_VORI_cleaned, x_val_VORI=X_Test_5_VORI_cleaned, y_train_VORI=Y_Train_5_VORI, y_val_VORI=Y_Test_5_VORI,
    best_models_VRBA=best_5days_models_VRBA_corr, 
    x_train_VRBA=X_Train_5_VRBA_cleaned, x_val_VRBA=X_Test_5_VRBA_cleaned, y_train_VRBA=Y_Train_5_VRBA, y_val_VRBA=Y_Test_5_VRBA,
    best_features_VORI=best_features_5days_VORI_corr, 
    best_features_VRBA=best_features_5days_VRBA_corr,
    output_csv="MSc_Bryan_Rincon/Training Results/leaderboard_corr_5days_val.csv"
)

# %%
leaderboard_sorted_5days_corr.head()
# Out:
#   Model_Name  Accuracy VORI  Precision VORI  Recall VORI  F1_Score VORI  \
# 1     RF_SFM       0.537587        0.615397     0.599647       0.531678
# 0   RF_NO_FS       0.540267        0.627818     0.551848       0.518767
#
#    TP VORI    TN VORI    FP VORI    FN VORI  TP_VORI_%  FN_VORI_%  TN_VORI_%  \
# 1    107.5  39.333333  50.333333  54.333333  59.964688  40.035312  56.084266
# 0    100.0  45.166667  44.500000  61.833333  55.184823  44.815177  65.943332
#
#    FP_VORI_%  Accuracy VRBA  Precision VRBA  Recall VRBA  F1_Score VRBA  \
# 1  43.915734       0.649617        0.633010     0.736018       0.631466
# 0  34.056668       0.642941        0.648238     0.722915       0.624080
#
#    TP VRBA    TN VRBA    FP VRBA    FN VRBA  TP_VRBA_%  FN_VRBA_%  TN_VRBA_%  \
# 1    133.0  40.000000  49.666667  28.833333  73.601805  26.398195  47.523365
# 0    130.0  41.833333  47.833333  31.833333  72.291476  27.708524  53.499182
#
#    FP_VRBA_%  Both_TP_%  Both_FN_%  VORI_only_Rate_%  VRBA_only_Rate_%  \
# 1  52.476635  47.296547  13.730054         12.668141         26.305258
# 0  46.500818  47.518563  20.042265          7.666259         24.772913
#
#    Both_TN_Rate_%  Both_FP_Rate_%  VORI_only_TN_Rate_%  VRBA_only_TN_Rate_%
# 1       34.779298       31.171666            21.304968            12.744067
# 0       41.937082       22.494568            24.006250            11.562100

# %%
def get_station_features_with_scores(model_years, target_station, feature_dict, top_n=25):
    """
    Extract features and their importance scores for a given station.
    """
    # Validate the input format for the model years.
    if not isinstance(model_years, list):
        raise ValueError("Expecting a list of model years")

    # Aggregate importance scores across all selected model years for the target station.
    aggregated_importance = {}
    for model_year in model_years:
        model_year_key = int(model_year)

        # Check whether the current model year exists in the feature dictionary.
        if model_year_key in feature_dict:
            station_dict = feature_dict[model_year_key]

            # Check whether the target station is present for that model year.
            if target_station in station_dict:
                # Sum the importance scores for each feature across years.
                for feature_name, importance_value in station_dict[target_station].items():
                    aggregated_importance[feature_name] = aggregated_importance.get(feature_name, 0) + float(importance_value)

    # Sort features by total importance score in descending order.
    sorted_features = sorted(aggregated_importance.items(), key=lambda x: x[1], reverse=True)

    # Return only the top N features with their aggregated importance scores.
    return {feat: score for feat, score in sorted_features[:top_n]}


def generate_truth_table_and_features_summary(time_analysis_results, features_classement, top_n_features=25, min_model_count=1, save_path=None):
    """
    Aggregate temporal analysis results, group important features by event,
    and print the classification summary.
    """
    # Flatten the nested temporal analysis dictionary into a list of event records.
    records = []
    for year, categories_dict in time_analysis_results.items():
        for category, dates in categories_dict.items():
            for date in dates:
                records.append({
                    "Date": date,
                    "Category": category,
                    "key": year
                })

    # Build a DataFrame from the flattened records.
    df_all = pd.DataFrame(records)
    df_all["Date"] = pd.to_datetime(df_all["Date"])

    # Group event records by date and category, keeping all model years associated with each event.
    df_grouped = df_all.groupby(["Date", "Category"])["key"].agg(list).reset_index()
    df_grouped["Model_Count"] = df_grouped["key"].apply(len)
    df_grouped = df_grouped.rename(columns={"key": "Model_Years"})

    # Add the top feature-score dictionaries for VORI and VRBA for each grouped event.
    df_grouped["Dict_VORI"] = df_grouped.apply(
        lambda row: get_station_features_with_scores(row["Model_Years"], "VORI", features_classement, top_n=top_n_features),
        axis=1
    )
    df_grouped["Dict_VRBA"] = df_grouped.apply(
        lambda row: get_station_features_with_scores(row["Model_Years"], "VRBA", features_classement, top_n=top_n_features),
        axis=1
    )

    # Combine VORI and VRBA feature-score dictionaries into a unified score dictionary.
    df_grouped["Combined_Feature_Scores"] = df_grouped.apply(
        lambda row: dict(Counter(row["Dict_VORI"]) + Counter(row["Dict_VRBA"])),
        axis=1
    )

    # Optionally save the full grouped summary to CSV.
    if save_path:
        df_grouped.to_csv(save_path, index=False)

    # Display a summary of the classification counts.
    print(f"\n--- Classification summary (Min Model Count: {min_model_count}) ---")

    # Human-readable labels for each event category.
    categories_labels = {
        "both_tp": "Eruptions detected by both stations",
        "both_fn": "Eruptions missed by both stations",
        "vori_only_tp": "Eruptions detected by VORI",
        "vrba_only_tp": "Eruptions detected by VRBA",
        "vori_only_tn": "Non-eruptions correctly detected by VORI",
        "vrba_only_tn": "Non-eruptions correctly detected by VRBA",
        "both_fp": "False alarms for both stations",
        "both_tn": "Non-eruptions correctly rejected by both stations"
    }

    # Count how many grouped events belong to each category, respecting the minimum model count threshold.
    for cat_key, label in categories_labels.items():
        count = len(df_grouped[(df_grouped["Model_Count"] >= min_model_count) & (df_grouped["Category"] == cat_key)])
        print(f"{label}: {count}")

    # Return the full grouped summary DataFrame.
    return df_grouped

# %%
coverage_analysis_test, time_analysis_results_test, features_classement_test = print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI, best_features_5days_VORI, X_Train_5_VORI, X_Test_5_VORI, Y_Train_5_VORI, Y_Test_5_VORI,
    best_5days_models_VRBA, best_features_5days_VRBA, X_Train_5_VRBA, X_Test_5_VRBA, Y_Train_5_VRBA, Y_Test_5_VRBA,
    train_test_years_splits,
    best_features='selected' ,
    five_days=True , return_time=True,
    time = time_Test,time_5days = time_5days_Test,
    coverage = coverage_Test, coverage_5days = coverage_5days_Test

)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 87 109]
#  [ 11  24]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.44      0.59       196
#            1       0.18      0.69      0.29        35
#
#     accuracy                           0.48       231
#    macro avg       0.53      0.56      0.44       231
# weighted avg       0.78      0.48      0.55       231
#
#
#  Top Features (VORI)
# Sum_LP                        0.136751
# Max_LP                        0.095446
# Delta_Max_Min_LP              0.060472
# Quantile Changes RSAM VORI    0.050432
# Mean Min Values DSAR VORI     0.036912
# Mean Min Values RSAM VORI     0.036451
# Last_LP                       0.035285
# Max peak RSAM VORI            0.029263
# Avg drop DSAR VORI            0.028825
# Max drop DSAR VORI            0.028270
# season                        0.026553
# Sum_Precipitations            0.025507
# Median Value RSAM VORI        0.025427
# Var Value RSAM VORI           0.025185
# Max drop RSAM VORI            0.024879
# Avg drop RSAM VORI            0.024462
# Max_Precipitations            0.024375
# Avg Value RSAM VORI           0.024085
# Delta_Max_Min_tornillo        0.023585
# Max_tornillo                  0.023553
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.71
# Mean Magnitude (Missed - FN):   2.66 ± 0.92
# Low magnitude events were more detected
#  length of time array: 231
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 93 103]
#  [ 17  18]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.47      0.61       196
#            1       0.15      0.51      0.23        35
#
#     accuracy                           0.48       231
#    macro avg       0.50      0.49      0.42       231
# weighted avg       0.74      0.48      0.55       231
#
#
#  Top Features (VRBA)
# Sum_LP                        0.145300
# Max_LP                        0.077130
# Quantile Changes RSAM VRBA    0.076301
# Delta_Max_Min_LP              0.064738
# Median Value DSAR VRBA        0.040558
# Quantile Changes DSAR VRBA    0.036386
# Mean Min Values RSAM VRBA     0.035675
# Mean Min Values DSAR VRBA     0.031846
# Var Value DSAR VRBA           0.030434
# Last_LP                       0.030392
# Max peak RSAM VRBA            0.028821
# Std Value DSAR VRBA           0.027713
# Avg peak DSAR VRBA            0.026919
# Max peak DSAR VRBA            0.026450
# Avg Value DSAR VRBA           0.025675
# Avg peak RSAM VRBA            0.023090
# Var Value RSAM VRBA           0.021761
# Avg Value RSAM VRBA           0.021597
# Max Drop Depth DSAR VRBA      0.020245
# Delta_Max_Min_tornillo        0.020202
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.55 ± 0.63
# Mean Magnitude (Missed - FN):   2.62 ± 0.91
# Low magnitude events were more detected
#  length of time array: 231
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 18 | Mean VORI RSAM Coverage: 94.62±19.27% | Mean VORI DSAR Coverage: 97.82±9.02% | Mean VRBA Coverage: 54.14±29.51%
# Both Missed (FN): 11 | Mean VORI RSAM Coverage: 92.89±15.64% | Mean VORI DSAR Coverage: 93.62±15.04% | Mean VRBA Coverage: 62.39±38.97%
# Both False Positives (FP): 87 | Mean VORI RSAM Coverage: 99.11±2.65% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 90.16±14.79%
# Both True Negatives (TN): 71 | Mean VORI RSAM Coverage: 99.88±0.27% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 92.83±13.18%
# VORI Detected Without VRBA (TP): 6 | Mean VORI RSAM Coverage: 75.43+-37.61% | Mean VORI DSAR Coverage: 87.19+-19.76% | Mean VRBA Coverage: 57.62+-45.74%
# VRBA Detected Without VORI (TP): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VORI Detected Without VRBA (TN): 16 | Mean VORI RSAM Coverage: 99.95+-0.00% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 83.20+-20.58%
# VRBA Detected Without VORI (TN): 22 | Mean VORI RSAM Coverage: 99.18+-1.91% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 96.46+-6.98%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 39  13]
#  [112  56]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.26      0.75      0.38        52
#            1       0.81      0.33      0.47       168
#
#     accuracy                           0.43       220
#    macro avg       0.53      0.54      0.43       220
# weighted avg       0.68      0.43      0.45       220
#
#
#  Top Features (VORI)
# Sum_LP                        0.103284
# Mean Min Values DSAR VORI     0.054529
# Max_tornillo                  0.053362
# Max_LP                        0.052517
# Max drop DSAR VORI            0.052266
# Avg drop DSAR VORI            0.049962
# Delta_Max_Min_tornillo        0.042756
# Delta_Max_Min_LP              0.037762
# Median Value DSAR VORI        0.037475
# Quantile Changes RSAM VORI    0.036901
# Max peak DSAR VORI            0.036110
# Sum_tornillo                  0.034404
# Avg peak DSAR VORI            0.031513
# Std Value RSAM VORI           0.031141
# Var Value RSAM VORI           0.030148
# Max peak RSAM VORI            0.029888
# Avg peak RSAM VORI            0.029324
# Avg Value RSAM VORI           0.026511
# Mean Min Values RSAM VORI     0.025089
# Median Value RSAM VORI        0.023799
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.41 ± 0.76
# Mean Magnitude (Missed - FN):   3.26 ± 0.69
# High magnitude events were more detected
#  length of time array: 220
# Detected Lahars (TP): 1 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2020-01-30 18:13:42.427
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 45   7]
#  [ 61 107]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.42      0.87      0.57        52
#            1       0.94      0.64      0.76       168
#
#     accuracy                           0.69       220
#    macro avg       0.68      0.75      0.66       220
# weighted avg       0.82      0.69      0.71       220
#
#
#  Top Features (VRBA)
# Sum_LP                        0.172825
# Quantile Changes RSAM VRBA    0.102435
# Median Value DSAR VRBA        0.093221
# Quantile Changes DSAR VRBA    0.088647
# Std Value DSAR VRBA           0.078539
# Var Value DSAR VRBA           0.071286
# Max_LP                        0.038012
# Avg peak DSAR VRBA            0.033303
# Max drop RSAM VRBA            0.032430
# Mean Min Values RSAM VRBA     0.030748
# Max_tornillo                  0.030464
# Avg Value DSAR VRBA           0.028680
# Max peak RSAM VRBA            0.027638
# Delta_Max_Min_tornillo        0.026461
# Avg drop RSAM VRBA            0.025942
# Delta_Max_Min_LP              0.025027
# Mean Min Values DSAR VRBA     0.024709
# Avg Value RSAM VRBA           0.024674
# Avg peak RSAM VRBA            0.024277
# Sum_tornillo                  0.020682
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.30 ± 0.76
# Mean Magnitude (Missed - FN):   3.33 ± 0.63
# Low magnitude events were more detected
#  length of time array: 220
# Detected Lahars (TP): 2 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2020-01-30 18:13:42.427
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 44 | Mean VORI RSAM Coverage: 93.36±13.38% | Mean VORI DSAR Coverage: 99.25±3.23% | Mean VRBA Coverage: 92.05±10.29%
# Both Missed (FN): 49 | Mean VORI RSAM Coverage: 91.96±12.88% | Mean VORI DSAR Coverage: 95.72±12.99% | Mean VRBA Coverage: 91.27±17.08%
# Both False Positives (FP): 2 | Mean VORI RSAM Coverage: 99.87±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 99.94±0.00%
# Both True Negatives (TN): 34 | Mean VORI RSAM Coverage: 85.58±30.65% | Mean VORI DSAR Coverage: 90.77±22.73% | Mean VRBA Coverage: 97.48±7.54%
# VORI Detected Without VRBA (TP): 12 | Mean VORI RSAM Coverage: 97.86+-4.96% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 97.60+-2.78%
# VRBA Detected Without VORI (TP): 63 | Mean VORI RSAM Coverage: 98.07+-4.90% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 94.40+-10.86%
# VORI Detected Without VRBA (TN): 5 | Mean VORI RSAM Coverage: 99.81+-0.14% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 99.94+-0.00%
# VRBA Detected Without VORI (TN): 11 | Mean VORI RSAM Coverage: 99.76+-0.18% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 82.56+-23.70%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 58 136]
#  [  8  17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.30      0.45       194
#            1       0.11      0.68      0.19        25
#
#     accuracy                           0.34       219
#    macro avg       0.49      0.49      0.32       219
# weighted avg       0.79      0.34      0.42       219
#
#
#  Top Features (VORI)
# Max drop DSAR VORI            0.079132
# Median Value DSAR VORI        0.075282
# Avg drop DSAR VORI            0.068890
# Mean Min Values DSAR VORI     0.068601
# Avg peak DSAR VORI            0.057364
# Max_Precipitations            0.056157
# Sum_LP                        0.055887
# Sum_Precipitations            0.043692
# Max_tornillo                  0.041943
# Quantile Changes DSAR VORI    0.039504
# Std Value DSAR VORI           0.039433
# Var Value DSAR VORI           0.038347
# Quantile Changes RSAM VORI    0.031120
# Sum_VT                        0.030685
# Avg Value RSAM VORI           0.029431
# Std Value RSAM VORI           0.028576
# Delta_Max_Min_tornillo        0.028493
# Max Drop Depth RSAM VORI      0.022632
# Max Prominence RSAM VORI      0.021948
# Median Value RSAM VORI        0.018887
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.95 ± 0.99
# Mean Magnitude (Missed - FN):   3.09 ± 0.72
# Low magnitude events were more detected
#  length of time array: 219
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 78 116]
#  [  8  17]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.91      0.40      0.56       194
#            1       0.13      0.68      0.22        25
#
#     accuracy                           0.43       219
#    macro avg       0.52      0.54      0.39       219
# weighted avg       0.82      0.43      0.52       219
#
#
#  Top Features (VRBA)
# Max peak DSAR VRBA            0.169415
# Avg peak DSAR VRBA            0.141252
# Median Value DSAR VRBA        0.123168
# Avg Value DSAR VRBA           0.108616
# Quantile Changes DSAR VRBA    0.080983
# Max_LP                        0.048159
# Mean Min Values RSAM VRBA     0.045645
# Sum_LP                        0.042920
# Var Value DSAR VRBA           0.039210
# Std Value DSAR VRBA           0.035888
# Quantile Changes RSAM VRBA    0.029263
# Delta_Max_Min_LP              0.025410
# Avg drop DSAR VRBA            0.022147
# Max drop DSAR VRBA            0.019355
# Std peak RSAM VRBA            0.016361
# Avg drop RSAM VRBA            0.014401
# Max_Precipitations            0.014051
# Max Drop Depth DSAR VRBA      0.010981
# Avg Drop Depth DSAR VRBA      0.007996
# Avg Value RSAM VRBA           0.004780
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.93 ± 0.78
# Mean Magnitude (Missed - FN):   3.14 ± 1.17
# Low magnitude events were more detected
#  length of time array: 219
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 12 | Mean VORI RSAM Coverage: 97.87±3.49% | Mean VORI DSAR Coverage: 98.69±2.95% | Mean VRBA Coverage: 70.54±15.82%
# Both Missed (FN): 3 | Mean VORI RSAM Coverage: 65.28±30.02% | Mean VORI DSAR Coverage: 65.28±30.02% | Mean VRBA Coverage: 31.43±54.44%
# Both False Positives (FP): 92 | Mean VORI RSAM Coverage: 85.58±28.71% | Mean VORI DSAR Coverage: 90.64±23.78% | Mean VRBA Coverage: 76.49±29.17%
# Both True Negatives (TN): 34 | Mean VORI RSAM Coverage: 93.30±16.71% | Mean VORI DSAR Coverage: 96.77±10.61% | Mean VRBA Coverage: 73.67±23.90%
# VORI Detected Without VRBA (TP): 5 | Mean VORI RSAM Coverage: 85.49+-14.23% | Mean VORI DSAR Coverage: 90.16+-14.01% | Mean VRBA Coverage: 42.11+-30.74%
# VRBA Detected Without VORI (TP): 5 | Mean VORI RSAM Coverage: 99.93+-0.02% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 83.76+-22.26%
# VORI Detected Without VRBA (TN): 24 | Mean VORI RSAM Coverage: 99.88+-0.03% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 75.71+-21.08%
# VRBA Detected Without VORI (TN): 44 | Mean VORI RSAM Coverage: 90.58+-22.98% | Mean VORI DSAR Coverage: 94.80+-21.22% | Mean VRBA Coverage: 70.80+-24.05%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 20  24]
#  [ 63 187]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.24      0.45      0.31        44
#            1       0.89      0.75      0.81       250
#
#     accuracy                           0.70       294
#    macro avg       0.56      0.60      0.56       294
# weighted avg       0.79      0.70      0.74       294
#
#
#  Top Features (VORI)
# Sum_LP                        0.103076
# Mean Min Values DSAR VORI     0.068384
# Max_LP                        0.053805
# Max drop DSAR VORI            0.051890
# Avg drop DSAR VORI            0.048938
# Quantile Changes RSAM VORI    0.047692
# Delta_Max_Min_LP              0.036266
# Median Value DSAR VORI        0.033486
# Avg peak DSAR VORI            0.031534
# Max_Precipitations            0.030778
# Std Value DSAR VORI           0.030118
# Max peak DSAR VORI            0.028515
# Max peak RSAM VORI            0.028006
# Quantile Changes DSAR VORI    0.027010
# Mean Min Values RSAM VORI     0.026445
# Sum_Precipitations            0.026147
# Sum_VT                        0.026123
# Var Value DSAR VORI           0.025792
# Avg Value DSAR VORI           0.025238
# Avg peak RSAM VORI            0.024522
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.72 ± 0.60
# Mean Magnitude (Missed - FN):   3.17 ± 0.64
# Low magnitude events were more detected
#  length of time array: 294
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 31  13]
#  [ 58 192]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.35      0.70      0.47        44
#            1       0.94      0.77      0.84       250
#
#     accuracy                           0.76       294
#    macro avg       0.64      0.74      0.66       294
# weighted avg       0.85      0.76      0.79       294
#
#
#  Top Features (VRBA)
# Sum_LP                        0.112524
# Quantile Changes RSAM VRBA    0.095141
# Median Value DSAR VRBA        0.077438
# Avg Value DSAR VRBA           0.063098
# Max peak DSAR VRBA            0.054551
# Quantile Changes DSAR VRBA    0.053494
# Max_LP                        0.051608
# Avg peak DSAR VRBA            0.045762
# Var Value DSAR VRBA           0.040206
# Std Value DSAR VRBA           0.034749
# Delta_Max_Min_LP              0.032661
# Mean Min Values RSAM VRBA     0.028883
# Sum_VT                        0.028187
# Mean Min Values DSAR VRBA     0.028150
# Avg Value RSAM VRBA           0.026333
# Max drop RSAM VRBA            0.024342
# Max peak RSAM VRBA            0.021369
# Std Value RSAM VRBA           0.020526
# Var Value RSAM VRBA           0.020466
# Median Value RSAM VRBA        0.020316
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.80 ± 0.63
# Mean Magnitude (Missed - FN):   2.95 ± 0.67
# Low magnitude events were more detected
#  length of time array: 294
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 154 | Mean VORI RSAM Coverage: 97.68±5.06% | Mean VORI DSAR Coverage: 99.58±1.48% | Mean VRBA Coverage: 67.10±20.39%
# Both Missed (FN): 25 | Mean VORI RSAM Coverage: 96.59±16.56% | Mean VORI DSAR Coverage: 96.63±16.57% | Mean VRBA Coverage: 64.77±24.13%
# Both False Positives (FP): 8 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 41.12±23.74%
# Both True Negatives (TN): 15 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 53.03±13.82%
# VORI Detected Without VRBA (TP): 33 | Mean VORI RSAM Coverage: 98.55+-3.43% | Mean VORI DSAR Coverage: 98.57+-3.42% | Mean VRBA Coverage: 58.86+-17.76%
# VRBA Detected Without VORI (TP): 38 | Mean VORI RSAM Coverage: 96.96+-10.16% | Mean VORI DSAR Coverage: 97.02+-10.18% | Mean VRBA Coverage: 55.52+-10.77%
# VORI Detected Without VRBA (TN): 5 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 45.61+-25.51%
# VRBA Detected Without VORI (TN): 16 | Mean VORI RSAM Coverage: 99.54+-1.63% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 37.86+-21.85%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[  2   6]
#  [ 83 311]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.02      0.25      0.04         8
#            1       0.98      0.79      0.87       394
#
#     accuracy                           0.78       402
#    macro avg       0.50      0.52      0.46       402
# weighted avg       0.96      0.78      0.86       402
#
#
#  Top Features (VORI)
# Max_Precipitations              0.055879
# Quantile Changes RSAM VORI      0.052087
# Max_tornillo                    0.044701
# Delta_Max_Min_Precipitations    0.044336
# Sum_LP                          0.042476
# Sum_Precipitations              0.041739
# Mean Min Values RSAM VORI       0.041487
# Delta_Max_Min_tornillo          0.040636
# Sum_tornillo                    0.031559
# Avg Value DSAR VORI             0.031468
# Quantile Changes DSAR VORI      0.030099
# Avg drop DSAR VORI              0.028535
# Delta_Max_Min_LP                0.028468
# Avg drop RSAM VORI              0.028082
# Max_LP                          0.027819
# Var Value RSAM VORI             0.026961
# Std Value RSAM VORI             0.026738
# Avg Value RSAM VORI             0.026733
# Mean Min Values DSAR VORI       0.026366
# Var Value DSAR VORI             0.026312
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.78 ± 0.72
# Mean Magnitude (Missed - FN):   2.84 ± 0.63
# Low magnitude events were more detected
#  length of time array: 402
# Detected Lahars (TP): 7 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# Detected Lahar Event - Magnitude: 5.20, Time: 2023-04-21 21:50:10.251
# Detected Lahar Event - Magnitude: 4.79, Time: 2023-05-14 08:58:05.785
# Detected Lahar Event - Magnitude: 4.98, Time: 2023-05-25 20:35:31.649
# Detected Lahar Event - Magnitude: 5.11, Time: 2023-05-28 03:34:53.507
# Detected Lahar Event - Magnitude: 4.74, Time: 2023-05-29 08:44:09.899
# Detected Lahar Event - Magnitude: 4.40, Time: 2023-11-05 21:17:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.97, Time: 2023-04-14 15:35:36.445
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[  5   3]
#  [ 36 358]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.12      0.62      0.20         8
#            1       0.99      0.91      0.95       394
#
#     accuracy                           0.90       402
#    macro avg       0.56      0.77      0.58       402
# weighted avg       0.97      0.90      0.93       402
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.171730
# Median Value DSAR VRBA        0.090032
# Sum_LP                        0.073836
# Quantile Changes DSAR VRBA    0.064276
# Mean Min Values RSAM VRBA     0.062195
# Mean Min Values DSAR VRBA     0.050115
# Avg peak DSAR VRBA            0.031777
# Sum_tornillo                  0.030948
# Max drop DSAR VRBA            0.029977
# Delta_Max_Min_LP              0.027794
# Max drop RSAM VRBA            0.027633
# Avg drop RSAM VRBA            0.025794
# Sum_VT                        0.025627
# Sum_Precipitations            0.023816
# Max_tornillo                  0.023704
# Max_Precipitations            0.022613
# Max_LP                        0.022420
# Std Value DSAR VRBA           0.020676
# Avg Value RSAM VRBA           0.020218
# Avg Value DSAR VRBA           0.019334
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.81 ± 0.71
# Mean Magnitude (Missed - FN):   2.67 ± 0.65
# High magnitude events were more detected
#  length of time array: 402
# Detected Lahars (TP): 7 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.97, Time: 2023-04-14 15:35:36.445
# Detected Lahar Event - Magnitude: 5.20, Time: 2023-04-21 21:50:10.251
# Detected Lahar Event - Magnitude: 4.79, Time: 2023-05-14 08:58:05.785
# Detected Lahar Event - Magnitude: 4.98, Time: 2023-05-25 20:35:31.649
# Detected Lahar Event - Magnitude: 5.11, Time: 2023-05-28 03:34:53.507
# Detected Lahar Event - Magnitude: 4.74, Time: 2023-05-29 08:44:09.899
# Detected Lahar Event - Magnitude: 4.40, Time: 2023-11-05 21:17:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 286 | Mean VORI RSAM Coverage: 92.19±17.80% | Mean VORI DSAR Coverage: 95.56±14.86% | Mean VRBA Coverage: 72.98±10.90%
# Both Missed (FN): 11 | Mean VORI RSAM Coverage: 68.63±37.65% | Mean VORI DSAR Coverage: 72.76±34.55% | Mean VRBA Coverage: 63.54±27.48%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.79±0.04% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 69.07±2.63%
# Both True Negatives (TN): 2 | Mean VORI RSAM Coverage: 98.97±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 69.87±3.92%
# VORI Detected Without VRBA (TP): 25 | Mean VORI RSAM Coverage: 92.75+-15.08% | Mean VORI DSAR Coverage: 94.87+-12.47% | Mean VRBA Coverage: 82.07+-9.84%
# VRBA Detected Without VORI (TP): 72 | Mean VORI RSAM Coverage: 88.95+-24.60% | Mean VORI DSAR Coverage: 91.17+-24.10% | Mean VRBA Coverage: 67.49+-16.42%
# VORI Detected Without VRBA (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
# VRBA Detected Without VORI (TN): 3 | Mean VORI RSAM Coverage: 99.26+-0.53% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 74.03+-7.37%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[27 17]
#  [40 59]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.40      0.61      0.49        44
#            1       0.78      0.60      0.67        99
#
#     accuracy                           0.60       143
#    macro avg       0.59      0.60      0.58       143
# weighted avg       0.66      0.60      0.62       143
#
#
#  Top Features (VORI)
# Sum_LP                          0.182327
# Max drop DSAR VORI              0.106490
# Quantile Changes RSAM VORI      0.103737
# Mean Min Values RSAM VORI       0.066555
# Max_LP                          0.064063
# Mean Min Values DSAR VORI       0.059937
# Max_tornillo                    0.047054
# Quantile Changes DSAR VORI      0.044847
# Max peak RSAM VORI              0.041500
# Sum_Precipitations              0.038691
# Delta_Max_Min_Precipitations    0.035874
# Avg peak RSAM VORI              0.035824
# Std Value RSAM VORI             0.034131
# Avg Prominence RSAM VORI        0.030980
# Delta_Max_Min_tornillo          0.027095
# Std Value DSAR VORI             0.020183
# Avg drop DSAR VORI              0.019965
# Var Value DSAR VORI             0.018648
# Sum_tornillo                    0.013837
# Delta_Max_Min_LP                0.008263
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.17 ± 0.54
# Mean Magnitude (Missed - FN):   2.11 ± 0.47
# High magnitude events were more detected
#  length of time array: 143
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[11 33]
#  [20 79]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.35      0.25      0.29        44
#            1       0.71      0.80      0.75        99
#
#     accuracy                           0.63       143
#    macro avg       0.53      0.52      0.52       143
# weighted avg       0.60      0.63      0.61       143
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.158934
# Quantile Changes RSAM VRBA    0.128442
# Sum_LP                        0.074288
# Avg Value DSAR VRBA           0.071077
# Std Value DSAR VRBA           0.064788
# Delta_Max_Min_LP              0.046899
# Quantile Changes DSAR VRBA    0.040128
# Max drop DSAR VRBA            0.039346
# season                        0.033056
# Mean Min Values RSAM VRBA     0.030549
# Mean Min Values DSAR VRBA     0.029901
# Max_LP                        0.026312
# Avg Value RSAM VRBA           0.026043
# Max_Precipitations            0.023765
# Avg peak RSAM VRBA            0.023133
# Sum_Precipitations            0.021197
# Avg drop RSAM VRBA            0.021133
# Var Value RSAM VRBA           0.021076
# Median Value RSAM VRBA        0.019535
# Avg Drop Depth DSAR VRBA      0.018116
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.15 ± 0.51
# Mean Magnitude (Missed - FN):   2.12 ± 0.56
# High magnitude events were more detected
#  length of time array: 143
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 51 | Mean VORI RSAM Coverage: 67.79±37.97% | Mean VORI DSAR Coverage: 67.79±37.97% | Mean VRBA Coverage: 59.66±11.76%
# Both Missed (FN): 12 | Mean VORI RSAM Coverage: 30.60±39.79% | Mean VORI DSAR Coverage: 30.60±39.79% | Mean VRBA Coverage: 47.15±20.09%
# Both False Positives (FP): 15 | Mean VORI RSAM Coverage: 84.88±13.63% | Mean VORI DSAR Coverage: 84.89±13.64% | Mean VRBA Coverage: 55.21±3.88%
# Both True Negatives (TN): 9 | Mean VORI RSAM Coverage: 67.70±21.92% | Mean VORI DSAR Coverage: 67.70±21.92% | Mean VRBA Coverage: 53.78±2.72%
# VORI Detected Without VRBA (TP): 8 | Mean VORI RSAM Coverage: 33.66+-39.56% | Mean VORI DSAR Coverage: 34.74+-40.89% | Mean VRBA Coverage: 51.03+-25.20%
# VRBA Detected Without VORI (TP): 28 | Mean VORI RSAM Coverage: 67.15+-40.98% | Mean VORI DSAR Coverage: 67.15+-40.98% | Mean VRBA Coverage: 54.09+-12.56%
# VORI Detected Without VRBA (TN): 18 | Mean VORI RSAM Coverage: 65.61+-16.87% | Mean VORI DSAR Coverage: 65.61+-16.86% | Mean VRBA Coverage: 53.74+-2.40%
# VRBA Detected Without VORI (TN): 2 | Mean VORI RSAM Coverage: 69.07+-10.88% | Mean VORI DSAR Coverage: 69.07+-10.88% | Mean VRBA Coverage: 53.81+-0.15%

# %%
# Print the final summary of the classification 
df_final = generate_truth_table_and_features_summary(
    time_analysis_results=time_analysis_results_test,
    features_classement=features_classement_test,
    top_n_features=25,
    min_model_count=1,
    # save_path='MSc_Bryan_Rincon/Training Results/features_classement_analysis_test.csv'
)
# Out:
# --- Classification summary (Min Model Count: 1) ---
# Eruptions detected by both stations: 565
# Eruptions missed by both stations: 111
# Eruptions detected by VORI: 89
# Eruptions detected by VRBA: 206
# Non-eruptions correctly detected by VORI: 68
# Non-eruptions correctly detected by VRBA: 98
# False alarms for both stations: 207
# Non-eruptions correctly rejected by both stations: 165

# %%
coverage_analysis_corr_test, time_analysis_results_corr_test, features_classement_corr_test = print_report_best_model_per_year_out_of_dataset(
    best_5days_models_VORI_corr, best_features_5days_VORI_corr, X_Train_5_VORI_cleaned, X_Test_5_VORI_cleaned, Y_Train_5_VORI, Y_Test_5_VORI,
    best_5days_models_VRBA_corr, best_features_5days_VRBA_corr, X_Train_5_VRBA_cleaned, X_Test_5_VRBA_cleaned, Y_Train_5_VRBA, Y_Test_5_VRBA,
    train_test_years_splits,
    best_features='selected' ,
    five_days=True , return_time=True,
    time = time_Test,time_5days = time_5days_Test,
    coverage = coverage_Test, coverage_5days = coverage_5days_Test

)
# Out:
# ============================================================
#  EVALUATION TRAIN Dataset [2020, 2021, 2022, 2023, 2024] without test year 2019
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 89 107]
#  [ 14  21]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.45      0.60       196
#            1       0.16      0.60      0.26        35
#
#     accuracy                           0.48       231
#    macro avg       0.51      0.53      0.43       231
# weighted avg       0.76      0.48      0.54       231
#
#
#  Top Features (VORI)
# Sum_LP                        0.379489
# Mean Min Values RSAM VORI     0.108741
# Quantile Changes RSAM VORI    0.102561
# Mean Min Values DSAR VORI     0.092872
# Sum_Precipitations            0.080085
# Max_tornillo                  0.073027
# Quantile Changes DSAR VORI    0.070449
# Sum_VT                        0.048976
# season                        0.043800
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.53 ± 0.62
# Mean Magnitude (Missed - FN):   2.68 ± 0.96
# Low magnitude events were more detected
#  length of time array: 231
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 88 108]
#  [ 12  23]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.45      0.59       196
#            1       0.18      0.66      0.28        35
#
#     accuracy                           0.48       231
#    macro avg       0.53      0.55      0.44       231
# weighted avg       0.77      0.48      0.55       231
#
#
#  Top Features (VRBA)
# Sum_LP                        0.318919
# Quantile Changes RSAM VRBA    0.184905
# Std Value DSAR VRBA           0.086877
# Avg peak RSAM VRBA            0.085693
# Mean Min Values RSAM VRBA     0.085596
# Quantile Changes DSAR VRBA    0.073299
# Mean Min Values DSAR VRBA     0.045857
# Var Value RSAM VRBA           0.043630
# Last_LP                       0.042019
# Delta_Max_Min_tornillo        0.033205
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.48 ± 0.62
# Mean Magnitude (Missed - FN):   2.79 ± 0.99
# Low magnitude events were more detected
#  length of time array: 231
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.87, Time: 2019-01-20 07:27:05.050
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 15 | Mean VORI RSAM Coverage: 93.56±21.06% | Mean VORI DSAR Coverage: 97.39±9.88% | Mean VRBA Coverage: 59.12±30.26%
# Both Missed (FN): 6 | Mean VORI RSAM Coverage: 95.56±7.92% | Mean VORI DSAR Coverage: 96.35±8.06% | Mean VRBA Coverage: 63.45±44.65%
# Both False Positives (FP): 64 | Mean VORI RSAM Coverage: 98.79±3.09% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 90.53±14.69%
# Both True Negatives (TN): 45 | Mean VORI RSAM Coverage: 99.85±0.33% | Mean VORI DSAR Coverage: 99.95±0.00% | Mean VRBA Coverage: 93.42±14.19%
# VORI Detected Without VRBA (TP): 6 | Mean VORI RSAM Coverage: 75.43+-37.61% | Mean VORI DSAR Coverage: 87.19+-19.76% | Mean VRBA Coverage: 57.62+-45.74%
# VRBA Detected Without VORI (TP): 8 | Mean VORI RSAM Coverage: 93.52+-17.87% | Mean VORI DSAR Coverage: 93.95+-16.95% | Mean VRBA Coverage: 49.15+-31.30%
# VORI Detected Without VRBA (TN): 44 | Mean VORI RSAM Coverage: 99.93+-0.08% | Mean VORI DSAR Coverage: 99.95+-0.00% | Mean VRBA Coverage: 89.97+-15.52%
# VRBA Detected Without VORI (TN): 43 | Mean VORI RSAM Coverage: 99.58+-1.22% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 91.42+-13.04%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2021, 2022, 2023, 2024] without test year 2020
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 33  19]
#  [107  61]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.24      0.63      0.34        52
#            1       0.76      0.36      0.49       168
#
#     accuracy                           0.43       220
#    macro avg       0.50      0.50      0.42       220
# weighted avg       0.64      0.43      0.46       220
#
#
#  Top Features (VORI)
# Sum_LP                          0.255097
# Avg drop DSAR VORI              0.234048
# Max_tornillo                    0.139201
# Max peak RSAM VORI              0.093598
# Mean Min Values RSAM VORI       0.079856
# Quantile Changes RSAM VORI      0.074314
# Var Value RSAM VORI             0.049467
# Delta_Max_Min_Precipitations    0.040885
# Max Drop Depth RSAM VORI        0.033535
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.35 ± 0.71
# Mean Magnitude (Missed - FN):   3.29 ± 0.72
# High magnitude events were more detected
#  length of time array: 220
# Detected Lahars (TP): 0 | Missed Lahars (FN): 2
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.00, Time: 2020-01-30 18:13:42.427
# Missed Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 46   6]
#  [ 54 114]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.46      0.88      0.61        52
#            1       0.95      0.68      0.79       168
#
#     accuracy                           0.73       220
#    macro avg       0.70      0.78      0.70       220
# weighted avg       0.83      0.73      0.75       220
#
#
#  Top Features (VRBA)
# Sum_LP                        0.158557
# Quantile Changes RSAM VRBA    0.132770
# Avg peak DSAR VRBA            0.115604
# Quantile Changes DSAR VRBA    0.101696
# Delta_Max_Min_tornillo        0.071875
# Avg Drop Depth DSAR VRBA      0.071370
# Avg peak RSAM VRBA            0.070713
# Mean Min Values RSAM VRBA     0.057130
# Mean Min Values DSAR VRBA     0.044454
# Last_LP                       0.043104
# Var Value RSAM VRBA           0.042952
# Sum_Precipitations            0.036925
# Avg Drop Depth RSAM VRBA      0.026775
# Avg Prominence DSAR VRBA      0.026073
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.26 ± 0.72
# Mean Magnitude (Missed - FN):   3.41 ± 0.70
# Low magnitude events were more detected
#  length of time array: 220
# Detected Lahars (TP): 2 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2020-01-30 18:13:42.427
# Detected Lahar Event - Magnitude: 4.58, Time: 2020-05-25 09:25:52.157
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 50 | Mean VORI RSAM Coverage: 96.99±5.76% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 93.12±8.72%
# Both Missed (FN): 43 | Mean VORI RSAM Coverage: 91.55±13.34% | Mean VORI DSAR Coverage: 95.13±13.78% | Mean VRBA Coverage: 90.88±18.05%
# Both False Positives (FP): 4 | Mean VORI RSAM Coverage: 99.86±0.02% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 99.94±0.00%
# Both True Negatives (TN): 31 | Mean VORI RSAM Coverage: 84.18±31.79% | Mean VORI DSAR Coverage: 89.88±23.64% | Mean VRBA Coverage: 97.61±7.86%
# VORI Detected Without VRBA (TP): 11 | Mean VORI RSAM Coverage: 97.69+-5.16% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 89.70+-15.78%
# VRBA Detected Without VORI (TP): 64 | Mean VORI RSAM Coverage: 95.41+-11.63% | Mean VORI DSAR Coverage: 99.47+-2.69% | Mean VRBA Coverage: 95.16+-9.76%
# VORI Detected Without VRBA (TN): 2 | Mean VORI RSAM Coverage: 99.86+-0.02% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 99.94+-0.00%
# VRBA Detected Without VORI (TN): 15 | Mean VORI RSAM Coverage: 99.80+-0.16% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 86.43+-21.15%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2022, 2023, 2024] without test year 2021
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 47 147]
#  [  9  16]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.24      0.38       194
#            1       0.10      0.64      0.17        25
#
#     accuracy                           0.29       219
#    macro avg       0.47      0.44      0.27       219
# weighted avg       0.75      0.29      0.35       219
#
#
#  Top Features (VORI)
# Mean Min Values DSAR VORI     0.158007
# Avg peak DSAR VORI            0.103093
# Sum_LP                        0.087319
# Max_Precipitations            0.085043
# Var Value DSAR VORI           0.080496
# Max_tornillo                  0.062524
# Quantile Changes DSAR VORI    0.059263
# Quantile Changes RSAM VORI    0.054730
# Max peak RSAM VORI            0.045243
# Sum_VT                        0.043775
# Mean Min Values RSAM VORI     0.040595
# Std Value RSAM VORI           0.039251
# Avg Prominence RSAM VORI      0.037918
# Median Value RSAM VORI        0.035404
# Max Drop Depth RSAM VORI      0.033769
# Avg drop RSAM VORI            0.033570
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.80 ± 0.79
# Mean Magnitude (Missed - FN):   3.35 ± 1.03
# Low magnitude events were more detected
#  length of time array: 219
# Detected Lahars (TP): 0 | Missed Lahars (FN): 1
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 74 120]
#  [ 12  13]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.38      0.53       194
#            1       0.10      0.52      0.16        25
#
#     accuracy                           0.40       219
#    macro avg       0.48      0.45      0.35       219
# weighted avg       0.77      0.40      0.49       219
#
#
#  Top Features (VRBA)
# Max peak DSAR VRBA            0.407616
# Quantile Changes DSAR VRBA    0.235438
# Quantile Changes RSAM VRBA    0.119843
# Max_LP                        0.095957
# Mean Min Values RSAM VRBA     0.064530
# Avg Drop Depth DSAR VRBA      0.043520
# Avg Value RSAM VRBA           0.033094
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 3.42 ± 0.85
# Mean Magnitude (Missed - FN):   2.53 ± 0.74
# High magnitude events were more detected
#  length of time array: 219
# Detected Lahars (TP): 1 | Missed Lahars (FN): 0
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.43, Time: 2021-06-28 11:42:04.132
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 7 | Mean VORI RSAM Coverage: 97.27±4.57% | Mean VORI DSAR Coverage: 97.79±3.71% | Mean VRBA Coverage: 72.43±17.53%
# Both Missed (FN): 3 | Mean VORI RSAM Coverage: 65.28±30.02% | Mean VORI DSAR Coverage: 65.28±30.02% | Mean VRBA Coverage: 31.43±54.44%
# Both False Positives (FP): 106 | Mean VORI RSAM Coverage: 89.26±24.90% | Mean VORI DSAR Coverage: 93.00±20.45% | Mean VRBA Coverage: 78.22±25.45%
# Both True Negatives (TN): 33 | Mean VORI RSAM Coverage: 96.09±12.53% | Mean VORI DSAR Coverage: 99.90±0.27% | Mean VRBA Coverage: 73.37±24.52%
# VORI Detected Without VRBA (TP): 9 | Mean VORI RSAM Coverage: 95.12+-7.31% | Mean VORI DSAR Coverage: 97.87+-6.21% | Mean VRBA Coverage: 53.23+-27.41%
# VRBA Detected Without VORI (TP): 6 | Mean VORI RSAM Coverage: 94.10+-14.29% | Mean VORI DSAR Coverage: 94.90+-12.36% | Mean VRBA Coverage: 81.62+-20.59%
# VORI Detected Without VRBA (TN): 14 | Mean VORI RSAM Coverage: 99.90+-0.04% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 74.75+-15.43%
# VRBA Detected Without VORI (TN): 41 | Mean VORI RSAM Coverage: 82.87+-30.23% | Mean VORI DSAR Coverage: 88.91+-27.37% | Mean VRBA Coverage: 66.22+-30.72%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2023, 2024] without test year 2022
#
#     STATION: VORI
#
#  Confusion Matrix
# [[ 39   5]
#  [ 99 151]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.28      0.89      0.43        44
#            1       0.97      0.60      0.74       250
#
#     accuracy                           0.65       294
#    macro avg       0.63      0.75      0.59       294
# weighted avg       0.87      0.65      0.70       294
#
#
#  Top Features (VORI)
# Sum_LP                        0.174304
# Mean Min Values DSAR VORI     0.127949
# Avg peak DSAR VORI            0.091200
# Quantile Changes RSAM VORI    0.073890
# Std Value DSAR VORI           0.064982
# Max peak RSAM VORI            0.062391
# Max_Precipitations            0.061806
# Quantile Changes DSAR VORI    0.053245
# Last_LP                       0.052508
# Var Value RSAM VORI           0.051134
# Avg drop RSAM VORI            0.046246
# Avg Prominence RSAM VORI      0.039424
# Avg Drop Depth RSAM VORI      0.038333
# Sum_VT                        0.034553
# Max_tornillo                  0.028034
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.69 ± 0.57
# Mean Magnitude (Missed - FN):   3.06 ± 0.68
# Low magnitude events were more detected
#  length of time array: 294
# Detected Lahars (TP): 1 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# Missed Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 22  22]
#  [ 53 197]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.29      0.50      0.37        44
#            1       0.90      0.79      0.84       250
#
#     accuracy                           0.74       294
#    macro avg       0.60      0.64      0.60       294
# weighted avg       0.81      0.74      0.77       294
#
#
#  Top Features (VRBA)
# Sum_LP                        0.218229
# Median Value DSAR VRBA        0.191168
# Quantile Changes RSAM VRBA    0.163713
# Quantile Changes DSAR VRBA    0.102233
# Var Value DSAR VRBA           0.069312
# Median Value RSAM VRBA        0.050822
# Mean Min Values RSAM VRBA     0.047970
# Sum_VT                        0.038545
# Var Value RSAM VRBA           0.034296
# Avg Drop Depth DSAR VRBA      0.029105
# Sum_tornillo                  0.027922
# Sum_Precipitations            0.026686
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.77 ± 0.62
# Mean Magnitude (Missed - FN):   3.06 ± 0.65
# Low magnitude events were more detected
#  length of time array: 294
# Detected Lahars (TP): 2 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.40, Time: 2022-01-30 19:08:00.000
# Detected Lahar Event - Magnitude: 5.00, Time: 2022-06-01 00:33:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.50, Time: 2022-01-23 08:24:45.682
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 145 | Mean VORI RSAM Coverage: 97.93±5.10% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 66.85±21.14%
# Both Missed (FN): 47 | Mean VORI RSAM Coverage: 98.11±12.08% | Mean VORI DSAR Coverage: 98.18±12.08% | Mean VRBA Coverage: 59.56±20.00%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 33.06±24.05%
# Both True Negatives (TN): 20 | Mean VORI RSAM Coverage: 99.94±0.00% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 55.53±7.74%
# VORI Detected Without VRBA (TP): 6 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 56.09+-18.22%
# VRBA Detected Without VORI (TP): 52 | Mean VORI RSAM Coverage: 95.84+-8.96% | Mean VORI DSAR Coverage: 95.87+-8.95% | Mean VRBA Coverage: 61.07+-13.80%
# VORI Detected Without VRBA (TN): 19 | Mean VORI RSAM Coverage: 99.60+-1.50% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 37.04+-24.71%
# VRBA Detected Without VORI (TN): 2 | Mean VORI RSAM Coverage: 99.94+-0.00% | Mean VORI DSAR Coverage: 99.94+-0.00% | Mean VRBA Coverage: 22.33+-11.18%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2024] without test year 2023
#
#     STATION: VORI
#
#  Confusion Matrix
# [[  5   3]
#  [ 49 345]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.09      0.62      0.16         8
#            1       0.99      0.88      0.93       394
#
#     accuracy                           0.87       402
#    macro avg       0.54      0.75      0.55       402
# weighted avg       0.97      0.87      0.91       402
#
#
#  Top Features (VORI)
# Sum_LP                        0.244834
# Sum_tornillo                  0.148189
# Max_Precipitations            0.146399
# Mean Min Values DSAR VORI     0.136766
# Quantile Changes RSAM VORI    0.087038
# Delta_Max_Min_LP              0.050655
# Quantile Changes DSAR VORI    0.050281
# Last_Precipitations           0.038896
# Max peak DSAR VORI            0.034042
# Last_tornillo                 0.033794
# Avg Prominence RSAM VORI      0.016618
# Max Drop Depth RSAM VORI      0.012490
# season                        0.000000
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.76 ± 0.70
# Mean Magnitude (Missed - FN):   3.01 ± 0.68
# Low magnitude events were more detected
#  length of time array: 402
# Detected Lahars (TP): 6 | Missed Lahars (FN): 2
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 5.20, Time: 2023-04-21 21:50:10.251
# Detected Lahar Event - Magnitude: 4.79, Time: 2023-05-14 08:58:05.785
# Detected Lahar Event - Magnitude: 4.98, Time: 2023-05-25 20:35:31.649
# Detected Lahar Event - Magnitude: 5.11, Time: 2023-05-28 03:34:53.507
# Detected Lahar Event - Magnitude: 4.74, Time: 2023-05-29 08:44:09.899
# Detected Lahar Event - Magnitude: 4.40, Time: 2023-11-05 21:17:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# Missed Lahar Event - Magnitude: 4.97, Time: 2023-04-14 15:35:36.445
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[  4   4]
#  [ 26 368]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.13      0.50      0.21         8
#            1       0.99      0.93      0.96       394
#
#     accuracy                           0.93       402
#    macro avg       0.56      0.72      0.59       402
# weighted avg       0.97      0.93      0.95       402
#
#
#  Top Features (VRBA)
# Quantile Changes RSAM VRBA    0.190762
# Median Value DSAR VRBA        0.144560
# Quantile Changes DSAR VRBA    0.101972
# Mean Min Values RSAM VRBA     0.089840
# Sum_LP                        0.083114
# Avg peak RSAM VRBA            0.071510
# Var Value DSAR VRBA           0.068533
# Max_Precipitations            0.054682
# Delta_Max_Min_LP              0.052767
# Sum_tornillo                  0.051062
# Var Value RSAM VRBA           0.036668
# Sum_VT                        0.028247
# Avg Drop Depth DSAR VRBA      0.026284
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.81 ± 0.71
# Mean Magnitude (Missed - FN):   2.58 ± 0.64
# High magnitude events were more detected
#  length of time array: 402
# Detected Lahars (TP): 7 | Missed Lahars (FN): 1
#
#  Detected Lahar Events (TP) - Magnitude and Time
# Detected Lahar Event - Magnitude: 4.97, Time: 2023-04-14 15:35:36.445
# Detected Lahar Event - Magnitude: 5.20, Time: 2023-04-21 21:50:10.251
# Detected Lahar Event - Magnitude: 4.79, Time: 2023-05-14 08:58:05.785
# Detected Lahar Event - Magnitude: 4.98, Time: 2023-05-25 20:35:31.649
# Detected Lahar Event - Magnitude: 5.11, Time: 2023-05-28 03:34:53.507
# Detected Lahar Event - Magnitude: 4.74, Time: 2023-05-29 08:44:09.899
# Detected Lahar Event - Magnitude: 4.40, Time: 2023-11-05 21:17:00.000
#
#  Missed Lahar Events (FN) - Magnitude and Time
# Missed Lahar Event - Magnitude: 4.70, Time: 2023-02-06 15:05:00.000
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 322 | Mean VORI RSAM Coverage: 91.10±20.08% | Mean VORI DSAR Coverage: 94.51±17.69% | Mean VRBA Coverage: 72.58±11.63%
# Both Missed (FN): 3 | Mean VORI RSAM Coverage: 48.26±44.36% | Mean VORI DSAR Coverage: 48.46±44.59% | Mean VRBA Coverage: 29.93±28.10%
# Both False Positives (FP): 3 | Mean VORI RSAM Coverage: 99.81±0.07% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 69.03±2.69%
# Both True Negatives (TN): 4 | Mean VORI RSAM Coverage: 98.96±0.01% | Mean VORI DSAR Coverage: 99.94±0.00% | Mean VRBA Coverage: 73.97±5.58%
# VORI Detected Without VRBA (TP): 23 | Mean VORI RSAM Coverage: 87.02+-23.43% | Mean VORI DSAR Coverage: 90.19+-19.20% | Mean VRBA Coverage: 81.95+-9.51%
# VRBA Detected Without VORI (TP): 46 | Mean VORI RSAM Coverage: 94.90+-12.66% | Mean VORI DSAR Coverage: 95.95+-12.21% | Mean VRBA Coverage: 68.14+-16.68%
# VORI Detected Without VRBA (TN): 1 | Mean VORI RSAM Coverage: 99.82+-nan% | Mean VORI DSAR Coverage: 99.94+-nan% | Mean VRBA Coverage: 66.04+-nan%
# VRBA Detected Without VORI (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%
#
# ============================================================
#  EVALUATION TRAIN Dataset [2019, 2020, 2021, 2022, 2023] without test year 2024
#
#     STATION: VORI
#
#  Confusion Matrix
# [[23 21]
#  [48 51]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.32      0.52      0.40        44
#            1       0.71      0.52      0.60        99
#
#     accuracy                           0.52       143
#    macro avg       0.52      0.52      0.50       143
# weighted avg       0.59      0.52      0.54       143
#
#
#  Top Features (VORI)
# Sum_LP                        0.233839
# Mean Min Values DSAR VORI     0.122916
# Quantile Changes RSAM VORI    0.093533
# Max_Precipitations            0.084219
# Mean Min Values RSAM VORI     0.074083
# Delta_Max_Min_tornillo        0.073615
# Avg Value RSAM VORI           0.066231
# Std Value DSAR VORI           0.057930
# Max peak DSAR VORI            0.055812
# Var Value RSAM VORI           0.045843
# Quantile Changes DSAR VORI    0.036301
# Avg Drop Depth RSAM VORI      0.036130
# season                        0.019546
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.16 ± 0.55
# Mean Magnitude (Missed - FN):   2.12 ± 0.48
# High magnitude events were more detected
#  length of time array: 143
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#     STATION: VRBA
#
#  Confusion Matrix
# [[ 6 38]
#  [16 83]]
#
#  Classification Report
#               precision    recall  f1-score   support
#
#            0       0.27      0.14      0.18        44
#            1       0.69      0.84      0.75        99
#
#     accuracy                           0.62       143
#    macro avg       0.48      0.49      0.47       143
# weighted avg       0.56      0.62      0.58       143
#
#
#  Top Features (VRBA)
# Median Value DSAR VRBA        0.306535
# Quantile Changes RSAM VRBA    0.153568
# Sum_LP                        0.132515
# Avg Value RSAM VRBA           0.096082
# Var Value DSAR VRBA           0.080781
# Quantile Changes DSAR VRBA    0.074365
# Delta_Max_Min_tornillo        0.072926
# Max drop RSAM VRBA            0.032948
# Sum_Precipitations            0.025854
# season                        0.024426
# dtype: float64
#
#  Error & Magnitude Analysis
# Mean Magnitude (Detected - TP): 2.14 ± 0.50
# Mean Magnitude (Missed - FN):   2.17 ± 0.62
# Low magnitude events were more detected
#  length of time array: 143
# Detected Lahars (TP): 0 | Missed Lahars (FN): 0
# ----------------------------------------
#
#  Summary for VRBA
# Both Detected (TP): 43 | Mean VORI RSAM Coverage: 70.70±34.79% | Mean VORI DSAR Coverage: 70.70±34.79% | Mean VRBA Coverage: 60.93±12.50%
# Both Missed (FN): 8 | Mean VORI RSAM Coverage: 39.46±48.77% | Mean VORI DSAR Coverage: 39.46±48.77% | Mean VRBA Coverage: 46.83±19.74%
# Both False Positives (FP): 21 | Mean VORI RSAM Coverage: 80.33±13.23% | Mean VORI DSAR Coverage: 80.34±13.24% | Mean VRBA Coverage: 54.96±3.65%
# Both True Negatives (TN): 6 | Mean VORI RSAM Coverage: 69.55±24.34% | Mean VORI DSAR Coverage: 69.55±24.34% | Mean VRBA Coverage: 54.45±2.40%
# VORI Detected Without VRBA (TP): 8 | Mean VORI RSAM Coverage: 55.53+-39.03% | Mean VORI DSAR Coverage: 56.61+-39.71% | Mean VRBA Coverage: 52.68+-23.20%
# VRBA Detected Without VORI (TP): 40 | Mean VORI RSAM Coverage: 54.35+-44.82% | Mean VORI DSAR Coverage: 54.35+-44.82% | Mean VRBA Coverage: 52.89+-13.14%
# VORI Detected Without VRBA (TN): 17 | Mean VORI RSAM Coverage: 64.55+-19.21% | Mean VORI DSAR Coverage: 64.55+-19.21% | Mean VRBA Coverage: 53.31+-2.04%
# VRBA Detected Without VORI (TN): 0 | Mean VORI RSAM Coverage: nan+-nan% | Mean VORI DSAR Coverage: nan+-nan% | Mean VRBA Coverage: nan+-nan%

# %%
# Print the final summary of the classification 
df_final_corr = generate_truth_table_and_features_summary(
    time_analysis_results=time_analysis_results_corr_test,
    features_classement=features_classement_corr_test,
    top_n_features=25,
    min_model_count=1,
    # save_path='MSc_Bryan_Rincon/Training Results/features_classement_analysis_test.csv'
)
# Out:
# --- Classification summary (Min Model Count: 1) ---
# Eruptions detected by both stations: 582
# Eruptions missed by both stations: 110
# Eruptions detected by VORI: 63
# Eruptions detected by VRBA: 216
# Non-eruptions correctly detected by VORI: 97
# Non-eruptions correctly detected by VRBA: 101
# False alarms for both stations: 201
# Non-eruptions correctly rejected by both stations: 139
